# %% [markdown]
# # IPAVentures horizon scan — run `2026-09-13T2114`
#
# Generated 2026-09-14 02:11 UTC by `python -m src.notebook --run-id 2026-09-13T2114`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = '2026-09-13T2114'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    2026-09-13T2114
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 18,342

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
if _method == "bertopic":
    # Under BERTopic the similarity threshold does not cluster anything —
    # HDBSCAN works on density in UMAP space and takes no cosine cut-off. It is
    # read for one purpose only: attaching documents from non-forming sources
    # to the nearest finished topic. Labelled for what it does, so a reviewer
    # is not left comparing it against a clustering threshold from another run.
    print("Attachment thresh :", _thresh.get(_backend, "not recorded"),
          f"x ratio {_topics_cfg.get('attachment_threshold_ratio', 0.6)}")
    # THE SEED. UMAP's initialisation is stochastic, so this is the difference
    # between a topic set another analyst can reproduce and one they cannot.
    # Printed from the run's own snapshot, never from today's config file.
    _bt = _topics_cfg.get("bertopic") or {}
    print("BERTopic seed     :", _bt.get("random_state", "NOT RECORDED"))
    print("BERTopic UMAP     :",
          f"n_neighbors={_bt.get('n_neighbors')}, "
          f"n_components={_bt.get('n_components')}, "
          f"min_dist={_bt.get('min_dist')}, metric={_bt.get('metric')}")
    print("BERTopic HDBSCAN  :",
          f"min_cluster_size={_bt.get('min_cluster_size') or _topics_cfg.get('min_topic_size')}, "
          f"min_samples={_bt.get('min_samples')}, "
          f"selection={_bt.get('cluster_selection_method')}")
    if not isinstance(_bt.get("random_state"), int):
        print("\n  WARNING: no seed recorded for this run. UMAP is stochastic, "
              "so the topics below cannot be reproduced exactly, even from this "
              "same corpus and config.")
else:
    print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : bge
# Clustering method : bertopic
# Attachment thresh : 0.9 x ratio 0.6
# BERTopic seed     : 42
# BERTopic UMAP     : n_neighbors=15, n_components=5, min_dist=0.0, metric=cosine
# BERTopic HDBSCAN  : min_cluster_size=8, min_samples=None, selection=eom
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status      in  out    seconds  message
# ------------------------  -------  -----  ---  ---------  ----------------------------------------------------------------
# stage0_strategy           success      —   34      0.300  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage1_collect            partial  10927  580  17611.300  10927 fetched, 580 new, 10 failed/skipped pairs, 15 partial in …
# stage2_emergence          success  18342  117    185.300  117 topics from 18342 documents across 9 slices (2018-2026); 30…
# stage5_synthesis          success    117  117     21.600  ranked 117 topics; outputs written
# stage3_scoring            success    117  117     20.300  scored 117 topics; mean fit 0.489, mean leverage 0.359, 0 criti…
# stage4_opportunity_index  success    117  117      0.200  indexed 117 of 117 topics (0 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# gdelt           9703        2024       2026      17
# openalex        3879        2018       2026      20
# crossref        2396        2018       2026      13
# arxiv           2214        2018       2026       9
# datagovau        150        2022       2026       3
#
# What this run's collection actually did (per source query):
#
# source     status   queries  records
# ---------  -------  -------  -------
# arxiv      failed         8        0
# arxiv      partial        1       60
# crossref   success       13     2500
# datagovau  success        3      150
# gdelt      failed         2        0
# gdelt      partial       14     3072
# gdelt      success        2     1258
# openalex   success       20     3887

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018        935
# 2019       1019
# 2020       1183
# 2021       1070
# 2022        974
# 2023       1003
# 2024       1642
# 2025       5708
# 2026       4808
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       8032
# Political           2987
# Economic            2637
# Legal               1902
# Values              1108
# Social              1000
# Environmental        676

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                   STEEPV         documents  sources
# ---------------------------  -------------  ---------  -------
# ct_quantum                   Technological       1662        3
# ai_governance_assurance      Political           1572        5
# digital_identity_provenance  Technological       1420        3
# ai_authorship_inventorship   Legal               1223        4
# ct_biotech                   Technological       1120        3
# indigenous_knowledge         Values              1108        3
# ip_finance_valuation         Economic            1088        3
# ip_enforcement_counterfeit   Economic            1079        3
# trust_institutions           Social              1000        3
# gov_service_delivery         Political            910        4
# ct_ai                        Technological        772        3
# ip_admin_automation          Technological        769        4
# geographical_indications     Legal                679        3
# ct_energy                    Environmental        676        2
# ip_search_retrieval          Technological        650        3
# ct_advanced_manufacturing    Technological        649        2
# ct_autonomous                Technological        644        2
# ip_policy_reform             Political            505        4
# ip_sme_access                Economic             470        3
# ct_advanced_ict              Technological        346        2

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Failed queries by source: arxiv (8), gdelt (2). Each failure costs that frame's contribution to the corpus, so the shortlist is drawn from a slightly different scan than the frame file describes.

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic                  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# ---------------------  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# 2026-09-13T2114-T0099  copyright page / copyright notice               24  0.30  0.12  0.91  0.67  0.54       0.82  H2  weak
# 2026-09-13T2114-T0059  enforcement intellectual / property right /     66  0.23  0.15  0.78  0.60  1.00       0.81  H1  weak
# 2026-09-13T2114-T0063  cultural heritage / property cultural / inte    36  0.20  0.17  0.88  0.74  0.50       0.80  H1  weak
# 2026-09-13T2114-T0033  kilometre km / square kilometre / africa / p    59  0.36  0.20  0.81  0.68  0.42       0.79  H2  strong
# 2026-09-13T2114-T0110  criminal / ip / enforcement / intellectual p    27  0.19  0.19  0.80  0.64  0.88       0.77  H3  weak
# 2026-09-13T2114-T0089  quantum / entanglement / communication / tel    41  0.26  0.04  0.84  0.57  0.99       0.76  H1  weak
# 2026-09-13T2114-T0017  covid-19 / trust / pandemic / health           101  0.20  0.21  0.79  0.61  0.78       0.74  H1  strong
# 2026-09-13T2114-T0069  dashboard / digital project / queensland / c    38  0.27  0.43  0.81  0.50  0.78       0.74  H2  weak
# 2026-09-13T2114-T0032  llm / medical / chatgpt / language              61  0.15  0.26  0.85  0.68  0.84       0.74  H1  strong
# 2026-09-13T2114-T0090  quantum / cavity / qubit / optomechanical       22  0.21  0.09  0.87  0.52  0.81       0.72  H3  weak
# 2026-09-13T2114-T0045  drug / psychedelic / regulatory / pharmaceut   399  0.09  0.07  0.67  0.50  0.65       0.27  H1  strong
# 2026-09-13T2114-T0100  ip / intellectual property / trade / enforce    85  0.14  0.00  0.69  0.52  0.81       0.26  H1  noise
# 2026-09-13T2114-T0021  authenticity / influencer / media / content    126  0.13  0.00  0.75  0.48  0.86       0.25  H1  latent
# 2026-09-13T2114-T0007  indigenous / traditional knowledge / cultura   180  0.13  0.00  0.76  0.39  0.95       0.25  H1  latent
# 2026-09-13T2114-T0031  innovation / patent / firm / intellectual pr    75  0.12  0.00  0.79  0.35  0.89       0.23  H1  latent
# 2026-09-13T2114-T0012  blockchain / technology / supply chain / sma   243  0.11  0.00  0.71  0.50  0.80       0.20  H1  latent
# 2026-09-13T2114-T0073  startup / venture / entrepreneurial / valuat    80  0.13  0.00  0.72  0.41  0.82       0.19  H1  noise
# 2026-09-13T2114-T0076  counterfeit / illicit / market / consumer      526  0.14  0.00  0.63  0.49  0.60       0.17  H1  noise
# 2026-09-13T2114-T0054  deepfake / content / aigc / ai-generated       773  0.12  0.00  0.69  0.50  0.58       0.16  H2  latent

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 117 of 117 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 14,091 of 18,342 documents (77%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 10 topic(s) sit within 0.05 of a Three Horizons cut-point (llm / language / task / reasoning (0.71 → H2); graph / isometric / vertice / polynomial (0.71 → H2); valuation / briefing / valuer / avm (0.71 → H2); copyright page / copyright notice (0.71 → H2); preface / regulatory policy / frontmatte (0.77 → H1); watermark / text / llm / language (0.77 → H1); adm / automated decision-making / accoun (0.77 → H1); ai / governance / public / artificial in (0.77 → H1); rag / text / language / retrieval (0.77 → H1); video / visual / retrieval / caption (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic                  label                                   fit  closest objective                     leverage  DISR field
# ---------------------  ------------------------------------  -----  ------------------------------------  --------  ----------
# 2026-09-13T2114-T0027  automated decision-making / adminis…  0.667  SI-3 AI and Automated Decision Maki…     0.455  —
# 2026-09-13T2114-T0070  intellectual property / property pr…  0.609  4.1 Innovation and adaptiveness in …     0.383  —
# 2026-09-13T2114-T0116  copyright / artificial intelligence…  0.691  SI-3 AI and Automated Decision Maki…     0.423  —
# 2026-09-13T2114-T0053  patent retrieval / retrieval system…  0.535  4.1 Innovation and adaptiveness in …     0.437  —
# 2026-09-13T2114-T0059  enforcement intellectual / property…  0.547  4.1 Innovation and adaptiveness in …     0.377  —
# 2026-09-13T2114-T0060  ip / law / intellectual property / …  0.548  4.1 Innovation and adaptiveness in …     0.413  —
# 2026-09-13T2114-T0069  dashboard / digital project / queen…  0.522  4.2 Innovative digital and data-dri…     0.406  —
# 2026-09-13T2114-T0010  intellectual property / right / pro…  0.557  4.1 Innovation and adaptiveness in …     0.416  —
# 2026-09-13T2114-T0004  patent / retrieval / classification…  0.533  4.1 Innovation and adaptiveness in …     0.449  —
# 2026-09-13T2114-T0020  artificial intelligence / patent / …  0.718  SI-3 AI and Automated Decision Maki…     0.483  —
# 2026-09-13T2114-T0049  adm / automated decision-making / a…  0.726  SI-3 AI and Automated Decision Maki…     0.463  —
# 2026-09-13T2114-T0110  criminal / ip / enforcement / intel…  0.547  4.1 Innovation and adaptiveness in …     0.353  —
# 2026-09-13T2114-T0063  cultural heritage / property cultur…  0.505  4.1 Innovation and adaptiveness in …     0.361  —
# 2026-09-13T2114-T0026  indigenous / intellectual / propert…  0.611  SI-5 First Nations Strategy              0.446  —
# 2026-09-13T2114-T0055  ai / patent / invention / inventors…  0.618  SI-3 AI and Automated Decision Maki…     0.461  —
# 2026-09-13T2114-T0103  intellectual property / african / a…  0.524  4.1 Innovation and adaptiveness in …     0.393  —
# 2026-09-13T2114-T0015  ai / education / chatgpt / teacher    0.510  SI-3 AI and Automated Decision Maki…     0.363  —
# 2026-09-13T2114-T0001  service delivery / government / dig…  0.636  4.2 Innovative digital and data-dri…     0.364  —
# 2026-09-13T2114-T0032  llm / medical / chatgpt / language    0.502  SI-3 AI and Automated Decision Maki…     0.351  —
# 2026-09-13T2114-T0003  llm / language / task / reasoning     0.520  SI-3 AI and Automated Decision Maki…     0.357  —
# 2026-09-13T2114-T0109  valuation / intellectual / property…  0.558  4.1 Innovation and adaptiveness in …     0.404  —
# 2026-09-13T2114-T0061  ai / copyright / generative / autho…  0.573  SI-3 AI and Automated Decision Maki…     0.422  —
# 2026-09-13T2114-T0052  vaccine / covid-19 / pandemic / wai…  0.519  4.1 Innovation and adaptiveness in …     0.395  —
# 2026-09-13T2114-T0074  prior art / patent / art search / a…  0.477  SI-3 AI and Automated Decision Maki…     0.388  —
# 2026-09-13T2114-T0088  cultural heritage / protection cult…  0.532  4.1 Innovation and adaptiveness in …     0.345  —
# 2026-09-13T2114-T0081  genetic resource / benefit sharing …  0.572  4.1 Innovation and adaptiveness in …     0.405  —
# 2026-09-13T2114-T0009  ai / governance / public / artifici…  0.734  SI-3 AI and Automated Decision Maki…     0.459  —
# 2026-09-13T2114-T0023  green innovation / firm / circular …  0.668  4.1 Innovation and adaptiveness in …     0.438  —
# 2026-09-13T2114-T0058  gene / crop / crispr / editing        0.465  4.1 Innovation and adaptiveness in …     0.340  —
# 2026-09-13T2114-T0077  access medicine / medicine africa /…  0.551  2.1 Access to and benefits from IP …     0.372  —
# 2026-09-13T2114-T0064  unlearning / erasure / diffusion / …  0.485  4.1 Innovation and adaptiveness in …     0.328  —
# 2026-09-13T2114-T0099  copyright page / copyright notice     0.453  4.1 Innovation and adaptiveness in …     0.323  —
# 2026-09-13T2114-T0115  hydrogen / energy / green / carbon …  0.451  4.1 Innovation and adaptiveness in …     0.370  —
# 2026-09-13T2114-T0034  ai / healthcare / gdpr / health care  0.588  SI-3 AI and Automated Decision Maki…     0.417  —
# 2026-09-13T2114-T0094  examiner / patent / rejection / exa…  0.476  4.1 Innovation and adaptiveness in …     0.573  —
# 2026-09-13T2114-T0031  innovation / patent / firm / intell…  0.664  4.1 Innovation and adaptiveness in …     0.446  —
# 2026-09-13T2114-T0085  intellectual property / enforcement…  0.561  4.1 Innovation and adaptiveness in …     0.372  —
# 2026-09-13T2114-T0043  navigation / robot / task / agent     0.462  SI-3 AI and Automated Decision Maki…     0.330  —
# 2026-09-13T2114-T0065  reef / park / australian marine / c…  0.442  4.2 Innovative digital and data-dri…     0.391  —
# 2026-09-13T2114-T0022  watermark / text / llm / language     0.447  SI-3 AI and Automated Decision Maki…     0.350  —
# 2026-09-13T2114-T0111  opengov / ul / au / li                0.431  4.2 Innovative digital and data-dri…     0.367  —
# 2026-09-13T2114-T0000  geographical indication / gi / kent…  0.618  SI-1 Geographical indications regis…     0.353  —
# 2026-09-13T2114-T0017  covid-19 / trust / pandemic / health  0.435  SI-3 AI and Automated Decision Maki…     0.331  —
# 2026-09-13T2114-T0098  agent / vulnerability / patch / plu…  0.467  SI-3 AI and Automated Decision Maki…     0.360  —
# 2026-09-13T2114-T0108  intellectual capital / sme / enterp…  0.541  4.1 Innovation and adaptiveness in …     0.378  —
# 2026-09-13T2114-T0008  trust / institution / public / citi…  0.527  1.1 Trust and confidence in a high-…     0.298  —
# 2026-09-13T2114-T0084  intellectual property / property gl…  0.565  4.1 Innovation and adaptiveness in …     0.376  —
# 2026-09-13T2114-T0007  indigenous / traditional knowledge …  0.555  SI-5 First Nations Strategy              0.435  —
# 2026-09-13T2114-T0037  patent / citation / technology / im…  0.519  4.1 Innovation and adaptiveness in …     0.474  —
# 2026-09-13T2114-T0006  preface / regulatory policy / front…  0.482  SI-3 AI and Automated Decision Maki…     0.382  —
# 2026-09-13T2114-T0082  intellectual property / collateral …  0.552  4.1 Innovation and adaptiveness in …     0.373  —
# 2026-09-13T2114-T0104  robot / soft / actuation / jumping    0.455  4.1 Innovation and adaptiveness in …     0.361  —
# 2026-09-13T2114-T0073  startup / venture / entrepreneurial…  0.543  4.1 Innovation and adaptiveness in …     0.416  —
# 2026-09-13T2114-T0005  trust / institution / public / gove…  0.529  1.1 Trust and confidence in a high-…     0.330  —
# 2026-09-13T2114-T0114  traditional cultural / cultural exp…  0.489  4.1 Innovation and adaptiveness in …     0.358  —
# 2026-09-13T2114-T0095  lidar / object / autonomous / datas…  0.449  4.2 Innovative digital and data-dri…     0.359  —
# 2026-09-13T2114-T0066  energy / renewable / storage / hydr…  0.447  4.2 Innovative digital and data-dri…     0.334  —
# 2026-09-13T2114-T0018  energy / renewable / storage / batt…  0.453  4.2 Innovative digital and data-dri…     0.324  —
# 2026-09-13T2114-T0035  crispr / editing / gene / cas9        0.416  4.1 Innovation and adaptiveness in …     0.327  —
# 2026-09-13T2114-T0078  valuation / property / editorial / …  0.446  4.1 Innovation and adaptiveness in …     0.368  —
# 2026-09-13T2114-T0097  video / visual / retrieval / caption  0.453  4.2 Innovative digital and data-dri…     0.300  —
# 2026-09-13T2114-T0100  ip / intellectual property / trade …  0.532  4.1 Innovation and adaptiveness in …     0.377  —
# 2026-09-13T2114-T0057  bone / additive manufacturing / sca…  0.466  4.2 Innovative digital and data-dri…     0.352  —
# 2026-09-13T2114-T0072  valuation / briefing / valuer / avm   0.497  4.1 Innovation and adaptiveness in …     0.359  —
# 2026-09-13T2114-T0079  rag / text / language / retrieval     0.435  SI-3 AI and Automated Decision Maki…     0.353  —
# 2026-09-13T2114-T0112  trademark / infringement / brand / …  0.511  4.1 Innovation and adaptiveness in …     0.360  —
# 2026-09-13T2114-T0092  trust / preprint / peer / public      0.514  1.1 Trust and confidence in a high-…     0.359  —
# 2026-09-13T2114-T0029  vehicle / autonomous / driving / avs  0.464  SI-3 AI and Automated Decision Maki…     0.324  —
# 2026-09-13T2114-T0056  synthetic biology / microbial / con…  0.441  SI-3 AI and Automated Decision Maki…     0.350  —
# 2026-09-13T2114-T0011  battery / energy storage / lithium …  0.438  4.2 Innovative digital and data-dri…     0.324  —
# 2026-09-13T2114-T0051  galaxy / dwarf / rm / black hole      0.377  4.2 Innovative digital and data-dri…     0.320  —
# 2026-09-13T2114-T0113  indoor / positioning / navigation /…  0.420  4.1 Innovation and adaptiveness in …     0.297  —
# 2026-09-13T2114-T0083  quantum / variational / algorithm /…  0.358  SI-3 AI and Automated Decision Maki…     0.291  —
# 2026-09-13T2114-T0096  graph / gnn / network / node          0.402  4.2 Innovative digital and data-dri…     0.371  —
# 2026-09-13T2114-T0050  odometry / navigation / lidar / sen…  0.404  4.2 Innovative digital and data-dri…     0.336  —
# 2026-09-13T2114-T0046  learning / rl / reinforcement / rew…  0.492  SI-3 AI and Automated Decision Maki…     0.316  —
# 2026-09-13T2114-T0041  image / dataset / facial / network    0.423  4.2 Innovative digital and data-dri…     0.320  —
# 2026-09-13T2114-T0047  scene / point cloud / image / object  0.433  4.2 Innovative digital and data-dri…     0.327  —
# 2026-09-13T2114-T0101  quantum / photonic / dot / metasurf…  0.405  4.2 Innovative digital and data-dri…     0.327  —
# 2026-09-13T2114-T0021  authenticity / influencer / media /…  0.490  4.2 Innovative digital and data-dri…     0.316  —
# 2026-09-13T2114-T0076  counterfeit / illicit / market / co…  0.459  4.1 Innovation and adaptiveness in …     0.341  —
# 2026-09-13T2114-T0106  graph / isometric / vertice / polyn…  0.412  SI-3 AI and Automated Decision Maki…     0.349  —
# 2026-09-13T2114-T0040  spin / quantum / magnetic / nv        0.416  4.2 Innovative digital and data-dri…     0.325  —
# 2026-09-13T2114-T0036  quantum / learning / classical / ma…  0.438  SI-3 AI and Automated Decision Maki…     0.309  —
# 2026-09-13T2114-T0002  watermark / image / attack / dnn      0.440  4.1 Innovation and adaptiveness in …     0.306  —
# 2026-09-13T2114-T0014  quantum / lattice / many-body / sys…  0.385  4.2 Innovative digital and data-dri…     0.287  —
# 2026-09-13T2114-T0075  honey / geographical origin / food …  0.429  SI-1 Geographical indications regis…     0.338  —
# 2026-09-13T2114-T0080  higg / dark matter / decay / scalar   0.376  4.2 Innovative digital and data-dri…     0.302  —
# 2026-09-13T2114-T0086  quantum / entanglement / network / …  0.397  4.1 Innovation and adaptiveness in …     0.297  —
# 2026-09-13T2114-T0019  quantum / cryptography / cryptograp…  0.412  SI-3 AI and Automated Decision Maki…     0.300  —
# 2026-09-13T2114-T0039  covariance / sample / matrix / prior  0.390  SI-3 AI and Automated Decision Maki…     0.316  —
#
# strategic fit  range 0.346–0.734  median 0.467
# asset leverage range 0.282–0.573  median 0.353

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic                  label                                 attention  attention_tone  policy_salience  research_growth  index
# ---------------------  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# 2026-09-13T2114-T0027  automated decision-making / administ      0.888           0.448            0.698            0.724  0.734
# 2026-09-13T2114-T0070  intellectual property / property pro      0.750           0.767            0.931            0.948  0.865
# 2026-09-13T2114-T0116  copyright / artificial intelligence       0.922           0.103            0.638            0.750  0.698
# 2026-09-13T2114-T0053  patent retrieval / retrieval system       0.155           0.668            0.672            0.836  0.578
# 2026-09-13T2114-T0059  enforcement intellectual / property       0.608           0.017            0.957            0.323  0.520
# 2026-09-13T2114-T0060  ip / law / intellectual property / c      0.328           0.500            0.940            0.323  0.490
# 2026-09-13T2114-T0069  dashboard / digital project / queens      0.328           0.629            0.629            0.690  0.562
# 2026-09-13T2114-T0010  intellectual property / right / prop      0.853           0.543            0.983            0.323  0.660
# 2026-09-13T2114-T0004  patent / retrieval / classification       0.250           0.379            0.862            0.922  0.647
# 2026-09-13T2114-T0020  artificial intelligence / patent / i      0.983           0.397            0.733            0.672  0.745
# 2026-09-13T2114-T0049  adm / automated decision-making / ac      0.664           0.457            0.784            0.862  0.738
# 2026-09-13T2114-T0110  criminal / ip / enforcement / intell      0.328           0.035            0.767            0.957  0.619
# 2026-09-13T2114-T0063  cultural heritage / property cultura      0.220           0.121            0.578            0.323  0.329
# 2026-09-13T2114-T0026  indigenous / intellectual / property      0.914           0.888            0.845            0.664  0.806
# 2026-09-13T2114-T0055  ai / patent / invention / inventorsh      0.871           0.362            0.914            0.845  0.812
# 2026-09-13T2114-T0103  intellectual property / african / ar      0.724           0.517            0.776            0.716  0.709
# 2026-09-13T2114-T0036  quantum / learning / classical / mac      0.897           0.935            0.103            0.323  0.512
# 2026-09-13T2114-T0002  watermark / image / attack / dnn          0.483           0.345            0.215            0.323  0.347
# 2026-09-13T2114-T0014  quantum / lattice / many-body / syst      0.052           0.254            0.310            0.323  0.232
# 2026-09-13T2114-T0075  honey / geographical origin / food /      0.371           0.026            0.164            0.323  0.265
# 2026-09-13T2114-T0080  higg / dark matter / decay / scalar       0.052           0.254            0.009            0.323  0.161
# 2026-09-13T2114-T0086  quantum / entanglement / network / t      0.759           0.935            0.198            0.323  0.494
# 2026-09-13T2114-T0019  quantum / cryptography / cryptograph      0.966           0.784            0.250            0.323  0.549
# 2026-09-13T2114-T0039  covariance / sample / matrix / prior      0.220           0.871            0.129            0.323  0.312

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 117 topics — largest deviation 8.34e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 117 of 117 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  automated decision-making / administrative  H1  strong  0.664  0.667  0.455  0.734      0.917
#   2  intellectual property / property protectio  H2  weak    0.701  0.609  0.383  0.865      0.867
#   3  copyright / artificial intelligence / gene  H1  weak    0.613  0.691  0.423  0.698      0.866
#   4  patent retrieval / retrieval system / info  H2  strong  0.713  0.535  0.437  0.578      0.860
#   5  enforcement intellectual / property right   H1  weak    0.808  0.547  0.377  0.520      0.856
#   6  ip / law / intellectual property / chapter  H1  weak    0.671  0.548  0.413  0.490      0.843
#   7  dashboard / digital project / queensland /  H2  weak    0.739  0.522  0.406  0.562      0.832
#   8  intellectual property / right / property l  H1  strong  0.633  0.557  0.416  0.660      0.828
#   9  patent / retrieval / classification / prio  H2  strong  0.635  0.533  0.449  0.647      0.821
#  10  artificial intelligence / patent / invento  H2  strong  0.522  0.718  0.483  0.745      0.812
#  11  adm / automated decision-making / accounta  H1  strong  0.515  0.726  0.463  0.738      0.804
#  12  criminal / ip / enforcement / intellectual  H3  weak    0.772  0.547  0.353  0.619      0.789
#  13  cultural heritage / property cultural / in  H1  weak    0.800  0.505  0.361  0.329      0.770
#  14  indigenous / intellectual / property / cul  H1  latent  0.503  0.611  0.446  0.806      0.759
#  15  ai / patent / invention / inventorship      H1  strong  0.486  0.618  0.461  0.812      0.757
#  16  intellectual property / african / aripo /   H1  weak    0.601  0.524  0.393  0.709      0.741
#  17  ai / education / chatgpt / teacher          H1  strong  0.694  0.510  0.363  0.660      0.738
#  18  service delivery / government / digital /   H2  strong  0.547  0.636  0.364  0.831      0.732
#  19  llm / medical / chatgpt / language          H1  strong  0.736  0.502  0.351  0.510      0.712
#  20  llm / language / task / reasoning           H2  strong  0.659  0.520  0.357  0.635      0.712
#  21  valuation / intellectual / property / asse  H1  weak    0.500  0.558  0.404  0.733      0.707
#  22  ai / copyright / generative / authorship    H1  strong  0.469  0.573  0.422  0.750      0.696
#  23  vaccine / covid-19 / pandemic / waiver      H1  strong  0.544  0.519  0.395  0.458      0.678
#  24  prior art / patent / art search / art opti  H2  weak    0.600  0.477  0.388  0.646      0.669
#  25  cultural heritage / protection cultural /   H1  weak    0.603  0.532  0.345  0.581      0.658
#  26  genetic resource / benefit sharing / plant  H1  weak    0.426  0.572  0.405  0.579      0.639
#  96  battery / energy storage / lithium / lib    H1  latent  0.471  0.438  0.324  0.516      0.336
#  97  galaxy / dwarf / rm / black hole            H2  strong  0.577  0.377  0.320  0.346      0.335
#  98  indoor / positioning / navigation / system  H1  weak    0.551  0.420  0.297  0.255      0.327
#  99  quantum / variational / algorithm / vqe     H1  noise   0.625  0.358  0.291  0.180      0.322
# 100  graph / gnn / network / node                H1  noise   0.421  0.402  0.371  0.182      0.313
# 101  odometry / navigation / lidar / sensor      H1  latent  0.472  0.404  0.336  0.310      0.297
# 102  learning / rl / reinforcement / reward      H1  latent  0.317  0.492  0.316  0.293      0.295
# 103  image / dataset / facial / network          H1  latent  0.473  0.423  0.320  0.295      0.294
# 104  scene / point cloud / image / object        H1  latent  0.430  0.433  0.327  0.239      0.285
# 105  quantum / photonic / dot / metasurface      H1  noise   0.465  0.405  0.327  0.416      0.269
# 106  authenticity / influencer / media / conten  H1  latent  0.255  0.490  0.316  0.462      0.266
# 107  counterfeit / illicit / market / consumer   H1  noise   0.171  0.459  0.341  0.533      0.262
# 108  graph / isometric / vertice / polynomial    H2  weak    0.406  0.412  0.349  0.363      0.257
# 109  spin / quantum / magnetic / nv              H1  latent  0.426  0.416  0.325  0.289      0.240
# 110  quantum / learning / classical / machine    H1  latent  0.354  0.438  0.309  0.512      0.214
# 111  watermark / image / attack / dnn            H1  latent  0.354  0.440  0.306  0.347      0.213
# 112  quantum / lattice / many-body / system      H1  latent  0.475  0.385  0.287  0.232      0.206
# 113  honey / geographical origin / food / wine   H1  noise   0.278  0.429  0.338  0.265      0.204
# 114  higg / dark matter / decay / scalar         H1  noise   0.454  0.376  0.302  0.161      0.189
# 115  quantum / entanglement / network / telepor  H1  noise   0.437  0.397  0.297  0.494      0.175
# 116  quantum / cryptography / cryptographic / s  H1  strong  0.390  0.412  0.300  0.549      0.169
# 117  covariance / sample / matrix / prior        H1  latent  0.353  0.390  0.316  0.312      0.134

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.467, leverage 0.353).
#
# ACT (51)
#       1  automated decision-making / administrative / government / la
#       2  intellectual property / property protection / firm / corpora
#       3  copyright / artificial intelligence / generative artificial
#       4  patent retrieval / retrieval system / information retrieval
#       5  enforcement intellectual / property right / intellectual pro
#       6  ip / law / intellectual property / chapter
#       7  dashboard / digital project / queensland / contribution publ
#       8  intellectual property / right / property law / cambridge int
#       9  patent / retrieval / classification / prior art
#      10  artificial intelligence / patent / inventorship / intelligen
#      11  adm / automated decision-making / accountability / human
#      12  criminal / ip / enforcement / intellectual property
#      13  cultural heritage / property cultural / intellectual / intan
#      14  indigenous / intellectual / property / cultural
#      15  ai / patent / invention / inventorship
#      16  intellectual property / african / aripo / property organizat
#      17  ai / education / chatgpt / teacher
#      18  service delivery / government / digital / public service
#      20  llm / language / task / reasoning
#      21  valuation / intellectual / property / asset
#      22  ai / copyright / generative / authorship
#      23  vaccine / covid-19 / pandemic / waiver
#      24  prior art / patent / art search / art option
#      26  genetic resource / benefit sharing / plant / access benefit
#      27  ai / governance / public / artificial intelligence
#      28  green innovation / firm / circular / patent
#      30  access medicine / medicine africa / intellectual property /
#      34  ai / healthcare / gdpr / health care
#      35  examiner / patent / rejection / examination
#      36  innovation / patent / firm / intellectual property
#      37  intellectual property / enforcement / right / property prote
#      44  agent / vulnerability / patch / plugin
#      45  intellectual capital / sme / enterprise / knowledge manageme
#      47  intellectual property / property global / international inte
#      48  indigenous / traditional knowledge / cultural / people
#      49  patent / citation / technology / impact
#      50  preface / regulatory policy / frontmatter / acknowledgment
#      51  intellectual property / collateral / ipr / msme
#      53  startup / venture / entrepreneurial / valuation
#      55  traditional cultural / cultural expression / lampung / indon
#      62  ip / intellectual property / trade / enforcement
#      64  valuation / briefing / valuer / avm
#      66  trademark / infringement / brand / counterfeiting
#      67  trust / preprint / peer / public
#      69  drug / psychedelic / regulatory / pharmaceutical
#      71  iot / wireless / network / communication
#      74  blockchain / technology / supply chain / smart contract
#      75  medicine / trip / access / pharmaceutical
#      80  deepfake / content / aigc / ai-generated
#      82  robot / agricultural / crop / phenotyping
#      84  cancer / learning / disease / patient
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (8)
#      19  llm / medical / chatgpt / language
#      25  cultural heritage / protection cultural / heritage instituti
#      31  unlearning / erasure / diffusion / concept
#      42  geographical indication / gi / kente / product
#      46  trust / institution / public / citizen
#      54  trust / institution / public / government
#     102  learning / rl / reinforcement / reward
#     106  authenticity / influencer / media / content
#
# CAPABILITY LOOKING FOR A PROBLEM (8)
#      33  hydrogen / energy / green / carbon neutrality
#      39  reef / park / australian marine / coral
#      41  opengov / ul / au / li
#      52  robot / soft / actuation / jumping
#      56  lidar / object / autonomous / dataset
#      60  valuation / property / editorial / market cycle
#      83  attack / watermarking / signal / detection
#     100  graph / gnn / network / node
#
# WATCH (50)
#      29  gene / crop / crispr / editing
#      32  copyright page / copyright notice
#      38  navigation / robot / task / agent
#      40  watermark / text / llm / language
#      43  covid-19 / trust / pandemic / health
#      57  energy / renewable / storage / hydrogen
#      58  energy / renewable / storage / battery
#      59  crispr / editing / gene / cas9
#      61  video / visual / retrieval / caption
#      63  bone / additive manufacturing / scaffold / porous
#      65  rag / text / language / retrieval
#      68  vehicle / autonomous / driving / avs
#      70  synthetic biology / cell-free / biomanufacturing / metabolic
#      72  quantum / entanglement / communication / teleportation
#      73  swarm / robot / system / collective behavior
#      76  quantum / error / qubit / code
#      77  kilometre km / square kilometre / africa / population millio
#      78  lammp / molecular / hps / electronic structure
#      79  synthetic biology / cyanobacteria / metabolic / microalgae
#      81  quantum / cavity / qubit / optomechanical
#      85  additive manufacturing / material / alloy / printing
#      86  energy / grid / storage system / renewable
#      87  vaccine / covid-19 / hesitancy / vaccination
#      88  remote sensing / agriculture / crop / sensor
#      89  microplastic / polymer / dye / wastewater
#      90  surgical / robot / surgery / autonomous
#      91  hydrogen / energy / storage / electrolysis
#      92  music / audio / speech / watermarking
#      93  underwater / auv / autonomous / navigation
#      94  uav / navigation / autonomous / unmanned
#      95  synthetic biology / microbial / consortia / metabolic
#      96  battery / energy storage / lithium / lib
#      97  galaxy / dwarf / rm / black hole
#      98  indoor / positioning / navigation / system
#      99  quantum / variational / algorithm / vqe
#     101  odometry / navigation / lidar / sensor
#     103  image / dataset / facial / network
#     104  scene / point cloud / image / object
#     105  quantum / photonic / dot / metasurface
#     107  counterfeit / illicit / market / consumer
#     108  graph / isometric / vertice / polynomial
#     109  spin / quantum / magnetic / nv
#     110  quantum / learning / classical / machine
#     111  watermark / image / attack / dnn
#     112  quantum / lattice / many-body / system
#     113  honey / geographical origin / food / wine
#     114  higg / dark matter / decay / scalar
#     115  quantum / entanglement / network / teleportation
#     116  quantum / cryptography / cryptographic / security
#     117  covariance / sample / matrix / prior

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = '2026-09-13T2114-T0027'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  automated decision-making / administrative / government / law
# 204 documents · 2018–2026 · H1 · strong
#
# Defining terms: automated decision-making, decision-making, automated, administrative, administrative decision-making, administrative law, automated decision, government, governmental automated, decision, law, decision making
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  █████
#      2019     4  █████
#      2020     7  █████████
#      2021     6  ████████
#      2022     3  ████
#      2023    18  ████████████████████████  ← burst
#      2024     5  ███████
#      2025     6  ████████
#      2026     7  █████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Situating the Rule of Law in the Context of Automated Decision-Making
#     crossref · 2023 · The Rule of Law and Automated Decision-Making
#     https://doi.org/10.1007/978-3-031-30142-1_2
#   • Automated Decision-Making and the Law
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_3
#   • Automated Decision-making
#     crossref · 2025 · Smart Court
#     https://doi.org/10.1017/9781009319232.007
#   • The Rule of Law and Automated Decision-Making
#     crossref · 2023 · book
#     https://doi.org/10.1007/978-3-031-30142-1
#   • Automated Decision Making
#     gdelt · 2025 · mondaq.com
#     https://www.mondaq.com:443/unitedstates/privacy-protection/1714862/automated-decision-making

# %%
TOPIC_ID = '2026-09-13T2114-T0070'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  intellectual property / property protection / firm / corporate
# 95 documents · 2018–2026 · H2 · weak
#
# Defining terms: intellectual property, intellectual, property protection, property, protection, firm, corporate, financing, digital, digital governance, firm innovation, quasi-natural
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██
#      2019     0
#      2020     0
#      2021     3  ██████
#      2022     1  ██
#      2023     2  ████
#      2024     3  ██████
#      2025    13  ████████████████████████  ← burst
#      2026     6  ███████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Digital governance, financial support, and intellectual property protection transformation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108250
#   • Intellectual property protection and corporate digital transformation: An empirical analysis fro
#     crossref · 2025 · International Review of Economics &amp; Finance
#     https://doi.org/10.1016/j.iref.2025.104125
#   • Digital finance development, intellectual property protection, and regional innovation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108217
#   • Legal infrastructures for firm innovation: Effects of intellectual property protection in the er
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2024.106343
#   • Intellectual property protection policy and firms' digital investment: Evidence from a quasi-nat
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2026.110478

# %%
TOPIC_ID = '2026-09-13T2114-T0116'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  copyright / artificial intelligence / generative artificial / generated object
# 277 documents · 2022–2026 · H1 · weak
#
# Defining terms: copyright, artificial intelligence, intelligence, artificial, generative artificial, generated object, generative, intelligence generated, ai, attribution, object, generated
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     0
#      2022     1  ████
#      2023     1  ████
#      2024     6  ████████████████████████  ← burst
#      2025     5  ████████████████████  ← burst
#      2026     5  ████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Copyright Issues Related to Generative Artificial Intelligence (AI)
#     crossref · 2026 · Artificial Intelligence and the Rule of Law
#     https://doi.org/10.1007/978-981-95-8781-0
#   • Artificial Intelligence and Copyright: Navigating Issues and Challenges
#     crossref · 2024 · European Economic Letters
#     https://doi.org/10.52783/eel.v14i4.2252
#   • Copyright Policy Options for Generative Artificial Intelligence
#     crossref · 2024 · report
#     https://doi.org/10.3386/w32106
#   • Attribution of Copyright for Generative Artificial Intelligence Creations
#     crossref · 2025 · Proceedings of the 1st International Conference on Politics, Law, and Social S
#     https://doi.org/10.5220/0014380900004859
#   • Generative Artificial Intelligence and the Basic Framework of the Copyright System
#     crossref · 2026 · Artificial Intelligence and the Rule of Law
#     https://doi.org/10.1007/978-981-95-8781-0_1

# %%
TOPIC_ID = '2026-09-13T2114-T0053'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  patent retrieval / retrieval system / information retrieval / learning prior
# 38 documents · 2018–2026 · H2 · strong
#
# Defining terms: patent retrieval, retrieval, patent, retrieval system, information retrieval, learning prior, mapreduce, retrieval-based learning, retrieval patent, retrieval-based, chinese patent, patent information
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ██████
#      2019     4  ████████████
#      2020     2  ██████
#      2021     2  ██████
#      2022     5  ███████████████
#      2023     6  ██████████████████
#      2024     5  ███████████████
#      2025     2  ██████
#      2026     8  ████████████████████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Challenges in Patent Information Retrieval
#     crossref · 2020 · The Information Retrieval Series
#     https://doi.org/10.1007/978-981-15-5554-1_4
#   • Patent retrieval: a literature review
#     crossref · 2019 · Knowledge and Information Systems
#     https://doi.org/10.1007/s10115-018-1322-7
#   • A Recapitulation of Patent Retrieval
#     crossref · 2024 · Journal of Intellectual Property Rights
#     https://doi.org/10.56042/jipr.v29i1.1435
#   • An Abstract-Level Patent Retrieval Model
#     crossref · 2023 · Proceedings of the 4th International Conference on Artificial Intelligence and
#     https://doi.org/10.1145/3652628.3652710
#   • Rethinking patent retrieval with language models: Toward scalable and efficient search
#     crossref · 2026 · World Patent Information
#     https://doi.org/10.1016/j.wpi.2026.102433

# %%
TOPIC_ID = '2026-09-13T2114-T0059'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  enforcement intellectual / property right / intellectual property / right eu
# 66 documents · 2018–2026 · H1 · weak
#
# Defining terms: enforcement intellectual, property right, enforcement, intellectual property, intellectual, right, property, right eu, eu member, hungary, finland, member state
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  █
#      2019    30  ████████████████████████  ← burst
#      2020     1  █
#      2021     0
#      2022     0
#      2023     0
#      2024     0
#      2025     0
#      2026     2  ██
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Enforcement of Intellectual Property Rights in the EU Member States
#     crossref · 2019 · book
#     https://doi.org/10.1017/9781780687827
#   • Enforcement of Intellectual Property Rights in Hungary
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.016
#   • Enforcement of Intellectual Property Rights in the Czech Republic
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.009
#   • Enforcement of Intellectual Property Rights in Slovakia
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.027
#   • Enforcement of Intellectual Property Rights in Portugal
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.025

# %%
TOPIC_ID = '2026-09-13T2114-T0060'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  ip / law / intellectual property / chapter
# 42 documents · 2018–2026 · H1 · weak
#
# Defining terms: ip, law, ip law, intellectual property, intellectual, chapter, unregistered design, property, unregistered, registered design, european, property law
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██
#      2019    15  ████████████████████████  ← burst
#      2020     0
#      2021     4  ██████
#      2022     1  ██
#      2023    10  ████████████████
#      2024     1  ██
#      2025     0
#      2026     2  ███
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Contemporary Intellectual Property
#     crossref · 2023 · edited-book
#     https://doi.org/10.1093/he/9780192855916.001.0001
#   • Holyoak and Torremans Intellectual Property Law
#     crossref · 2019 · edited-book
#     https://doi.org/10.1093/he/9780198836452.001.0001
#   • Contemporary Intellectual Property
#     crossref · 2019 · edited-book
#     https://doi.org/10.1093/he/9780198799801.001.0001
#   • 1. Intellectual property law: an introduction
#     crossref · 2019 · Contemporary Intellectual Property
#     https://doi.org/10.1093/he/9780198799801.003.0001
#   • 1. Intellectual property law: an introduction
#     crossref · 2023 · Contemporary Intellectual Property
#     https://doi.org/10.1093/he/9780192855916.003.0001

# %%
TOPIC_ID = '2026-09-13T2114-T0069'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  dashboard / digital project / queensland / contribution published
# 38 documents · 2025–2026 · H2 · weak
#
# Defining terms: dashboard, project dashboard, digital project, queensland, digital, queensland government, contribution published, dashboard contribution, dashboard faq, dashboard resource, dashboard website, enabled initiative
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     0
#      2022     0
#      2023     0
#      2024     0
#      2025     7  ███████  ← burst
#      2026    23  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • DE—Digital Projects Dashboard contribution
#     datagovau · 2026 · Education
#     https://data.gov.au/data/dataset/de-digital-projects-dashboard-contribution
#   • DSDIP—Digital Projects Dashboard contribution
#     datagovau · 2026 · State Development, Infrastructure and Planning
#     https://data.gov.au/data/dataset/dsdip-digital-projects-dashboard-contribution
#   • DPC—Digital Projects Dashboard contribution
#     datagovau · 2026 · Premier and Cabinet
#     https://data.gov.au/data/dataset/dpc-digital-projects-dashboard-contribution
#   • DPI —Digital Projects Dashboard contribution
#     datagovau · 2026 · Primary Industries
#     https://data.gov.au/data/dataset/dpi-digital-projects-dashboard-contribution
#   • Cross Gov—Digital Projects Dashboard contribution
#     datagovau · 2026 · Customer Services, Open Data and Small and Family Business
#     https://data.gov.au/data/dataset/cross-gov-digital-projects-dashboard-contribution

# %%
TOPIC_ID = '2026-09-13T2114-T0010'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  intellectual property / right / property law / cambridge intellectual
# 189 documents · 2018–2026 · H1 · strong
#
# Defining terms: intellectual property, intellectual, property, right, property right, property law, cambridge intellectual, right intellectual, cambridge, property information, law, ip
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     8  █████████
#      2019    21  ████████████████████████  ← burst
#      2020     6  ███████
#      2021    12  ██████████████
#      2022     4  █████
#      2023     6  ███████
#      2024     9  ██████████
#      2025    10  ███████████
#      2026     6  ███████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Introduction to intellectual property
#     crossref · 2024 · Taxation of Intellectual Property
#     https://doi.org/10.5040/9781526524973.chapter-002
#   • Intellectual property law
#     crossref · 2023 · Research Handbook on the Enforcement of EU Law
#     https://doi.org/10.4337/9781802208030.00038
#   • Intellectual Property As Property
#     crossref · 2019 · Research Handbook on the Economics of Intellectual Property Law
#     https://doi.org/10.4337/9781789903997.00005
#   • Intellectual property aspects
#     crossref · 2021 · Promoting Access to Medical Technologies and Innovation, 2nd edition
#     https://doi.org/10.30875/9789287053374c006
#   • Intellectual Property Rights
#     crossref · 2023 · Practitioner Perspectives on Intangible Cultural Heritage
#     https://doi.org/10.4324/9781003144052-4

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
