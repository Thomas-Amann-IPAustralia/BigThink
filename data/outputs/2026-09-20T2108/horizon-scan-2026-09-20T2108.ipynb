# %% [markdown]
# # IPAVentures horizon scan — run `2026-09-20T2108`
#
# Generated 2026-09-21 01:08 UTC by `python -m src.notebook --run-id 2026-09-20T2108`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = '2026-09-20T2108'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    2026-09-20T2108
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 33,168

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
if _method == "bertopic":
    # Under BERTopic the similarity threshold does not cluster anything —
    # HDBSCAN works on density in UMAP space and takes no cosine cut-off. It is
    # read for one purpose only: attaching documents from non-forming sources
    # to the nearest finished topic. Labelled for what it does, so a reviewer
    # is not left comparing it against a clustering threshold from another run.
    print("Attachment thresh :", _thresh.get(_backend, "not recorded"),
          f"x ratio {_topics_cfg.get('attachment_threshold_ratio', 0.6)}")
    # THE SEED. UMAP's initialisation is stochastic, so this is the difference
    # between a topic set another analyst can reproduce and one they cannot.
    # Printed from the run's own snapshot, never from today's config file.
    _bt = _topics_cfg.get("bertopic") or {}
    print("BERTopic seed     :", _bt.get("random_state", "NOT RECORDED"))
    print("BERTopic UMAP     :",
          f"n_neighbors={_bt.get('n_neighbors')}, "
          f"n_components={_bt.get('n_components')}, "
          f"min_dist={_bt.get('min_dist')}, metric={_bt.get('metric')}")
    print("BERTopic HDBSCAN  :",
          f"min_cluster_size={_bt.get('min_cluster_size') or _topics_cfg.get('min_topic_size')}, "
          f"min_samples={_bt.get('min_samples')}, "
          f"selection={_bt.get('cluster_selection_method')}")
    if not isinstance(_bt.get("random_state"), int):
        print("\n  WARNING: no seed recorded for this run. UMAP is stochastic, "
              "so the topics below cannot be reproduced exactly, even from this "
              "same corpus and config.")
else:
    print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : bge
# Clustering method : bertopic
# Attachment thresh : 0.9 x ratio 0.6
# BERTopic seed     : 42
# BERTopic UMAP     : n_neighbors=15, n_components=5, min_dist=0.0, metric=cosine
# BERTopic HDBSCAN  : min_cluster_size=8, min_samples=None, selection=eom
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status      in    out   seconds  message
# ------------------------  -------  -----  -----  --------  ----------------------------------------------------------------
# stage0_strategy           success      —     34     0.300  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage1_collect            partial  28956  14826  9328.900  28956 fetched, 14826 new, 1 failed/skipped pairs, 24 partial in…
# stage2_emergence          success  33168    117  4962.500  117 topics from 33168 documents across 9 slices (2018-2026); 28…
# stage5_synthesis          success    117    117    59.900  ranked 117 topics; outputs written
# stage3_scoring            success    117    117    58.900  scored 117 topics; mean fit 0.485, mean leverage 0.353, 0 criti…
# stage4_opportunity_index  success    117    117     0.400  indexed 117 of 117 topics (0 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# gdelt          14996        2024       2026      25
# openalex        7379        2018       2026      35
# crossref        5328        2018       2026      28
# arxiv           3092        2018       2026      12
# oecd            1930        2018       2026      32
# datagovau        443        2022       2026       9
#
# What this run's collection actually did (per source query):
#
# source     status   queries  records
# ---------  -------  -------  -------
# arxiv      success       12     3080
# crossref   success       28     5420
# datagovau  success        9      450
# gdelt      failed         1        0
# gdelt      partial       24     9844
# gdelt      success        1      518
# oecd       success       32     2059
# openalex   success       35     7585

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018       1789
# 2019       1979
# 2020       2339
# 2021       2172
# 2022       1868
# 2023       1982
# 2024       2583
# 2025       9817
# 2026       8639
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       9521
# Economic            6126
# Political           5764
# Environmental       4404
# Social              3430
# Legal               2127
# Values              1796

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                         STEEPV         documents  sources
# ---------------------------------  -------------  ---------  -------
# ai_governance_assurance            Political           1897        6
# ct_quantum                         Technological       1761        4
# digital_identity_provenance        Technological       1529        3
# workforce_skills_automation        Economic            1375        5
# climate_adaptation                 Environmental       1369        5
# digital_competition_platforms      Economic            1287        4
# defence_dual_use                   Political           1266        4
# gov_service_delivery               Political           1253        5
# ai_authorship_inventorship         Legal               1243        5
# trust_institutions                 Social              1212        4
# ct_biotech                         Technological       1198        4
# ip_finance_valuation               Economic            1192        4
# indigenous_knowledge               Values              1178        4
# ip_enforcement_counterfeit         Economic            1119        4
# information_integrity              Social               909        4
# geographical_indications           Legal                884        3
# health_system_innovation           Social               848        4
# ct_ai                              Technological        844        4
# ip_admin_automation                Technological        820        5
# ct_advanced_manufacturing          Technological        820        3
# geoeconomics_supply_chains         Political            815        5
# ct_energy                          Environmental        800        3
# space_earth_observation            Technological        797        4
# ip_search_retrieval                Technological        683        3
# ct_autonomous                      Technological        682        3
# water_security                     Environmental        681        4
# food_agriculture_systems           Environmental        646        5
# strategic_foresight_practice       Values               618        3
# housing_construction_productivity  Economic             557        4
# ip_sme_access                      Economic             548        4
# ip_policy_reform                   Political            533        5
# circular_economy_materials         Environmental        512        4
# ageing_wellbeing                   Social               461        3
# oceans_blue_economy                Environmental        396        3
# ct_advanced_ict                    Technological        387        3
# oecd_southeast_asia_reports        Economic              48        1

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Failed queries by source: gdelt (1). Each failure costs that frame's contribution to the corpus, so the shortlist is drawn from a slightly different scan than the frame file describes.

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic                  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# ---------------------  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# 2026-09-20T2108-T0014  supply chain / chain resilience / resilience   140  0.19  0.19  0.87  0.68  0.86       0.85  H1  strong
# 2026-09-20T2108-T0039  patent / art search / prior art / retrieval     76  0.21  0.12  0.86  0.69  0.74       0.82  H2  strong
# 2026-09-20T2108-T0046  llm / medical / chatgpt / clinical              66  0.16  0.29  0.87  0.67  0.81       0.79  H1  strong
# 2026-09-20T2108-T0008  circular / economy / recycling / product des   193  0.16  0.13  0.84  0.69  0.92       0.76  H1  strong
# 2026-09-20T2108-T0098  wellbeing / policy / basic vision / governme    66  0.23  0.30  0.78  0.59  0.46       0.76  H1  weak
# 2026-09-20T2108-T0085  heritage / cultural / intellectual / propert    75  0.19  0.19  0.77  0.60  0.88       0.76  H1  weak
# 2026-09-20T2108-T0060  kilometre km / square kilometre / africa / p    64  0.35  0.20  0.79  0.61  0.23       0.75  H2  weak
# 2026-09-20T2108-T0072  cas9 / genome / crispr / editing                56  0.22  0.06  0.85  0.57  0.86       0.75  H1  weak
# 2026-09-20T2108-T0102  precision agriculture / system precision / a    48  0.20  0.03  0.82  0.66  0.88       0.75  H2  noise
# 2026-09-20T2108-T0005  amr / antimicrobial / sepsis / resistance      235  0.16  0.33  0.83  0.68  0.73       0.74  H3  strong
# 2026-09-20T2108-T0056  watermark / text / llm / language               63  0.21  0.36  0.88  0.50  0.55       0.73  H2  strong
# 2026-09-20T2108-T0042  crispr / editing / gene / cas9                 106  0.20  0.07  0.76  0.61  0.97       0.72  H1  strong
# 2026-09-20T2108-T0068  earth observation / satellite / european / o    67  0.20  0.11  0.79  0.60  0.81       0.71  H1  weak
# 2026-09-20T2108-T0116  earth observation / satellite / cube / image    43  0.21  0.02  0.81  0.62  0.89       0.71  H1  noise
# 2026-09-20T2108-T0074  water / treatment / removal / adsorbent         48  0.19  0.07  0.83  0.69  0.70       0.71  H1  weak
# 2026-09-20T2108-T0081  pricing / algorithmic / collusion / competit    78  0.16  0.33  0.77  0.58  0.81       0.69  H3  weak
# 2026-09-20T2108-T0079  learning / task / robot / policy                44  0.20  0.20  0.86  0.51  0.67       0.69  H2  weak
# 2026-09-20T2108-T0104  enforcement intellectual / property right /    120  0.24  0.15  0.71  0.54  0.85       0.68  H1  weak
# 2026-09-20T2108-T0032  automated decision-making / administrative /   301  0.19  0.26  0.75  0.55  0.78       0.68  H1  strong
# 2026-09-20T2108-T0012  patent / retrieval / prior art / classificat   142  0.15  0.22  0.86  0.53  0.88       0.67  H2  strong
# 2026-09-20T2108-T0109  housing / household / rental / dwelling        110  0.22  0.42  0.74  0.50  0.75       0.67  H1  weak
# 2026-09-20T2108-T0094  water / evaporation / photothermal / solar      44  0.18  0.07  0.82  0.56  0.86       0.67  H1  weak
# 2026-09-20T2108-T0027  misinformation / online / age / nudging        477  0.21  0.30  0.70  0.53  0.72       0.66  H1  strong
# 2026-09-20T2108-T0114  trust / covid-19 / public / pandemic            36  0.20  0.09  0.86  0.49  0.82       0.66  H1  weak
# 2026-09-20T2108-T0091  intellectual / property protection / firm /    129  0.18  0.32  0.75  0.55  0.78       0.66  H2  weak
# 2026-09-20T2108-T0019  trust / institution / public / doctrine        182  0.20  0.00  0.78  0.62  0.78       0.64  H2  latent
# 2026-09-20T2108-T0004  llm / language / task / agent                  303  0.14  0.38  0.81  0.55  0.81       0.64  H3  strong
# 2026-09-20T2108-T0011  loneliness / social isolation / mental / hea   154  0.16  0.11  0.84  0.57  0.70       0.63  H1  strong
# 2026-09-20T2108-T0053  vehicle / driving / autonomous / avs           105  0.18  0.20  0.77  0.51  0.86       0.63  H2  strong
# 2026-09-20T2108-T0033  drought / catchment / water / streamflow        82  0.16  0.06  0.84  0.73  0.70       0.63  H1  strong
# 2026-09-20T2108-T0059  audio / music / speech / watermarking           65  0.17  0.29  0.82  0.50  0.78       0.63  H3  strong
# 2026-09-20T2108-T0038  supply chain / chain resilience / sc / disru    77  0.14  0.05  0.88  0.61  0.85       0.61  H1  strong
# 2026-09-20T2108-T0041  supply chain / pandemic / covid-19 / food      170  0.15  0.22  0.77  0.55  0.89       0.61  H1  strong
# 2026-09-20T2108-T0010  ai / education / chatgpt / generative          311  0.13  0.28  0.76  0.58  0.89       0.60  H1  strong
# 2026-09-20T2108-T0097  autonomous driving / lidar / segmentation /     36  0.20  0.06  0.86  0.50  0.65       0.59  H2  weak
# 2026-09-20T2108-T0090  nanotechnology / nanoparticle / nps / nanoma    46  0.15  0.04  0.82  0.63  0.79       0.59  H1  noise
# 2026-09-20T2108-T0016  circular / ce / economy / product              130  0.12  0.10  0.85  0.62  0.79       0.58  H1  strong
# 2026-09-20T2108-T0106  front matter / frontmatter / back matter / p    70  0.26  0.00  0.73  0.56  0.99       0.58  H1  noise
# 2026-09-20T2108-T0028  blockchain / supply chain / traceability / t    84  0.15  0.08  0.88  0.57  0.64       0.57  H1  strong
# 2026-09-20T2108-T0035  energy / storage / renewable / battery         111  0.22  0.00  0.79  0.52  0.96       0.57  H1  latent
# 2026-09-20T2108-T0040  competition / digital platform / digital mar   384  0.19  0.21  0.68  0.52  0.69       0.57  H2  strong
# 2026-09-20T2108-T0067  housing / supply / construction / nbsp         202  0.19  0.18  0.70  0.54  0.48       0.57  H2  weak
# 2026-09-20T2108-T0025  recycling / plastic / waste / circular         132  0.12  0.13  0.80  0.62  0.80       0.56  H1  strong
# 2026-09-20T2108-T0092  lidar / odometry / slam / inertial              42  0.20  0.00  0.84  0.51  0.92       0.56  H1  noise
# 2026-09-20T2108-T0078  image / inpainting / learning / dataset         49  0.18  0.00  0.83  0.55  0.85       0.56  H1  noise
# 2026-09-20T2108-T0051  cent / per / forecast / export earning         329  0.18  0.42  0.65  0.50  0.73       0.55  H1  strong
# 2026-09-20T2108-T0026  blue economy / ocean / marine / economy indi   229  0.17  0.07  0.69  0.58  0.82       0.55  H1  strong
# 2026-09-20T2108-T0093  fire / forest / climate / change                46  0.16  0.00  0.82  0.70  0.77       0.55  H1  noise
# 2026-09-20T2108-T0073  wireless / communication / ris / mimo           54  0.16  0.00  0.81  0.65  0.84       0.54  H1  noise
# 2026-09-20T2108-T0065  automated / decision / adm / human             101  0.13  0.16  0.77  0.53  0.91       0.53  H1  weak
# 2026-09-20T2108-T0111  ip / criminal / enforcement / intellectual p   122  0.18  0.13  0.71  0.53  0.63       0.53  H3  weak
# 2026-09-20T2108-T0086  aerosol / satellite / emission / aod            42  0.16  0.08  0.84  0.51  0.73       0.52  H1  weak
# 2026-09-20T2108-T0057  membrane / water / desalination / separation    61  0.18  0.07  0.82  0.49  0.72       0.52  H1  weak
# 2026-09-20T2108-T0070  single-cell / cancer / nf / scrna-seq          118  0.15  0.08  0.71  0.63  0.76       0.52  H1  weak
# 2026-09-20T2108-T0108  critical mineral / supply chain / mineral su   326  0.16  0.36  0.68  0.51  0.44       0.52  H3  weak
# 2026-09-20T2108-T0048  hydrogen / electrolysis / energy / storage     104  0.18  0.00  0.77  0.62  0.80       0.52  H1  latent
# 2026-09-20T2108-T0037  battery / energy storage / lib / lithium-ion   145  0.17  0.00  0.76  0.60  0.85       0.51  H1  latent
# 2026-09-20T2108-T0017  ageing / population / older / elderly          232  0.16  0.04  0.75  0.62  0.72       0.51  H1  latent
# 2026-09-20T2108-T0061  patent / ai / invention / inventorship         227  0.15  0.25  0.72  0.52  0.72       0.51  H1  strong
# 2026-09-20T2108-T0034  service delivery / digital / government / pu   264  0.15  0.29  0.73  0.51  0.67       0.50  H2  strong
# 2026-09-20T2108-T0095  export control / dual-use / eu / control reg   159  0.18  0.10  0.66  0.55  0.37       0.50  H1  weak
# 2026-09-20T2108-T0013  climate / food / crop / agriculture            234  0.11  0.08  0.78  0.59  0.81       0.50  H1  strong
# 2026-09-20T2108-T0020  energy / storage / grid / renewable            124  0.17  0.00  0.82  0.56  0.78       0.50  H1  latent
# 2026-09-20T2108-T0099  vaccine / covid-19 / waiver / pandemic         105  0.17  0.13  0.72  0.45  0.83       0.49  H1  weak
# 2026-09-20T2108-T0045  satellite / leo / constellation / network       73  0.16  0.07  0.82  0.47  0.82       0.49  H1  strong
# 2026-09-20T2108-T0077  robot / agricultural / crop / navigation        48  0.16  0.02  0.86  0.42  0.84       0.48  H1  noise
# 2026-09-20T2108-T0049  agriculture / crop / iot / farming              72  0.15  0.00  0.86  0.58  0.82       0.48  H1  latent
# 2026-09-20T2108-T0064  galaxy / star / stellar / halo                  54  0.20  0.00  0.84  0.50  0.64       0.47  H1  noise
# 2026-09-20T2108-T0113  graph / gnn / neural / network                  43  0.17  0.00  0.79  0.52  0.89       0.47  H1  noise
# 2026-09-20T2108-T0100  breeding / crop / maize / plant                 47  0.15  0.00  0.80  0.58  0.91       0.47  H1  noise
# 2026-09-20T2108-T0007  watermark / image / attack / dnn               212  0.20  0.00  0.85  0.49  0.74       0.46  H1  latent
# 2026-09-20T2108-T0105  landslide / satellite / flood / sar             33  0.16  0.05  0.85  0.42  0.80       0.46  H1  noise
# 2026-09-20T2108-T0115  battery / electric / energy storage / bms       54  0.17  0.00  0.76  0.56  0.82       0.46  H1  noise
# 2026-09-20T2108-T0047  indigenous / intellectual / property / cultu   440  0.19  0.02  0.69  0.52  0.66       0.45  H1  latent
# 2026-09-20T2108-T0080  posterior / algorithm / matrix / phase retri    42  0.14  0.00  0.83  0.57  0.82       0.45  H1  noise
# 2026-09-20T2108-T0044  patent / artificial intelligence / inventors   875  0.18  0.05  0.70  0.52  0.59       0.44  H2  strong
# 2026-09-20T2108-T0076  table content / note / list illustration / l   209  0.21  0.00  0.68  0.53  0.74       0.44  H1  noise
# 2026-09-20T2108-T0089  star / tess / exoplanet / orbital               39  0.18  0.00  0.83  0.50  0.64       0.43  H1  noise
# 2026-09-20T2108-T0006  synthetic biology / gene / cell / metabolic    314  0.14  0.18  0.77  0.49  0.69       0.43  H1  strong
# 2026-09-20T2108-T0066  ai / public / governance / sector              281  0.15  0.19  0.71  0.47  0.75       0.41  H1  weak
# 2026-09-20T2108-T0069  service delivery / public service / digital    281  0.19  0.00  0.71  0.55  0.65       0.41  H2  noise
# 2026-09-20T2108-T0009  additive manufacturing / material / bone / p   175  0.15  0.00  0.80  0.56  0.68       0.40  H1  latent
# 2026-09-20T2108-T0021  intellectual property / property right / pro   413  0.19  0.00  0.71  0.53  0.69       0.40  H1  latent
# 2026-09-20T2108-T0058  satellite / image / eo / earth observation      63  0.14  0.00  0.82  0.52  0.93       0.40  H1  noise
# 2026-09-20T2108-T0096  surgical / robotic / surgery / surgeon          43  0.16  0.00  0.81  0.50  0.84       0.40  H1  noise
# 2026-09-20T2108-T0071  esg / corporate / firm / governance             78  0.14  0.00  0.79  0.56  0.82       0.39  H1  noise
# 2026-09-20T2108-T0062  governance / nature-based / urban / nbs         83  0.10  0.09  0.79  0.46  0.82       0.36  H1  weak
# 2026-09-20T2108-T0110  valuation / valuer / briefing / avm             85  0.14  0.00  0.71  0.60  0.78       0.36  H2  noise
# 2026-09-20T2108-T0082  green / innovation / patent / firm             128  0.11  0.11  0.75  0.44  0.82       0.35  H1  weak
# 2026-09-20T2108-T0103  deepfake / content / ai-generated / aigc       770  0.15  0.07  0.69  0.50  0.57       0.35  H1  weak
# 2026-09-20T2108-T0015  trust / public / institution / citizen         234  0.15  0.00  0.81  0.49  0.83       0.35  H1  latent
# 2026-09-20T2108-T0003  geographical indication / gi / kente / produ   459  0.14  0.01  0.78  0.48  0.85       0.35  H1  latent
# 2026-09-20T2108-T0043  ai / health / clinical / gdpr                  186  0.14  0.00  0.76  0.55  0.76       0.35  H1  latent
# 2026-09-20T2108-T0050  employment / skill / youth / graduate          476  0.18  0.00  0.67  0.52  0.42       0.34  H2  latent
# 2026-09-20T2108-T0101  misinformation / disinformation / media / fa   217  0.15  0.03  0.65  0.51  0.70       0.33  H1  noise
# 2026-09-20T2108-T0075  blue economy / ocean / marine / maritime       137  0.14  0.06  0.75  0.49  0.70       0.33  H1  weak
# 2026-09-20T2108-T0029  indigenous / traditional knowledge / intelle   126  0.15  0.00  0.78  0.37  0.93       0.32  H2  latent
# 2026-09-20T2108-T0001  climate / adaptation / change / disaster       857  0.10  0.00  0.76  0.58  0.81       0.32  H1  latent
# 2026-09-20T2108-T0000  quantum / qubit / entanglement / computing    1614  0.14  0.00  0.75  0.53  0.82       0.32  H1  latent
# 2026-09-20T2108-T0052  defence / innovation / military / dual-use     465  0.15  0.02  0.67  0.52  0.54       0.31  H2  latent
# 2026-09-20T2108-T0112  foresight / scenario planning / strategic /     47  0.13  0.00  0.80  0.47  0.95       0.31  H1  noise
# 2026-09-20T2108-T0055  foresight / anticipatory / governance / poli   102  0.11  0.02  0.76  0.45  0.94       0.31  H2  latent
# 2026-09-20T2108-T0036  cancer / disease / mri / learning               84  0.14  0.00  0.80  0.48  0.86       0.30  H1  latent
# 2026-09-20T2108-T0107  influencer / authenticity / brand / tiktok     110  0.17  0.00  0.71  0.46  0.75       0.29  H1  noise
# 2026-09-20T2108-T0018  automation / worker / employment / job         650  0.13  0.07  0.71  0.50  0.62       0.28  H2  strong
# 2026-09-20T2108-T0022  health / digital / dht / technology            371  0.13  0.00  0.73  0.52  0.80       0.28  H1  latent
# 2026-09-20T2108-T0088  regulatory policy / plc / regulatory reform   2307  0.16  0.00  0.61  0.50  0.05       0.26  H1  noise
# 2026-09-20T2108-T0063  water / management / security / urban          153  0.12  0.00  0.76  0.49  0.83       0.26  H1  noise
# 2026-09-20T2108-T0002  construction / prefabricated / housing / mod   385  0.12  0.00  0.80  0.49  0.78       0.25  H1  latent
# 2026-09-20T2108-T0031  blockchain / technology / smart contract / f   274  0.14  0.00  0.70  0.51  0.76       0.24  H1  latent
# 2026-09-20T2108-T0087  dma / competition law / digital market / dra   287  0.16  0.00  0.73  0.49  0.49       0.24  H1  noise
# 2026-09-20T2108-T0054  marine / fungi / ocean / biotechnological       70  0.12  0.00  0.81  0.41  0.78       0.23  H1  latent
# 2026-09-20T2108-T0030  patent / citation / technology / innovation    128  0.09  0.00  0.78  0.44  0.90       0.23  H1  latent
# 2026-09-20T2108-T0083  honey / pesticide / geographical origin / fo    80  0.13  0.00  0.73  0.46  0.84       0.22  H1  noise
# 2026-09-20T2108-T0084  ai / ethic / governance / artificial intelli   273  0.13  0.00  0.73  0.51  0.65       0.22  H1  noise
# 2026-09-20T2108-T0023  patent / innovation / firm / intellectual pr   259  0.11  0.00  0.75  0.45  0.72       0.16  H1  latent
# 2026-09-20T2108-T0024  market / price / stock / volatility            569  0.12  0.00  0.65  0.50  0.64       0.16  H1  latent

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 117 of 117 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 24,459 of 33,168 documents (74%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 12 topic(s) sit within 0.05 of a Three Horizons cut-point (ip / criminal / enforcement / intellectu (0.33 → H3); housing / supply / construction / nbsp (0.40 → H2); patent / art search / prior art / retrie (0.71 → H2); autonomous driving / lidar / segmentatio (0.71 → H2); automation / worker / employment / job (0.71 → H2); service delivery / public service / digi (0.71 → H2); cent / per / forecast / export earning (0.77 → H1); patent / ai / invention / inventorship (0.77 → H1); regulatory policy / plc / regulatory ref (0.77 → H1); front matter / frontmatter / back matter (0.77 → H1); earth observation / satellite / cube / i (0.77 → H1); wellbeing / policy / basic vision / gove (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic                  label                                   fit  closest objective                     leverage  DISR field
# ---------------------  ------------------------------------  -----  ------------------------------------  --------  ----------
# 2026-09-20T2108-T0032  automated decision-making / adminis…  0.714  SI-3 AI and Automated Decision Maki…     0.472  —
# 2026-09-20T2108-T0039  patent / art search / prior art / r…  0.530  4.1 Innovation and adaptiveness in …     0.448  —
# 2026-09-20T2108-T0091  intellectual / property protection …  0.646  4.1 Innovation and adaptiveness in …     0.406  —
# 2026-09-20T2108-T0012  patent / retrieval / prior art / cl…  0.543  4.1 Innovation and adaptiveness in …     0.458  —
# 2026-09-20T2108-T0085  heritage / cultural / intellectual …  0.522  4.1 Innovation and adaptiveness in …     0.378  —
# 2026-09-20T2108-T0065  automated / decision / adm / human    0.728  SI-3 AI and Automated Decision Maki…     0.460  —
# 2026-09-20T2108-T0104  enforcement intellectual / property…  0.552  4.1 Innovation and adaptiveness in …     0.368  —
# 2026-09-20T2108-T0008  circular / economy / recycling / pr…  0.501  4.1 Innovation and adaptiveness in …     0.359  —
# 2026-09-20T2108-T0116  earth observation / satellite / cub…  0.488  4.2 Innovative digital and data-dri…     0.389  —
# 2026-09-20T2108-T0040  competition / digital platform / di…  0.626  4.2 Innovative digital and data-dri…     0.378  —
# 2026-09-20T2108-T0046  llm / medical / chatgpt / clinical    0.486  SI-3 AI and Automated Decision Maki…     0.352  —
# 2026-09-20T2108-T0081  pricing / algorithmic / collusion /…  0.490  4.2 Innovative digital and data-dri…     0.369  —
# 2026-09-20T2108-T0014  supply chain / chain resilience / r…  0.495  4.1 Innovation and adaptiveness in …     0.343  —
# 2026-09-20T2108-T0061  patent / ai / invention / inventors…  0.609  SI-3 AI and Automated Decision Maki…     0.456  —
# 2026-09-20T2108-T0044  patent / artificial intelligence / …  0.704  SI-3 AI and Automated Decision Maki…     0.472  —
# 2026-09-20T2108-T0102  precision agriculture / system prec…  0.470  4.1 Innovation and adaptiveness in …     0.355  —
# 2026-09-20T2108-T0010  ai / education / chatgpt / generati…  0.518  4.2 Innovative digital and data-dri…     0.361  —
# 2026-09-20T2108-T0066  ai / public / governance / sector     0.696  SI-3 AI and Automated Decision Maki…     0.426  —
# 2026-09-20T2108-T0016  circular / ce / economy / product     0.490  4.1 Innovation and adaptiveness in …     0.370  —
# 2026-09-20T2108-T0004  llm / language / task / agent         0.505  SI-3 AI and Automated Decision Maki…     0.350  —
# 2026-09-20T2108-T0028  blockchain / supply chain / traceab…  0.486  4.2 Innovative digital and data-dri…     0.380  —
# 2026-09-20T2108-T0072  cas9 / genome / crispr / editing      0.472  4.1 Innovation and adaptiveness in …     0.338  —
# 2026-09-20T2108-T0019  trust / institution / public / doct…  0.530  1.1 Trust and confidence in a high-…     0.326  —
# 2026-09-20T2108-T0047  indigenous / intellectual / propert…  0.554  SI-5 First Nations Strategy              0.402  —
# 2026-09-20T2108-T0099  vaccine / covid-19 / waiver / pande…  0.514  4.1 Innovation and adaptiveness in …     0.392  —
# 2026-09-20T2108-T0027  misinformation / online / age / nud…  0.475  4.1 Innovation and adaptiveness in …     0.348  —
# 2026-09-20T2108-T0034  service delivery / digital / govern…  0.685  4.2 Innovative digital and data-dri…     0.347  —
# 2026-09-20T2108-T0111  ip / criminal / enforcement / intel…  0.523  4.1 Innovation and adaptiveness in …     0.352  —
# 2026-09-20T2108-T0021  intellectual property / property ri…  0.562  4.1 Innovation and adaptiveness in …     0.418  —
# 2026-09-20T2108-T0038  supply chain / chain resilience / s…  0.484  4.2 Innovative digital and data-dri…     0.349  —
# 2026-09-20T2108-T0082  green / innovation / patent / firm    0.618  4.1 Innovation and adaptiveness in …     0.406  —
# 2026-09-20T2108-T0056  watermark / text / llm / language     0.444  SI-3 AI and Automated Decision Maki…     0.348  —
# 2026-09-20T2108-T0029  indigenous / traditional knowledge …  0.596  SI-5 First Nations Strategy              0.451  —
# 2026-09-20T2108-T0043  ai / health / clinical / gdpr         0.566  SI-3 AI and Automated Decision Maki…     0.425  —
# 2026-09-20T2108-T0098  wellbeing / policy / basic vision /…  0.453  SI-3 AI and Automated Decision Maki…     0.319  —
# 2026-09-20T2108-T0090  nanotechnology / nanoparticle / nps…  0.445  SI-3 AI and Automated Decision Maki…     0.374  —
# 2026-09-20T2108-T0079  learning / task / robot / policy      0.484  SI-3 AI and Automated Decision Maki…     0.316  —
# 2026-09-20T2108-T0084  ai / ethic / governance / artificia…  0.730  SI-3 AI and Automated Decision Maki…     0.458  —
# 2026-09-20T2108-T0112  foresight / scenario planning / str…  0.653  4.1 Innovation and adaptiveness in …     0.391  —
# 2026-09-20T2108-T0003  geographical indication / gi / kent…  0.638  SI-1 Geographical indications regis…     0.368  —
# 2026-09-20T2108-T0114  trust / covid-19 / public / pandemic  0.459  1.1 Trust and confidence in a high-…     0.328  —
# 2026-09-20T2108-T0053  vehicle / driving / autonomous / avs  0.465  SI-3 AI and Automated Decision Maki…     0.326  —
# 2026-09-20T2108-T0069  service delivery / public service /…  0.694  4.2 Innovative digital and data-dri…     0.332  —
# 2026-09-20T2108-T0023  patent / innovation / firm / intell…  0.644  4.1 Innovation and adaptiveness in …     0.442  —
# 2026-09-20T2108-T0030  patent / citation / technology / in…  0.561  4.1 Innovation and adaptiveness in …     0.490  —
# 2026-09-20T2108-T0055  foresight / anticipatory / governan…  0.619  4.1 Innovation and adaptiveness in …     0.371  —
# 2026-09-20T2108-T0097  autonomous driving / lidar / segmen…  0.445  4.2 Innovative digital and data-dri…     0.351  —
# 2026-09-20T2108-T0018  automation / worker / employment / …  0.533  SI-3 AI and Automated Decision Maki…     0.411  —
# 2026-09-20T2108-T0041  supply chain / pandemic / covid-19 …  0.423  4.1 Innovation and adaptiveness in …     0.358  —
# 2026-09-20T2108-T0052  defence / innovation / military / d…  0.595  4.1 Innovation and adaptiveness in …     0.364  —
# 2026-09-20T2108-T0031  blockchain / technology / smart con…  0.533  4.1 Innovation and adaptiveness in …     0.405  —
# 2026-09-20T2108-T0049  agriculture / crop / iot / farming    0.468  SI-3 AI and Automated Decision Maki…     0.360  —
# 2026-09-20T2108-T0035  energy / storage / renewable / batt…  0.463  4.2 Innovative digital and data-dri…     0.323  —
# 2026-09-20T2108-T0109  housing / household / rental / dwel…  0.374  SI-3 AI and Automated Decision Maki…     0.361  —
# 2026-09-20T2108-T0110  valuation / valuer / briefing / avm   0.490  4.1 Innovation and adaptiveness in …     0.366  —
# 2026-09-20T2108-T0108  critical mineral / supply chain / m…  0.452  4.2 Innovative digital and data-dri…     0.351  —
# 2026-09-20T2108-T0103  deepfake / content / ai-generated /…  0.485  SI-3 AI and Automated Decision Maki…     0.373  —
# 2026-09-20T2108-T0077  robot / agricultural / crop / navig…  0.457  SI-3 AI and Automated Decision Maki…     0.353  —
# 2026-09-20T2108-T0095  export control / dual-use / eu / co…  0.452  2.1 Access to and benefits from IP …     0.352  —
# 2026-09-20T2108-T0022  health / digital / dht / technology   0.520  4.2 Innovative digital and data-dri…     0.372  —
# 2026-09-20T2108-T0005  amr / antimicrobial / sepsis / resi…  0.429  4.1 Innovation and adaptiveness in …     0.297  —
# 2026-09-20T2108-T0088  regulatory policy / plc / regulator…  0.509  SI-3 AI and Automated Decision Maki…     0.378  —
# 2026-09-20T2108-T0086  aerosol / satellite / emission / aod  0.427  SI-3 AI and Automated Decision Maki…     0.362  —
# 2026-09-20T2108-T0042  crispr / editing / gene / cas9        0.419  4.1 Innovation and adaptiveness in …     0.315  —
# 2026-09-20T2108-T0087  dma / competition law / digital mar…  0.501  4.2 Innovative digital and data-dri…     0.390  —
# 2026-09-20T2108-T0068  earth observation / satellite / eur…  0.417  4.1 Innovation and adaptiveness in …     0.314  —
# 2026-09-20T2108-T0025  recycling / plastic / waste / circu…  0.451  4.1 Innovation and adaptiveness in …     0.318  —
# 2026-09-20T2108-T0051  cent / per / forecast / export earn…  0.398  SI-3 AI and Automated Decision Maki…     0.366  —
# 2026-09-20T2108-T0059  audio / music / speech / watermarki…  0.413  SI-3 AI and Automated Decision Maki…     0.330  —
# 2026-09-20T2108-T0062  governance / nature-based / urban /…  0.485  4.1 Innovation and adaptiveness in …     0.350  —
# 2026-09-20T2108-T0026  blue economy / ocean / marine / eco…  0.431  4.1 Innovation and adaptiveness in …     0.335  —
# 2026-09-20T2108-T0036  cancer / disease / mri / learning     0.499  SI-3 AI and Automated Decision Maki…     0.359  —
# 2026-09-20T2108-T0033  drought / catchment / water / strea…  0.407  4.1 Innovation and adaptiveness in …     0.328  —
# 2026-09-20T2108-T0037  battery / energy storage / lib / li…  0.448  4.2 Innovative digital and data-dri…     0.326  —
# 2026-09-20T2108-T0015  trust / public / institution / citi…  0.535  1.1 Trust and confidence in a high-…     0.317  —
# 2026-09-20T2108-T0048  hydrogen / electrolysis / energy / …  0.460  4.2 Innovative digital and data-dri…     0.311  —
# 2026-09-20T2108-T0113  graph / gnn / neural / network        0.418  4.2 Innovative digital and data-dri…     0.371  —
# 2026-09-20T2108-T0078  image / inpainting / learning / dat…  0.436  4.2 Innovative digital and data-dri…     0.315  —
# 2026-09-20T2108-T0074  water / treatment / removal / adsor…  0.402  4.2 Innovative digital and data-dri…     0.289  —
# 2026-09-20T2108-T0058  satellite / image / eo / earth obse…  0.442  SI-3 AI and Automated Decision Maki…     0.365  —
# 2026-09-20T2108-T0009  additive manufacturing / material /…  0.471  4.2 Innovative digital and data-dri…     0.329  —
# 2026-09-20T2108-T0050  employment / skill / youth / gradua…  0.483  4.2 Innovative digital and data-dri…     0.348  —
# 2026-09-20T2108-T0060  kilometre km / square kilometre / a…  0.350  4.2 Innovative digital and data-dri…     0.295  —
# 2026-09-20T2108-T0096  surgical / robotic / surgery / surg…  0.449  SI-3 AI and Automated Decision Maki…     0.351  —
# 2026-09-20T2108-T0006  synthetic biology / gene / cell / m…  0.450  4.2 Innovative digital and data-dri…     0.342  —
# 2026-09-20T2108-T0011  loneliness / social isolation / men…  0.400  4.2 Innovative digital and data-dri…     0.304  —
# 2026-09-20T2108-T0076  table content / note / list illustr…  0.437  4.2 Innovative digital and data-dri…     0.348  —
# 2026-09-20T2108-T0073  wireless / communication / ris / mi…  0.420  4.2 Innovative digital and data-dri…     0.321  —
# 2026-09-20T2108-T0020  energy / storage / grid / renewable   0.445  4.2 Innovative digital and data-dri…     0.310  —
# 2026-09-20T2108-T0094  water / evaporation / photothermal …  0.384  4.2 Innovative digital and data-dri…     0.286  —
# 2026-09-20T2108-T0092  lidar / odometry / slam / inertial    0.387  4.2 Innovative digital and data-dri…     0.324  —
# 2026-09-20T2108-T0093  fire / forest / climate / change      0.428  4.1 Innovation and adaptiveness in …     0.302  —
# 2026-09-20T2108-T0070  single-cell / cancer / nf / scrna-s…  0.396  4.2 Innovative digital and data-dri…     0.330  —
# 2026-09-20T2108-T0067  housing / supply / construction / n…  0.402  4.1 Innovation and adaptiveness in …     0.312  —
# 2026-09-20T2108-T0071  esg / corporate / firm / governance   0.460  4.1 Innovation and adaptiveness in …     0.320  —
# 2026-09-20T2108-T0075  blue economy / ocean / marine / mar…  0.453  4.1 Innovation and adaptiveness in …     0.331  —
# 2026-09-20T2108-T0106  front matter / frontmatter / back m…  0.356  SI-3 AI and Automated Decision Maki…     0.316  —
# 2026-09-20T2108-T0017  ageing / population / older / elder…  0.421  4.2 Innovative digital and data-dri…     0.304  —
# 2026-09-20T2108-T0013  climate / food / crop / agriculture   0.394  SI-3 AI and Automated Decision Maki…     0.328  —
# 2026-09-20T2108-T0057  membrane / water / desalination / s…  0.419  4.1 Innovation and adaptiveness in …     0.275  —
# 2026-09-20T2108-T0007  watermark / image / attack / dnn      0.431  4.1 Innovation and adaptiveness in …     0.303  —
# 2026-09-20T2108-T0107  influencer / authenticity / brand /…  0.477  4.2 Innovative digital and data-dri…     0.311  —
# 2026-09-20T2108-T0115  battery / electric / energy storage…  0.421  4.2 Innovative digital and data-dri…     0.315  —
# 2026-09-20T2108-T0100  breeding / crop / maize / plant       0.399  4.1 Innovation and adaptiveness in …     0.322  —
# 2026-09-20T2108-T0080  posterior / algorithm / matrix / ph…  0.381  SI-3 AI and Automated Decision Maki…     0.335  —
# 2026-09-20T2108-T0001  climate / adaptation / change / dis…  0.454  4.1 Innovation and adaptiveness in …     0.308  —
# 2026-09-20T2108-T0024  market / price / stock / volatility   0.438  SI-3 AI and Automated Decision Maki…     0.345  —
# 2026-09-20T2108-T0101  misinformation / disinformation / m…  0.421  SI-3 AI and Automated Decision Maki…     0.322  —
# 2026-09-20T2108-T0002  construction / prefabricated / hous…  0.439  SI-3 AI and Automated Decision Maki…     0.326  —
# 2026-09-20T2108-T0045  satellite / leo / constellation / n…  0.379  4.2 Innovative digital and data-dri…     0.287  —
# 2026-09-20T2108-T0083  honey / pesticide / geographical or…  0.432  SI-1 Geographical indications regis…     0.327  —
# 2026-09-20T2108-T0054  marine / fungi / ocean / biotechnol…  0.410  4.2 Innovative digital and data-dri…     0.348  —
# 2026-09-20T2108-T0064  galaxy / star / stellar / halo        0.378  4.2 Innovative digital and data-dri…     0.292  —
# 2026-09-20T2108-T0105  landslide / satellite / flood / sar   0.369  4.2 Innovative digital and data-dri…     0.284  —
# 2026-09-20T2108-T0063  water / management / security / urb…  0.433  4.1 Innovation and adaptiveness in …     0.304  —
# 2026-09-20T2108-T0089  star / tess / exoplanet / orbital     0.359  4.2 Innovative digital and data-dri…     0.297  —
# 2026-09-20T2108-T0000  quantum / qubit / entanglement / co…  0.412  4.2 Innovative digital and data-dri…     0.307  —
#
# strategic fit  range 0.350–0.730  median 0.460
# asset leverage range 0.275–0.490  median 0.348

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic                  label                                 attention  attention_tone  policy_salience  research_growth  index
# ---------------------  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# 2026-09-20T2108-T0032  automated decision-making / administ      0.862           0.397            0.793            0.819  0.776
# 2026-09-20T2108-T0039  patent / art search / prior art / re      0.259           0.690            0.750            0.845  0.632
# 2026-09-20T2108-T0091  intellectual / property protection /      0.733           0.836            0.940            0.897  0.851
# 2026-09-20T2108-T0012  patent / retrieval / prior art / cla      0.315           0.534            0.897            0.940  0.698
# 2026-09-20T2108-T0085  heritage / cultural / intellectual /      0.534           0.716            0.690            0.310  0.513
# 2026-09-20T2108-T0065  automated / decision / adm / human        0.603           0.405            0.862            0.871  0.735
# 2026-09-20T2108-T0104  enforcement intellectual / property       0.724           0.000            0.948            0.310  0.546
# 2026-09-20T2108-T0008  circular / economy / recycling / pro      0.491           0.914            0.448            0.310  0.467
# 2026-09-20T2108-T0116  earth observation / satellite / cube      0.371           0.595            0.215            0.724  0.485
# 2026-09-20T2108-T0040  competition / digital platform / dig      0.905           0.138            0.664            0.716  0.691
# 2026-09-20T2108-T0046  llm / medical / chatgpt / clinical        0.082           0.086            0.371            0.974  0.465
# 2026-09-20T2108-T0081  pricing / algorithmic / collusion /       0.504           0.241            0.121            0.991  0.555
# 2026-09-20T2108-T0014  supply chain / chain resilience / re      0.388           0.379            0.155            0.888  0.509
# 2026-09-20T2108-T0061  patent / ai / invention / inventorsh      0.819           0.155            0.931            0.905  0.798
# 2026-09-20T2108-T0044  patent / artificial intelligence / i      0.991           0.172            0.819            0.664  0.739
# 2026-09-20T2108-T0102  precision agriculture / system preci      0.379           0.655            0.517            0.776  0.584
# 2026-09-20T2108-T0010  ai / education / chatgpt / generativ      0.716           0.147            0.733            0.784  0.677
# 2026-09-20T2108-T0066  ai / public / governance / sector         0.853           0.466            1.000            0.759  0.809
# 2026-09-20T2108-T0016  circular / ce / economy / product         0.039           0.922            0.638            0.310  0.380
# 2026-09-20T2108-T0004  llm / language / task / agent             0.474           0.672            0.629            0.957  0.704
# 2026-09-20T2108-T0028  blockchain / supply chain / traceabi      0.108           0.474            0.526            0.310  0.321
# 2026-09-20T2108-T0072  cas9 / genome / crispr / editing          0.293           0.767            0.466            0.310  0.396
# 2026-09-20T2108-T0019  trust / institution / public / doctr      0.707           0.052            0.802            0.629  0.625
# 2026-09-20T2108-T0047  indigenous / intellectual / property      0.922           0.905            0.828            0.655  0.804
# 2026-09-20T2108-T0099  vaccine / covid-19 / waiver / pandem      0.655           0.612            0.776            0.310  0.557
# 2026-09-20T2108-T0027  misinformation / online / age / nudg      0.931           0.121            0.164            0.802  0.610
# 2026-09-20T2108-T0034  service delivery / digital / governm      0.750           0.267            0.974            0.862  0.785
# 2026-09-20T2108-T0111  ip / criminal / enforcement / intell      0.664           0.035            0.879            0.698  0.653
# 2026-09-20T2108-T0021  intellectual property / property rig      0.914           0.259            0.991            0.310  0.642
# 2026-09-20T2108-T0038  supply chain / chain resilience / sc      0.039           0.060            0.379            0.853  0.409
# 2026-09-20T2108-T0082  green / innovation / patent / firm        0.543           0.966            0.810            0.310  0.574
# 2026-09-20T2108-T0056  watermark / text / llm / language         0.211           0.345            0.422            1.000  0.555
# 2026-09-20T2108-T0029  indigenous / traditional knowledge /      0.565           0.888            0.845            0.310  0.579
# 2026-09-20T2108-T0043  ai / health / clinical / gdpr             0.776           0.509            0.724            0.310  0.568
# 2026-09-20T2108-T0098  wellbeing / policy / basic vision /       0.409           0.741            0.716            0.948  0.711
# 2026-09-20T2108-T0090  nanotechnology / nanoparticle / nps       0.138           0.759            0.603            0.310  0.381
# 2026-09-20T2108-T0079  learning / task / robot / policy          0.069           0.099            0.569            0.879  0.476
# 2026-09-20T2108-T0084  ai / ethic / governance / artificial      0.845           0.362            0.957            0.310  0.626
# 2026-09-20T2108-T0112  foresight / scenario planning / stra      0.345           0.698            0.552            0.310  0.423
# 2026-09-20T2108-T0003  geographical indication / gi / kente      0.810           0.793            0.655            0.681  0.726
# 2026-09-20T2108-T0114  trust / covid-19 / public / pandemic      0.108           0.112            0.888            0.310  0.363
# 2026-09-20T2108-T0053  vehicle / driving / autonomous / avs      0.621           0.388            0.388            0.836  0.615
# 2026-09-20T2108-T0069  service delivery / public service /       0.871           0.543            0.983            0.310  0.661
# 2026-09-20T2108-T0023  patent / innovation / firm / intelle      0.603           0.853            0.966            0.310  0.615
# 2026-09-20T2108-T0030  patent / citation / technology / inn      0.578           0.621            0.922            0.310  0.569
# 2026-09-20T2108-T0055  foresight / anticipatory / governanc      0.517           0.483            0.784            0.707  0.643
# 2026-09-20T2108-T0097  autonomous driving / lidar / segment      0.039           0.319            0.052            0.931  0.390
# 2026-09-20T2108-T0018  automation / worker / employment / j      0.957           0.422            0.612            0.690  0.719
# 2026-09-20T2108-T0041  supply chain / pandemic / covid-19 /      0.603           0.043            0.276            0.828  0.540
# 2026-09-20T2108-T0052  defence / innovation / military / du      0.940           0.776            0.681            0.638  0.753
# 2026-09-20T2108-T0031  blockchain / technology / smart cont      0.836           0.552            0.767            0.310  0.601
# 2026-09-20T2108-T0049  agriculture / crop / iot / farming        0.259           0.647            0.560            0.310  0.393
# 2026-09-20T2108-T0035  energy / storage / renewable / batte      0.565           0.983            0.509            0.310  0.511
# 2026-09-20T2108-T0109  housing / household / rental / dwell      0.431           0.578            0.698            0.310  0.469
# 2026-09-20T2108-T0110  valuation / valuer / briefing / avm       0.629           0.802            0.621            0.310  0.535
# 2026-09-20T2108-T0108  critical mineral / supply chain / mi      0.897           0.586            0.345            0.810  0.700
# 2026-09-20T2108-T0103  deepfake / content / ai-generated /       0.983           0.190            0.586            0.647  0.678
# 2026-09-20T2108-T0077  robot / agricultural / crop / naviga      0.138           0.448            0.397            0.733  0.445
# 2026-09-20T2108-T0095  export control / dual-use / eu / con      0.759           0.026            0.500            0.793  0.624
# 2026-09-20T2108-T0022  health / digital / dht / technology       0.784           0.526            0.759            0.310  0.581
# 2026-09-20T2108-T0005  amr / antimicrobial / sepsis / resis      0.293           0.457            0.086            0.966  0.501
# 2026-09-20T2108-T0088  regulatory policy / plc / regulatory      1.000           0.181            0.905            0.310  0.638
# 2026-09-20T2108-T0086  aerosol / satellite / emission / aod      0.039           0.491            0.362            0.310  0.264
# 2026-09-20T2108-T0042  crispr / editing / gene / cas9            0.586           0.819            0.043            0.310  0.388
# 2026-09-20T2108-T0087  dma / competition law / digital mark      0.698           0.440            0.543            0.310  0.494
# 2026-09-20T2108-T0068  earth observation / satellite / euro      0.409           0.310            0.310            0.310  0.339
# 2026-09-20T2108-T0025  recycling / plastic / waste / circul      0.345           1.000            0.336            0.310  0.408
# 2026-09-20T2108-T0051  cent / per / forecast / export earni      0.879           0.931            0.241            0.310  0.534
# 2026-09-20T2108-T0059  audio / music / speech / watermarkin      0.293           0.129            0.069            0.983  0.465
# 2026-09-20T2108-T0062  governance / nature-based / urban /       0.168           0.879            0.836            0.310  0.459
# 2026-09-20T2108-T0026  blue economy / ocean / marine / econ      0.793           0.707            0.172            0.310  0.467
# 2026-09-20T2108-T0036  cancer / disease / mri / learning         0.345           0.569            0.250            0.310  0.337
# 2026-09-20T2108-T0033  drought / catchment / water / stream      0.108           0.280            0.198            0.922  0.437
# 2026-09-20T2108-T0037  battery / energy storage / lib / lit      0.685           0.871            0.302            0.310  0.485
# 2026-09-20T2108-T0015  trust / public / institution / citiz      0.457           0.069            0.914            0.310  0.467
# 2026-09-20T2108-T0048  hydrogen / electrolysis / energy / s      0.526           0.974            0.129            0.310  0.409
# 2026-09-20T2108-T0113  graph / gnn / neural / network            0.345           0.810            0.224            0.310  0.359
# 2026-09-20T2108-T0078  image / inpainting / learning / data      0.168           0.302            0.112            0.310  0.221
# 2026-09-20T2108-T0074  water / treatment / removal / adsorb      0.004           0.215            0.138            0.310  0.169
# 2026-09-20T2108-T0058  satellite / image / eo / earth obser      0.168           0.336            0.190            0.310  0.243
# 2026-09-20T2108-T0009  additive manufacturing / material /       0.444           0.724            0.647            0.310  0.477
# 2026-09-20T2108-T0050  employment / skill / youth / graduat      0.888           0.560            0.440            0.310  0.540
# 2026-09-20T2108-T0060  kilometre km / square kilometre / af      0.211           0.009            0.095            0.310  0.195
# 2026-09-20T2108-T0096  surgical / robotic / surgery / surge      0.211           0.681            0.207            0.310  0.300
# 2026-09-20T2108-T0006  synthetic biology / gene / cell / me      0.741           0.733            0.267            0.310  0.477
# 2026-09-20T2108-T0011  loneliness / social isolation / ment      0.138           0.099            0.319            0.310  0.237
# 2026-09-20T2108-T0076  table content / note / list illustra      0.802           0.293            0.871            0.310  0.585
# 2026-09-20T2108-T0073  wireless / communication / ris / mim      0.211           0.828            0.431            0.310  0.370
# 2026-09-20T2108-T0020  energy / storage / grid / renewable       0.422           0.991            0.578            0.310  0.486
# 2026-09-20T2108-T0094  water / evaporation / photothermal /      0.259           0.957            0.060            0.310  0.312
# 2026-09-20T2108-T0092  lidar / odometry / slam / inertial        0.108           0.634            0.284            0.310  0.283
# 2026-09-20T2108-T0093  fire / forest / climate / change          0.259           0.280            0.259            0.310  0.279
# 2026-09-20T2108-T0070  single-cell / cancer / nf / scrna-se      0.672           0.784            0.004            0.310  0.401
# 2026-09-20T2108-T0067  housing / supply / construction / nb      0.767           0.431            0.103            0.750  0.565
# 2026-09-20T2108-T0071  esg / corporate / firm / governance       0.345           0.517            0.853            0.310  0.473
# 2026-09-20T2108-T0075  blue economy / ocean / marine / mari      0.211           0.750            0.457            0.767  0.529
# 2026-09-20T2108-T0106  front matter / frontmatter / back ma      0.552           0.414            0.534            0.310  0.446
# 2026-09-20T2108-T0017  ageing / population / older / elderl      0.638           0.500            0.328            0.741  0.585
# 2026-09-20T2108-T0013  climate / food / crop / agriculture       0.647           0.603            0.672            0.310  0.529
# 2026-09-20T2108-T0057  membrane / water / desalination / se      0.168           0.897            0.293            0.310  0.333
# 2026-09-20T2108-T0007  watermark / image / attack / dnn          0.397           0.328            0.147            0.310  0.299
# 2026-09-20T2108-T0107  influencer / authenticity / brand /       0.685           0.017            0.405            0.310  0.408
# 2026-09-20T2108-T0115  battery / electric / energy storage       0.444           0.948            0.474            0.310  0.463
# 2026-09-20T2108-T0100  breeding / crop / maize / plant           0.315           0.845            0.414            0.310  0.399
# 2026-09-20T2108-T0080  posterior / algorithm / matrix / pha      0.004           0.215            0.078            0.310  0.154
# 2026-09-20T2108-T0001  climate / adaptation / change / disa      0.948           0.371            0.741            0.310  0.606
# 2026-09-20T2108-T0024  market / price / stock / volatility       0.966           0.862            0.707            0.310  0.661
# 2026-09-20T2108-T0101  misinformation / disinformation / me      0.828           0.353            0.595            0.672  0.662
# 2026-09-20T2108-T0002  construction / prefabricated / housi      0.474           0.250            0.491            0.310  0.394
# 2026-09-20T2108-T0045  satellite / leo / constellation / ne      0.259           0.634            0.181            0.914  0.516
# 2026-09-20T2108-T0083  honey / pesticide / geographical ori      0.504           0.078            0.353            0.310  0.350
# 2026-09-20T2108-T0054  marine / fungi / ocean / biotechnolo      0.211           0.664            0.035            0.310  0.258
# 2026-09-20T2108-T0064  galaxy / star / stellar / halo            0.082           0.215            0.026            0.310  0.165
# 2026-09-20T2108-T0105  landslide / satellite / flood / sar       0.039           0.215            0.017            0.310  0.150
# 2026-09-20T2108-T0063  water / management / security / urba      0.474           0.164            0.483            0.310  0.382
# 2026-09-20T2108-T0089  star / tess / exoplanet / orbital         0.039           0.215            0.004            0.310  0.147
# 2026-09-20T2108-T0000  quantum / qubit / entanglement / com      0.974           0.940            0.233            0.310  0.561

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 117 topics — largest deviation 8.37e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 117 of 117 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  automated decision-making / administrative  H1  strong  0.681  0.714  0.472  0.776      0.928
#   2  patent / art search / prior art / retrieva  H2  strong  0.816  0.530  0.448  0.632      0.901
#   3  intellectual / property protection / firm   H2  weak    0.659  0.646  0.406  0.851      0.861
#   4  patent / retrieval / prior art / classific  H2  strong  0.674  0.543  0.458  0.698      0.859
#   5  heritage / cultural / intellectual / prope  H1  weak    0.756  0.522  0.378  0.513      0.844
#   6  automated / decision / adm / human          H1  weak    0.531  0.728  0.460  0.735      0.822
#   7  enforcement intellectual / property right   H1  weak    0.683  0.552  0.368  0.546      0.807
#   8  circular / economy / recycling / product d  H1  strong  0.760  0.501  0.359  0.467      0.786
#   9  earth observation / satellite / cube / ima  H1  noise   0.715  0.488  0.389  0.485      0.783
#  10  competition / digital platform / digital m  H2  strong  0.570  0.626  0.378  0.691      0.781
#  11  llm / medical / chatgpt / clinical          H1  strong  0.786  0.486  0.352  0.465      0.760
#  12  pricing / algorithmic / collusion / compet  H3  weak    0.687  0.490  0.369  0.555      0.759
#  13  supply chain / chain resilience / resilien  H1  strong  0.850  0.495  0.343  0.509      0.747
#  14  patent / ai / invention / inventorship      H1  strong  0.507  0.609  0.456  0.798      0.745
#  15  patent / artificial intelligence / invento  H2  strong  0.441  0.704  0.472  0.739      0.730
#  16  precision agriculture / system precision /  H2  noise   0.747  0.470  0.355  0.584      0.710
#  17  ai / education / chatgpt / generative       H1  strong  0.602  0.518  0.361  0.677      0.704
#  18  ai / public / governance / sector           H1  weak    0.413  0.696  0.426  0.809      0.694
#  19  circular / ce / economy / product           H1  strong  0.583  0.490  0.370  0.380      0.691
#  20  llm / language / task / agent               H3  strong  0.639  0.505  0.350  0.704      0.691
#  21  blockchain / supply chain / traceability /  H1  strong  0.571  0.486  0.380  0.321      0.689
#  22  cas9 / genome / crispr / editing            H1  weak    0.747  0.472  0.338  0.396      0.677
#  23  trust / institution / public / doctrine     H2  latent  0.641  0.530  0.326  0.625      0.662
#  24  indigenous / intellectual / property / cul  H1  latent  0.453  0.554  0.402  0.804      0.651
#  25  vaccine / covid-19 / waiver / pandemic      H1  weak    0.491  0.514  0.392  0.557      0.647
#  26  misinformation / online / age / nudging     H1  strong  0.664  0.475  0.348  0.610      0.645
#  27  service delivery / digital / government /   H2  strong  0.504  0.685  0.347  0.785      0.645
#  28  ip / criminal / enforcement / intellectual  H3  weak    0.525  0.523  0.352  0.653      0.637
#  29  intellectual property / property right / p  H1  latent  0.403  0.562  0.418  0.642      0.637
#  30  supply chain / chain resilience / sc / dis  H1  strong  0.610  0.484  0.349  0.409      0.631
#  31  green / innovation / patent / firm          H1  weak    0.351  0.618  0.406  0.574      0.627
#  32  watermark / text / llm / language           H2  strong  0.734  0.444  0.348  0.555      0.611
#  33  indigenous / traditional knowledge / intel  H2  latent  0.322  0.596  0.451  0.579      0.609
#  34  ai / health / clinical / gdpr               H1  latent  0.346  0.566  0.425  0.568      0.608
#  35  wellbeing / policy / basic vision / govern  H1  weak    0.759  0.453  0.319  0.711      0.606
#  36  nanotechnology / nanoparticle / nps / nano  H1  noise   0.588  0.445  0.374  0.381      0.606
#  37  learning / task / robot / policy            H2  weak    0.686  0.484  0.316  0.476      0.604
#  38  ai / ethic / governance / artificial intel  H1  noise   0.222  0.730  0.458  0.626      0.596
#  39  foresight / scenario planning / strategic   H1  noise   0.306  0.653  0.391  0.423      0.593
#  40  geographical indication / gi / kente / pro  H1  latent  0.349  0.638  0.368  0.726      0.583
#  41  trust / covid-19 / public / pandemic        H1  weak    0.660  0.459  0.328  0.363      0.580
#  42  vehicle / driving / autonomous / avs        H2  strong  0.633  0.465  0.326  0.615      0.562
#  43  service delivery / public service / digita  H2  noise   0.408  0.694  0.332  0.661      0.560
#  44  patent / innovation / firm / intellectual   H1  latent  0.162  0.644  0.442  0.615      0.557
#  45  patent / citation / technology / innovatio  H1  latent  0.231  0.561  0.490  0.569      0.556
#  46  foresight / anticipatory / governance / po  H2  latent  0.305  0.619  0.371  0.643      0.553
#  47  autonomous driving / lidar / segmentation   H2  weak    0.592  0.445  0.351  0.390      0.550
#  48  automation / worker / employment / job      H2  strong  0.279  0.533  0.411  0.719      0.538
#  49  supply chain / pandemic / covid-19 / food   H1  strong  0.609  0.423  0.358  0.540      0.530
#  50  defence / innovation / military / dual-use  H2  latent  0.311  0.595  0.364  0.753      0.528
#  51  blockchain / technology / smart contract /  H1  latent  0.244  0.533  0.405  0.601      0.517
#  52  agriculture / crop / iot / farming          H1  latent  0.481  0.468  0.360  0.393      0.516
#  53  energy / storage / renewable / battery      H1  latent  0.570  0.463  0.323  0.511      0.513
#  54  housing / household / rental / dwelling     H1  weak    0.674  0.374  0.361  0.469      0.507
#  55  valuation / valuer / briefing / avm         H2  noise   0.359  0.490  0.366  0.535      0.501
#  56  critical mineral / supply chain / mineral   H3  weak    0.519  0.452  0.351  0.700      0.500
#  57  deepfake / content / ai-generated / aigc    H1  weak    0.350  0.485  0.373  0.678      0.496
#  58  robot / agricultural / crop / navigation    H1  noise   0.485  0.457  0.353  0.445      0.491
#  59  export control / dual-use / eu / control r  H1  weak    0.500  0.452  0.352  0.624      0.489
#  60  health / digital / dht / technology         H1  latent  0.277  0.520  0.372  0.581      0.487
#  61  amr / antimicrobial / sepsis / resistance   H3  strong  0.743  0.429  0.297  0.501      0.481
#  62  regulatory policy / plc / regulatory refor  H1  noise   0.258  0.509  0.378  0.638      0.479
#  63  aerosol / satellite / emission / aod        H1  weak    0.522  0.427  0.362  0.264      0.479
#  64  crispr / editing / gene / cas9              H1  strong  0.724  0.419  0.315  0.388      0.477
#  65  dma / competition law / digital market / d  H1  noise   0.242  0.501  0.390  0.494      0.472
#  66  earth observation / satellite / european /  H1  weak    0.715  0.417  0.314  0.339      0.465
#  67  recycling / plastic / waste / circular      H1  strong  0.563  0.451  0.318  0.408      0.461
#  68  cent / per / forecast / export earning      H1  strong  0.550  0.398  0.366  0.534      0.453
#  69  audio / music / speech / watermarking       H3  strong  0.626  0.413  0.330  0.465      0.452
#  70  governance / nature-based / urban / nbs     H1  weak    0.364  0.485  0.350  0.459      0.449
#  71  blue economy / ocean / marine / economy in  H1  strong  0.549  0.431  0.335  0.467      0.447
#  72  cancer / disease / mri / learning           H1  latent  0.304  0.499  0.359  0.337      0.444
#  73  drought / catchment / water / streamflow    H1  strong  0.632  0.407  0.328  0.437      0.440
#  74  battery / energy storage / lib / lithium-i  H1  latent  0.512  0.448  0.326  0.485      0.428
#  75  trust / public / institution / citizen      H1  latent  0.349  0.535  0.317  0.467      0.426
#  76  hydrogen / electrolysis / energy / storage  H1  latent  0.516  0.460  0.311  0.409      0.421
#  77  graph / gnn / neural / network              H1  noise   0.468  0.418  0.371  0.359      0.417
#  78  image / inpainting / learning / dataset     H1  noise   0.559  0.436  0.315  0.221      0.409
#  79  water / treatment / removal / adsorbent     H1  weak    0.706  0.402  0.289  0.169      0.409
#  80  satellite / image / eo / earth observation  H1  noise   0.400  0.442  0.365  0.243      0.408
#  81  additive manufacturing / material / bone /  H1  latent  0.403  0.471  0.329  0.477      0.403
#  82  employment / skill / youth / graduate       H2  latent  0.338  0.483  0.348  0.540      0.402
#  83  kilometre km / square kilometre / africa /  H2  weak    0.754  0.350  0.295  0.195      0.392
#  84  surgical / robotic / surgery / surgeon      H1  noise   0.395  0.449  0.351  0.300      0.392
#  85  synthetic biology / gene / cell / metaboli  H1  strong  0.430  0.450  0.342  0.477      0.386
#  86  loneliness / social isolation / mental / h  H1  strong  0.633  0.400  0.304  0.237      0.377
#  87  table content / note / list illustration /  H1  noise   0.438  0.437  0.348  0.585      0.375
#  88  wireless / communication / ris / mimo       H1  noise   0.535  0.420  0.321  0.370      0.375
#  89  energy / storage / grid / renewable         H1  latent  0.496  0.445  0.310  0.486      0.356
#  90  water / evaporation / photothermal / solar  H1  weak    0.667  0.384  0.286  0.312      0.356
#  91  lidar / odometry / slam / inertial          H1  noise   0.561  0.387  0.324  0.283      0.352
#  92  fire / forest / climate / change            H1  noise   0.546  0.428  0.302  0.279      0.351
#  93  single-cell / cancer / nf / scrna-seq       H1  weak    0.522  0.396  0.330  0.401      0.347
#  94  housing / supply / construction / nbsp      H2  weak    0.568  0.402  0.312  0.565      0.345
#  95  esg / corporate / firm / governance         H1  noise   0.393  0.460  0.320  0.473      0.344
#  96  blue economy / ocean / marine / maritime    H1  weak    0.327  0.453  0.331  0.529      0.328
#  97  front matter / frontmatter / back matter /  H1  noise   0.576  0.356  0.316  0.446      0.327
#  98  ageing / population / older / elderly       H1  latent  0.509  0.421  0.304  0.585      0.314
#  99  climate / food / crop / agriculture         H1  strong  0.497  0.394  0.328  0.529      0.306
# 100  membrane / water / desalination / separati  H1  weak    0.522  0.419  0.275  0.333      0.295
# 101  watermark / image / attack / dnn            H1  latent  0.465  0.431  0.303  0.299      0.283
# 102  influencer / authenticity / brand / tiktok  H1  noise   0.289  0.477  0.311  0.408      0.281
# 103  battery / electric / energy storage / bms   H1  noise   0.457  0.421  0.315  0.463      0.278
# 104  breeding / crop / maize / plant             H1  noise   0.467  0.399  0.322  0.399      0.270
# 105  posterior / algorithm / matrix / phase ret  H1  noise   0.450  0.381  0.335  0.154      0.269
# 106  climate / adaptation / change / disaster    H1  latent  0.320  0.454  0.308  0.606      0.261
# 107  market / price / stock / volatility         H1  latent  0.155  0.438  0.345  0.661      0.232
# 108  misinformation / disinformation / media /   H1  noise   0.328  0.421  0.322  0.662      0.224
# 109  construction / prefabricated / housing / m  H1  latent  0.249  0.439  0.326  0.394      0.224
# 110  satellite / leo / constellation / network   H1  strong  0.487  0.379  0.287  0.516      0.204
# 111  honey / pesticide / geographical origin /   H1  noise   0.224  0.432  0.327  0.350      0.200
# 112  marine / fungi / ocean / biotechnological   H1  latent  0.231  0.410  0.348  0.258      0.199
# 113  galaxy / star / stellar / halo              H1  noise   0.468  0.378  0.292  0.165      0.195
# 114  landslide / satellite / flood / sar         H1  noise   0.463  0.369  0.284  0.150      0.166
# 115  water / management / security / urban       H1  noise   0.258  0.433  0.304  0.382      0.165
# 116  star / tess / exoplanet / orbital           H1  noise   0.434  0.359  0.297  0.147      0.158
# 117  quantum / qubit / entanglement / computing  H1  latent  0.320  0.412  0.307  0.561      0.150

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.460, leverage 0.348).
#
# ACT (46)
#       1  automated decision-making / administrative / accountability
#       2  patent / art search / prior art / retrieval
#       3  intellectual / property protection / firm / innovation
#       4  patent / retrieval / prior art / classification
#       5  heritage / cultural / intellectual / property
#       6  automated / decision / adm / human
#       7  enforcement intellectual / property right / intellectual pro
#       8  circular / economy / recycling / product design
#       9  earth observation / satellite / cube / imagery
#      10  competition / digital platform / digital market / policy
#      11  llm / medical / chatgpt / clinical
#      12  pricing / algorithmic / collusion / competition
#      14  patent / ai / invention / inventorship
#      15  patent / artificial intelligence / inventorship / law
#      16  precision agriculture / system precision / agriculture food
#      17  ai / education / chatgpt / generative
#      18  ai / public / governance / sector
#      19  circular / ce / economy / product
#      20  llm / language / task / agent
#      21  blockchain / supply chain / traceability / technology
#      24  indigenous / intellectual / property / cultural
#      25  vaccine / covid-19 / waiver / pandemic
#      26  misinformation / online / age / nudging
#      28  ip / criminal / enforcement / intellectual property
#      29  intellectual property / property right / property law / righ
#      30  supply chain / chain resilience / sc / disruption
#      31  green / innovation / patent / firm
#      33  indigenous / traditional knowledge / intellectual / cultural
#      34  ai / health / clinical / gdpr
#      38  ai / ethic / governance / artificial intelligence
#      39  foresight / scenario planning / strategic / scenario thinkin
#      40  geographical indication / gi / kente / product
#      44  patent / innovation / firm / intellectual property
#      45  patent / citation / technology / innovation
#      46  foresight / anticipatory / governance / policy
#      48  automation / worker / employment / job
#      50  defence / innovation / military / dual-use
#      51  blockchain / technology / smart contract / fintech
#      52  agriculture / crop / iot / farming
#      55  valuation / valuer / briefing / avm
#      57  deepfake / content / ai-generated / aigc
#      60  health / digital / dht / technology
#      62  regulatory policy / plc / regulatory reform / government
#      65  dma / competition law / digital market / draft
#      70  governance / nature-based / urban / nbs
#      72  cancer / disease / mri / learning
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (13)
#      13  supply chain / chain resilience / resilience supply / chain
#      22  cas9 / genome / crispr / editing
#      23  trust / institution / public / doctrine
#      27  service delivery / digital / government / public service
#      37  learning / task / robot / policy
#      42  vehicle / driving / autonomous / avs
#      43  service delivery / public service / digital / government
#      53  energy / storage / renewable / battery
#      75  trust / public / institution / citizen
#      81  additive manufacturing / material / bone / printing
#      82  employment / skill / youth / graduate
#      95  esg / corporate / firm / governance
#     102  influencer / authenticity / brand / tiktok
#
# CAPABILITY LOOKING FOR A PROBLEM (13)
#      36  nanotechnology / nanoparticle / nps / nanomaterial
#      47  autonomous driving / lidar / segmentation / object
#      49  supply chain / pandemic / covid-19 / food
#      54  housing / household / rental / dwelling
#      56  critical mineral / supply chain / mineral supply / chain res
#      58  robot / agricultural / crop / navigation
#      59  export control / dual-use / eu / control regulation
#      63  aerosol / satellite / emission / aod
#      68  cent / per / forecast / export earning
#      77  graph / gnn / neural / network
#      80  satellite / image / eo / earth observation
#      84  surgical / robotic / surgery / surgeon
#     112  marine / fungi / ocean / biotechnological
#
# WATCH (45)
#      32  watermark / text / llm / language
#      35  wellbeing / policy / basic vision / government
#      41  trust / covid-19 / public / pandemic
#      61  amr / antimicrobial / sepsis / resistance
#      64  crispr / editing / gene / cas9
#      66  earth observation / satellite / european / observation polic
#      67  recycling / plastic / waste / circular
#      69  audio / music / speech / watermarking
#      71  blue economy / ocean / marine / economy indian
#      73  drought / catchment / water / streamflow
#      74  battery / energy storage / lib / lithium-ion
#      76  hydrogen / electrolysis / energy / storage
#      78  image / inpainting / learning / dataset
#      79  water / treatment / removal / adsorbent
#      83  kilometre km / square kilometre / africa / population millio
#      85  synthetic biology / gene / cell / metabolic
#      86  loneliness / social isolation / mental / health
#      87  table content / note / list illustration / list author
#      88  wireless / communication / ris / mimo
#      89  energy / storage / grid / renewable
#      90  water / evaporation / photothermal / solar
#      91  lidar / odometry / slam / inertial
#      92  fire / forest / climate / change
#      93  single-cell / cancer / nf / scrna-seq
#      94  housing / supply / construction / nbsp
#      96  blue economy / ocean / marine / maritime
#      97  front matter / frontmatter / back matter / prelim
#      98  ageing / population / older / elderly
#      99  climate / food / crop / agriculture
#     100  membrane / water / desalination / separation
#     101  watermark / image / attack / dnn
#     103  battery / electric / energy storage / bms
#     104  breeding / crop / maize / plant
#     105  posterior / algorithm / matrix / phase retrieval
#     106  climate / adaptation / change / disaster
#     107  market / price / stock / volatility
#     108  misinformation / disinformation / media / fake
#     109  construction / prefabricated / housing / modular
#     110  satellite / leo / constellation / network
#     111  honey / pesticide / geographical origin / food
#     113  galaxy / star / stellar / halo
#     114  landslide / satellite / flood / sar
#     115  water / management / security / urban
#     116  star / tess / exoplanet / orbital
#     117  quantum / qubit / entanglement / computing

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = '2026-09-20T2108-T0032'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  automated decision-making / administrative / accountability / ai
# 301 documents · 2018–2026 · H1 · strong
#
# Defining terms: automated decision-making, decision-making, automated, administrative, accountability, automated decision, ai, administrative decision-making, administrative law, governmental automated, decision, government
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  █████
#      2019     1  █
#      2020     7  ████████
#      2021     7  ████████
#      2022     5  ██████
#      2023    21  ████████████████████████  ← burst
#      2024     8  █████████  ← burst
#      2025    12  ██████████████  ← burst
#      2026    10  ███████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Situating the Rule of Law in the Context of Automated Decision-Making
#     crossref · 2023 · The Rule of Law and Automated Decision-Making
#     https://doi.org/10.1007/978-3-031-30142-1_2
#   • Automated Decision-Making and the Law
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_3
#   • Confronting the Legal Challenges of Governmental Automated Decision-Making
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_5
#   • Automated Decision-making
#     crossref · 2025 · Smart Court
#     https://doi.org/10.1017/9781009319232.007
#   • Contesting Automated Decisions: Limits to the Right to Human Intervention in Automated Decision-
#     crossref · 2018 · SSRN Electronic Journal
#     https://doi.org/10.2139/ssrn.3264189

# %%
TOPIC_ID = '2026-09-20T2108-T0039'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  patent / art search / prior art / retrieval
# 76 documents · 2018–2026 · H2 · strong
#
# Defining terms: patent, art search, prior art, retrieval, patent retrieval, patent prior, art, prior, search, retrieval patent, information retrieval, keyword-based
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  ███████
#      2019     6  ██████████
#      2020     7  ████████████
#      2021     4  ███████
#      2022    11  ███████████████████
#      2023     8  ██████████████
#      2024     8  ██████████████
#      2025     5  █████████
#      2026    14  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • On the use of Intelligent Information Retrieval in Patent Prior-Art Search
#     crossref · 2024 · Roshd -e- Fanavari
#     https://doi.org/10.61186/jstpi.44174.20.77.24
#   • Challenges in Patent Information Retrieval
#     crossref · 2020 · The Information Retrieval Series
#     https://doi.org/10.1007/978-981-15-5554-1_4
#   • A Recapitulation of Patent Retrieval
#     crossref · 2024 · Journal of Intellectual Property Rights
#     https://doi.org/10.56042/jipr.v29i1.1435
#   • Patent retrieval: a literature review
#     crossref · 2019 · Knowledge and Information Systems
#     https://doi.org/10.1007/s10115-018-1322-7
#   • An Abstract-Level Patent Retrieval Model
#     crossref · 2023 · Proceedings of the 4th International Conference on Artificial Intelligence and
#     https://doi.org/10.1145/3652628.3652710

# %%
TOPIC_ID = '2026-09-20T2108-T0091'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  intellectual / property protection / firm / innovation
# 129 documents · 2018–2026 · H2 · weak
#
# Defining terms: intellectual, intellectual property, property protection, property, protection, firm, innovation, corporate, property right, patent, digital, financing
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██
#      2019     1  ██
#      2020     0
#      2021     2  ███
#      2022     3  █████
#      2023     5  ████████
#      2024     2  ███
#      2025    15  ████████████████████████  ← burst
#      2026     8  █████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Intellectual property litigation, financing constraints, and firms’ innovation resilience
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.109085
#   • Intellectual property protection and firm innovation capability
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2026.109559
#   • Legal infrastructures for firm innovation: Effects of intellectual property protection in the er
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2024.106343
#   • Digital finance development, intellectual property protection, and regional innovation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108217
#   • Intellectual property protection and enterprise innovation: Evidence from China
#     crossref · 2024 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2024.105253

# %%
TOPIC_ID = '2026-09-20T2108-T0012'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  patent / retrieval / prior art / classification
# 142 documents · 2018–2026 · H2 · strong
#
# Defining terms: patent, retrieval, patent classification, prior art, patent retrieval, classification, document, search, language, patent document, patent claim, claim
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     5  █████
#      2019    12  ███████████
#      2020     8  ███████
#      2021    10  █████████
#      2022    16  ███████████████
#      2023    16  ███████████████
#      2024    17  ████████████████
#      2025    26  ████████████████████████  ← burst
#      2026    20  ██████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Innovating Patent Retrieval: A Comprehensive Review of Techniques, Trends, and Challenges in Pri
#     crossref · 2024 · Applied System Innovation
#     https://doi.org/10.3390/asi7050091
#   • Innovating Patent Retrieval: A Comprehensive Review of Techniques, Trends, and Challenges in Pri
#     openalex · 2024 · Applied System Innovation
#     https://doi.org/10.3390/asi7050091
#   • Natural language processing in the patent domain: a survey
#     crossref · 2025 · Artificial Intelligence Review
#     https://doi.org/10.1007/s10462-025-11168-z
#   • Natural language processing in the patent domain: a survey
#     openalex · 2025 · Artificial Intelligence Review
#     https://doi.org/10.1007/s10462-025-11168-z
#   • The Harvard USPTO Patent Dataset: A Large-Scale, Well-Structured, and Multi-Purpose Corpus of Pa
#     arxiv · 2022 · arXiv
#     http://arxiv.org/abs/2207.04043v1

# %%
TOPIC_ID = '2026-09-20T2108-T0085'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  heritage / cultural / intellectual / property
# 75 documents · 2018–2025 · H1 · weak
#
# Defining terms: heritage, cultural heritage, cultural, property cultural, intellectual, intellectual property, property, intangible cultural, cultural property, handbook intellectual, heritage intellectual, intangible
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  █
#      2019     3  ███
#      2020     2  ██
#      2021     3  ███
#      2022    28  ████████████████████████  ← burst
#      2023     1  █
#      2024     0
#      2025     1  █
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Research Handbook on Intellectual Property and Cultural Heritage
#     crossref · 2022 · edited-book
#     https://doi.org/10.4337/9781800376915
#   • Intellectual Property Rights and Intangible Cultural Heritage
#     crossref · 2022 · Munich Studies on Innovation and Competition
#     https://doi.org/10.1007/978-3-031-08104-0_4
#   • Introduction to the Research Handbook on Intellectual Property and Cultural Heritage: Overview o
#     crossref · 2022 · Research Handbook on Intellectual Property and Cultural Heritage
#     https://doi.org/10.4337/9781800376915/book-part-9781800376915-5
#   • Introduction to the Research Handbook on Intellectual Property and Cultural Heritage: Overview o
#     crossref · 2022 · Research Handbook on Intellectual Property and Cultural Heritage
#     https://doi.org/10.4337/9781800376915.00005
#   • Intangible cultural heritage, intellectual property and the public domain
#     crossref · 2022 · Research Handbook on Intellectual Property and Cultural Heritage
#     https://doi.org/10.4337/9781800376915/book-part-9781800376915-26

# %%
TOPIC_ID = '2026-09-20T2108-T0065'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  automated / decision / adm / human
# 101 documents · 2018–2026 · H1 · weak
#
# Defining terms: automated, automated decision-making, decision, adm, human, decision-making, automated decision, ai, law, system, algorithm, algorithmic
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██
#      2019     4  █████████
#      2020     4  █████████
#      2021     6  █████████████
#      2022     6  █████████████
#      2023     6  █████████████
#      2024     5  ███████████
#      2025     7  ███████████████  ← burst
#      2026    11  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Administrative law and the machines of government: judicial review of automated public-sector de
#     crossref · 2019 · Legal Studies
#     https://doi.org/10.1017/lst.2019.9
#   • Automated Decision-Making in EU Public Law and Governance
#     crossref · 2024 · Governance of Automated Decision-Making and EU Law
#     https://doi.org/10.1093/9780198919575.003.0011
#   • Reviewable Automated Decision-Making
#     crossref · 2020 · posted-content
#     https://doi.org/10.2139/ssrn.3689166
#   • Natural Justice in Automated Decision-Making: Algorithms and Audi-Alteram Partem Rule
#     crossref · 2026 · posted-content
#     https://doi.org/10.2139/ssrn.6070726
#   • Rethinking Administrative Discretion in the Age of Automated Decision-Making: Accountability and
#     crossref · 2026 · Lex Journal : Kajian Hukum dan Keadilan
#     https://doi.org/10.25139/lex.v10is1.12666

# %%
TOPIC_ID = '2026-09-20T2108-T0104'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  enforcement intellectual / property right / intellectual property / right eu
# 120 documents · 2018–2026 · H1 · weak
#
# Defining terms: enforcement intellectual, property right, intellectual property, enforcement, intellectual, right, property, right eu, eu member, ireland, member state, member
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ██  ← burst
#      2019    28  ████████████████████████  ← burst
#      2020     1  █
#      2021     0
#      2022     1  █
#      2023     0
#      2024     0
#      2025     0
#      2026     1  █
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Enforcement of Intellectual Property Rights in the EU Member States
#     crossref · 2019 · book
#     https://doi.org/10.1017/9781780687827
#   • Enforcement of intellectual property rights
#     crossref · 2022 · Seville’s EU Intellectual Property Law and Policy
#     https://doi.org/10.4337/9781788976404.00016
#   • Enforcement of Intellectual Property Rights in the Czech Republic
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.009
#   • Enforcement of Intellectual Property Rights in Slovakia
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.027
#   • Enforcement of Intellectual Property Rights in Hungary
#     crossref · 2019 · Enforcement of Intellectual Property Rights in the EU Member States
#     https://doi.org/10.1017/9781780687827.016

# %%
TOPIC_ID = '2026-09-20T2108-T0008'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  circular / economy / recycling / product design
# 193 documents · 2018–2026 · H1 · strong
#
# Defining terms: circular, circular economy, economy, recycling, product design, product, design, recycling circular, waste, plastic, circular product, plastic recycling
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018    10  ████████
#      2019    21  █████████████████
#      2020    24  ███████████████████
#      2021    18  ██████████████
#      2022    11  █████████
#      2023    19  ███████████████
#      2024    30  ████████████████████████  ← burst
#      2025    20  ████████████████
#      2026    11  █████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Design for recycling: The circular economy starts here
#     crossref · 2020 · MRS Bulletin
#     https://doi.org/10.1557/mrs.2020.314
#   • Waste Material Recycling in the Circular Economy - Challenges and Developments
#     crossref · 2022 · edited-book
#     https://doi.org/10.5772/intechopen.95163
#   • Sustainable Product Design Enabling Circular Economy
#     crossref · 2025 · MTZ worldwide
#     https://doi.org/10.1007/s38313-025-2131-5
#   • Recycling and Business Model(s) in the Circular Economy
#     crossref · 2024 · Recycling, a Challenge for the Circular Economy
#     https://doi.org/10.1002/9781394325757.ch3
#   • Circular Economy and Sustainability: the Past, the Present and the Future Directions
#     openalex · 2021 · Circular Economy and Sustainability
#     https://doi.org/10.1007/s43615-021-00030-3

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
