# %% [markdown]
# # IPAVentures horizon scan — run `verify-bertopic`
#
# Generated 2026-08-31 10:58 UTC by `python -m src.notebook --run-id verify-bertopic`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = 'verify-bertopic'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    verify-bertopic
# database  /home/user/BigThink/data/bigthink.duckdb
# documents 7,501

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
if _method == "bertopic":
    # Under BERTopic the similarity threshold does not cluster anything —
    # HDBSCAN works on density in UMAP space and takes no cosine cut-off. It is
    # read for one purpose only: attaching documents from non-forming sources
    # to the nearest finished topic. Labelled for what it does, so a reviewer
    # is not left comparing it against a clustering threshold from another run.
    print("Attachment thresh :", _thresh.get(_backend, "not recorded"),
          f"x ratio {_topics_cfg.get('attachment_threshold_ratio', 0.6)}")
    # THE SEED. UMAP's initialisation is stochastic, so this is the difference
    # between a topic set another analyst can reproduce and one they cannot.
    # Printed from the run's own snapshot, never from today's config file.
    _bt = _topics_cfg.get("bertopic") or {}
    print("BERTopic seed     :", _bt.get("random_state", "NOT RECORDED"))
    print("BERTopic UMAP     :",
          f"n_neighbors={_bt.get('n_neighbors')}, "
          f"n_components={_bt.get('n_components')}, "
          f"min_dist={_bt.get('min_dist')}, metric={_bt.get('metric')}")
    print("BERTopic HDBSCAN  :",
          f"min_cluster_size={_bt.get('min_cluster_size') or _topics_cfg.get('min_topic_size')}, "
          f"min_samples={_bt.get('min_samples')}, "
          f"selection={_bt.get('cluster_selection_method')}")
    if not isinstance(_bt.get("random_state"), int):
        print("\n  WARNING: no seed recorded for this run. UMAP is stochastic, "
              "so the topics below cannot be reproduced exactly, even from this "
              "same corpus and config.")
else:
    print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : bge
# Clustering method : bertopic
# Attachment thresh : 0.9 x ratio 0.6
# BERTopic seed     : 42
# BERTopic UMAP     : n_neighbors=15, n_components=5, min_dist=0.0, metric=cosine
# BERTopic HDBSCAN  : min_cluster_size=8, min_samples=None, selection=eom
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status     in  out   seconds  message
# ------------------------  -------  ----  ---  --------  ----------------------------------------------------------------
# stage0_strategy           success     —   34     0.400  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage2_emergence          success  7501  114  1148.200  114 topics from 7501 documents across 9 slices (2018-2026); 25 …
# stage5_synthesis          success   114  114    20.900  ranked 114 topics; outputs written
# stage3_scoring            success   114  114    19.800  scored 114 topics; mean fit 0.595, mean leverage 0.366, 114 cri…
# stage4_opportunity_index  success   114  114     0.600  indexed 99 of 114 topics (15 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# crossref        2437        2018       2026      13
# gdelt           2317        2026       2026      16
# arxiv           2018        2018       2026       9
# openalex         581        2018       2026      20
# datagovau        148        2022       2026       3
#
# What this run's collection actually did (per source query):
#
# source  status  queries  records
# ------  ------  -------  -------
# (no rows)

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018        509
# 2019        570
# 2020        604
# 2021        548
# 2022        527
# 2023        561
# 2024        581
# 2025        649
# 2026       2952
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       3239
# Political           1438
# Economic            1009
# Legal                908
# Values               424
# Social               334
# Environmental        149

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                   STEEPV         documents  sources
# ---------------------------  -------------  ---------  -------
# ai_governance_assurance      Political            692        5
# ai_authorship_inventorship   Legal                553        4
# ip_search_retrieval          Technological        494        3
# ct_quantum                   Technological        493        3
# digital_identity_provenance  Technological        477        3
# gov_service_delivery         Political            457        4
# ip_admin_automation          Technological        443        4
# indigenous_knowledge         Values               424        3
# ip_enforcement_counterfeit   Economic             410        3
# ip_finance_valuation         Economic             375        3
# ct_autonomous                Technological        358        2
# geographical_indications     Legal                355        3
# ct_biotech                   Technological        337        3
# trust_institutions           Social               334        3
# ip_policy_reform             Political            289        4
# ct_ai                        Technological        277        3
# ip_sme_access                Economic             224        2
# ct_advanced_ict              Technological        189        2
# ct_advanced_manufacturing    Technological        171        2
# ct_energy                    Environmental        149        2

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic                  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# ---------------------  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# verify-bertopic-T0059  arc additive / wire arc / additive manufactu    22  0.26  0.34  0.97  0.70  0.72       0.89  H1  weak
# verify-bertopic-T0048  financial autonomy / local government / gove    28  0.29  0.14  0.96  0.70  0.00       0.81  H1  strong
# verify-bertopic-T0061  copyright page / copyright notice               23  0.28  0.12  0.95  0.69  0.26       0.80  H1  weak
# verify-bertopic-T0106  trust / iceland / financial / crisis            12  0.23  0.09  0.88  0.79  0.41       0.79  H2  weak
# verify-bertopic-T0047  dashboard / digital project / queensland / c    30  0.27  0.43  0.87  0.51  0.63       0.77  H2  strong
# verify-bertopic-T0016  africa / kilometre km / square kilometre / p    55  0.35  0.20  0.82  0.70  0.13       0.77  H2  strong
# verify-bertopic-T0049  trust / covid-19 / pandemic / public            30  0.20  0.10  0.84  0.68  0.91       0.74  H1  strong
# verify-bertopic-T0081  competition policy / intellectual property /    16  0.17  0.18  0.91  0.72  0.00       0.73  H2  weak
# verify-bertopic-T0038  cultural heritage / property cultural / inte    33  0.17  0.17  0.90  0.77  0.20       0.73  H1  strong
# verify-bertopic-T0104  elevation / elvis / river / area cover          12  0.36  0.28  0.92  0.50  0.00       0.72  H2  weak
# verify-bertopic-T0042  enforcement intellectual / property right /     45  0.20  0.15  0.82  0.64  0.89       0.72  H1  strong
# verify-bertopic-T0015  trust / institution / public / citizen          62  0.17  0.16  0.84  0.73  0.77       0.71  H2  strong
# verify-bertopic-T0076  covid-19 / vaccine / pandemic / crisis-criti    19  0.18  0.10  0.87  0.63  0.88       0.70  H1  weak
# verify-bertopic-T0068  preface / acknowledgment / list illustration    26  0.21  0.11  0.81  0.65  0.78       0.69  H1  weak
# verify-bertopic-T0074  opengov / ul / li / au                          21  0.27  0.36  0.84  0.50  0.49       0.68  H1  weak
# verify-bertopic-T0109  genai / generative / chatgpt / ethical          12  0.15  0.14  0.88  0.63  0.94       0.67  H1  weak
# verify-bertopic-T0012  automated decision-making / administrative /    80  0.16  0.18  0.83  0.72  0.74       0.67  H1  strong
# verify-bertopic-T0094  patent portfolio / portfolio management         24  0.17  0.20  0.80  0.62  0.99       0.67  H3  weak
# verify-bertopic-T0034  intellectual property / property protection     44  0.15  0.23  0.83  0.72  0.83       0.66  H3  strong
# verify-bertopic-T0060  education / ai / metaverse / chatgpt            28  0.16  0.13  0.80  0.70  0.95       0.65  H1  weak
# verify-bertopic-T0088  ipgod / ip australia / property government /    15  0.22  0.14  0.90  0.50  0.18       0.65  H1  weak
# verify-bertopic-T0007  geographical indication / trade / protection   110  0.18  0.05  0.85  0.68  0.78       0.64  H2  strong
# verify-bertopic-T0030  retrieval / patent / learning prior / mapred    36  0.17  0.04  0.88  0.80  0.00       0.64  H2  strong
# verify-bertopic-T0041  gene / crispr / editing / genome                37  0.20  0.05  0.80  0.62  0.82       0.62  H1  strong
# verify-bertopic-T0017  watermarking / text / llm / language            61  0.17  0.34  0.86  0.50  0.64       0.61  H1  strong
# verify-bertopic-T0046  reef / park / marine / australia                39  0.19  0.43  0.78  0.50  0.73       0.60  H2  strong
# verify-bertopic-T0091  foramen / ovale / percutaneous / closure        15  0.28  0.00  0.86  0.70  0.35       0.60  H1  noise
# verify-bertopic-T0087  valuation / intellectual / property / asset     15  0.15  0.08  0.88  0.73  0.00       0.60  H1  weak
# verify-bertopic-T0004  trust / institution / public / driver          124  0.19  0.00  0.82  0.74  0.72       0.60  H2  latent
# verify-bertopic-T0098  embodied / video / clap / scene                 14  0.18  0.20  0.86  0.50  0.37       0.60  H3  weak
# verify-bertopic-T0077  aesthetic / nesp / dugong / flickr              23  0.19  0.38  0.80  0.50  0.68       0.59  H2  weak
# verify-bertopic-T0018  law / ip / chapter / copyright                  48  0.14  0.17  0.83  0.72  0.59       0.59  H1  strong
# verify-bertopic-T0105  art search / prior art / patent / augmenting    14  0.18  0.00  0.87  0.73  0.85       0.59  H1  noise
# verify-bertopic-T0051  unlearning / erasure / concept / diffusion      27  0.15  0.28  0.88  0.51  0.29       0.59  H1  strong
# verify-bertopic-T0037  valuation / editorial / property / appendix     93  0.20  0.08  0.68  0.57  0.93       0.59  H1  strong
# verify-bertopic-T0101  decision-making / accountability / ai / auto    68  0.22  0.13  0.76  0.56  0.25       0.59  H2  weak
# verify-bertopic-T0064  video / vlm / visual / retrieval                21  0.19  0.06  0.87  0.51  0.28       0.58  H1  weak
# verify-bertopic-T0067  hydrogen / energy / storage / ammonia           26  0.23  0.00  0.80  0.71  0.88       0.58  H1  noise
# verify-bertopic-T0033  gis / geographical indication / agreement /     39  0.18  0.01  0.84  0.71  0.50       0.57  H2  latent
# verify-bertopic-T0112  asset / intellectual property / collateral /    14  0.16  0.11  0.81  0.62  0.76       0.56  H2  weak
# verify-bertopic-T0040  quantum / state / qubit / sensing               35  0.24  0.04  0.86  0.50  0.42       0.56  H2  strong
# verify-bertopic-T0045  quantum / error / qubit / gate                  33  0.20  0.06  0.86  0.50  0.53       0.56  H2  strong
# verify-bertopic-T0056  intellectual property / african / ip / niger    34  0.17  0.02  0.81  0.65  0.91       0.56  H1  latent
# verify-bertopic-T0009  intellectual property / right / property law   105  0.14  0.11  0.85  0.68  0.62       0.55  H1  strong
# verify-bertopic-T0032  ai / patent / invention / inventor              47  0.14  0.14  0.83  0.66  0.62       0.55  H1  strong
# verify-bertopic-T0008  ai / decision-making / adm / automated         141  0.10  0.30  0.77  0.66  0.82       0.54  H2  strong
# verify-bertopic-T0083  battery / energy storage / lithium-ion / sib    71  0.21  0.04  0.71  0.55  0.87       0.54  H1  weak
# verify-bertopic-T0089  underwater / auv / autonomous / vehicle         14  0.18  0.03  0.88  0.46  0.99       0.54  H1  noise
# verify-bertopic-T0111  higg / scalar / decay / meson                   10  0.24  0.02  0.87  0.50  0.00       0.54  H1  noise
# verify-bertopic-T0050  navigation / robot / task / learning            26  0.18  0.02  0.88  0.51  0.62       0.53  H2  latent
# verify-bertopic-T0082  accountability / social care / nursing / dec    22  0.22  0.00  0.77  0.65  0.90       0.53  H2  noise
# verify-bertopic-T0065  ai / copyright / uk / artificial                39  0.14  0.23  0.80  0.60  0.69       0.53  H2  weak
# verify-bertopic-T0006  patent / retrieval / classification / search    96  0.12  0.07  0.89  0.57  0.79       0.52  H2  strong
# verify-bertopic-T0019  access medicine / pharmaceutical / intellect    86  0.15  0.06  0.74  0.64  1.00       0.52  H1  strong
# verify-bertopic-T0005  artificial intelligence / patent / inventors   231  0.13  0.21  0.76  0.62  0.77       0.51  H2  strong
# verify-bertopic-T0031  music / audio / watermarking / voice            37  0.14  0.19  0.85  0.52  0.30       0.51  H2  strong
# verify-bertopic-T0058  energy storage / storage system / renewable     31  0.23  0.00  0.80  0.58  0.82       0.51  H1  noise
# verify-bertopic-T0022  synthetic biology / microbial / gene / cell     65  0.15  0.08  0.77  0.53  0.96       0.49  H1  strong
# verify-bertopic-T0100  retrieval / document / snippet / abstractive    13  0.15  0.11  0.88  0.50  0.20       0.49  H2  weak
# verify-bertopic-T0052  prior art / patent / art defense / art prior    37  0.15  0.04  0.78  0.65  0.91       0.49  H2  strong
# verify-bertopic-T0102  hps / chemical / reaction / cof                 12  0.17  0.00  0.85  0.60  0.96       0.49  H1  noise
# verify-bertopic-T0013  indigenous / intellectual / property / cultu   128  0.16  0.05  0.77  0.60  0.85       0.48  H1  strong
# verify-bertopic-T0078  genetic resource / benefit sharing / farmer     24  0.13  0.05  0.80  0.67  0.94       0.48  H1  weak
# verify-bertopic-T0028  odometry / navigation / positioning / lidar     37  0.18  0.00  0.86  0.51  0.94       0.47  H1  latent
# verify-bertopic-T0003  llm / language / task / reasoning              107  0.12  0.18  0.83  0.53  0.60       0.47  H2  strong
# verify-bertopic-T0095  robot / soft / actuation / tip                  16  0.17  0.00  0.82  0.57  0.96       0.45  H1  noise
# verify-bertopic-T0021  vehicle / autonomous / driving / safety         43  0.18  0.00  0.86  0.52  0.70       0.44  H1  latent
# verify-bertopic-T0053  valuation / briefing / valuer / market          31  0.16  0.00  0.82  0.79  0.29       0.44  H1  latent
# verify-bertopic-T0110  image / patent / retrieval / industrial good    10  0.16  0.00  0.90  0.57  0.72       0.44  H1  noise
# verify-bertopic-T0036  robot / swarm / uav / navigation                34  0.16  0.06  0.84  0.46  0.85       0.44  H1  strong
# verify-bertopic-T0085  additive manufacturing / material / printing    33  0.19  0.00  0.75  0.57  0.89       0.43  H1  noise
# verify-bertopic-T0107  entity / text / texsmart / rair                 11  0.17  0.03  0.87  0.50  0.00       0.43  H3  noise
# verify-bertopic-T0096  quantum / measurement / magic / gate            13  0.21  0.00  0.87  0.50  0.00       0.43  H2  noise
# verify-bertopic-T0103  influencer / authenticity / media / instagra    44  0.16  0.05  0.68  0.51  0.92       0.43  H1  weak
# verify-bertopic-T0086  black hole / pbh / thermodynamic / dm           15  0.24  0.00  0.85  0.50  0.00       0.43  H1  noise
# verify-bertopic-T0073  quantum / spin / nv / diamond                   20  0.22  0.00  0.85  0.50  0.47       0.42  H1  noise
# verify-bertopic-T0062  patent / examiner / prior art / rejection       34  0.13  0.04  0.77  0.63  0.86       0.42  H3  weak
# verify-bertopic-T0093  cultural / heritage / gallery auction / mana    77  0.22  0.00  0.68  0.54  0.68       0.41  H1  noise
# verify-bertopic-T0071  trade / agreement / facilitation / viii        128  0.23  0.00  0.65  0.53  0.59       0.40  H1  noise
# verify-bertopic-T0010  ip / enforcement / intellectual / counterfei   125  0.11  0.05  0.76  0.55  0.95       0.40  H2  strong
# verify-bertopic-T0097  dialog / emotion / conversational / misleadi    13  0.19  0.00  0.87  0.50  0.00       0.40  H1  noise
# verify-bertopic-T0001  service delivery / government / digital / pu   299  0.15  0.02  0.74  0.65  0.76       0.40  H2  latent
# verify-bertopic-T0090  valuation / intellectual property / asset /     38  0.17  0.00  0.74  0.58  0.95       0.40  H1  noise
# verify-bertopic-T0079  flow / fluid / equation / lbm                   16  0.17  0.02  0.83  0.50  0.00       0.39  H1  noise
# verify-bertopic-T0084  china / intellectual property / chinese / in    29  0.16  0.00  0.78  0.63  0.87       0.39  H2  noise
# verify-bertopic-T0092  dwarf / disk / leo / hd                         15  0.20  0.00  0.83  0.50  0.35       0.39  H2  noise
# verify-bertopic-T0043  navigation / robot / deep reinforcement / le    31  0.18  0.00  0.87  0.50  0.73       0.39  H1  latent
# verify-bertopic-T0099  spin / film / magnetic / inas                   13  0.20  0.00  0.84  0.50  0.00       0.39  H1  noise
# verify-bertopic-T0035  learning / rl / reinforcement / reward          33  0.14  0.06  0.86  0.50  0.00       0.39  H1  strong
# verify-bertopic-T0070  intellectual property / enforcement / proper    42  0.15  0.00  0.76  0.60  0.99       0.37  H1  noise
# verify-bertopic-T0057  graph / gnn / node / network                    23  0.16  0.02  0.86  0.50  0.00       0.37  H1  noise
# verify-bertopic-T0011  quantum / system / fermionic / phase            72  0.20  0.00  0.84  0.50  0.00       0.37  H1  latent
# verify-bertopic-T0044  gi / geographical indication / product / exp    33  0.17  0.00  0.86  0.39  0.88       0.36  H1  latent
# verify-bertopic-T0069  blockchain / nft / non-fungible / copyright     44  0.12  0.04  0.72  0.53  0.91       0.35  H1  weak
# verify-bertopic-T0039  ris / communication / wireless / isac           36  0.15  0.00  0.81  0.56  0.86       0.34  H1  latent
# verify-bertopic-T0027  image / dataset / facial / learning             47  0.15  0.00  0.82  0.52  0.82       0.34  H1  latent
# verify-bertopic-T0072  intellectual property / biotechnology / open    44  0.13  0.00  0.76  0.62  0.98       0.34  H1  noise
# verify-bertopic-T0075  graph / isometric / vertice / cycle             17  0.15  0.03  0.85  0.50  0.00       0.34  H2  noise
# verify-bertopic-T0020  point cloud / object / image / detection        44  0.17  0.00  0.86  0.50  0.08       0.32  H1  latent
# verify-bertopic-T0029  crop / remote sensing / agriculture / weed      39  0.14  0.00  0.84  0.50  0.88       0.32  H1  latent
# verify-bertopic-T0026  quantum / circuit / qubit / gate               116  0.16  0.00  0.73  0.51  0.82       0.31  H1  latent
# verify-bertopic-T0080  kd / knowledge distillation / domain / teach    16  0.16  0.00  0.87  0.50  0.00       0.31  H1  noise
# verify-bertopic-T0000  watermark / image / attack / dnn               211  0.15  0.00  0.86  0.50  0.62       0.30  H1  latent
# verify-bertopic-T0025  nodule / lung / ct / mri                        40  0.13  0.00  0.81  0.56  0.76       0.30  H1  latent
# verify-bertopic-T0014  indigenous / cultural / traditional knowledg    81  0.13  0.02  0.80  0.45  0.98       0.30  H1  latent
# verify-bertopic-T0108  quantum / blockchain / nist / encryption        74  0.17  0.00  0.68  0.50  0.22       0.29  H1  noise
# verify-bertopic-T0063  deepfake / content / ai / governance           145  0.11  0.03  0.70  0.50  0.69       0.28  H3  noise
# verify-bertopic-T0066  intellectual / property / nsrc / participati    34  0.13  0.00  0.79  0.62  0.40       0.28  H1  noise
# verify-bertopic-T0054  learning / diagnosis / disease / prediction     26  0.10  0.00  0.81  0.55  0.75       0.27  H1  latent
# verify-bertopic-T0024  algorithm / covariance / optimization / baye    42  0.10  0.02  0.82  0.50  0.00       0.25  H1  latent
# verify-bertopic-T0023  regulatory policy / government / policy maki   397  0.15  0.00  0.62  0.52  0.49       0.25  H1  latent
# verify-bertopic-T0002  patent / innovation / firm / intellectual      120  0.08  0.00  0.82  0.47  0.95       0.21  H1  latent
# verify-bertopic-T0113  tc / idea generation / technological resourc    17  0.09  0.00  0.74  0.50  0.90       0.21  H2  noise
# verify-bertopic-T0055  attack / watermarking / iot / detection         27  0.14  0.00  0.80  0.50  0.76       0.20  H1  latent

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 114 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 114 of 114 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 5,850 of 7,501 documents (78%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 14 topic(s) sit within 0.05 of a Three Horizons cut-point (entity / text / texsmart / rair (0.33 → H3); ip / enforcement / intellectual / counte (0.36 → H2); accountability / social care / nursing / (0.36 → H2); ai / decision-making / adm / automated (0.37 → H2); dwarf / disk / leo / hd (0.37 → H2); retrieval / document / snippet / abstrac (0.40 → H2); geographical indication / trade / protec (0.71 → H2); tc / idea generation / technological res (0.71 → H2); graph / isometric / vertice / cycle (0.71 → H2); valuation / briefing / valuer / market (0.77 → H1); learning / diagnosis / disease / predict (0.77 → H1); intellectual / property / nsrc / partici (0.77 → H1); unlearning / erasure / concept / diffusi (0.77 → H1); video / vlm / visual / retrieval (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic                  label                                   fit  closest objective                     leverage  DISR field
# ---------------------  ------------------------------------  -----  ------------------------------------  --------  ------------------------------------
# verify-bertopic-T0059  arc additive / wire arc / additive …  0.704  SI-3 AI and Automated Decision Maki…     0.481  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0012  automated decision-making / adminis…  0.781  SI-3 AI and Automated Decision Maki…     0.463  CT-AI Artificial intelligence
# verify-bertopic-T0081  competition policy / intellectual p…  0.698  4.1 Innovation and adaptiveness in …     0.398  CT-ICT Advanced information and com…
# verify-bertopic-T0109  genai / generative / chatgpt / ethi…  0.704  4.2 Innovative digital and data-dri…     0.406  CT-AI Artificial intelligence
# verify-bertopic-T0101  decision-making / accountability / …  0.806  SI-3 AI and Automated Decision Maki…     0.464  CT-AI Artificial intelligence
# verify-bertopic-T0094  patent portfolio / portfolio manage…  0.686  4.1 Innovation and adaptiveness in …     0.435  CT-BIO Biotechnologies
# verify-bertopic-T0034  intellectual property / property pr…  0.715  4.1 Innovation and adaptiveness in …     0.392  CT-ICT Advanced information and com…
# verify-bertopic-T0008  ai / decision-making / adm / automa…  0.903  SI-3 AI and Automated Decision Maki…     0.501  CT-AI Artificial intelligence
# verify-bertopic-T0047  dashboard / digital project / queen…  0.628  4.2 Innovative digital and data-dri…     0.404  CT-ICT Advanced information and com…
# verify-bertopic-T0088  ipgod / ip australia / property gov…  0.628  4.1 Innovation and adaptiveness in …     0.497  CT-BIO Biotechnologies
# verify-bertopic-T0032  ai / patent / invention / inventor    0.715  SI-3 AI and Automated Decision Maki…     0.465  CT-AI Artificial intelligence
# verify-bertopic-T0005  artificial intelligence / patent / …  0.823  SI-3 AI and Automated Decision Maki…     0.473  CT-AI Artificial intelligence
# verify-bertopic-T0087  valuation / intellectual / property…  0.665  4.1 Innovation and adaptiveness in …     0.400  CT-BIO Biotechnologies
# verify-bertopic-T0042  enforcement intellectual / property…  0.634  4.1 Innovation and adaptiveness in …     0.369  CT-ICT Advanced information and com…
# verify-bertopic-T0030  retrieval / patent / learning prior…  0.627  4.1 Innovation and adaptiveness in …     0.434  CT-ICT Advanced information and com…
# verify-bertopic-T0018  law / ip / chapter / copyright        0.645  4.1 Innovation and adaptiveness in …     0.439  CT-BIO Biotechnologies
# verify-bertopic-T0065  ai / copyright / uk / artificial      0.712  SI-3 AI and Automated Decision Maki…     0.451  CT-AI Artificial intelligence
# verify-bertopic-T0007  geographical indication / trade / p…  0.788  SI-1 Geographical indications regis…     0.345  CT-ICT Advanced information and com…
# verify-bertopic-T0076  covid-19 / vaccine / pandemic / cri…  0.601  4.1 Innovation and adaptiveness in …     0.401  CT-BIO Biotechnologies
# verify-bertopic-T0105  art search / prior art / patent / a…  0.609  4.1 Innovation and adaptiveness in …     0.484  CT-ICT Advanced information and com…
# verify-bertopic-T0038  cultural heritage / property cultur…  0.608  4.1 Innovation and adaptiveness in …     0.365  CT-ICT Advanced information and com…
# verify-bertopic-T0112  asset / intellectual property / col…  0.654  4.1 Innovation and adaptiveness in …     0.384  CT-ICT Advanced information and com…
# verify-bertopic-T0033  gis / geographical indication / agr…  0.710  SI-1 Geographical indications regis…     0.349  CT-ICT Advanced information and com…
# verify-bertopic-T0006  patent / retrieval / classification…  0.632  4.1 Innovation and adaptiveness in …     0.459  CT-AI Artificial intelligence
# verify-bertopic-T0009  intellectual property / right / pro…  0.633  4.1 Innovation and adaptiveness in …     0.396  CT-ICT Advanced information and com…
# verify-bertopic-T0013  indigenous / intellectual / propert…  0.670  SI-5 First Nations Strategy              0.411  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0060  education / ai / metaverse / chatgpt  0.594  SI-3 AI and Automated Decision Maki…     0.357  CT-AI Artificial intelligence
# verify-bertopic-T0084  china / intellectual property / chi…  0.751  4.1 Innovation and adaptiveness in …     0.417  CT-ICT Advanced information and com…
# verify-bertopic-T0015  trust / institution / public / citi…  0.629  1.1 Trust and confidence in a high-…     0.304  CT-QUANTUM Quantum technologies
# verify-bertopic-T0090  valuation / intellectual property /…  0.693  4.1 Innovation and adaptiveness in …     0.434  CT-ICT Advanced information and com…
# verify-bertopic-T0110  image / patent / retrieval / indust…  0.621  4.1 Innovation and adaptiveness in …     0.428  CT-ICT Advanced information and com…
# verify-bertopic-T0004  trust / institution / public / driv…  0.624  1.1 Trust and confidence in a high-…     0.326  CT-ICT Advanced information and com…
# verify-bertopic-T0061  copyright page / copyright notice     0.553  4.1 Innovation and adaptiveness in …     0.323  CT-BIO Biotechnologies
# verify-bertopic-T0074  opengov / ul / li / au                0.535  4.2 Innovative digital and data-dri…     0.374  CT-ICT Advanced information and com…
# verify-bertopic-T0037  valuation / editorial / property / …  0.560  4.1 Innovation and adaptiveness in …     0.373  CT-ICT Advanced information and com…
# verify-bertopic-T0017  watermarking / text / llm / language  0.563  SI-3 AI and Automated Decision Maki…     0.346  CT-AI Artificial intelligence
# verify-bertopic-T0100  retrieval / document / snippet / ab…  0.597  4.1 Innovation and adaptiveness in …     0.397  CT-AI Artificial intelligence
# verify-bertopic-T0078  genetic resource / benefit sharing …  0.618  4.1 Innovation and adaptiveness in …     0.381  CT-BIO Biotechnologies
# verify-bertopic-T0049  trust / covid-19 / pandemic / public  0.545  1.1 Trust and confidence in a high-…     0.327  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0062  patent / examiner / prior art / rej…  0.596  4.1 Innovation and adaptiveness in …     0.490  CT-ICT Advanced information and com…
# verify-bertopic-T0019  access medicine / pharmaceutical / …  0.598  4.1 Innovation and adaptiveness in …     0.369  CT-ICT Advanced information and com…
# verify-bertopic-T0056  intellectual property / african / i…  0.587  4.1 Innovation and adaptiveness in …     0.356  CT-ICT Advanced information and com…
# verify-bertopic-T0051  unlearning / erasure / concept / di…  0.597  4.1 Innovation and adaptiveness in …     0.337  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0082  accountability / social care / nurs…  0.599  SI-3 AI and Automated Decision Maki…     0.352  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0014  indigenous / cultural / traditional…  0.694  SI-5 First Nations Strategy              0.448  CT-ICT Advanced information and com…
# verify-bertopic-T0010  ip / enforcement / intellectual / c…  0.667  4.1 Innovation and adaptiveness in …     0.366  CT-BIO Biotechnologies
# verify-bertopic-T0002  patent / innovation / firm / intell…  0.705  4.1 Innovation and adaptiveness in …     0.463  CT-ICT Advanced information and com…
# verify-bertopic-T0048  financial autonomy / local governme…  0.536  SI-3 AI and Automated Decision Maki…     0.323  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0046  reef / park / marine / australia      0.523  4.2 Innovative digital and data-dri…     0.396  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0052  prior art / patent / art defense / …  0.580  4.1 Innovation and adaptiveness in …     0.388  CT-ICT Advanced information and com…
# verify-bertopic-T0070  intellectual property / enforcement…  0.663  4.1 Innovation and adaptiveness in …     0.384  CT-ICT Advanced information and com…
# verify-bertopic-T0072  intellectual property / biotechnolo…  0.653  4.1 Innovation and adaptiveness in …     0.411  CT-BIO Biotechnologies
# verify-bertopic-T0003  llm / language / task / reasoning     0.612  SI-3 AI and Automated Decision Maki…     0.361  CT-AI Artificial intelligence
# verify-bertopic-T0001  service delivery / government / dig…  0.725  4.2 Innovative digital and data-dri…     0.338  CT-ICT Advanced information and com…
# verify-bertopic-T0063  deepfake / content / ai / governance  0.666  SI-3 AI and Automated Decision Maki…     0.411  CT-AI Artificial intelligence
# verify-bertopic-T0091  foramen / ovale / percutaneous / cl…  0.539  4.1 Innovation and adaptiveness in …     0.346  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0104  elevation / elvis / river / area co…  0.536  4.2 Innovative digital and data-dri…     0.315  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0069  blockchain / nft / non-fungible / c…  0.633  4.1 Innovation and adaptiveness in …     0.385  CT-ICT Advanced information and com…
# verify-bertopic-T0053  valuation / briefing / valuer / mar…  0.603  4.1 Innovation and adaptiveness in …     0.350  CT-BIO Biotechnologies
# verify-bertopic-T0068  preface / acknowledgment / list ill…  0.530  4.1 Innovation and adaptiveness in …     0.335  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0083  battery / energy storage / lithium-…  0.559  4.2 Innovative digital and data-dri…     0.346  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0113  tc / idea generation / technologica…  0.624  4.1 Innovation and adaptiveness in …     0.471  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0044  gi / geographical indication / prod…  0.702  SI-1 Geographical indications regis…     0.345  CT-BIO Biotechnologies
# verify-bertopic-T0095  robot / soft / actuation / tip        0.564  4.1 Innovation and adaptiveness in …     0.362  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0041  gene / crispr / editing / genome      0.532  4.1 Innovation and adaptiveness in …     0.338  CT-BIO Biotechnologies
# verify-bertopic-T0106  trust / iceland / financial / crisis  0.534  4.2 Innovative digital and data-dri…     0.285  CT-ICT Advanced information and com…
# verify-bertopic-T0066  intellectual / property / nsrc / pa…  0.652  4.1 Innovation and adaptiveness in …     0.388  CT-ICT Advanced information and com…
# verify-bertopic-T0077  aesthetic / nesp / dugong / flickr    0.520  SI-3 AI and Automated Decision Maki…     0.347  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0107  entity / text / texsmart / rair       0.548  4.1 Innovation and adaptiveness in …     0.378  CT-AI Artificial intelligence
# verify-bertopic-T0050  navigation / robot / task / learning  0.562  SI-3 AI and Automated Decision Maki…     0.323  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0098  embodied / video / clap / scene       0.536  4.2 Innovative digital and data-dri…     0.321  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0064  video / vlm / visual / retrieval      0.543  4.2 Innovative digital and data-dri…     0.308  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0058  energy storage / storage system / r…  0.546  4.2 Innovative digital and data-dri…     0.333  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0023  regulatory policy / government / po…  0.614  SI-2 Regulatory reform supporting t…     0.381  CT-BIO Biotechnologies
# verify-bertopic-T0028  odometry / navigation / positioning…  0.542  4.2 Innovative digital and data-dri…     0.348  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0016  africa / kilometre km / square kilo…  0.446  4.2 Innovative digital and data-dri…     0.298  CT-ICT Advanced information and com…
# verify-bertopic-T0102  hps / chemical / reaction / cof       0.517  4.2 Innovative digital and data-dri…     0.377  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0021  vehicle / autonomous / driving / sa…  0.572  SI-3 AI and Automated Decision Maki…     0.319  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0089  underwater / auv / autonomous / veh…  0.542  SI-3 AI and Automated Decision Maki…     0.312  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0071  trade / agreement / facilitation / …  0.554  SI-1 Geographical indications regis…     0.347  CT-ICT Advanced information and com…
# verify-bertopic-T0029  crop / remote sensing / agriculture…  0.566  SI-3 AI and Automated Decision Maki…     0.374  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0035  learning / rl / reinforcement / rew…  0.602  SI-3 AI and Automated Decision Maki…     0.328  CT-AI Artificial intelligence
# verify-bertopic-T0103  influencer / authenticity / media /…  0.588  4.2 Innovative digital and data-dri…     0.312  CT-ICT Advanced information and com…
# verify-bertopic-T0022  synthetic biology / microbial / gen…  0.533  SI-3 AI and Automated Decision Maki…     0.343  CT-BIO Biotechnologies
# verify-bertopic-T0054  learning / diagnosis / disease / pr…  0.597  SI-3 AI and Automated Decision Maki…     0.367  CT-AI Artificial intelligence
# verify-bertopic-T0085  additive manufacturing / material /…  0.536  4.2 Innovative digital and data-dri…     0.345  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0097  dialog / emotion / conversational /…  0.561  4.2 Innovative digital and data-dri…     0.328  CT-AI Artificial intelligence
# verify-bertopic-T0067  hydrogen / energy / storage / ammon…  0.528  4.2 Innovative digital and data-dri…     0.293  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0036  robot / swarm / uav / navigation      0.542  SI-3 AI and Automated Decision Maki…     0.320  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0043  navigation / robot / deep reinforce…  0.574  SI-3 AI and Automated Decision Maki…     0.313  CT-AI Artificial intelligence
# verify-bertopic-T0020  point cloud / object / image / dete…  0.544  4.2 Innovative digital and data-dri…     0.353  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0045  quantum / error / qubit / gate        0.499  4.1 Innovation and adaptiveness in …     0.300  CT-QUANTUM Quantum technologies
# verify-bertopic-T0111  higg / scalar / decay / meson         0.475  4.2 Innovative digital and data-dri…     0.319  CT-QUANTUM Quantum technologies
# verify-bertopic-T0073  quantum / spin / nv / diamond         0.530  4.2 Innovative digital and data-dri…     0.345  CT-QUANTUM Quantum technologies
# verify-bertopic-T0031  music / audio / watermarking / voice  0.520  4.2 Innovative digital and data-dri…     0.311  CT-QUANTUM Quantum technologies
# verify-bertopic-T0057  graph / gnn / node / network          0.493  4.2 Innovative digital and data-dri…     0.390  CT-AI Artificial intelligence
# verify-bertopic-T0024  algorithm / covariance / optimizati…  0.560  SI-3 AI and Automated Decision Maki…     0.350  CT-AI Artificial intelligence
# verify-bertopic-T0040  quantum / state / qubit / sensing     0.455  4.2 Innovative digital and data-dri…     0.269  CT-QUANTUM Quantum technologies
# verify-bertopic-T0025  nodule / lung / ct / mri              0.558  SI-3 AI and Automated Decision Maki…     0.330  CT-AI Artificial intelligence
# verify-bertopic-T0027  image / dataset / facial / learning   0.539  4.2 Innovative digital and data-dri…     0.335  CT-AI Artificial intelligence
# verify-bertopic-T0039  ris / communication / wireless / is…  0.533  SI-3 AI and Automated Decision Maki…     0.346  CT-ICT Advanced information and com…
# verify-bertopic-T0055  attack / watermarking / iot / detec…  0.544  4.1 Innovation and adaptiveness in …     0.350  CT-ICT Advanced information and com…
# verify-bertopic-T0093  cultural / heritage / gallery aucti…  0.535  4.1 Innovation and adaptiveness in …     0.310  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0075  graph / isometric / vertice / cycle   0.502  4.1 Innovation and adaptiveness in …     0.356  CT-AUTON Autonomous systems, roboti…
# verify-bertopic-T0080  kd / knowledge distillation / domai…  0.537  4.2 Innovative digital and data-dri…     0.328  CT-AI Artificial intelligence
# verify-bertopic-T0086  black hole / pbh / thermodynamic / …  0.468  4.2 Innovative digital and data-dri…     0.315  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0000  watermark / image / attack / dnn      0.542  4.1 Innovation and adaptiveness in …     0.307  CT-AI Artificial intelligence
# verify-bertopic-T0096  quantum / measurement / magic / gate  0.484  4.1 Innovation and adaptiveness in …     0.285  CT-QUANTUM Quantum technologies
# verify-bertopic-T0092  dwarf / disk / leo / hd               0.498  4.2 Innovative digital and data-dri…     0.311  CT-ENERGY Clean energy generation a…
# verify-bertopic-T0079  flow / fluid / equation / lbm         0.477  4.2 Innovative digital and data-dri…     0.288  CT-AMM Advanced manufacturing and m…
# verify-bertopic-T0099  spin / film / magnetic / inas         0.466  4.1 Innovation and adaptiveness in …     0.300  CT-QUANTUM Quantum technologies
# verify-bertopic-T0011  quantum / system / fermionic / phase  0.490  4.2 Innovative digital and data-dri…     0.294  CT-QUANTUM Quantum technologies
# verify-bertopic-T0026  quantum / circuit / qubit / gate      0.507  SI-3 AI and Automated Decision Maki…     0.305  CT-QUANTUM Quantum technologies
# verify-bertopic-T0108  quantum / blockchain / nist / encry…  0.528  4.1 Innovation and adaptiveness in …     0.304  CT-QUANTUM Quantum technologies
#
# strategic fit  range 0.446–0.903  median 0.577
# asset leverage range 0.269–0.501  median 0.351

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic                  label                                 attention  attention_tone  policy_salience  research_growth  index
# ---------------------  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# verify-bertopic-T0059  arc additive / wire arc / additive m      0.142           0.142            0.363            0.982  0.490
# verify-bertopic-T0012  automated decision-making / administ      0.712           0.487            0.699            0.832  0.725
# verify-bertopic-T0081  competition policy / intellectual pr      0.142           0.142            0.796            0.894  0.561
# verify-bertopic-T0101  decision-making / accountability / a      0.903           0.513            0.832            0.752  0.787
# verify-bertopic-T0094  patent portfolio / portfolio managem      0.686           0.717            0.991            0.814  0.807
# verify-bertopic-T0034  intellectual property / property pro      0.686           0.690            0.965            0.876  0.819
# verify-bertopic-T0008  ai / decision-making / adm / automat      0.894           0.611            0.894            0.867  0.851
# verify-bertopic-T0047  dashboard / digital project / queens      0.341           0.562            0.602            0.620  0.527
# verify-bertopic-T0088  ipgod / ip australia / property gove      0.142           0.142            1.000            0.288  0.395
# verify-bertopic-T0032  ai / patent / invention / inventor        0.730           0.496            0.876            0.929  0.807
# verify-bertopic-T0005  artificial intelligence / patent / i      0.991           0.478            0.752            0.796  0.806
# verify-bertopic-T0087  valuation / intellectual / property       0.142           0.142            0.911            0.894  0.588
# verify-bertopic-T0042  enforcement intellectual / property       0.752           0.301            0.938            0.288  0.579
# verify-bertopic-T0030  retrieval / patent / learning prior       0.142           0.142            0.637            0.788  0.486
# verify-bertopic-T0018  law / ip / chapter / copyright            0.341           0.562            0.867            0.288  0.472
# verify-bertopic-T0065  ai / copyright / uk / artificial          0.792           0.381            0.770            0.920  0.784
# verify-bertopic-T0007  geographical indication / trade / pr      0.814           0.796            0.593            0.805  0.757
# verify-bertopic-T0076  covid-19 / vaccine / pandemic / cris      0.420           0.336            0.620            0.288  0.410
# verify-bertopic-T0038  cultural heritage / property cultura      0.341           0.863            0.540            0.288  0.430
# verify-bertopic-T0033  gis / geographical indication / agre      0.557           0.885            0.557            0.602  0.612
# verify-bertopic-T0006  patent / retrieval / classification       0.142           0.142            0.761            0.858  0.540
# verify-bertopic-T0009  intellectual property / right / prop      0.770           0.584            0.956            0.288  0.622
# verify-bertopic-T0013  indigenous / intellectual / property      0.947           0.832            0.743            0.699  0.798
# verify-bertopic-T0060  education / ai / metaverse / chatgpt      0.557           0.522            0.628            0.938  0.704
# verify-bertopic-T0084  china / intellectual property / chin      0.752           0.681            0.814            0.288  0.594
# verify-bertopic-T0015  trust / institution / public / citiz      0.597           0.354            0.858            0.770  0.691
# verify-bertopic-T0090  valuation / intellectual property /       0.841           0.770            0.885            0.288  0.648
# verify-bertopic-T0004  trust / institution / public / drive      0.792           0.372            0.823            0.584  0.676
# verify-bertopic-T0061  copyright page / copyright notice         0.341           0.451            0.841            0.965  0.692
# verify-bertopic-T0074  opengov / ul / li / au                    0.469           0.389            0.460            0.288  0.394
# verify-bertopic-T0037  valuation / editorial / property / a      0.920           0.823            0.655            0.288  0.623
# verify-bertopic-T0017  watermarking / text / llm / language      0.655           0.407            0.416            0.991  0.688
# verify-bertopic-T0078  genetic resource / benefit sharing /      0.615           0.779            0.664            0.288  0.530
# verify-bertopic-T0049  trust / covid-19 / pandemic / public      0.420           0.708            0.735            0.288  0.481
# verify-bertopic-T0062  patent / examiner / prior art / reje      0.730           0.602            0.681            0.708  0.696
# verify-bertopic-T0019  access medicine / pharmaceutical / i      0.876           0.673            0.779            0.288  0.622
# verify-bertopic-T0056  intellectual property / african / ip      0.686           0.469            0.690            0.628  0.641
# verify-bertopic-T0051  unlearning / erasure / concept / dif      0.341           0.863            0.257            1.000  0.615
# verify-bertopic-T0082  accountability / social care / nursi      0.597           0.363            0.982            0.288  0.551
# verify-bertopic-T0014  indigenous / cultural / traditional       0.792           0.876            0.788            0.637  0.746
# verify-bertopic-T0010  ip / enforcement / intellectual / co      0.885           0.292            0.850            0.761  0.763
# verify-bertopic-T0002  patent / innovation / firm / intelle      0.686           0.752            0.947            0.288  0.615
# verify-bertopic-T0048  financial autonomy / local governmen      0.142           0.142            0.726            0.288  0.331
# verify-bertopic-T0046  reef / park / marine / australia          0.655           0.965            0.566            0.288  0.541
# verify-bertopic-T0052  prior art / patent / art defense / a      0.712           0.425            0.531            0.717  0.637
# verify-bertopic-T0070  intellectual property / enforcement       0.827           0.319            0.929            0.288  0.601
# verify-bertopic-T0072  intellectual property / biotechnolog      0.858           0.699            0.717            0.288  0.605
# verify-bertopic-T0003  llm / language / task / reasoning         0.142           0.142            0.469            0.894  0.484
# verify-bertopic-T0001  service delivery / government / digi      0.974           0.549            0.974            0.611  0.795
# verify-bertopic-T0063  deepfake / content / ai / governance      0.982           0.434            0.584            0.593  0.687
# verify-bertopic-T0091  foramen / ovale / percutaneous / clo      0.341           0.646            0.266            0.288  0.340
# verify-bertopic-T0069  blockchain / nft / non-fungible / co      0.850           0.655            0.549            0.646  0.684
# verify-bertopic-T0053  valuation / briefing / valuer / mark      0.557           0.841            0.575            0.288  0.500
# verify-bertopic-T0068  preface / acknowledgment / list illu      0.557           0.664            0.611            0.681  0.626
# verify-bertopic-T0083  battery / energy storage / lithium-i      0.911           0.850            0.283            0.288  0.536
# verify-bertopic-T0113  tc / idea generation / technological      0.615           0.788            0.487            0.288  0.490
# verify-bertopic-T0044  gi / geographical indication / produ      0.469           0.898            0.451            0.288  0.451
# verify-bertopic-T0095  robot / soft / actuation / tip            0.469           0.814            0.310            0.288  0.408
# verify-bertopic-T0041  gene / crispr / editing / genome          0.557           0.735            0.071            0.288  0.369
# verify-bertopic-T0066  intellectual / property / nsrc / par      0.752           0.628            0.805            0.288  0.586
# verify-bertopic-T0077  aesthetic / nesp / dugong / flickr        0.557           0.991            0.327            0.288  0.459
# verify-bertopic-T0050  navigation / robot / task / learning      0.142           0.142            0.407            0.664  0.388
# verify-bertopic-T0064  video / vlm / visual / retrieval          0.142           0.142            0.195            0.850  0.404
# verify-bertopic-T0058  energy storage / storage system / re      0.633           0.974            0.496            0.288  0.519
# verify-bertopic-T0023  regulatory policy / government / pol      1.000           0.637            0.920            0.288  0.687
# verify-bertopic-T0028  odometry / navigation / positioning       0.142           0.142            0.389            0.288  0.251
# verify-bertopic-T0016  africa / kilometre km / square kilom      0.341           1.000            0.159            0.288  0.357
# verify-bertopic-T0021  vehicle / autonomous / driving / saf      0.142           0.142            0.398            0.288  0.254
# verify-bertopic-T0071  trade / agreement / facilitation / v      0.965           0.620            0.673            0.288  0.616
# verify-bertopic-T0029  crop / remote sensing / agriculture       0.420           0.593            0.504            0.288  0.414
# verify-bertopic-T0035  learning / rl / reinforcement / rewa      0.142           0.142            0.443            0.288  0.264
# verify-bertopic-T0103  influencer / authenticity / media /       0.867           0.310            0.372            0.288  0.480
# verify-bertopic-T0022  synthetic biology / microbial / gene      0.827           0.743            0.026            0.288  0.439
# verify-bertopic-T0054  learning / diagnosis / disease / pre      0.420           0.416            0.212            0.288  0.324
# verify-bertopic-T0085  additive manufacturing / material /       0.792           0.956            0.292            0.288  0.516
# verify-bertopic-T0067  hydrogen / energy / storage / ammoni      0.557           0.982            0.345            0.288  0.462
# verify-bertopic-T0036  robot / swarm / uav / navigation          0.420           0.575            0.336            0.288  0.372
# verify-bertopic-T0043  navigation / robot / deep reinforcem      0.142           0.142            0.301            0.288  0.231
# verify-bertopic-T0020  point cloud / object / image / detec      0.142           0.142            0.133            0.288  0.191
# verify-bertopic-T0045  quantum / error / qubit / gate            0.509           0.938            0.354            0.841  0.640
# verify-bertopic-T0073  quantum / spin / nv / diamond             0.420           0.938            0.009            0.288  0.338
# verify-bertopic-T0031  music / audio / watermarking / voice      0.341           0.451            0.230            0.947  0.542
# verify-bertopic-T0057  graph / gnn / node / network              0.142           0.142            0.106            0.664  0.318
# verify-bertopic-T0024  algorithm / covariance / optimizatio      0.142           0.142            0.177            0.690  0.344
# verify-bertopic-T0040  quantum / state / qubit / sensing         0.469           0.938            0.142            0.779  0.556
# verify-bertopic-T0025  nodule / lung / ct / mri                  0.142           0.142            0.097            0.288  0.183
# verify-bertopic-T0027  image / dataset / facial / learning       0.633           0.398            0.221            0.288  0.386
# verify-bertopic-T0039  ris / communication / wireless / isa      0.509           0.761            0.434            0.288  0.443
# verify-bertopic-T0055  attack / watermarking / iot / detect      0.509           0.540            0.319            0.288  0.390
# verify-bertopic-T0093  cultural / heritage / gallery auctio      0.934           0.805            0.425            0.288  0.571
# verify-bertopic-T0075  graph / isometric / vertice / cycle       0.142           0.142            0.053            0.735  0.330
# verify-bertopic-T0080  kd / knowledge distillation / domain      0.142           0.142            0.274            0.288  0.224
# verify-bertopic-T0086  black hole / pbh / thermodynamic / d      0.142           0.142            0.035            0.288  0.168
# verify-bertopic-T0000  watermark / image / attack / dnn          0.655           0.531            0.203            0.288  0.404
# verify-bertopic-T0092  dwarf / disk / leo / hd                   0.341           0.898            0.000            0.288  0.307
# verify-bertopic-T0079  flow / fluid / equation / lbm             0.142           0.142            0.150            0.664  0.328
# verify-bertopic-T0011  quantum / system / fermionic / phase      0.142           0.142            0.381            0.288  0.249
# verify-bertopic-T0026  quantum / circuit / qubit / gate          0.956           0.920            0.239            0.288  0.547
# verify-bertopic-T0108  quantum / blockchain / nist / encryp      0.934           0.911            0.044            0.288  0.494
#
# 15 topic(s) suppressed as too thin to index honestly: verify-bertopic-T0109, verify-bertopic-T0105, verify-bertopic-T0112, verify-bertopic-T0110, verify-bertopic-T0100, verify-bertopic-T0104, verify-bertopic-T0106, verify-bertopic-T0107, verify-bertopic-T0098, verify-bertopic-T0102, verify-bertopic-T0089, verify-bertopic-T0097, verify-bertopic-T0111, verify-bertopic-T0096, verify-bertopic-T0099

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 99 topics — largest deviation 8.63e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 15 of 114 topics carry fewer than 15 documents and have no index at all. They are suppressed rather than scored zero: an unmeasurable index and a low one are different claims.
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 114 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 114 of 114 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  arc additive / wire arc / additive manufac  H1  weak    0.890  0.704  0.481  0.490      0.954
#   2  automated decision-making / administrative  H1  strong  0.669  0.781  0.463  0.725      0.911
#   3  competition policy / intellectual property  H2  weak    0.731  0.698  0.398  0.561      0.869
#   4  genai / generative / chatgpt / ethical      H1  weak    0.670  0.704  0.406      —      0.856
#   5  decision-making / accountability / ai / au  H2  weak    0.585  0.806  0.464  0.787      0.852
#   6  patent portfolio / portfolio management     H3  weak    0.668  0.686  0.435  0.807      0.851
#   7  intellectual property / property protectio  H3  strong  0.665  0.715  0.392  0.819      0.846
#   8  ai / decision-making / adm / automated      H2  strong  0.540  0.903  0.501  0.851      0.841
#   9  dashboard / digital project / queensland /  H2  strong  0.768  0.628  0.404  0.527      0.827
#  10  ipgod / ip australia / property government  H1  weak    0.652  0.628  0.497  0.395      0.825
#  11  ai / patent / invention / inventor          H1  strong  0.547  0.715  0.465  0.807      0.804
#  12  artificial intelligence / patent / invento  H2  strong  0.511  0.823  0.473  0.806      0.795
#  13  valuation / intellectual / property / asse  H1  weak    0.600  0.665  0.400  0.588      0.779
#  14  enforcement intellectual / property right   H1  strong  0.720  0.634  0.369  0.579      0.778
#  15  retrieval / patent / learning prior / mapr  H2  strong  0.638  0.627  0.434  0.486      0.776
#  16  law / ip / chapter / copyright              H1  strong  0.592  0.645  0.439  0.472      0.776
#  17  ai / copyright / uk / artificial            H2  weak    0.526  0.712  0.451  0.784      0.765
#  18  geographical indication / trade / protecti  H2  strong  0.640  0.788  0.345  0.757      0.764
#  19  covid-19 / vaccine / pandemic / crisis-cri  H1  weak    0.696  0.601  0.401  0.410      0.760
#  20  art search / prior art / patent / augmenti  H1  noise   0.592  0.609  0.484      —      0.750
#  21  cultural heritage / property cultural / in  H1  strong  0.726  0.608  0.365  0.430      0.730
#  22  asset / intellectual property / collateral  H2  weak    0.563  0.654  0.384      —      0.706
#  23  gis / geographical indication / agreement   H2  latent  0.574  0.710  0.349  0.612      0.702
#  24  patent / retrieval / classification / sear  H2  strong  0.524  0.632  0.459  0.540      0.696
#  25  intellectual property / right / property l  H1  strong  0.549  0.633  0.396  0.622      0.691
#  26  indigenous / intellectual / property / cul  H1  strong  0.485  0.670  0.411  0.798      0.679
#  27  education / ai / metaverse / chatgpt        H1  weak    0.655  0.594  0.357  0.704      0.654
#  28  china / intellectual property / chinese /   H2  noise   0.393  0.751  0.417  0.594      0.645
#  29  trust / institution / public / citizen      H2  strong  0.711  0.629  0.304  0.691      0.632
#  30  valuation / intellectual property / asset   H1  noise   0.395  0.693  0.434  0.648      0.622
#  31  image / patent / retrieval / industrial go  H1  noise   0.442  0.621  0.428      —      0.602
#  32  trust / institution / public / driver       H2  latent  0.599  0.624  0.326  0.676      0.600
#  33  copyright page / copyright notice           H1  weak    0.800  0.553  0.323  0.692      0.589
#  34  opengov / ul / li / au                      H1  weak    0.685  0.535  0.374  0.394      0.586
#  35  valuation / editorial / property / appendi  H1  strong  0.586  0.560  0.373  0.623      0.586
#  36  watermarking / text / llm / language        H1  strong  0.609  0.563  0.346  0.688      0.582
#  37  retrieval / document / snippet / abstracti  H2  weak    0.492  0.597  0.397      —      0.581
#  38  genetic resource / benefit sharing / farme  H1  weak    0.483  0.618  0.381  0.530      0.573
#  39  trust / covid-19 / pandemic / public        H1  strong  0.735  0.545  0.327  0.481      0.572
#  40  patent / examiner / prior art / rejection   H3  weak    0.418  0.596  0.490  0.696      0.565
#  41  access medicine / pharmaceutical / intelle  H1  strong  0.523  0.598  0.369  0.622      0.562
#  42  intellectual property / african / ip / nig  H1  latent  0.555  0.587  0.356  0.641      0.562
#  43  unlearning / erasure / concept / diffusion  H1  strong  0.586  0.597  0.337  0.615      0.561
#  44  accountability / social care / nursing / d  H2  noise   0.526  0.599  0.352  0.551      0.554
#  45  indigenous / cultural / traditional knowle  H1  latent  0.297  0.694  0.448  0.746      0.554
#  46  ip / enforcement / intellectual / counterf  H2  strong  0.397  0.667  0.366  0.763      0.552
#  47  patent / innovation / firm / intellectual   H1  latent  0.213  0.705  0.463  0.615      0.551
#  48  financial autonomy / local government / go  H1  strong  0.810  0.536  0.323  0.331      0.545
#  49  reef / park / marine / australia            H2  strong  0.605  0.523  0.396  0.541      0.545
#  50  prior art / patent / art defense / art pri  H2  strong  0.485  0.580  0.388  0.637      0.542
#  51  intellectual property / enforcement / prop  H1  noise   0.372  0.663  0.384  0.601      0.534
#  52  intellectual property / biotechnology / op  H1  noise   0.338  0.653  0.411  0.605      0.534
#  53  llm / language / task / reasoning           H2  strong  0.468  0.612  0.361  0.484      0.534
#  54  service delivery / government / digital /   H2  latent  0.396  0.725  0.338  0.795      0.531
#  55  deepfake / content / ai / governance        H3  noise   0.277  0.666  0.411  0.687      0.515
#  56  foramen / ovale / percutaneous / closure    H1  noise   0.603  0.539  0.346  0.340      0.509
#  57  elevation / elvis / river / area cover      H2  weak    0.721  0.536  0.315      —      0.504
#  58  blockchain / nft / non-fungible / copyrigh  H1  weak    0.354  0.633  0.385  0.684      0.504
#  59  valuation / briefing / valuer / market      H1  latent  0.442  0.603  0.350  0.500      0.500
#  60  preface / acknowledgment / list illustrati  H1  weak    0.691  0.530  0.335  0.626      0.492
#  61  battery / energy storage / lithium-ion / s  H1  weak    0.538  0.559  0.346  0.536      0.487
#  62  tc / idea generation / technological resou  H2  noise   0.211  0.624  0.471  0.490      0.479
#  63  gi / geographical indication / product / e  H1  latent  0.361  0.702  0.345  0.451      0.474
#  64  robot / soft / actuation / tip              H1  noise   0.446  0.564  0.362  0.408      0.473
#  65  gene / crispr / editing / genome            H1  strong  0.619  0.532  0.338  0.369      0.472
#  66  trust / iceland / financial / crisis        H2  weak    0.789  0.534  0.285      —      0.468
#  67  intellectual / property / nsrc / participa  H1  noise   0.276  0.652  0.388  0.586      0.468
#  68  aesthetic / nesp / dugong / flickr          H2  weak    0.592  0.520  0.347  0.459      0.448
#  69  entity / text / texsmart / rair             H3  noise   0.431  0.548  0.378      —      0.443
#  70  navigation / robot / task / learning        H2  latent  0.530  0.562  0.323  0.388      0.442
#  71  embodied / video / clap / scene             H3  weak    0.598  0.536  0.321      —      0.436
#  72  video / vlm / visual / retrieval            H1  weak    0.579  0.543  0.308  0.404      0.419
#  73  energy storage / storage system / renewabl  H1  noise   0.506  0.546  0.333  0.519      0.409
#  74  regulatory policy / government / policy ma  H1  latent  0.250  0.614  0.381  0.687      0.403
#  75  odometry / navigation / positioning / lida  H1  latent  0.474  0.542  0.348  0.251      0.397
#  76  africa / kilometre km / square kilometre /  H2  strong  0.766  0.446  0.298  0.357      0.396
#  77  hps / chemical / reaction / cof             H1  noise   0.485  0.517  0.377      —      0.387
#  78  vehicle / autonomous / driving / safety     H1  latent  0.444  0.572  0.319  0.254      0.385
#  79  underwater / auv / autonomous / vehicle     H1  noise   0.537  0.542  0.312      —      0.385
#  80  trade / agreement / facilitation / viii     H1  noise   0.403  0.554  0.347  0.616      0.376
#  81  crop / remote sensing / agriculture / weed  H1  latent  0.319  0.566  0.374  0.414      0.374
#  82  learning / rl / reinforcement / reward      H1  strong  0.386  0.602  0.328  0.264      0.368
#  83  influencer / authenticity / media / instag  H1  weak    0.426  0.588  0.312  0.480      0.360
#  84  synthetic biology / microbial / gene / cel  H1  strong  0.494  0.533  0.343  0.439      0.357
#  85  learning / diagnosis / disease / predictio  H1  latent  0.275  0.597  0.367  0.324      0.356
#  86  additive manufacturing / material / printi  H1  noise   0.431  0.536  0.345  0.516      0.345
#  87  dialog / emotion / conversational / mislea  H1  noise   0.396  0.561  0.328      —      0.345
#  88  hydrogen / energy / storage / ammonia       H1  noise   0.579  0.528  0.293  0.462      0.331
#  89  robot / swarm / uav / navigation            H1  strong  0.436  0.542  0.320  0.372      0.323
#  90  navigation / robot / deep reinforcement /   H1  latent  0.388  0.574  0.313  0.231      0.311
#  91  point cloud / object / image / detection    H1  latent  0.324  0.544  0.353  0.191      0.302
#  92  quantum / error / qubit / gate              H2  strong  0.558  0.499  0.300  0.640      0.301
#  93  higg / scalar / decay / meson               H1  noise   0.535  0.475  0.319      —      0.293
#  94  quantum / spin / nv / diamond               H1  noise   0.424  0.530  0.345  0.338      0.292
#  95  music / audio / watermarking / voice        H2  strong  0.508  0.520  0.311  0.542      0.287
#  96  graph / gnn / node / network                H1  noise   0.371  0.493  0.390  0.318      0.285
#  97  algorithm / covariance / optimization / ba  H1  latent  0.250  0.560  0.350  0.344      0.285
#  98  quantum / state / qubit / sensing           H2  strong  0.561  0.455  0.269  0.556      0.262
#  99  nodule / lung / ct / mri                    H1  latent  0.300  0.558  0.330  0.183      0.253
# 100  image / dataset / facial / learning         H1  latent  0.338  0.539  0.335  0.386      0.248
# 101  ris / communication / wireless / isac       H1  latent  0.339  0.533  0.346  0.443      0.247
# 102  attack / watermarking / iot / detection     H1  latent  0.201  0.544  0.350  0.390      0.243
# 103  cultural / heritage / gallery auction / ma  H1  noise   0.405  0.535  0.310  0.571      0.236
# 104  graph / isometric / vertice / cycle         H2  noise   0.337  0.502  0.356  0.330      0.223
# 105  kd / knowledge distillation / domain / tea  H1  noise   0.307  0.537  0.328  0.224      0.209
# 106  black hole / pbh / thermodynamic / dm       H1  noise   0.426  0.468  0.315  0.168      0.193
# 107  watermark / image / attack / dnn            H1  latent  0.304  0.542  0.307  0.404      0.174
# 108  quantum / measurement / magic / gate        H2  noise   0.427  0.484  0.285      —      0.166
# 109  dwarf / disk / leo / hd                     H2  noise   0.390  0.498  0.311  0.307      0.160
# 110  flow / fluid / equation / lbm               H1  noise   0.394  0.477  0.288  0.328      0.128
# 111  spin / film / magnetic / inas               H1  noise   0.386  0.466  0.300      —      0.116
# 112  quantum / system / fermionic / phase        H1  latent  0.368  0.490  0.294  0.249      0.111
# 113  quantum / circuit / qubit / gate            H1  latent  0.312  0.507  0.305  0.547      0.108
# 114  quantum / blockchain / nist / encryption    H1  noise   0.286  0.528  0.304  0.494      0.106

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.577, leverage 0.351).
#
# ACT (47)
#       1  arc additive / wire arc / additive manufacturing / intellige
#       2  automated decision-making / administrative / government / ac
#       3  competition policy / intellectual property / property compet
#       4  genai / generative / chatgpt / ethical
#       5  decision-making / accountability / ai / automated
#       6  patent portfolio / portfolio management
#       7  intellectual property / property protection / corporate / di
#       8  ai / decision-making / adm / automated
#       9  dashboard / digital project / queensland / contribution publ
#      10  ipgod / ip australia / property government / government open
#      11  ai / patent / invention / inventor
#      12  artificial intelligence / patent / inventorship / ai
#      13  valuation / intellectual / property / asset
#      14  enforcement intellectual / property right / intellectual pro
#      15  retrieval / patent / learning prior / mapreduce
#      16  law / ip / chapter / copyright
#      17  ai / copyright / uk / artificial
#      19  covid-19 / vaccine / pandemic / crisis-critical
#      20  art search / prior art / patent / augmenting keyword-based
#      21  cultural heritage / property cultural / intellectual / intan
#      22  asset / intellectual property / collateral / ip
#      24  patent / retrieval / classification / search
#      25  intellectual property / right / property law / cambridge int
#      26  indigenous / intellectual / property / cultural
#      27  education / ai / metaverse / chatgpt
#      28  china / intellectual property / chinese / innovation evidenc
#      30  valuation / intellectual property / asset / intangible
#      31  image / patent / retrieval / industrial good
#      37  retrieval / document / snippet / abstractive
#      38  genetic resource / benefit sharing / farmer / access benefit
#      40  patent / examiner / prior art / rejection
#      41  access medicine / pharmaceutical / intellectual property / t
#      42  intellectual property / african / ip / nigeria
#      44  accountability / social care / nursing / decision-making
#      45  indigenous / cultural / traditional knowledge / intellectual
#      46  ip / enforcement / intellectual / counterfeit
#      47  patent / innovation / firm / intellectual
#      50  prior art / patent / art defense / art prior
#      51  intellectual property / enforcement / property right / law p
#      52  intellectual property / biotechnology / open science / neuro
#      53  llm / language / task / reasoning
#      55  deepfake / content / ai / governance
#      58  blockchain / nft / non-fungible / copyright
#      62  tc / idea generation / technological resource / technology i
#      67  intellectual / property / nsrc / participating organisation
#      74  regulatory policy / government / policy making / regulatory
#      85  learning / diagnosis / disease / prediction
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (10)
#      18  geographical indication / trade / protection / eu
#      23  gis / geographical indication / agreement / gi protection
#      29  trust / institution / public / citizen
#      32  trust / institution / public / driver
#      43  unlearning / erasure / concept / diffusion
#      54  service delivery / government / digital / public service
#      59  valuation / briefing / valuer / market
#      63  gi / geographical indication / product / export
#      82  learning / rl / reinforcement / reward
#      83  influencer / authenticity / media / instagram
#
# CAPABILITY LOOKING FOR A PROBLEM (10)
#      34  opengov / ul / li / au
#      35  valuation / editorial / property / appendix
#      49  reef / park / marine / australia
#      64  robot / soft / actuation / tip
#      69  entity / text / texsmart / rair
#      77  hps / chemical / reaction / cof
#      81  crop / remote sensing / agriculture / weed
#      91  point cloud / object / image / detection
#      96  graph / gnn / node / network
#     104  graph / isometric / vertice / cycle
#
# WATCH (47)
#      33  copyright page / copyright notice
#      36  watermarking / text / llm / language
#      39  trust / covid-19 / pandemic / public
#      48  financial autonomy / local government / government system /
#      56  foramen / ovale / percutaneous / closure
#      57  elevation / elvis / river / area cover
#      60  preface / acknowledgment / list illustration / note
#      61  battery / energy storage / lithium-ion / sib
#      65  gene / crispr / editing / genome
#      66  trust / iceland / financial / crisis
#      68  aesthetic / nesp / dugong / flickr
#      70  navigation / robot / task / learning
#      71  embodied / video / clap / scene
#      72  video / vlm / visual / retrieval
#      73  energy storage / storage system / renewable / grid
#      75  odometry / navigation / positioning / lidar
#      76  africa / kilometre km / square kilometre / population
#      78  vehicle / autonomous / driving / safety
#      79  underwater / auv / autonomous / vehicle
#      80  trade / agreement / facilitation / viii
#      84  synthetic biology / microbial / gene / cell
#      86  additive manufacturing / material / printing / ceramic
#      87  dialog / emotion / conversational / misleadingness
#      88  hydrogen / energy / storage / ammonia
#      89  robot / swarm / uav / navigation
#      90  navigation / robot / deep reinforcement / learning
#      92  quantum / error / qubit / gate
#      93  higg / scalar / decay / meson
#      94  quantum / spin / nv / diamond
#      95  music / audio / watermarking / voice
#      97  algorithm / covariance / optimization / bayesian
#      98  quantum / state / qubit / sensing
#      99  nodule / lung / ct / mri
#     100  image / dataset / facial / learning
#     101  ris / communication / wireless / isac
#     102  attack / watermarking / iot / detection
#     103  cultural / heritage / gallery auction / management issue
#     105  kd / knowledge distillation / domain / teacher
#     106  black hole / pbh / thermodynamic / dm
#     107  watermark / image / attack / dnn
#     108  quantum / measurement / magic / gate
#     109  dwarf / disk / leo / hd
#     110  flow / fluid / equation / lbm
#     111  spin / film / magnetic / inas
#     112  quantum / system / fermionic / phase
#     113  quantum / circuit / qubit / gate
#     114  quantum / blockchain / nist / encryption

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = 'verify-bertopic-T0059'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  arc additive / wire arc / additive manufacturing / intelligence wire
# 22 documents · 2018–2025 · H1 · weak
#
# Defining terms: arc additive, wire arc, additive manufacturing, wire, intelligence wire, manufacturing systematic, arc, patent landscape, systematic patent, additive, manufacturing, landscape
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ███
#      2019     0
#      2020     0
#      2021     0
#      2022     0
#      2023     0
#      2024     1  █
#      2025    19  ████████████████████████  ← burst
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Review for "Artificial Intelligence in Wire Arc Additive Manufacturing: A Systematic Review and
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/eng2.70518/v4/review3
#   • Review for "Artificial Intelligence in Wire Arc Additive Manufacturing: A Systematic Review and
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/eng2.70518/v1/review3
#   • Review for "Artificial Intelligence in Wire Arc Additive Manufacturing: A Systematic Review and
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/eng2.70518/v2/review1
#   • Review for "Artificial Intelligence in Wire Arc Additive Manufacturing: A Systematic Review and
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/eng2.70518/v1/review1
#   • Review for "Artificial Intelligence in Wire Arc Additive Manufacturing: A Systematic Review and
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/eng2.70518/v2/review2

# %%
TOPIC_ID = 'verify-bertopic-T0012'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  automated decision-making / administrative / government / accountability
# 80 documents · 2018–2026 · H1 · strong
#
# Defining terms: automated decision-making, decision-making, automated, administrative, government, administrative decision-making, administrative law, automated decision, decision, accountability, governmental automated, decision making
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     3  ████
#      2019     4  █████
#      2020     7  █████████
#      2021     8  ██████████
#      2022     4  █████
#      2023    19  ████████████████████████  ← burst
#      2024     7  █████████
#      2025     8  ██████████
#      2026     8  ██████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Situating the Rule of Law in the Context of Automated Decision-Making
#     crossref · 2023 · The Rule of Law and Automated Decision-Making
#     https://doi.org/10.1007/978-3-031-30142-1_2
#   • Automated Decision-making
#     crossref · 2025 · Smart Court
#     https://doi.org/10.1017/9781009319232.007
#   • Automated Decision-Making and the Law
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_3
#   • Understanding Automated Decision-Making in the Public Sector: A Classification of Automated, Adm
#     crossref · 2022 · Progress in IS
#     https://doi.org/10.1007/978-3-030-92644-1_3
#   • Confronting the Legal Challenges of Governmental Automated Decision-Making
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_5

# %%
TOPIC_ID = 'verify-bertopic-T0081'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  competition policy / intellectual property / property competition / policy intellectual
# 16 documents · 2021–2026 · H2 · weak
#
# Defining terms: competition policy, competition, intellectual property, intellectual, property competition, policy intellectual, policy, vis, property, competition law, enforcement experience, vis intellectual
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021    11  ████████████████████████  ← burst
#      2022     0
#      2023     2  ████
#      2024     0
#      2025     2  ████
#      2026     1  ██
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Competition Policy and Intellectual Property: Insights from Developed Country Experience
#     crossref · 2021 · Competition Policy and Intellectual Property in Today's Global Economy
#     https://doi.org/10.1017/9781108157827.016
#   • The Competition Policy Roots of Intellectual Property Law: A Reflection
#     crossref · 2021 · Competition Policy and Intellectual Property in Today's Global Economy
#     https://doi.org/10.1017/9781108157827.008
#   • Time to Look Afresh at the International Dimension of Competition Policy and Intellectual Proper
#     crossref · 2021 · Competition Policy and Intellectual Property in Today's Global Economy
#     https://doi.org/10.1017/9781108157827.031
#   • The Application of Competition Policy vis-à-vis Intellectual Property Rights: The Evolution of T
#     crossref · 2021 · Competition Policy and Intellectual Property in Today's Global Economy
#     https://doi.org/10.1017/9781108157827.004
#   • Competition Policy, Intellectual Property and Network Industries: Post-1995 Enforcement Experien
#     crossref · 2021 · Competition Policy and Intellectual Property in Today's Global Economy
#     https://doi.org/10.1017/9781108157827.023

# %%
TOPIC_ID = 'verify-bertopic-T0109'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  genai / generative / chatgpt / ethical
# 12 documents · 2023–2026 · H1 · weak
#
# Defining terms: genai, generative, ai, generative ai, chatgpt, ethical, discord, generative artificial, brand, genai tool, attack, intelligence
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     0
#      2022     0
#      2023     6  ████████████████████████  ← burst
#      2024     3  ████████████  ← burst
#      2025     1  ████  ← burst
#      2026     1  ████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Opinion Paper: “So what if ChatGPT wrote it?” Multidisciplinary perspectives on opportunities, c
#     openalex · 2023 · International Journal of Information Management
#     https://doi.org/10.1016/j.ijinfomgt.2023.102642
#   • Human resource management in the age of generative artificial intelligence: Perspectives and res
#     openalex · 2023 · Human Resource Management Journal
#     https://doi.org/10.1111/1748-8583.12524
#   • Do you create your content yourself? Using generative artificial intelligence for social media c
#     openalex · 2024 · Journal of Retailing and Consumer Services
#     https://doi.org/10.1016/j.jretconser.2024.103790
#   • Generative artificial intelligence
#     openalex · 2023 · Electronic Markets
#     https://doi.org/10.1007/s12525-023-00680-1
#   • Sophistication in GenAI Use: Field Evidence from a Large Firm
#     arxiv · 2026 · arXiv
#     http://arxiv.org/abs/2608.27364v1

# %%
TOPIC_ID = 'verify-bertopic-T0101'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  decision-making / accountability / ai / automated
# 68 documents · 2020–2026 · H2 · weak
#
# Defining terms: decision-making, automated decision-making, accountability, ai, automated, fairness, ethical, accountability transparency, transparency, ethic, corporate, decision making
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     1  █████
#      2021     1  █████
#      2022     1  █████
#      2023     2  ██████████
#      2024     1  █████
#      2025     5  ████████████████████████
#      2026     2  ██████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Ethical Implications of AI in Decision - Making: Exploring Bias, Accountability, and Transparenc
#     crossref · 2024 · International Journal of Science and Research (IJSR)
#     https://doi.org/10.21275/sr241127154622
#   • Fairness, Accountability, and Transparency in AI: Ethical Challenges in Data-Driven Decision-Mak
#     crossref · 2025 · posted-content
#     https://doi.org/10.2139/ssrn.5128174
#   • ARTIFICIAL INTELLIGENCE AS A JURIDICAL PERSON: RETHINKING ACCOUNTABILITY IN THE ERA OF AUTOMATED
#     crossref · 2026 · LawFoyer International Journal of Doctrinal Legal Research
#     https://doi.org/10.70183/lijdlr.2026.v04.164
#   • AI and Corporate Ethics: Legal Accountability in the Age of Automated Decision-Making
#     crossref · 2025 · posted-content
#     https://doi.org/10.2139/ssrn.5422454
#   • How to Explain and Justify Almost Any Decision: Potential Pitfalls for Accountability in AI Deci
#     crossref · 2023 · 2023 ACM Conference on Fairness, Accountability, and Transparency
#     https://doi.org/10.1145/3593013.3593972

# %%
TOPIC_ID = 'verify-bertopic-T0094'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  patent portfolio / portfolio management
# 24 documents · 2018–2025 · H3 · weak
#
# Defining terms: patent portfolio, portfolio, portfolio management, patent, management
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ███
#      2019     2  █████
#      2020     0
#      2021     0
#      2022     0
#      2023     1  ███
#      2024     0
#      2025     9  ████████████████████████  ← burst
#      2026     0    ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Patent Portfolio Management
#     crossref · 2025 · monograph
#     https://doi.org/10.4337/9781035346196
#   • Strategizing patent portfolio management
#     crossref · 2025 · Patent Portfolio Management
#     https://doi.org/10.4337/9781035346196.00010
#   • Introduction to patent portfolio management
#     crossref · 2025 · Patent Portfolio Management
#     https://doi.org/10.4337/9781035346196.00009
#   • Organizing patent portfolio management
#     crossref · 2025 · Patent Portfolio Management
#     https://doi.org/10.4337/9781035346196.00012
#   • Extracting value from the patent portfolio
#     crossref · 2025 · Patent Portfolio Management
#     https://doi.org/10.4337/9781035346196.00016

# %%
TOPIC_ID = 'verify-bertopic-T0034'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  intellectual property / property protection / corporate / digital
# 44 documents · 2018–2026 · H3 · strong
#
# Defining terms: intellectual property, intellectual, property protection, property, corporate, protection, digital, digital transformation, firm, governance, corporate governance, financing
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     5  █████████
#      2019     0
#      2020     1  ██
#      2021     2  ████
#      2022     0
#      2023     1  ██
#      2024     4  ███████
#      2025    13  ████████████████████████  ← burst
#      2026     7  █████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Intellectual property protection and corporate digital transformation: An empirical analysis fro
#     crossref · 2025 · International Review of Economics &amp; Finance
#     https://doi.org/10.1016/j.iref.2025.104125
#   • Digital governance, financial support, and intellectual property protection transformation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108250
#   • Intellectual property protection and firm innovation capability
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2026.109559
#   • Intellectual property protection policy and firms' digital investment: Evidence from a quasi-nat
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2026.110478
#   • Digital finance development, intellectual property protection, and regional innovation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108217

# %%
TOPIC_ID = 'verify-bertopic-T0008'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  ai / decision-making / adm / automated
# 141 documents · 2018–2026 · H2 · strong
#
# Defining terms: ai, decision-making, automated decision-making, adm, automated, accountability, governance, decision, public, human, algorithmic, system
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  ███
#      2019     5  ████
#      2020     3  ██
#      2021     7  ██████
#      2022     5  ████
#      2023     8  ███████
#      2024    17  ██████████████
#      2025    13  ███████████
#      2026    29  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • THE ETHICAL, LEGAL, AND SOCIAL IMPLICATIONS OF DEPLOYING AGENTIC AI: EXAMINING AUTONOMY, ACCOUNT
#     crossref · 2026 · Journal of Digital Security and Forensics
#     https://doi.org/10.29121/digisecforensics.v2.i1.2025.83
#   • Governing AI Decision‐Making: Balancing Innovation and Accountability
#     crossref · 2025 · Politics and Governance
#     https://doi.org/10.17645/pag.10245
#   • Ethics of Using Data in Automated Decision-Making (Comparative Perspectives on Transparency, Fai
#     crossref · 2025 · ECONOMICUS
#     https://doi.org/10.58944/vcev7439
#   • Automated Decision-Making in EU Public Law and Governance
#     crossref · 2024 · Governance of Automated Decision-Making and EU Law
#     https://doi.org/10.1093/9780198919575.003.0011
#   • Reviewable Automated Decision-Making
#     crossref · 2020 · posted-content
#     https://doi.org/10.2139/ssrn.3689166

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
