# %% [markdown]
# # IPAVentures horizon scan — run `2026-09-14T1447`
#
# Generated 2026-09-14 19:05 UTC by `python -m src.notebook --run-id 2026-09-14T1447`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = '2026-09-14T1447'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    2026-09-14T1447
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 31,513

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
if _method == "bertopic":
    # Under BERTopic the similarity threshold does not cluster anything —
    # HDBSCAN works on density in UMAP space and takes no cosine cut-off. It is
    # read for one purpose only: attaching documents from non-forming sources
    # to the nearest finished topic. Labelled for what it does, so a reviewer
    # is not left comparing it against a clustering threshold from another run.
    print("Attachment thresh :", _thresh.get(_backend, "not recorded"),
          f"x ratio {_topics_cfg.get('attachment_threshold_ratio', 0.6)}")
    # THE SEED. UMAP's initialisation is stochastic, so this is the difference
    # between a topic set another analyst can reproduce and one they cannot.
    # Printed from the run's own snapshot, never from today's config file.
    _bt = _topics_cfg.get("bertopic") or {}
    print("BERTopic seed     :", _bt.get("random_state", "NOT RECORDED"))
    print("BERTopic UMAP     :",
          f"n_neighbors={_bt.get('n_neighbors')}, "
          f"n_components={_bt.get('n_components')}, "
          f"min_dist={_bt.get('min_dist')}, metric={_bt.get('metric')}")
    print("BERTopic HDBSCAN  :",
          f"min_cluster_size={_bt.get('min_cluster_size') or _topics_cfg.get('min_topic_size')}, "
          f"min_samples={_bt.get('min_samples')}, "
          f"selection={_bt.get('cluster_selection_method')}")
    if not isinstance(_bt.get("random_state"), int):
        print("\n  WARNING: no seed recorded for this run. UMAP is stochastic, "
              "so the topics below cannot be reproduced exactly, even from this "
              "same corpus and config.")
else:
    print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : bge
# Clustering method : bertopic
# Attachment thresh : 0.9 x ratio 0.6
# BERTopic seed     : 42
# BERTopic UMAP     : n_neighbors=15, n_components=5, min_dist=0.0, metric=cosine
# BERTopic HDBSCAN  : min_cluster_size=8, min_samples=None, selection=eom
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status      in    out    seconds  message
# ------------------------  -------  -----  -----  ---------  ----------------------------------------------------------------
# stage0_strategy           success      —     34      0.300  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage1_collect            partial  24551  13171  10456.100  24551 fetched, 13171 new, 13 failed/skipped pairs, 22 partial i…
# stage2_emergence          success  31513    117   4953.800  117 topics from 31513 documents across 9 slices (2018-2026); 26…
# stage5_synthesis          success    117    117     25.200  ranked 117 topics; outputs written
# stage3_scoring            success    117    117     24.000  scored 117 topics; mean fit 0.486, mean leverage 0.355, 0 criti…
# stage4_opportunity_index  success    117    117      0.300  indexed 117 of 117 topics (0 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# gdelt          14241        2024       2026      25
# openalex        7372        2018       2026      35
# crossref        5318        2018       2026      28
# arxiv           2214        2018       2026       9
# oecd            1927        2018       2026      32
# datagovau        441        2022       2026       9
#
# What this run's collection actually did (per source query):
#
# source     status   queries  records
# ---------  -------  -------  -------
# arxiv      failed         2        0
# arxiv      skipped       10        0
# crossref   success       28     5420
# datagovau  success        9      450
# gdelt      failed         1        0
# gdelt      partial       22     6459
# gdelt      success        3     2525
# oecd       success       32     2057
# openalex   success       35     7640

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018       1711
# 2019       1899
# 2020       2263
# 2021       2103
# 2022       1794
# 2023       1899
# 2024       2580
# 2025       9334
# 2026       7930
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       8900
# Economic            5820
# Political           5181
# Environmental       4624
# Social              3213
# Legal               1958
# Values              1817

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                         STEEPV         documents  sources
# ---------------------------------  -------------  ---------  -------
# ai_governance_assurance            Political           1791        6
# ct_quantum                         Technological       1701        4
# climate_adaptation                 Environmental       1565        5
# digital_identity_provenance        Technological       1475        3
# digital_competition_platforms      Economic            1298        4
# ai_authorship_inventorship         Legal               1226        5
# gov_service_delivery               Political           1200        5
# indigenous_knowledge               Values              1192        4
# ct_biotech                         Technological       1160        4
# ip_finance_valuation               Economic            1137        4
# workforce_skills_automation        Economic            1121        4
# trust_institutions                 Social              1114        4
# ip_enforcement_counterfeit         Economic            1099        4
# information_integrity              Social               909        4
# defence_dual_use                   Political            841        3
# geoeconomics_supply_chains         Political            822        5
# ct_ai                              Technological        819        4
# ip_admin_automation                Technological        805        5
# food_agriculture_systems           Environmental        750        5
# ct_advanced_manufacturing          Technological        749        3
# geographical_indications           Legal                732        3
# health_system_innovation           Social               729        4
# ct_energy                          Environmental        714        3
# water_security                     Environmental        681        4
# ct_autonomous                      Technological        653        3
# ip_search_retrieval                Technological        650        3
# strategic_foresight_practice       Values               625        3
# housing_construction_productivity  Economic             560        4
# ip_sme_access                      Economic             558        4
# ip_policy_reform                   Political            527        5
# space_earth_observation            Technological        527        3
# circular_economy_materials         Environmental        514        4
# ageing_wellbeing                   Social               461        3
# oceans_blue_economy                Environmental        400        3
# ct_advanced_ict                    Technological        361        3
# oecd_southeast_asia_reports        Economic              47        1

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Failed queries by source: arxiv (2), gdelt (1). Each failure costs that frame's contribution to the corpus, so the shortlist is drawn from a slightly different scan than the frame file describes.

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic                  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# ---------------------  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# 2026-09-14T1447-T0012  chain resilience / supply chain / chain risk   142  0.18  0.19  0.87  0.69  0.86       0.84  H1  strong
# 2026-09-14T1447-T0116  loneliness / social isolation / older / adul    30  0.25  0.13  0.91  0.68  0.63       0.81  H1  weak
# 2026-09-14T1447-T0046  patent / retrieval / art search / prior art     66  0.21  0.13  0.87  0.72  0.64       0.80  H1  strong
# 2026-09-14T1447-T0044  llm / medical / chatgpt / clinical              69  0.16  0.29  0.86  0.68  0.82       0.79  H1  strong
# 2026-09-14T1447-T0093  precision agriculture / system precision / a    64  0.20  0.12  0.79  0.62  0.90       0.77  H2  weak
# 2026-09-14T1447-T0062  kilometre km / square kilometre / population    63  0.35  0.20  0.79  0.61  0.21       0.76  H2  weak
# 2026-09-14T1447-T0005  antimicrobial / amr / sepsis / resistance      235  0.16  0.34  0.83  0.68  0.74       0.75  H3  strong
# 2026-09-14T1447-T0006  circular / recycling / economy / product des   182  0.16  0.16  0.84  0.70  0.90       0.74  H1  strong
# 2026-09-14T1447-T0097  wellbeing / policy / affect / health            62  0.23  0.29  0.78  0.58  0.45       0.74  H1  weak
# 2026-09-14T1447-T0114  vaccine / covid-19 / vaccination / hesitancy    36  0.20  0.06  0.84  0.61  0.79       0.73  H1  weak
# 2026-09-14T1447-T0109  cultural heritage / property cultural / inte    78  0.21  0.17  0.73  0.58  0.96       0.73  H1  weak
# 2026-09-14T1447-T0013  llm / language / task / reasoning              131  0.17  0.17  0.83  0.59  0.85       0.73  H1  strong
# 2026-09-14T1447-T0065  watermarking / text / llm / language            60  0.22  0.34  0.87  0.50  0.57       0.72  H1  strong
# 2026-09-14T1447-T0111  water / nsw / portal / 2024data                 42  0.21  0.41  0.81  0.50  0.75       0.71  H1  weak
# 2026-09-14T1447-T0042  trust / covid-19 / pandemic / public            74  0.19  0.17  0.86  0.52  0.76       0.70  H1  strong
# 2026-09-14T1447-T0081  task / robot / learning / navigation            46  0.20  0.17  0.85  0.52  0.73       0.70  H2  weak
# 2026-09-14T1447-T0045  climate / resilience / adaptation / infrastr   115  0.16  0.21  0.79  0.61  0.83       0.68  H2  strong
# 2026-09-14T1447-T0088  foresight / anticipatory / scenario planning    88  0.17  0.20  0.75  0.56  0.89       0.67  H1  weak
# 2026-09-14T1447-T0011  patent / retrieval / prior art / classificat   137  0.15  0.20  0.86  0.53  0.87       0.67  H2  strong
# 2026-09-14T1447-T0027  automated decision-making / accountability /   341  0.19  0.24  0.75  0.54  0.77       0.67  H2  strong
# 2026-09-14T1447-T0038  drought / catchment / water / hydrological      70  0.16  0.10  0.86  0.74  0.61       0.67  H1  strong
# 2026-09-14T1447-T0104  housing / household / rental / dwelling        110  0.22  0.42  0.74  0.50  0.75       0.67  H1  weak
# 2026-09-14T1447-T0034  ai / education / teacher / chatgpt             199  0.16  0.26  0.75  0.57  0.80       0.66  H1  strong
# 2026-09-14T1447-T0077  audio / music / speech / watermarking           54  0.18  0.26  0.81  0.50  0.80       0.65  H3  weak
# 2026-09-14T1447-T0099  water / photothermal / solar / evaporation      39  0.18  0.05  0.82  0.55  0.83       0.64  H1  noise
# 2026-09-14T1447-T0029  misinformation / online / age / social media   558  0.21  0.29  0.69  0.53  0.70       0.64  H1  strong
# 2026-09-14T1447-T0105  dpi / em / climate / biosecurity risk           70  0.19  0.44  0.77  0.50  0.60       0.63  H2  weak
# 2026-09-14T1447-T0089  intellectual property / property protection    151  0.17  0.29  0.73  0.53  0.76       0.62  H2  weak
# 2026-09-14T1447-T0063  mineral / deposit / critical / geoscience      164  0.21  0.50  0.72  0.50  0.46       0.62  H2  strong
# 2026-09-14T1447-T0039  modular / housing / construction / supply       99  0.18  0.01  0.79  0.60  0.90       0.61  H1  latent
# 2026-09-14T1447-T0060  supply chain / food / pandemic / covid-19      144  0.15  0.20  0.77  0.55  0.88       0.61  H1  weak
# 2026-09-14T1447-T0086  enforcement intellectual / property right /    135  0.23  0.15  0.71  0.54  0.29       0.60  H1  weak
# 2026-09-14T1447-T0025  supply chain / chain resilience / sc / disru    93  0.14  0.06  0.88  0.62  0.85       0.60  H1  strong
# 2026-09-14T1447-T0008  loneliness / social isolation / health / old   155  0.16  0.10  0.84  0.59  0.68       0.59  H1  strong
# 2026-09-14T1447-T0020  trust / institution / public / doctrine        170  0.20  0.00  0.78  0.62  0.78       0.57  H2  latent
# 2026-09-14T1447-T0087  nanotechnology / nanoparticle / nanomaterial    54  0.15  0.04  0.79  0.63  0.84       0.57  H1  noise
# 2026-09-14T1447-T0043  competition / digital platform / digital mar   382  0.19  0.20  0.68  0.52  0.69       0.56  H2  strong
# 2026-09-14T1447-T0112  vehicle / autonomous / driving / avs            44  0.18  0.01  0.79  0.53  0.90       0.56  H1  noise
# 2026-09-14T1447-T0022  recycling / plastic / waste / circular         140  0.12  0.14  0.80  0.62  0.78       0.56  H1  strong
# 2026-09-14T1447-T0066  cent / forecast / per / export earning         380  0.19  0.41  0.65  0.50  0.68       0.56  H1  strong
# 2026-09-14T1447-T0070  earth observation / satellite / european / o    66  0.19  0.00  0.81  0.60  0.80       0.56  H1  noise
# 2026-09-14T1447-T0023  blockchain / supply chain / traceability / t   101  0.14  0.11  0.86  0.56  0.69       0.55  H1  strong
# 2026-09-14T1447-T0096  vaccine / covid-19 / waiver / pandemic          57  0.17  0.12  0.80  0.41  0.96       0.54  H1  weak
# 2026-09-14T1447-T0073  housing / supply / construction / nbsp         224  0.19  0.16  0.68  0.54  0.44       0.54  H2  weak
# 2026-09-14T1447-T0078  bone / additive manufacturing / scaffold / i    46  0.20  0.04  0.85  0.49  0.65       0.54  H1  noise
# 2026-09-14T1447-T0037  energy / grid / storage system / power          79  0.20  0.00  0.85  0.54  0.70       0.53  H1  latent
# 2026-09-14T1447-T0090  drought / water / hedging / policy              59  0.16  0.00  0.79  0.64  0.85       0.53  H1  noise
# 2026-09-14T1447-T0009  water / membrane / treatment / dye             139  0.16  0.05  0.81  0.59  0.57       0.53  H1  latent
# 2026-09-14T1447-T0068  video / learning / visual / memory              54  0.17  0.02  0.83  0.53  0.73       0.53  H1  noise
# 2026-09-14T1447-T0082  scene / point cloud / object / image            44  0.21  0.00  0.84  0.52  0.74       0.53  H1  noise
# 2026-09-14T1447-T0092  lidar / odometry / localization / inertial      40  0.20  0.00  0.84  0.51  0.84       0.53  H1  noise
# 2026-09-14T1447-T0071  hydrogen / electrolysis / energy / storage      88  0.18  0.00  0.76  0.60  0.85       0.52  H1  noise
# 2026-09-14T1447-T0047  synthetic biology / cell / biomanufacturing    141  0.17  0.11  0.75  0.51  0.82       0.52  H1  strong
# 2026-09-14T1447-T0103  critical mineral / supply chain / mineral su   258  0.16  0.37  0.69  0.52  0.46       0.51  H3  weak
# 2026-09-14T1447-T0007  intellectual property / property right / pro   507  0.17  0.09  0.74  0.54  0.72       0.51  H1  strong
# 2026-09-14T1447-T0095  export control / dual-use / eu / control reg   165  0.18  0.12  0.67  0.55  0.37       0.51  H1  weak
# 2026-09-14T1447-T0026  energy / storage / renewable / battery         123  0.22  0.00  0.79  0.52  0.80       0.51  H1  latent
# 2026-09-14T1447-T0113  climate / health / change / mental              70  0.17  0.00  0.75  0.60  0.90       0.51  H1  noise
# 2026-09-14T1447-T0018  ageing / population / older / policy           217  0.15  0.03  0.76  0.63  0.71       0.51  H1  latent
# 2026-09-14T1447-T0056  quantum / patent / ai / invention              232  0.15  0.28  0.71  0.52  0.72       0.50  H1  strong
# 2026-09-14T1447-T0057  climate / food / change / emission             116  0.14  0.05  0.79  0.59  0.84       0.50  H1  noise
# 2026-09-14T1447-T0033  artificial intelligence / patent / inventors   860  0.18  0.16  0.70  0.52  0.56       0.50  H2  strong
# 2026-09-14T1447-T0028  construction / housing / modular / prefabric    82  0.14  0.18  0.84  0.43  0.84       0.49  H2  strong
# 2026-09-14T1447-T0048  battery / energy storage / lib / lithium-ion   136  0.18  0.00  0.75  0.60  0.78       0.48  H1  latent
# 2026-09-14T1447-T0083  adm / automated decision-making / algorithmi    72  0.13  0.06  0.79  0.54  0.92       0.48  H2  weak
# 2026-09-14T1447-T0040  agriculture / crop / iot / precision            81  0.14  0.00  0.86  0.59  0.83       0.47  H1  latent
# 2026-09-14T1447-T0055  additive manufacturing / powder / alloy / ma    87  0.18  0.00  0.78  0.54  0.76       0.47  H1  noise
# 2026-09-14T1447-T0024  service delivery / govtech / digital / gover   280  0.15  0.28  0.74  0.49  0.72       0.46  H2  strong
# 2026-09-14T1447-T0004  watermarking / image / attack / dnn            241  0.19  0.00  0.85  0.49  0.75       0.45  H1  latent
# 2026-09-14T1447-T0059  uav / navigation / robot / autonomous           66  0.18  0.00  0.81  0.43  0.95       0.45  H1  noise
# 2026-09-14T1447-T0067  service delivery / public service / digital    301  0.19  0.01  0.70  0.54  0.21       0.45  H2  noise
# 2026-09-14T1447-T0098  cell / scrna-seq / cancer / sequencing         100  0.15  0.00  0.71  0.62  0.95       0.44  H1  noise
# 2026-09-14T1447-T0054  indigenous / intellectual property / cultura   402  0.20  0.01  0.69  0.52  0.67       0.44  H1  latent
# 2026-09-14T1447-T0058  cancer / patient / learning / disease           71  0.14  0.10  0.79  0.48  0.86       0.42  H1  strong
# 2026-09-14T1447-T0017  satellite / aerosol / ocean / observation      115  0.14  0.11  0.83  0.50  0.67       0.42  H1  strong
# 2026-09-14T1447-T0036  synthetic biology / metabolic / engineering     87  0.15  0.10  0.81  0.44  0.75       0.42  H1  strong
# 2026-09-14T1447-T0102  covariance / matrix / nonconvex / sample        42  0.14  0.04  0.79  0.52  0.85       0.42  H2  noise
# 2026-09-14T1447-T0019  climate / disaster / adaptation / drr          184  0.11  0.06  0.78  0.53  0.87       0.42  H1  strong
# 2026-09-14T1447-T0001  breeding / plant / crop / genetic              342  0.14  0.00  0.80  0.60  0.79       0.42  H1  latent
# 2026-09-14T1447-T0108  satellite / image / eo / earth observation      37  0.15  0.00  0.82  0.51  0.89       0.42  H1  noise
# 2026-09-14T1447-T0101  surgical / robot / surgery / surgeon            39  0.17  0.00  0.81  0.47  0.89       0.41  H1  noise
# 2026-09-14T1447-T0115  copyright / ai / generative / artificial       258  0.14  0.24  0.72  0.50  0.66       0.41  H1  weak
# 2026-09-14T1447-T0003  blue economy / marine / ocean / msp            438  0.12  0.00  0.75  0.55  0.92       0.41  H1  latent
# 2026-09-14T1447-T0080  esg / corporate / firm / disclosure             72  0.14  0.00  0.79  0.57  0.84       0.40  H1  noise
# 2026-09-14T1447-T0091  front matter / frontmatter / back matter / p   243  0.24  0.00  0.64  0.52  0.62       0.39  H1  noise
# 2026-09-14T1447-T0076  robot / agricultural / navigation / crop        50  0.16  0.00  0.86  0.40  0.80       0.39  H1  noise
# 2026-09-14T1447-T0035  circular / ce / economy / recycling            114  0.12  0.00  0.81  0.58  0.80       0.39  H1  latent
# 2026-09-14T1447-T0072  ai / public / governance / sector              332  0.15  0.16  0.72  0.47  0.70       0.39  H1  weak
# 2026-09-14T1447-T0110  misinformation / disinformation / media / fa   165  0.16  0.05  0.66  0.51  0.77       0.38  H1  noise
# 2026-09-14T1447-T0069  anticipatory / foresight / governance / stra    71  0.11  0.06  0.84  0.42  0.88       0.38  H1  weak
# 2026-09-14T1447-T0021  wireless / communication / edge / network      130  0.13  0.00  0.77  0.59  0.83       0.37  H1  latent
# 2026-09-14T1447-T0075  indigenous / traditional knowledge / intelle   116  0.15  0.04  0.74  0.43  0.89       0.36  H2  noise
# 2026-09-14T1447-T0002  geographical indication / gi / kente / produ   382  0.14  0.01  0.79  0.47  0.89       0.36  H1  latent
# 2026-09-14T1447-T0061  ai / gdpr / health / clinical                  181  0.15  0.00  0.75  0.54  0.76       0.35  H1  noise
# 2026-09-14T1447-T0015  automation / employment / worker / job         662  0.12  0.17  0.71  0.50  0.67       0.35  H1  strong
# 2026-09-14T1447-T0085  food / farming / agriculture / system          101  0.12  0.00  0.77  0.55  0.89       0.35  H1  noise
# 2026-09-14T1447-T0064  green innovation / patent / firm / environme   130  0.11  0.13  0.77  0.42  0.84       0.35  H1  weak
# 2026-09-14T1447-T0094  deepfake / aigc / content / ai-generated       771  0.15  0.13  0.68  0.50  0.58       0.34  H2  weak
# 2026-09-14T1447-T0079  governance / nbs / nature-based solution / p    74  0.10  0.08  0.79  0.46  0.83       0.34  H1  weak
# 2026-09-14T1447-T0049  marine / fungi / ocean / biotechnological       73  0.12  0.06  0.81  0.40  0.77       0.34  H1  strong
# 2026-09-14T1447-T0050  defence / innovation / military / dual-use     301  0.14  0.02  0.69  0.54  0.66       0.33  H1  latent
# 2026-09-14T1447-T0052  prefabricated / construction / mic / bim        64  0.16  0.00  0.85  0.39  0.76       0.33  H1  noise
# 2026-09-14T1447-T0032  climate / adaptation / resilience / change     392  0.15  0.00  0.74  0.54  0.71       0.33  H2  latent
# 2026-09-14T1447-T0053  employment / skill / youth / graduate          421  0.18  0.00  0.68  0.52  0.40       0.32  H2  latent
# 2026-09-14T1447-T0000  quantum / qubit / entanglement / computing    1627  0.14  0.00  0.74  0.52  0.82       0.30  H1  latent
# 2026-09-14T1447-T0106  valuation / valuer / briefing / avm            110  0.14  0.00  0.68  0.58  0.71       0.29  H2  noise
# 2026-09-14T1447-T0010  trust / public / institution / citizen         298  0.14  0.00  0.78  0.50  0.77       0.28  H1  latent
# 2026-09-14T1447-T0016  health / digital / dht / technology            355  0.12  0.00  0.74  0.53  0.82       0.28  H1  latent
# 2026-09-14T1447-T0084  regulatory policy / plc / enforcement / regu  2136  0.16  0.01  0.61  0.50  0.06       0.28  H1  noise
# 2026-09-14T1447-T0014  water / desalination / reuse / management      219  0.11  0.00  0.78  0.51  0.84       0.27  H1  latent
# 2026-09-14T1447-T0051  medicine / trip / access / patent              323  0.15  0.00  0.68  0.51  0.73       0.26  H1  latent
# 2026-09-14T1447-T0100  dma / competition law / digital market / dra   306  0.16  0.00  0.72  0.49  0.47       0.25  H1  noise
# 2026-09-14T1447-T0074  patent / citation / technology / sca            72  0.09  0.00  0.79  0.43  0.89       0.25  H1  noise
# 2026-09-14T1447-T0107  honey / geographical origin / food / authent    62  0.15  0.00  0.73  0.41  0.83       0.23  H1  noise
# 2026-09-14T1447-T0041  satellite / leo / orbit / space                 89  0.14  0.00  0.78  0.38  0.77       0.23  H1  latent
# 2026-09-14T1447-T0031  blockchain / technology / smart contract / f   277  0.14  0.00  0.70  0.51  0.75       0.23  H1  latent
# 2026-09-14T1447-T0030  patent / innovation / firm / intellectual pr   244  0.11  0.00  0.75  0.46  0.68       0.16  H1  latent

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 117 of 117 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 23,382 of 31,513 documents (74%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 16 topic(s) sit within 0.05 of a Three Horizons cut-point (climate / resilience / adaptation / infr (0.37 → H2); artificial intelligence / patent / inven (0.38 → H2); precision agriculture / system precision (0.38 → H2); covariance / matrix / nonconvex / sample (0.38 → H2); service delivery / govtech / digital / g (0.71 → H2); automated decision-making / accountabili (0.71 → H2); adm / automated decision-making / algori (0.71 → H2); deepfake / aigc / content / ai-generated (0.71 → H2); employment / skill / youth / graduate (0.71 → H2); defence / innovation / military / dual-u (0.77 → H1); regulatory policy / plc / enforcement /  (0.77 → H1); drought / water / hedging / policy (0.77 → H1); front matter / frontmatter / back matter (0.77 → H1); llm / language / task / reasoning (0.77 → H1); quantum / patent / ai / invention (0.77 → H1); watermarking / text / llm / language (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic                  label                                   fit  closest objective                     leverage  DISR field
# ---------------------  ------------------------------------  -----  ------------------------------------  --------  ----------
# 2026-09-14T1447-T0027  automated decision-making / account…  0.711  SI-3 AI and Automated Decision Maki…     0.470  —
# 2026-09-14T1447-T0046  patent / retrieval / art search / p…  0.546  4.1 Innovation and adaptiveness in …     0.438  —
# 2026-09-14T1447-T0011  patent / retrieval / prior art / cl…  0.534  4.1 Innovation and adaptiveness in …     0.461  —
# 2026-09-14T1447-T0088  foresight / anticipatory / scenario…  0.653  4.1 Innovation and adaptiveness in …     0.373  —
# 2026-09-14T1447-T0089  intellectual property / property pr…  0.620  4.1 Innovation and adaptiveness in …     0.404  —
# 2026-09-14T1447-T0043  competition / digital platform / di…  0.642  4.2 Innovative digital and data-dri…     0.377  —
# 2026-09-14T1447-T0033  artificial intelligence / patent / …  0.718  SI-3 AI and Automated Decision Maki…     0.481  —
# 2026-09-14T1447-T0044  llm / medical / chatgpt / clinical    0.500  SI-3 AI and Automated Decision Maki…     0.360  —
# 2026-09-14T1447-T0109  cultural heritage / property cultur…  0.506  4.1 Innovation and adaptiveness in …     0.367  —
# 2026-09-14T1447-T0083  adm / automated decision-making / a…  0.743  SI-3 AI and Automated Decision Maki…     0.477  —
# 2026-09-14T1447-T0086  enforcement intellectual / property…  0.523  4.1 Innovation and adaptiveness in …     0.384  —
# 2026-09-14T1447-T0006  circular / recycling / economy / pr…  0.501  4.1 Innovation and adaptiveness in …     0.358  —
# 2026-09-14T1447-T0034  ai / education / teacher / chatgpt    0.514  SI-3 AI and Automated Decision Maki…     0.367  —
# 2026-09-14T1447-T0056  quantum / patent / ai / invention     0.612  SI-3 AI and Automated Decision Maki…     0.451  —
# 2026-09-14T1447-T0096  vaccine / covid-19 / waiver / pande…  0.527  4.1 Innovation and adaptiveness in …     0.400  —
# 2026-09-14T1447-T0013  llm / language / task / reasoning     0.502  SI-3 AI and Automated Decision Maki…     0.351  —
# 2026-09-14T1447-T0007  intellectual property / property ri…  0.553  4.1 Innovation and adaptiveness in …     0.399  —
# 2026-09-14T1447-T0012  chain resilience / supply chain / c…  0.485  4.1 Innovation and adaptiveness in …     0.337  —
# 2026-09-14T1447-T0105  dpi / em / climate / biosecurity ri…  0.463  SI-3 AI and Automated Decision Maki…     0.404  —
# 2026-09-14T1447-T0023  blockchain / supply chain / traceab…  0.489  4.2 Innovative digital and data-dri…     0.383  —
# 2026-09-14T1447-T0054  indigenous / intellectual property …  0.591  SI-5 First Nations Strategy              0.420  —
# 2026-09-14T1447-T0093  precision agriculture / system prec…  0.466  SI-3 AI and Automated Decision Maki…     0.342  —
# 2026-09-14T1447-T0072  ai / public / governance / sector     0.705  SI-3 AI and Automated Decision Maki…     0.442  —
# 2026-09-14T1447-T0025  supply chain / chain resilience / s…  0.489  4.1 Innovation and adaptiveness in …     0.362  —
# 2026-09-14T1447-T0029  misinformation / online / age / soc…  0.477  4.1 Innovation and adaptiveness in …     0.361  —
# 2026-09-14T1447-T0111  water / nsw / portal / 2024data       0.441  SI-3 AI and Automated Decision Maki…     0.393  —
# 2026-09-14T1447-T0063  mineral / deposit / critical / geos…  0.459  4.2 Innovative digital and data-dri…     0.381  —
# 2026-09-14T1447-T0065  watermarking / text / llm / language  0.460  SI-3 AI and Automated Decision Maki…     0.347  —
# 2026-09-14T1447-T0115  copyright / ai / generative / artif…  0.583  SI-3 AI and Automated Decision Maki…     0.426  —
# 2026-09-14T1447-T0024  service delivery / govtech / digita…  0.669  4.2 Innovative digital and data-dri…     0.352  —
# 2026-09-14T1447-T0075  indigenous / traditional knowledge …  0.603  SI-5 First Nations Strategy              0.466  —
# 2026-09-14T1447-T0020  trust / institution / public / doct…  0.530  1.1 Trust and confidence in a high-…     0.322  —
# 2026-09-14T1447-T0064  green innovation / patent / firm / …  0.644  4.1 Innovation and adaptiveness in …     0.403  —
# 2026-09-14T1447-T0061  ai / gdpr / health / clinical         0.576  SI-3 AI and Automated Decision Maki…     0.435  —
# 2026-09-14T1447-T0069  anticipatory / foresight / governan…  0.604  4.1 Innovation and adaptiveness in …     0.380  —
# 2026-09-14T1447-T0035  circular / ce / economy / recycling   0.549  4.1 Innovation and adaptiveness in …     0.383  —
# 2026-09-14T1447-T0067  service delivery / public service /…  0.678  4.2 Innovative digital and data-dri…     0.330  —
# 2026-09-14T1447-T0002  geographical indication / gi / kent…  0.635  SI-1 Geographical indications regis…     0.371  —
# 2026-09-14T1447-T0015  automation / employment / worker / …  0.535  4.2 Innovative digital and data-dri…     0.408  —
# 2026-09-14T1447-T0087  nanotechnology / nanoparticle / nan…  0.448  SI-3 AI and Automated Decision Maki…     0.369  —
# 2026-09-14T1447-T0030  patent / innovation / firm / intell…  0.654  4.1 Innovation and adaptiveness in …     0.447  —
# 2026-09-14T1447-T0078  bone / additive manufacturing / sca…  0.477  4.2 Innovative digital and data-dri…     0.341  —
# 2026-09-14T1447-T0081  task / robot / learning / navigation  0.456  SI-3 AI and Automated Decision Maki…     0.322  —
# 2026-09-14T1447-T0090  drought / water / hedging / policy    0.483  SI-3 AI and Automated Decision Maki…     0.333  —
# 2026-09-14T1447-T0042  trust / covid-19 / pandemic / public  0.446  1.1 Trust and confidence in a high-…     0.322  —
# 2026-09-14T1447-T0050  defence / innovation / military / d…  0.599  4.1 Innovation and adaptiveness in …     0.367  —
# 2026-09-14T1447-T0103  critical mineral / supply chain / m…  0.457  SI-3 AI and Automated Decision Maki…     0.362  —
# 2026-09-14T1447-T0082  scene / point cloud / object / image  0.459  4.2 Innovative digital and data-dri…     0.357  —
# 2026-09-14T1447-T0040  agriculture / crop / iot / precision  0.477  SI-3 AI and Automated Decision Maki…     0.359  —
# 2026-09-14T1447-T0074  patent / citation / technology / sca  0.519  4.1 Innovation and adaptiveness in …     0.482  —
# 2026-09-14T1447-T0094  deepfake / aigc / content / ai-gene…  0.507  SI-3 AI and Automated Decision Maki…     0.384  —
# 2026-09-14T1447-T0045  climate / resilience / adaptation /…  0.456  4.1 Innovation and adaptiveness in …     0.309  —
# 2026-09-14T1447-T0060  supply chain / food / pandemic / co…  0.417  4.1 Innovation and adaptiveness in …     0.357  —
# 2026-09-14T1447-T0112  vehicle / autonomous / driving / avs  0.456  SI-3 AI and Automated Decision Maki…     0.326  —
# 2026-09-14T1447-T0066  cent / forecast / per / export earn…  0.401  SI-3 AI and Automated Decision Maki…     0.375  —
# 2026-09-14T1447-T0077  audio / music / speech / watermarki…  0.427  SI-3 AI and Automated Decision Maki…     0.328  —
# 2026-09-14T1447-T0016  health / digital / dht / technology   0.527  4.2 Innovative digital and data-dri…     0.370  —
# 2026-09-14T1447-T0039  modular / housing / construction / …  0.449  SI-3 AI and Automated Decision Maki…     0.319  —
# 2026-09-14T1447-T0031  blockchain / technology / smart con…  0.513  4.1 Innovation and adaptiveness in …     0.400  —
# 2026-09-14T1447-T0095  export control / dual-use / eu / co…  0.452  4.1 Innovation and adaptiveness in …     0.349  —
# 2026-09-14T1447-T0104  housing / household / rental / dwel…  0.371  SI-3 AI and Automated Decision Maki…     0.350  —
# 2026-09-14T1447-T0051  medicine / trip / access / patent     0.523  4.1 Innovation and adaptiveness in …     0.371  —
# 2026-09-14T1447-T0055  additive manufacturing / powder / a…  0.470  4.2 Innovative digital and data-dri…     0.338  —
# 2026-09-14T1447-T0084  regulatory policy / plc / enforceme…  0.502  SI-3 AI and Automated Decision Maki…     0.374  —
# 2026-09-14T1447-T0068  video / learning / visual / memory    0.455  4.2 Innovative digital and data-dri…     0.330  —
# 2026-09-14T1447-T0116  loneliness / social isolation / old…  0.392  4.2 Innovative digital and data-dri…     0.314  —
# 2026-09-14T1447-T0058  cancer / patient / learning / disea…  0.477  SI-3 AI and Automated Decision Maki…     0.339  —
# 2026-09-14T1447-T0005  antimicrobial / amr / sepsis / resi…  0.416  4.1 Innovation and adaptiveness in …     0.286  —
# 2026-09-14T1447-T0022  recycling / plastic / waste / circu…  0.441  4.1 Innovation and adaptiveness in …     0.324  —
# 2026-09-14T1447-T0108  satellite / image / eo / earth obse…  0.458  SI-3 AI and Automated Decision Maki…     0.363  —
# 2026-09-14T1447-T0097  wellbeing / policy / affect / health  0.413  SI-3 AI and Automated Decision Maki…     0.298  —
# 2026-09-14T1447-T0079  governance / nbs / nature-based sol…  0.497  SI-3 AI and Automated Decision Maki…     0.358  —
# 2026-09-14T1447-T0106  valuation / valuer / briefing / avm   0.493  4.1 Innovation and adaptiveness in …     0.367  —
# 2026-09-14T1447-T0018  ageing / population / older / policy  0.460  SI-3 AI and Automated Decision Maki…     0.324  —
# 2026-09-14T1447-T0036  synthetic biology / metabolic / eng…  0.462  SI-3 AI and Automated Decision Maki…     0.345  —
# 2026-09-14T1447-T0019  climate / disaster / adaptation / d…  0.487  4.1 Innovation and adaptiveness in …     0.324  —
# 2026-09-14T1447-T0101  surgical / robot / surgery / surgeon  0.457  SI-3 AI and Automated Decision Maki…     0.359  —
# 2026-09-14T1447-T0059  uav / navigation / robot / autonomo…  0.478  SI-3 AI and Automated Decision Maki…     0.320  —
# 2026-09-14T1447-T0003  blue economy / marine / ocean / msp   0.471  4.1 Innovation and adaptiveness in …     0.345  —
# 2026-09-14T1447-T0026  energy / storage / renewable / batt…  0.447  4.2 Innovative digital and data-dri…     0.336  —
# 2026-09-14T1447-T0114  vaccine / covid-19 / vaccination / …  0.402  4.1 Innovation and adaptiveness in …     0.287  —
# 2026-09-14T1447-T0062  kilometre km / square kilometre / p…  0.350  4.2 Innovative digital and data-dri…     0.301  —
# 2026-09-14T1447-T0100  dma / competition law / digital mar…  0.474  4.2 Innovative digital and data-dri…     0.380  —
# 2026-09-14T1447-T0048  battery / energy storage / lib / li…  0.448  4.2 Innovative digital and data-dri…     0.331  —
# 2026-09-14T1447-T0076  robot / agricultural / navigation /…  0.455  SI-3 AI and Automated Decision Maki…     0.353  —
# 2026-09-14T1447-T0001  breeding / plant / crop / genetic     0.455  4.1 Innovation and adaptiveness in …     0.345  —
# 2026-09-14T1447-T0053  employment / skill / youth / gradua…  0.482  4.2 Innovative digital and data-dri…     0.347  —
# 2026-09-14T1447-T0038  drought / catchment / water / hydro…  0.372  4.1 Innovation and adaptiveness in …     0.310  —
# 2026-09-14T1447-T0070  earth observation / satellite / eur…  0.411  4.2 Innovative digital and data-dri…     0.319  —
# 2026-09-14T1447-T0047  synthetic biology / cell / biomanuf…  0.418  SI-3 AI and Automated Decision Maki…     0.322  —
# 2026-09-14T1447-T0010  trust / public / institution / citi…  0.531  1.1 Trust and confidence in a high-…     0.316  —
# 2026-09-14T1447-T0032  climate / adaptation / resilience /…  0.482  4.1 Innovation and adaptiveness in …     0.333  —
# 2026-09-14T1447-T0037  energy / grid / storage system / po…  0.424  4.2 Innovative digital and data-dri…     0.292  —
# 2026-09-14T1447-T0071  hydrogen / electrolysis / energy / …  0.440  4.2 Innovative digital and data-dri…     0.296  —
# 2026-09-14T1447-T0098  cell / scrna-seq / cancer / sequenc…  0.413  4.2 Innovative digital and data-dri…     0.346  —
# 2026-09-14T1447-T0099  water / photothermal / solar / evap…  0.385  4.2 Innovative digital and data-dri…     0.282  —
# 2026-09-14T1447-T0057  climate / food / change / emission    0.393  SI-3 AI and Automated Decision Maki…     0.340  —
# 2026-09-14T1447-T0008  loneliness / social isolation / hea…  0.387  4.2 Innovative digital and data-dri…     0.300  —
# 2026-09-14T1447-T0073  housing / supply / construction / n…  0.396  4.1 Innovation and adaptiveness in …     0.316  —
# 2026-09-14T1447-T0017  satellite / aerosol / ocean / obser…  0.413  4.2 Innovative digital and data-dri…     0.345  —
# 2026-09-14T1447-T0021  wireless / communication / edge / n…  0.422  SI-3 AI and Automated Decision Maki…     0.358  —
# 2026-09-14T1447-T0009  water / membrane / treatment / dye    0.415  4.1 Innovation and adaptiveness in …     0.289  —
# 2026-09-14T1447-T0092  lidar / odometry / localization / i…  0.387  4.2 Innovative digital and data-dri…     0.318  —
# 2026-09-14T1447-T0004  watermarking / image / attack / dnn   0.438  4.1 Innovation and adaptiveness in …     0.304  —
# 2026-09-14T1447-T0113  climate / health / change / mental    0.408  4.1 Innovation and adaptiveness in …     0.301  —
# 2026-09-14T1447-T0110  misinformation / disinformation / m…  0.432  SI-3 AI and Automated Decision Maki…     0.326  —
# 2026-09-14T1447-T0049  marine / fungi / ocean / biotechnol…  0.416  4.2 Innovative digital and data-dri…     0.349  —
# 2026-09-14T1447-T0028  construction / housing / modular / …  0.405  4.1 Innovation and adaptiveness in …     0.300  —
# 2026-09-14T1447-T0080  esg / corporate / firm / disclosure   0.439  4.1 Innovation and adaptiveness in …     0.314  —
# 2026-09-14T1447-T0085  food / farming / agriculture / syst…  0.445  4.1 Innovation and adaptiveness in …     0.319  —
# 2026-09-14T1447-T0014  water / desalination / reuse / mana…  0.466  4.1 Innovation and adaptiveness in …     0.310  —
# 2026-09-14T1447-T0102  covariance / matrix / nonconvex / s…  0.397  SI-3 AI and Automated Decision Maki…     0.320  —
# 2026-09-14T1447-T0052  prefabricated / construction / mic …  0.444  SI-3 AI and Automated Decision Maki…     0.316  —
# 2026-09-14T1447-T0107  honey / geographical origin / food …  0.429  SI-1 Geographical indications regis…     0.329  —
# 2026-09-14T1447-T0091  front matter / frontmatter / back m…  0.359  SI-3 AI and Automated Decision Maki…     0.316  —
# 2026-09-14T1447-T0041  satellite / leo / orbit / space       0.397  4.2 Innovative digital and data-dri…     0.323  —
# 2026-09-14T1447-T0000  quantum / qubit / entanglement / co…  0.395  4.2 Innovative digital and data-dri…     0.291  —
#
# strategic fit  range 0.350–0.743  median 0.463
# asset leverage range 0.282–0.482  median 0.347

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic                  label                                 attention  attention_tone  policy_salience  research_growth  index
# ---------------------  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# 2026-09-14T1447-T0027  automated decision-making / accounta      0.897           0.371            0.819            0.776  0.774
# 2026-09-14T1447-T0046  patent / retrieval / art search / pr      0.116           0.543            0.741            0.819  0.562
# 2026-09-14T1447-T0011  patent / retrieval / prior art / cla      0.267           0.526            0.905            0.940  0.685
# 2026-09-14T1447-T0088  foresight / anticipatory / scenario       0.634           0.603            0.586            0.905  0.715
# 2026-09-14T1447-T0089  intellectual property / property pro      0.759           0.862            0.948            0.897  0.864
# 2026-09-14T1447-T0043  competition / digital platform / dig      0.922           0.828            0.655            0.707  0.772
# 2026-09-14T1447-T0033  artificial intelligence / patent / i      0.991           0.457            0.802            0.655  0.765
# 2026-09-14T1447-T0044  llm / medical / chatgpt / clinical        0.147           0.078            0.345            0.974  0.477
# 2026-09-14T1447-T0109  cultural heritage / property cultura      0.621           0.810            0.672            0.297  0.541
# 2026-09-14T1447-T0083  adm / automated decision-making / al      0.448           0.414            0.828            0.828  0.667
# 2026-09-14T1447-T0086  enforcement intellectual / property       0.720           0.009            0.957            0.297  0.543
# 2026-09-14T1447-T0006  circular / recycling / economy / pro      0.461           0.897            0.457            0.297  0.454
# 2026-09-14T1447-T0034  ai / education / teacher / chatgpt        0.647           0.138            0.733            0.793  0.659
# 2026-09-14T1447-T0056  quantum / patent / ai / invention         0.819           0.164            0.940            0.948  0.816
# 2026-09-14T1447-T0096  vaccine / covid-19 / waiver / pandem      0.379           0.836            0.793            0.297  0.502
# 2026-09-14T1447-T0013  llm / language / task / reasoning         0.392           0.741            0.483            0.931  0.645
# 2026-09-14T1447-T0007  intellectual property / property rig      0.948           0.267            0.991            0.297  0.649
# 2026-09-14T1447-T0012  chain resilience / supply chain / ch      0.353           0.388            0.147            0.879  0.494
# 2026-09-14T1447-T0105  dpi / em / climate / biosecurity ris      0.573           0.220            0.629            0.297  0.448
# 2026-09-14T1447-T0023  blockchain / supply chain / traceabi      0.237           0.509            0.543            0.297  0.362
# 2026-09-14T1447-T0054  indigenous / intellectual property /      0.940           0.922            0.853            0.638  0.811
# 2026-09-14T1447-T0093  precision agriculture / system preci      0.517           0.207            0.474            0.784  0.565
# 2026-09-14T1447-T0072  ai / public / governance / sector         0.862           0.448            1.000            0.716  0.794
# 2026-09-14T1447-T0025  supply chain / chain resilience / sc      0.039           0.328            0.353            0.922  0.459
# 2026-09-14T1447-T0029  misinformation / online / age / soci      0.966           0.043            0.095            0.759  0.579
# 2026-09-14T1447-T0111  water / nsw / portal / 2024data           0.116           0.573            0.707            0.297  0.373
# 2026-09-14T1447-T0063  mineral / deposit / critical / geosc      0.750           0.716            0.466            0.297  0.519
# 2026-09-14T1447-T0065  watermarking / text / llm / language      0.237           0.259            0.362            1.000  0.538
# 2026-09-14T1447-T0115  copyright / ai / generative / artifi      0.853           0.103            0.784            0.767  0.719
# 2026-09-14T1447-T0024  service delivery / govtech / digital      0.741           0.353            0.966            0.914  0.809
# 2026-09-14T1447-T0075  indigenous / traditional knowledge /      0.659           0.853            0.888            0.741  0.765
# 2026-09-14T1447-T0020  trust / institution / public / doctr      0.681           0.060            0.845            0.297  0.511
# 2026-09-14T1447-T0064  green innovation / patent / firm / e      0.517           0.957            0.871            0.297  0.575
# 2026-09-14T1447-T0061  ai / gdpr / health / clinical             0.784           0.440            0.767            0.297  0.568
# 2026-09-14T1447-T0069  anticipatory / foresight / governanc      0.078           0.534            0.836            0.862  0.587
# 2026-09-14T1447-T0035  circular / ce / economy / recycling       0.017           0.944            0.664            0.297  0.377
# 2026-09-14T1447-T0067  service delivery / public service /       0.879           0.621            0.974            0.629  0.783
# 2026-09-14T1447-T0002  geographical indication / gi / kente      0.733           0.733            0.698            0.664  0.700
# 2026-09-14T1447-T0015  automation / employment / worker / j      0.957           0.379            0.638            0.698  0.723
# 2026-09-14T1447-T0087  nanotechnology / nanoparticle / nano      0.319           0.707            0.560            0.297  0.414
# 2026-09-14T1447-T0030  patent / innovation / firm / intelle      0.573           0.776            0.983            0.297  0.596
# 2026-09-14T1447-T0078  bone / additive manufacturing / scaf      0.078           0.694            0.379            0.297  0.299
# 2026-09-14T1447-T0081  task / robot / learning / navigation      0.116           0.155            0.388            0.888  0.457
# 2026-09-14T1447-T0090  drought / water / hedging / policy        0.435           0.345            0.250            0.297  0.332
# 2026-09-14T1447-T0042  trust / covid-19 / pandemic / public      0.172           0.095            0.914            0.297  0.382
# 2026-09-14T1447-T0050  defence / innovation / military / du      0.871           0.647            0.681            0.647  0.721
# 2026-09-14T1447-T0103  critical mineral / supply chain / mi      0.845           0.483            0.215            0.845  0.654
# 2026-09-14T1447-T0082  scene / point cloud / object / image      0.039           0.241            0.060            0.297  0.159
# 2026-09-14T1447-T0040  agriculture / crop / iot / precision      0.297           0.362            0.595            0.297  0.375
# 2026-09-14T1447-T0074  patent / citation / technology / sca      0.392           0.491            0.862            0.297  0.481
# 2026-09-14T1447-T0094  deepfake / aigc / content / ai-gener      0.983           0.198            0.534            0.621  0.657
# 2026-09-14T1447-T0045  climate / resilience / adaptation /       0.634           0.293            0.328            0.853  0.599
# 2026-09-14T1447-T0060  supply chain / food / pandemic / cov      0.547           0.052            0.241            0.810  0.510
# 2026-09-14T1447-T0112  vehicle / autonomous / driving / avs      0.353           0.405            0.440            0.681  0.495
# 2026-09-14T1447-T0066  cent / forecast / per / export earni      0.914           0.664            0.198            0.297  0.498
# 2026-09-14T1447-T0077  audio / music / speech / watermarkin      0.267           0.112            0.103            0.957  0.454
# 2026-09-14T1447-T0016  health / digital / dht / technology       0.776           0.466            0.724            0.297  0.558
# 2026-09-14T1447-T0039  modular / housing / construction / s      0.547           0.845            0.121            0.672  0.526
# 2026-09-14T1447-T0031  blockchain / technology / smart cont      0.828           0.672            0.776            0.297  0.610
# 2026-09-14T1447-T0095  export control / dual-use / eu / con      0.767           0.017            0.448            0.802  0.616
# 2026-09-14T1447-T0104  housing / household / rental / dwell      0.435           0.284            0.690            0.297  0.429
# 2026-09-14T1447-T0051  medicine / trip / access / patent         0.888           0.121            0.897            0.297  0.591
# 2026-09-14T1447-T0055  additive manufacturing / powder / al      0.517           0.586            0.578            0.297  0.462
# 2026-09-14T1447-T0084  regulatory policy / plc / enforcemen      1.000           0.336            0.931            0.603  0.766
# 2026-09-14T1447-T0068  video / learning / visual / memory        0.078           0.129            0.414            0.750  0.400
# 2026-09-14T1447-T0116  loneliness / social isolation / olde      0.004           0.177            0.172            0.297  0.168
# 2026-09-14T1447-T0058  cancer / patient / learning / diseas      0.353           0.802            0.078            0.297  0.321
# 2026-09-14T1447-T0005  antimicrobial / amr / sepsis / resis      0.297           0.655            0.026            0.983  0.518
# 2026-09-14T1447-T0022  recycling / plastic / waste / circul      0.297           0.996            0.224            0.297  0.362
# 2026-09-14T1447-T0108  satellite / image / eo / earth obser      0.172           0.724            0.052            0.297  0.253
# 2026-09-14T1447-T0097  wellbeing / policy / affect / health      0.409           0.819            0.750            0.966  0.734
# 2026-09-14T1447-T0079  governance / nbs / nature-based solu      0.237           0.944            0.810            0.297  0.476
# 2026-09-14T1447-T0106  valuation / valuer / briefing / avm       0.694           0.767            0.647            0.297  0.551
# 2026-09-14T1447-T0018  ageing / population / older / policy      0.608           0.474            0.276            0.724  0.555
# 2026-09-14T1447-T0036  synthetic biology / metabolic / engi      0.328           0.879            0.284            0.297  0.372
# 2026-09-14T1447-T0019  climate / disaster / adaptation / dr      0.659           0.190            0.759            0.297  0.500
# 2026-09-14T1447-T0101  surgical / robot / surgery / surgeon      0.203           0.612            0.181            0.297  0.279
# 2026-09-14T1447-T0059  uav / navigation / robot / autonomou      0.297           0.500            0.293            0.297  0.320
# 2026-09-14T1447-T0003  blue economy / marine / ocean / msp       0.810           0.638            0.397            0.612  0.623
# 2026-09-14T1447-T0026  energy / storage / renewable / batte      0.608           0.983            0.491            0.297  0.515
# 2026-09-14T1447-T0114  vaccine / covid-19 / vaccination / h      0.203           0.694            0.336            0.297  0.325
# 2026-09-14T1447-T0062  kilometre km / square kilometre / po      0.237           0.000            0.043            0.297  0.185
# 2026-09-14T1447-T0100  dma / competition law / digital mark      0.720           0.759            0.526            0.297  0.530
# 2026-09-14T1447-T0048  battery / energy storage / lib / lit      0.694           0.888            0.259            0.297  0.474
# 2026-09-14T1447-T0076  robot / agricultural / navigation /       0.147           0.233            0.422            0.297  0.275
# 2026-09-14T1447-T0001  breeding / plant / crop / genetic         0.595           0.750            0.569            0.297  0.502
# 2026-09-14T1447-T0053  employment / skill / youth / graduat      0.905           0.552            0.371            0.297  0.523
# 2026-09-14T1447-T0038  drought / catchment / water / hydrol      0.004           0.177            0.035            0.991  0.380
# 2026-09-14T1447-T0070  earth observation / satellite / euro      0.353           0.517            0.207            0.297  0.318
# 2026-09-14T1447-T0047  synthetic biology / cell / biomanufa      0.707           0.681            0.155            0.297  0.430
# 2026-09-14T1447-T0010  trust / public / institution / citiz      0.487           0.035            0.922            0.297  0.469
# 2026-09-14T1447-T0032  climate / adaptation / resilience /       0.931           0.310            0.552            0.297  0.545
# 2026-09-14T1447-T0037  energy / grid / storage system / pow      0.172           0.914            0.517            0.297  0.385
# 2026-09-14T1447-T0071  hydrogen / electrolysis / energy / s      0.487           0.974            0.112            0.297  0.389
# 2026-09-14T1447-T0098  cell / scrna-seq / cancer / sequenci      0.672           0.793            0.000            0.297  0.396
# 2026-09-14T1447-T0099  water / photothermal / solar / evapo      0.203           0.966            0.086            0.297  0.298
# 2026-09-14T1447-T0057  climate / food / change / emission        0.586           0.397            0.612            0.297  0.468
# 2026-09-14T1447-T0008  loneliness / social isolation / heal      0.039           0.078            0.302            0.297  0.196
# 2026-09-14T1447-T0073  housing / supply / construction / nb      0.797           0.431            0.069            0.733  0.560
# 2026-09-14T1447-T0017  satellite / aerosol / ocean / observ      0.147           0.319            0.267            0.297  0.248
# 2026-09-14T1447-T0021  wireless / communication / edge / ne      0.560           0.871            0.621            0.297  0.518
# 2026-09-14T1447-T0009  water / membrane / treatment / dye        0.039           0.996            0.233            0.297  0.288
# 2026-09-14T1447-T0092  lidar / odometry / localization / in      0.078           0.573            0.310            0.297  0.268
# 2026-09-14T1447-T0004  watermarking / image / attack / dnn       0.409           0.250            0.129            0.297  0.285
# 2026-09-14T1447-T0113  climate / health / change / mental        0.487           0.276            0.716            0.297  0.449
# 2026-09-14T1447-T0110  misinformation / disinformation / me      0.797           0.302            0.603            0.690  0.655
# 2026-09-14T1447-T0049  marine / fungi / ocean / biotechnolo      0.203           0.784            0.017            0.297  0.261
# 2026-09-14T1447-T0028  construction / housing / modular / p      0.078           0.220            0.431            0.871  0.457
# 2026-09-14T1447-T0080  esg / corporate / firm / disclosure       0.353           0.595            0.879            0.297  0.486
# 2026-09-14T1447-T0085  food / farming / agriculture / syste      0.461           0.629            0.405            0.297  0.410
# 2026-09-14T1447-T0014  water / desalination / reuse / manag      0.534           0.147            0.319            0.297  0.354
# 2026-09-14T1447-T0102  covariance / matrix / nonconvex / sa      0.267           0.931            0.009            0.836  0.485
# 2026-09-14T1447-T0052  prefabricated / construction / mic /      0.116           0.078            0.500            0.297  0.266
# 2026-09-14T1447-T0107  honey / geographical origin / food /      0.487           0.026            0.138            0.297  0.284
# 2026-09-14T1447-T0091  front matter / frontmatter / back ma      0.836           0.422            0.509            0.297  0.520
# 2026-09-14T1447-T0041  satellite / leo / orbit / space           0.422           0.560            0.164            0.297  0.334
# 2026-09-14T1447-T0000  quantum / qubit / entanglement / com      0.974           0.905            0.190            0.297  0.543

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 117 topics — largest deviation 8.53e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 117 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 117 of 117 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  automated decision-making / accountability  H2  strong  0.668  0.711  0.470  0.774      0.922
#   2  patent / retrieval / art search / prior ar  H1  strong  0.797  0.546  0.438  0.562      0.910
#   3  patent / retrieval / prior art / classific  H2  strong  0.671  0.534  0.461  0.685      0.858
#   4  foresight / anticipatory / scenario planni  H1  weak    0.672  0.653  0.373  0.715      0.853
#   5  intellectual property / property protectio  H2  weak    0.620  0.620  0.404  0.864      0.844
#   6  competition / digital platform / digital m  H2  strong  0.565  0.642  0.377  0.772      0.788
#   7  artificial intelligence / patent / invento  H2  strong  0.496  0.718  0.481  0.765      0.784
#   8  llm / medical / chatgpt / clinical          H1  strong  0.794  0.500  0.360  0.477      0.780
#   9  cultural heritage / property cultural / in  H1  weak    0.729  0.506  0.367  0.541      0.779
#  10  adm / automated decision-making / algorith  H2  weak    0.479  0.743  0.477  0.667      0.775
#  11  enforcement intellectual / property right   H1  weak    0.600  0.523  0.384  0.543      0.763
#  12  circular / recycling / economy / product d  H1  strong  0.738  0.501  0.358  0.454      0.761
#  13  ai / education / teacher / chatgpt          H1  strong  0.659  0.514  0.367  0.659      0.749
#  14  quantum / patent / ai / invention           H1  strong  0.500  0.612  0.451  0.816      0.747
#  15  vaccine / covid-19 / waiver / pandemic      H1  weak    0.541  0.527  0.400  0.502      0.737
#  16  llm / language / task / reasoning           H1  strong  0.726  0.502  0.351  0.645      0.737
#  17  intellectual property / property right / p  H1  strong  0.512  0.553  0.399  0.649      0.717
#  18  chain resilience / supply chain / chain ri  H1  strong  0.838  0.485  0.337  0.494      0.716
#  19  dpi / em / climate / biosecurity risk       H2  weak    0.626  0.463  0.404  0.448      0.703
#  20  blockchain / supply chain / traceability /  H1  strong  0.551  0.489  0.383  0.362      0.685
#  21  indigenous / intellectual property / cultu  H1  latent  0.438  0.591  0.420  0.811      0.678
#  22  precision agriculture / system precision /  H2  weak    0.766  0.466  0.342  0.565      0.677
#  23  ai / public / governance / sector           H1  weak    0.388  0.705  0.442  0.794      0.674
#  24  supply chain / chain resilience / sc / dis  H1  strong  0.597  0.489  0.362  0.459      0.672
#  25  misinformation / online / age / social med  H1  strong  0.644  0.477  0.361  0.579      0.666
#  26  water / nsw / portal / 2024data             H1  weak    0.714  0.441  0.393  0.373      0.665
#  27  mineral / deposit / critical / geoscience   H2  strong  0.616  0.459  0.381  0.519      0.662
#  28  watermarking / text / llm / language        H1  strong  0.724  0.460  0.347  0.538      0.653
#  29  copyright / ai / generative / artificial    H1  weak    0.407  0.583  0.426  0.719      0.644
#  30  service delivery / govtech / digital / gov  H2  strong  0.457  0.669  0.352  0.809      0.640
#  31  indigenous / traditional knowledge / intel  H2  noise   0.361  0.603  0.466  0.765      0.635
#  32  trust / institution / public / doctrine     H2  latent  0.573  0.530  0.322  0.511      0.620
#  33  green innovation / patent / firm / environ  H1  weak    0.346  0.644  0.403  0.575      0.610
#  34  ai / gdpr / health / clinical               H1  noise   0.351  0.576  0.435  0.568      0.603
#  35  anticipatory / foresight / governance / st  H1  weak    0.376  0.604  0.380  0.587      0.598
#  36  circular / ce / economy / recycling         H1  latent  0.390  0.549  0.383  0.377      0.591
#  37  service delivery / public service / digita  H2  noise   0.450  0.678  0.330  0.783      0.583
#  38  geographical indication / gi / kente / pro  H1  latent  0.357  0.635  0.371  0.700      0.581
#  39  automation / employment / worker / job      H1  strong  0.349  0.535  0.408  0.723      0.581
#  40  nanotechnology / nanoparticle / nanomateri  H1  noise   0.565  0.448  0.369  0.414      0.575
#  41  patent / innovation / firm / intellectual   H1  latent  0.159  0.654  0.447  0.596      0.567
#  42  bone / additive manufacturing / scaffold /  H1  noise   0.537  0.477  0.341  0.299      0.555
#  43  task / robot / learning / navigation        H2  weak    0.700  0.456  0.322  0.457      0.553
#  44  drought / water / hedging / policy          H1  noise   0.530  0.483  0.333  0.332      0.548
#  45  trust / covid-19 / pandemic / public        H1  strong  0.705  0.446  0.322  0.382      0.533
#  46  defence / innovation / military / dual-use  H1  latent  0.333  0.599  0.367  0.721      0.532
#  47  critical mineral / supply chain / mineral   H3  weak    0.512  0.457  0.362  0.654      0.531
#  48  scene / point cloud / object / image        H1  noise   0.526  0.459  0.357  0.159      0.531
#  49  agriculture / crop / iot / precision        H1  latent  0.469  0.477  0.359  0.375      0.525
#  50  patent / citation / technology / sca        H1  noise   0.245  0.519  0.482  0.481      0.523
#  51  deepfake / aigc / content / ai-generated    H2  weak    0.343  0.507  0.384  0.657      0.519
#  52  climate / resilience / adaptation / infras  H2  strong  0.684  0.456  0.309  0.599      0.515
#  53  supply chain / food / pandemic / covid-19   H1  weak    0.605  0.417  0.357  0.510      0.511
#  54  vehicle / autonomous / driving / avs        H1  noise   0.563  0.456  0.326  0.495      0.500
#  55  cent / forecast / per / export earning      H1  strong  0.560  0.401  0.375  0.498      0.492
#  56  audio / music / speech / watermarking       H3  weak    0.650  0.427  0.328  0.454      0.487
#  57  health / digital / dht / technology         H1  latent  0.282  0.527  0.370  0.558      0.479
#  58  modular / housing / construction / supply   H1  latent  0.613  0.449  0.319  0.526      0.476
#  59  blockchain / technology / smart contract /  H1  latent  0.233  0.513  0.400  0.610      0.468
#  60  export control / dual-use / eu / control r  H1  weak    0.512  0.452  0.349  0.616      0.467
#  61  housing / household / rental / dwelling     H1  weak    0.666  0.371  0.350  0.429      0.465
#  62  medicine / trip / access / patent           H1  latent  0.259  0.523  0.371  0.591      0.464
#  63  additive manufacturing / powder / alloy /   H1  noise   0.466  0.470  0.338  0.462      0.458
#  64  regulatory policy / plc / enforcement / re  H1  noise   0.279  0.502  0.374  0.766      0.457
#  65  video / learning / visual / memory          H1  noise   0.527  0.455  0.330  0.400      0.456
#  66  loneliness / social isolation / older / ad  H1  weak    0.809  0.392  0.314  0.168      0.454
#  67  cancer / patient / learning / disease       H1  strong  0.425  0.477  0.339  0.321      0.454
#  68  antimicrobial / amr / sepsis / resistance   H3  strong  0.748  0.416  0.286  0.518      0.451
#  69  recycling / plastic / waste / circular      H1  strong  0.563  0.441  0.324  0.362      0.450
#  70  satellite / image / eo / earth observation  H1  noise   0.416  0.458  0.363  0.253      0.448
#  71  wellbeing / policy / affect / health        H1  weak    0.737  0.413  0.298  0.734      0.448
#  72  governance / nbs / nature-based solution /  H1  weak    0.339  0.497  0.358  0.476      0.443
#  73  valuation / valuer / briefing / avm         H2  noise   0.293  0.493  0.367  0.551      0.438
#  74  ageing / population / older / policy        H1  latent  0.505  0.460  0.324  0.555      0.437
#  75  synthetic biology / metabolic / engineerin  H1  strong  0.423  0.462  0.345  0.372      0.430
#  76  climate / disaster / adaptation / drr       H1  strong  0.418  0.487  0.324  0.500      0.428
#  77  surgical / robot / surgery / surgeon        H1  noise   0.412  0.457  0.359  0.279      0.426
#  78  uav / navigation / robot / autonomous       H1  noise   0.452  0.478  0.320  0.320      0.425
#  79  blue economy / marine / ocean / msp         H1  latent  0.407  0.471  0.345  0.623      0.425
#  80  energy / storage / renewable / battery      H1  latent  0.510  0.447  0.336  0.515      0.422
#  81  vaccine / covid-19 / vaccination / hesitan  H1  weak    0.730  0.402  0.287  0.325      0.416
#  82  kilometre km / square kilometre / populati  H2  weak    0.760  0.350  0.301  0.185      0.406
#  83  dma / competition law / digital market / d  H1  noise   0.249  0.474  0.380  0.530      0.399
#  84  battery / energy storage / lib / lithium-i  H1  latent  0.481  0.448  0.331  0.474      0.397
#  85  robot / agricultural / navigation / crop    H1  noise   0.391  0.455  0.353  0.275      0.384
#  86  breeding / plant / crop / genetic           H1  latent  0.418  0.455  0.345  0.502      0.379
#  87  employment / skill / youth / graduate       H2  latent  0.324  0.482  0.347  0.523      0.379
#  88  drought / catchment / water / hydrological  H1  strong  0.666  0.372  0.310  0.380      0.372
#  89  earth observation / satellite / european /  H1  noise   0.559  0.411  0.319  0.318      0.365
#  90  synthetic biology / cell / biomanufacturin  H1  strong  0.522  0.418  0.322  0.430      0.361
#  91  trust / public / institution / citizen      H1  latent  0.285  0.531  0.316  0.469      0.353
#  92  climate / adaptation / resilience / change  H2  latent  0.330  0.482  0.333  0.545      0.351
#  93  energy / grid / storage system / power      H1  latent  0.534  0.424  0.292  0.385      0.337
#  94  hydrogen / electrolysis / energy / storage  H1  noise   0.525  0.440  0.296  0.389      0.337
#  95  cell / scrna-seq / cancer / sequencing      H1  noise   0.440  0.413  0.346  0.396      0.333
#  96  water / photothermal / solar / evaporation  H1  noise   0.644  0.385  0.282  0.298      0.328
#  97  climate / food / change / emission          H1  noise   0.497  0.393  0.340  0.468      0.323
#  98  loneliness / social isolation / health / o  H1  strong  0.594  0.387  0.300  0.196      0.322
#  99  housing / supply / construction / nbsp      H2  weak    0.540  0.396  0.316  0.560      0.321
# 100  satellite / aerosol / ocean / observation   H1  strong  0.423  0.413  0.345  0.248      0.313
# 101  wireless / communication / edge / network   H1  latent  0.366  0.422  0.358  0.518      0.312
# 102  water / membrane / treatment / dye          H1  latent  0.528  0.415  0.289  0.288      0.308
# 103  lidar / odometry / localization / inertial  H1  noise   0.525  0.387  0.318  0.268      0.290
# 104  watermarking / image / attack / dnn         H1  latent  0.454  0.438  0.304  0.285      0.285
# 105  climate / health / change / mental          H1  noise   0.507  0.408  0.301  0.449      0.273
# 106  misinformation / disinformation / media /   H1  noise   0.379  0.432  0.326  0.655      0.265
# 107  marine / fungi / ocean / biotechnological   H1  strong  0.339  0.416  0.349  0.261      0.254
# 108  construction / housing / modular / prefabr  H2  strong  0.488  0.405  0.300  0.457      0.251
# 109  esg / corporate / firm / disclosure         H1  noise   0.403  0.439  0.314  0.486      0.245
# 110  food / farming / agriculture / system       H1  noise   0.348  0.445  0.319  0.410      0.238
# 111  water / desalination / reuse / management   H1  latent  0.274  0.466  0.310  0.354      0.232
# 112  covariance / matrix / nonconvex / sample    H2  noise   0.420  0.397  0.320  0.485      0.230
# 113  prefabricated / construction / mic / bim    H1  noise   0.332  0.444  0.316  0.266      0.203
# 114  honey / geographical origin / food / authe  H1  noise   0.234  0.429  0.329  0.284      0.182
# 115  front matter / frontmatter / back matter /  H1  noise   0.393  0.359  0.316  0.520      0.159
# 116  satellite / leo / orbit / space             H1  latent  0.234  0.397  0.323  0.334      0.109
# 117  quantum / qubit / entanglement / computing  H1  latent  0.297  0.395  0.291  0.543      0.077

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.463, leverage 0.347).
#
# ACT (44)
#       1  automated decision-making / accountability / administrative
#       2  patent / retrieval / art search / prior art
#       3  patent / retrieval / prior art / classification
#       4  foresight / anticipatory / scenario planning / governance
#       5  intellectual property / property protection / firm / patent
#       6  competition / digital platform / digital market / policy dig
#       7  artificial intelligence / patent / inventorship / intelligen
#       8  llm / medical / chatgpt / clinical
#       9  cultural heritage / property cultural / intellectual / intan
#      10  adm / automated decision-making / algorithmic / accountabili
#      11  enforcement intellectual / property right / intellectual pro
#      12  circular / recycling / economy / product design
#      13  ai / education / teacher / chatgpt
#      14  quantum / patent / ai / invention
#      15  vaccine / covid-19 / waiver / pandemic
#      16  llm / language / task / reasoning
#      17  intellectual property / property right / property law / enfo
#      19  dpi / em / climate / biosecurity risk
#      20  blockchain / supply chain / traceability / technology
#      21  indigenous / intellectual property / cultural / traditional
#      23  ai / public / governance / sector
#      24  supply chain / chain resilience / sc / disruption
#      25  misinformation / online / age / social media
#      29  copyright / ai / generative / artificial
#      30  service delivery / govtech / digital / government
#      31  indigenous / traditional knowledge / intellectual / tk
#      33  green innovation / patent / firm / environmental
#      34  ai / gdpr / health / clinical
#      35  anticipatory / foresight / governance / strategic
#      36  circular / ce / economy / recycling
#      38  geographical indication / gi / kente / product
#      39  automation / employment / worker / job
#      41  patent / innovation / firm / intellectual property
#      46  defence / innovation / military / dual-use
#      49  agriculture / crop / iot / precision
#      50  patent / citation / technology / sca
#      51  deepfake / aigc / content / ai-generated
#      57  health / digital / dht / technology
#      59  blockchain / technology / smart contract / fintech
#      62  medicine / trip / access / patent
#      64  regulatory policy / plc / enforcement / regulatory reform
#      72  governance / nbs / nature-based solution / polycentric
#      73  valuation / valuer / briefing / avm
#      83  dma / competition law / digital market / draft
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (15)
#      18  chain resilience / supply chain / chain risk / resilience su
#      22  precision agriculture / system precision / agriculture food
#      32  trust / institution / public / doctrine
#      37  service delivery / public service / digital / government
#      42  bone / additive manufacturing / scaffold / implant
#      44  drought / water / hedging / policy
#      63  additive manufacturing / powder / alloy / material
#      67  cancer / patient / learning / disease
#      76  climate / disaster / adaptation / drr
#      78  uav / navigation / robot / autonomous
#      79  blue economy / marine / ocean / msp
#      87  employment / skill / youth / graduate
#      91  trust / public / institution / citizen
#      92  climate / adaptation / resilience / change
#     111  water / desalination / reuse / management
#
# CAPABILITY LOOKING FOR A PROBLEM (15)
#      26  water / nsw / portal / 2024data
#      27  mineral / deposit / critical / geoscience
#      28  watermarking / text / llm / language
#      40  nanotechnology / nanoparticle / nanomaterial / nps
#      47  critical mineral / supply chain / mineral supply / domestic
#      48  scene / point cloud / object / image
#      53  supply chain / food / pandemic / covid-19
#      55  cent / forecast / per / export earning
#      60  export control / dual-use / eu / control regulation
#      61  housing / household / rental / dwelling
#      70  satellite / image / eo / earth observation
#      77  surgical / robot / surgery / surgeon
#      85  robot / agricultural / navigation / crop
#     101  wireless / communication / edge / network
#     107  marine / fungi / ocean / biotechnological
#
# WATCH (43)
#      43  task / robot / learning / navigation
#      45  trust / covid-19 / pandemic / public
#      52  climate / resilience / adaptation / infrastructure
#      54  vehicle / autonomous / driving / avs
#      56  audio / music / speech / watermarking
#      58  modular / housing / construction / supply
#      65  video / learning / visual / memory
#      66  loneliness / social isolation / older / adult
#      68  antimicrobial / amr / sepsis / resistance
#      69  recycling / plastic / waste / circular
#      71  wellbeing / policy / affect / health
#      74  ageing / population / older / policy
#      75  synthetic biology / metabolic / engineering / gene
#      80  energy / storage / renewable / battery
#      81  vaccine / covid-19 / vaccination / hesitancy
#      82  kilometre km / square kilometre / population million / afric
#      84  battery / energy storage / lib / lithium-ion
#      86  breeding / plant / crop / genetic
#      88  drought / catchment / water / hydrological
#      89  earth observation / satellite / european / observation polic
#      90  synthetic biology / cell / biomanufacturing / gene
#      93  energy / grid / storage system / power
#      94  hydrogen / electrolysis / energy / storage
#      95  cell / scrna-seq / cancer / sequencing
#      96  water / photothermal / solar / evaporation
#      97  climate / food / change / emission
#      98  loneliness / social isolation / health / older
#      99  housing / supply / construction / nbsp
#     100  satellite / aerosol / ocean / observation
#     102  water / membrane / treatment / dye
#     103  lidar / odometry / localization / inertial
#     104  watermarking / image / attack / dnn
#     105  climate / health / change / mental
#     106  misinformation / disinformation / media / fake
#     108  construction / housing / modular / prefabricated
#     109  esg / corporate / firm / disclosure
#     110  food / farming / agriculture / system
#     112  covariance / matrix / nonconvex / sample
#     113  prefabricated / construction / mic / bim
#     114  honey / geographical origin / food / authenticity
#     115  front matter / frontmatter / back matter / prelim
#     116  satellite / leo / orbit / space
#     117  quantum / qubit / entanglement / computing

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = '2026-09-14T1447-T0027'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  automated decision-making / accountability / administrative / ai
# 341 documents · 2018–2026 · H2 · strong
#
# Defining terms: automated decision-making, decision-making, automated, accountability, automated decision, administrative, ai, administrative decision-making, administrative law, governmental automated, decision making, decision
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  █████
#      2019     2  ██
#      2020     7  ████████
#      2021     7  ████████
#      2022     4  █████
#      2023    21  ████████████████████████  ← burst
#      2024     8  █████████  ← burst
#      2025    13  ███████████████  ← burst
#      2026    10  ███████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Situating the Rule of Law in the Context of Automated Decision-Making
#     crossref · 2023 · The Rule of Law and Automated Decision-Making
#     https://doi.org/10.1007/978-3-031-30142-1_2
#   • Automated Decision-Making and the Law
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_3
#   • Confronting the Legal Challenges of Governmental Automated Decision-Making
#     crossref · 2023 · Law, Governance and Technology Series
#     https://doi.org/10.1007/978-3-031-48125-3_5
#   • Automated Decision-making
#     crossref · 2025 · Smart Court
#     https://doi.org/10.1017/9781009319232.007
#   • The Rule of Law and Automated Decision-Making
#     crossref · 2023 · book
#     https://doi.org/10.1007/978-3-031-30142-1

# %%
TOPIC_ID = '2026-09-14T1447-T0046'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  patent / retrieval / art search / prior art
# 66 documents · 2018–2026 · H1 · strong
#
# Defining terms: patent, retrieval, art search, patent retrieval, prior art, patent prior, art, prior, search, retrieval patent, information retrieval, semantic
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  ███████
#      2019     6  ███████████
#      2020     6  ███████████
#      2021     4  ███████
#      2022    11  ████████████████████
#      2023     8  ███████████████
#      2024     7  █████████████
#      2025     3  ██████
#      2026    13  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • On the use of Intelligent Information Retrieval in Patent Prior-Art Search
#     crossref · 2024 · Roshd -e- Fanavari
#     https://doi.org/10.61186/jstpi.44174.20.77.24
#   • Challenges in Patent Information Retrieval
#     crossref · 2020 · The Information Retrieval Series
#     https://doi.org/10.1007/978-981-15-5554-1_4
#   • A Recapitulation of Patent Retrieval
#     crossref · 2024 · Journal of Intellectual Property Rights
#     https://doi.org/10.56042/jipr.v29i1.1435
#   • Patent retrieval: a literature review
#     crossref · 2019 · Knowledge and Information Systems
#     https://doi.org/10.1007/s10115-018-1322-7
#   • An Abstract-Level Patent Retrieval Model
#     crossref · 2023 · Proceedings of the 4th International Conference on Artificial Intelligence and
#     https://doi.org/10.1145/3652628.3652710

# %%
TOPIC_ID = '2026-09-14T1447-T0011'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  patent / retrieval / prior art / classification
# 137 documents · 2018–2026 · H2 · strong
#
# Defining terms: patent, retrieval, patent classification, prior art, patent retrieval, classification, language, patent claim, search, document, patent document, semantic
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     6  ██████
#      2019    12  ████████████
#      2020     6  ██████
#      2021    10  ██████████
#      2022    16  ███████████████
#      2023    16  ███████████████
#      2024    17  ████████████████
#      2025    25  ████████████████████████  ← burst
#      2026    19  ██████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Innovating Patent Retrieval: A Comprehensive Review of Techniques, Trends, and Challenges in Pri
#     crossref · 2024 · Applied System Innovation
#     https://doi.org/10.3390/asi7050091
#   • Innovating Patent Retrieval: A Comprehensive Review of Techniques, Trends, and Challenges in Pri
#     openalex · 2024 · Applied System Innovation
#     https://doi.org/10.3390/asi7050091
#   • Natural language processing in the patent domain: a survey
#     crossref · 2025 · Artificial Intelligence Review
#     https://doi.org/10.1007/s10462-025-11168-z
#   • Natural language processing in the patent domain: a survey
#     openalex · 2025 · Artificial Intelligence Review
#     https://doi.org/10.1007/s10462-025-11168-z
#   • Optimizing Patent Prior Art Search: An Approach Using Patent Abstract and Key Terms
#     crossref · 2025 · Information
#     https://doi.org/10.3390/info16020145

# %%
TOPIC_ID = '2026-09-14T1447-T0088'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  foresight / anticipatory / scenario planning / governance
# 88 documents · 2018–2026 · H1 · weak
#
# Defining terms: foresight, anticipatory, strategic foresight, anticipatory governance, scenario planning, governance, strategic, anticipatory innovation, anticipatory capacity, foresight anticipatory, corruption, scenario
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██
#      2019     2  █████
#      2020     3  ███████
#      2021     4  ██████████
#      2022     1  ██
#      2023     9  ██████████████████████  ← burst
#      2024     5  ████████████  ← burst
#      2025    10  ████████████████████████  ← burst
#      2026     3  ███████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Conceptualising strategic foresight
#     crossref · 2023 · Strategic Foresight
#     https://doi.org/10.4324/9781003302735-6
#   • Building Anticipatory Capacity with Strategic Foresight in Government
#     crossref · 2025 · OECD Public Governance Reviews
#     https://doi.org/10.1787/d7eb0bb6-en
#   • Supporting decision making with strategic foresight
#     crossref · 2023 · OECD Working Papers on Public Governance
#     https://doi.org/10.1787/1d78c791-en
#   • Strategic foresight
#     crossref · 2023 · Strategic Foresight
#     https://doi.org/10.4324/9781003302735-17
#   • Strategic foresight and its antecedents
#     crossref · 2023 · Strategic Foresight
#     https://doi.org/10.4324/9781003302735-15

# %%
TOPIC_ID = '2026-09-14T1447-T0089'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  intellectual property / property protection / firm / patent
# 151 documents · 2018–2026 · H2 · weak
#
# Defining terms: intellectual property, intellectual, property protection, property, protection, firm, patent, innovation, financing, digital governance, firm innovation, loan
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ████
#      2019     0
#      2020     1  ██
#      2021     3  ██████
#      2022     4  ███████
#      2023     5  █████████
#      2024     2  ████
#      2025    13  ████████████████████████  ← burst
#      2026     8  ███████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Intellectual property litigation, financing constraints, and firms’ innovation resilience
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.109085
#   • Intellectual property financing and enterprise growth
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.107076
#   • Digital finance development, intellectual property protection, and regional innovation
#     crossref · 2025 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2025.108217
#   • Intellectual property protection and enterprise innovation: Evidence from China
#     crossref · 2024 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2024.105253
#   • Intellectual property protection and firm innovation capability
#     crossref · 2026 · Finance Research Letters
#     https://doi.org/10.1016/j.frl.2026.109559

# %%
TOPIC_ID = '2026-09-14T1447-T0043'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  competition / digital platform / digital market / policy digital
# 382 documents · 2018–2026 · H2 · strong
#
# Defining terms: competition, digital platform, competition policy, platform, digital, platform competition, digital market, market, policy digital, pricing, policy, platform market
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     3  ████
#      2019     5  ████████
#      2020     6  █████████
#      2021     8  ████████████
#      2022     5  ████████
#      2023     1  ██
#      2024    16  ████████████████████████  ← burst
#      2025    12  ██████████████████  ← burst
#      2026     9  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Competition Policy and Digital Platforms
#     crossref · 2026 · Antitrust and Competition Policy
#     https://doi.org/10.1017/9781009724647.013
#   • Issues in Platform Competition Policy to Promote Contestable Digital Markets
#     crossref · 2024 · The Korean Journal of Industrial Organization
#     https://doi.org/10.36354/kjio.32.4.3
#   • Competition policy and digital platforms: six uncontroversial propositions
#     crossref · 2020 · European Competition Journal
#     https://doi.org/10.1080/17441056.2020.1730063
#   • The Platform Economy and Digital Markets in Relation to EU Competition and Market Regulation
#     crossref · 2025 · Competition Law and Digital Transformation
#     https://doi.org/10.1163/9789004737273_012
#   • Competition Law and Consumers in Digital Platforms
#     crossref · 2024 · Digitalization and Competition Policy in Japan
#     https://doi.org/10.1007/978-981-99-5310-3_9

# %%
TOPIC_ID = '2026-09-14T1447-T0033'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  artificial intelligence / patent / inventorship / intelligence technology
# 860 documents · 2018–2026 · H2 · strong
#
# Defining terms: artificial intelligence, artificial, patent, intelligence, inventorship, intelligence patent, patent law, intelligence technology, intelligence inventorship, law, intellectual property, patent artificial
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     5  ████████
#      2019     6  ██████████
#      2020    12  ███████████████████
#      2021     3  █████
#      2022     2  ███
#      2023    10  ████████████████
#      2024    10  ████████████████  ← burst
#      2025    15  ████████████████████████  ← burst
#      2026     9  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Artificial Intelligence and Patent Law
#     crossref · 2024 · Artificial Intelligence
#     https://doi.org/10.1201/9781003483571-11
#   • Legal Issues of Artificial Intelligence and Patent
#     crossref · 2018 · Korea Law Review
#     https://doi.org/10.36532/kulri.2018.90.197
#   • Artificial Intelligence and Intellectual Property
#     crossref · 2018 · World Patent Information
#     https://doi.org/10.1016/j.wpi.2018.06.001
#   • Artificial Intelligence And Intellectual Property : Challenges , Litigation , And Future Directi
#     gdelt · 2025 · mondaq.com
#     https://www.mondaq.com:443/unitedstates/new-technology/1724036/artificial-intelligence-and-intellectual-property-challenges-litigation-and-future-directions
#   • Artificial Intelligence as a Challenge for European Patent Law
#     crossref · 2024 · 2024 47th MIPRO ICT and Electronics Convention (MIPRO)
#     https://doi.org/10.1109/mipro60963.2024.10569722

# %%
TOPIC_ID = '2026-09-14T1447-T0044'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  llm / medical / chatgpt / clinical
# 69 documents · 2018–2026 · H1 · strong
#
# Defining terms: llm, medical, chatgpt, clinical, language, large language, health, health care, medical education, chatbot, patient, care
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  █
#      2019     1  █
#      2020     2  ██
#      2021     2  ██
#      2022     5  ████
#      2023    29  ████████████████████████  ← burst
#      2024    17  ██████████████  ← burst
#      2025     3  ██
#      2026     4  ███
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Evaluating the Feasibility of ChatGPT in Healthcare: An Analysis of Multiple Clinical and Resear
#     openalex · 2023 · Journal of Medical Systems
#     https://doi.org/10.1007/s10916-023-01925-4
#   • Large language models in health care: Development, applications, and challenges
#     openalex · 2023 · Health care science
#     https://doi.org/10.1002/hcs2.61
#   • The application of large language models in medicine: A scoping review
#     openalex · 2024 · iScience
#     https://doi.org/10.1016/j.isci.2024.109713
#   • The future landscape of large language models in medicine
#     openalex · 2023 · Communications Medicine
#     https://doi.org/10.1038/s43856-023-00370-1
#   • A study of generative large language model for medical research and healthcare
#     openalex · 2023 · npj Digital Medicine
#     https://doi.org/10.1038/s41746-023-00958-w

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
