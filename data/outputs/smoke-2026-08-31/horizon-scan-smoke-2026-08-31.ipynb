# %% [markdown]
# # IPAVentures horizon scan — run `smoke-2026-08-31`
#
# Generated 2026-08-31 00:40 UTC by `python -m src.notebook --run-id smoke-2026-08-31`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = 'smoke-2026-08-31'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    smoke-2026-08-31
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 2,911

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : hashing
# Clustering method : agglomerative
# Clustering thresh : 0.14
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status     in   out   seconds  message
# ------------------------  -------  ----  ----  --------  ----------------------------------------------------------------
# stage0_strategy           success     —    34     0.100  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage1_collect            partial  3000  2911  5665.100  3000 fetched, 2911 new, 3 failed/skipped pairs, 4 partial in 56…
# stage2_emergence          success  2911    49     7.400  49 topics from 2911 documents across 9 slices (2018-2026); 24 w…
# stage5_synthesis          success    49    49     1.300  ranked 49 topics; outputs written
# stage3_scoring            success    49    49     0.800  scored 49 topics; mean fit 0.106, mean leverage 0.056, 2 critic…
# stage4_opportunity_index  success    49    49     0.200  indexed 46 of 49 topics (3 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# 1 config value(s) have changed since this run.
# Scores below were computed under the STORED values, not these.
#
# setting               at run time  on disk now
# --------------------  -----------  -----------
# pipeline.sample_mode  yes          no

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# openalex         965        2018       2026      20
# gdelt            834        2024       2026      17
# crossref         641        2018       2026      13
# arxiv            323        2018       2021       7
# datagovau        148        2022       2026       3
#
# What this run's collection actually did (per source query):
#
# source     status   queries  records
# ---------  -------  -------  -------
# arxiv      failed         2        0
# arxiv      success        7      350
# crossref   success       13      650
# datagovau  success        3      150
# gdelt      failed         1        0
# gdelt      partial        4      200
# gdelt      success       13      650
# openalex   success       20     1000

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018        353
# 2019        331
# 2020        324
# 2021        211
# 2022        181
# 2023        218
# 2024        345
# 2025        771
# 2026        177
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       1099
# Political            638
# Economic             435
# Legal                340
# Values               150
# Social               149
# Environmental        100

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                   STEEPV         documents  sources
# ---------------------------  -------------  ---------  -------
# ai_governance_assurance      Political            238        5
# ip_admin_automation          Technological        200        4
# ip_policy_reform             Political            200        4
# gov_service_delivery         Political            200        4
# ai_authorship_inventorship   Legal                190        4
# indigenous_knowledge         Values               150        3
# geographical_indications     Legal                150        3
# ip_search_retrieval          Technological        149        3
# ip_enforcement_counterfeit   Economic             149        3
# trust_institutions           Social               149        3
# ip_sme_access                Economic             145        3
# ip_finance_valuation         Economic             141        3
# digital_identity_provenance  Technological        141        3
# ct_biotech                   Technological        141        3
# ct_quantum                   Technological        100        2
# ct_energy                    Environmental        100        2
# ct_autonomous                Technological         97        2
# ct_advanced_manufacturing    Technological         97        2
# ct_ai                        Technological         90        2
# ct_advanced_ict              Technological         84        2

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Failed queries by source: arxiv (2), gdelt (1). Each failure costs that frame's contribution to the corpus, so the shortlist is drawn from a slightly different scan than the frame file describes.

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# -----  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# T0020  copyright / administrative decision-making /    53  0.94  0.19  0.46  0.56  0.96       0.82  H2  strong
# T0010  trust / public institution / driver / oecd      44  0.81  0.17  0.45  0.69  0.36       0.80  H2  strong
# T0004  prior art / patent / art search / retrieval     61  0.69  0.18  0.39  0.66  0.86       0.76  H1  strong
# T0015  dashboard / digital project / queensland / c    28  0.80  0.43  0.76  0.50  0.79       0.75  H2  strong
# T0033  automated decision-making / value position /    20  0.77  0.05  0.38  0.69  0.93       0.74  H2  weak
# T0024  opengov / ul / strong / li                      19  0.79  0.38  0.74  0.50  0.40       0.72  H2  strong
# T0000  intellectual property / property right / enf   127  0.67  0.14  0.45  0.64  0.77       0.70  H1  strong
# T0013  service delivery / public service / digital     39  0.72  0.14  0.37  0.69  0.30       0.70  H2  strong
# T0035  elevation / elvis / river / resolution          14  0.77  0.29  0.79  0.50  0.30       0.70  H2  strong
# T0025  access medicine / medicine africa / law acce    26  0.84  0.00  0.38  0.63  1.00       0.69  H1  weak
# T0011  population / africa / kilometre / km            37  0.52  0.17  0.41  0.64  0.70       0.67  H2  strong
# T0041  llm / medical / clinical / language             19  0.45  0.11  0.33  0.69  0.99       0.66  H1  weak
# T0038  patent law / future patent / artificial inte    29  0.80  0.05  0.32  0.59  0.96       0.65  H2  weak
# T0018  marine / park / australian / specy              34  0.57  0.43  0.48  0.50  0.45       0.65  H2  strong
# T0023  valuation / asset / ip / property               21  0.77  0.00  0.52  0.64  0.61       0.61  H1  weak
# T0014  artificial intelligence / patent / inventors    54  0.75  0.04  0.32  0.61  0.87       0.59  H1  strong
# T0006  geographical / indication / trade / mark        50  0.78  0.00  0.44  0.59  0.92       0.59  H1  strong
# T0043  quantum / internet / network / repeater         13  0.58  0.00  0.37  0.69  0.96       0.59  H1  weak
# T0040  synthetic biology / consortia / microbial /     17  0.76  0.00  0.38  0.58  0.97       0.58  H1  weak
# T0030  ipgod / ip right / property government / gov    21  0.58  0.10  0.43  0.50  0.48       0.55  H1  weak
# T0017  chatgpt / generative / ai / education           46  0.32  0.17  0.29  0.60  1.00       0.53  H1  strong
# T0045  genome / editing / crispr / gene                17  0.56  0.00  0.33  0.63  1.00       0.53  H1  weak
# T0034  learning / machine / quantum / adversarial      18  0.59  0.00  0.39  0.56  0.94       0.51  H1  weak
# T0003  energy / storage / hydrogen / renewable         76  0.46  0.00  0.35  0.63  0.98       0.51  H1  strong
# T0042  genetic resource / benefit sharing / abs / a    16  0.60  0.00  0.37  0.63  0.80       0.50  H1  weak
# T0036  sensing / isac / remote / satellite             16  0.34  0.00  0.37  0.67  0.95       0.46  H1  weak
# T0044  quantum / readout / spin / sensing              15  0.49  0.00  0.35  0.61  0.90       0.46  H1  weak
# T0048  image / deep / learning / retrieval             13  0.48  0.00  0.37  0.55  0.96       0.44  H1  weak
# T0002  digital / govtech / public / government         71  0.26  0.24  0.34  0.40  0.97       0.44  H1  strong
# T0001  ai / patent / invention / aesthetic            139  0.11  0.23  0.29  0.58  0.89       0.44  H2  strong
# T0039  edge / computing / mobile / device              17  0.37  0.00  0.38  0.56  0.94       0.42  H1  weak
# T0027  trust / covid-19 / public / antibiotic          19  0.41  0.00  0.36  0.60  0.87       0.42  H1  weak
# T0046  trust / citizen / government / public           19  0.58  0.00  0.30  0.45  0.99       0.38  H1  weak
# T0008  additive manufacturing / material / metal /     60  0.37  0.00  0.30  0.55  0.99       0.37  H1  strong
# T0012  ai / public / governance / sector               90  0.30  0.18  0.22  0.47  0.94       0.37  H1  strong
# T0009  indigenous / traditional cultural / cultural    44  0.42  0.00  0.38  0.37  0.98       0.37  H1  strong
# T0047  intellectual capital / sme / enterprise / in    19  0.53  0.00  0.31  0.39  0.98       0.35  H1  weak
# T0005  watermark / image / neural / attack             54  0.26  0.06  0.34  0.50  0.84       0.34  H1  strong
# T0021  post-quantum / cryptography / security / alg    28  0.34  0.00  0.37  0.51  0.95       0.34  H1  strong
# T0029  blockchain / smart contract / technology / m    25  0.37  0.00  0.31  0.56  0.92       0.33  H1  weak
# T0037  quantum / circuit / computing / processor       46  0.43  0.00  0.30  0.55  0.80       0.33  H1  weak
# T0032  robot / navigation / mobile / localization      26  0.39  0.00  0.29  0.54  0.93       0.31  H1  weak
# T0026  trademark / infringement / brand / e-commerc    40  0.37  0.03  0.26  0.34  0.95       0.31  H2  strong
# T0016  agreement / trade / intellectual property /     40  0.23  0.00  0.32  0.55  0.98       0.30  H1  strong
# T0028  ipr / intellectual property / property right    20  0.35  0.00  0.35  0.37  0.95       0.27  H1  weak
# T0007  gi / geographical / indication / trade          54  0.28  0.00  0.32  0.45  0.98       0.26  H1  strong
# T0031  indigenous / knowledge / sovereignty / peopl    37  0.37  0.00  0.26  0.46  0.95       0.25  H1  weak
# T0019  learning / machine / dl / classification        27  0.27  0.00  0.38  0.43  0.81       0.24  H1  strong
# T0022  ip / law / intellectual property / fashion      52  0.31  0.00  0.24  0.50  0.82       0.22  H1  weak

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 49 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 49 of 49 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 1,870 of 2,911 documents (64%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 3 topic(s) sit within 0.05 of a Three Horizons cut-point (ai / patent / invention / aesthetic (0.36 → H2); copyright / administrative decision-maki (0.40 → H2); digital / govtech / public / government (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic  label                                   fit  closest objective                     leverage  DISR field
# -----  ------------------------------------  -----  ------------------------------------  --------  ------------------------------------
# T0013  service delivery / public service /…  0.263  4.2 Innovative digital and data-dri…     0.068  —
# T0010  trust / public institution / driver…  0.179  1.1 Trust and confidence in a high-…     0.045  —
# T0006  geographical / indication / trade /…  0.318  SI-1 Geographical indications regis…     0.070  —
# T0004  prior art / patent / art search / r…  0.059  4.2 Innovative digital and data-dri…     0.121  —
# T0030  ipgod / ip right / property governm…  0.121  4.1 Innovation and adaptiveness in …     0.230  —
# T0020  copyright / administrative decision…  0.057  SI-5 First Nations Strategy              0.096  —
# T0002  digital / govtech / public / govern…  0.228  4.2 Innovative digital and data-dri…     0.082  —
# T0014  artificial intelligence / patent / …  0.150  4.2 Innovative digital and data-dri…     0.059  —
# T0025  access medicine / medicine africa /…  0.214  2.1 Access to and benefits from IP …     0.037  —
# T0033  automated decision-making / value p…  0.095  SI-3 AI and Automated Decision Maki…     0.044  —
# T0015  dashboard / digital project / queen…  0.068  1.3 Reputation, influence and contr…     0.058  —
# T0023  valuation / asset / ip / property     0.095  3.1 Capabilities for current and fu…     0.067  —
# T0034  learning / machine / quantum / adve…  0.170  4.2 Innovative digital and data-dri…     0.052  —
# T0003  energy / storage / hydrogen / renew…  0.164  1.2 Awareness of the IP system           0.054  CT-ENERGY Clean energy generation a…
# T0046  trust / citizen / government / publ…  0.167  1.1 Trust and confidence in a high-…     0.071  —
# T0009  indigenous / traditional cultural /…  0.160  SI-5 First Nations Strategy              0.136  —
# T0024  opengov / ul / strong / li            0.058  4.2 Innovative digital and data-dri…     0.052  —
# T0038  patent law / future patent / artifi…  0.062  4.2 Innovative digital and data-dri…     0.067  —
# T0012  ai / public / governance / sector     0.165  SI-3 AI and Automated Decision Maki…     0.068  —
# T0042  genetic resource / benefit sharing …  0.155  2.1 Access to and benefits from IP …     0.044  —
# T0041  llm / medical / clinical / language   0.080  2.2 Customer experience excellence …     0.041  —
# T0048  image / deep / learning / retrieval   0.077  4.1 Innovation and adaptiveness in …     0.069  —
# T0001  ai / patent / invention / aesthetic   0.085  SI-3 AI and Automated Decision Maki…     0.059  —
# T0000  intellectual property / property ri…  0.055  SI-2 Regulatory reform supporting t…     0.042  —
# T0018  marine / park / australian / specy    0.066  4.2 Innovative digital and data-dri…     0.042  —
# T0017  chatgpt / generative / ai / educati…  0.111  4.2 Innovative digital and data-dri…     0.033  —
# T0035  elevation / elvis / river / resolut…  0.065  4.2 Innovative digital and data-dri…     0.027  —
# T0027  trust / covid-19 / public / antibio…  0.113  1.1 Trust and confidence in a high-…     0.038  —
# T0011  population / africa / kilometre / km  0.036  1.3 Reputation, influence and contr…     0.043  —
# T0031  indigenous / knowledge / sovereignt…  0.077  SI-5 First Nations Strategy              0.108  —
# T0036  sensing / isac / remote / satellite   0.055  4.1 Innovation and adaptiveness in …     0.048  —
# T0008  additive manufacturing / material /…  0.133  SI-4 SME education and outreach, in…     0.030  CT-AMM Advanced manufacturing and m…
# T0047  intellectual capital / sme / enterp…  0.134  4.1 Innovation and adaptiveness in …     0.033  —
# T0007  gi / geographical / indication / tr…  0.295  SI-1 Geographical indications regis…     0.027  —
# T0044  quantum / readout / spin / sensing    0.066  SI-5 First Nations Strategy              0.037  —
# T0040  synthetic biology / consortia / mic…  0.050  4.1 Innovation and adaptiveness in …     0.037  —
# T0016  agreement / trade / intellectual pr…  0.119  2.1 Access to and benefits from IP …     0.037  —
# T0026  trademark / infringement / brand / …  0.067  2.2 Customer experience excellence …     0.051  —
# T0043  quantum / internet / network / repe…  0.040  4.1 Innovation and adaptiveness in …     0.035  —
# T0028  ipr / intellectual property / prope…  0.081  2.1 Access to and benefits from IP …     0.038  —
# T0039  edge / computing / mobile / device    0.039  1.2 Awareness of the IP system           0.044  —
# T0021  post-quantum / cryptography / secur…  0.073  4.2 Innovative digital and data-dri…     0.034  —
# T0022  ip / law / intellectual property / …  0.055  4.1 Innovation and adaptiveness in …     0.065  —
# T0029  blockchain / smart contract / techn…  0.049  4.2 Innovative digital and data-dri…     0.045  —
# T0037  quantum / circuit / computing / pro…  0.053  SI-5 First Nations Strategy              0.043  —
# T0045  genome / editing / crispr / gene      0.034  SI-3 AI and Automated Decision Maki…     0.019  —
# T0005  watermark / image / neural / attack   0.054  2.1 Access to and benefits from IP …     0.035  —
# T0019  learning / machine / dl / classific…  0.044  4.2 Innovative digital and data-dri…     0.043  —
# T0032  robot / navigation / mobile / local…  0.034  2.1 Access to and benefits from IP …     0.022  —
#
# strategic fit  range 0.034–0.318  median 0.077
# asset leverage range 0.019–0.230  median 0.044

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic  label                                 attention  attention_tone  policy_salience  research_growth  index
# -----  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# T0013  service delivery / public service /       0.552           0.104            0.958            0.896  0.716
# T0010  trust / public institution / driver       0.615           0.021            0.625            0.979  0.676
# T0006  geographical / indication / trade /       0.552           0.708            0.688            0.385  0.543
# T0004  prior art / patent / art search / re      0.740           0.229            0.542            0.938  0.703
# T0030  ipgod / ip right / property governme      0.333           0.729            1.000            0.385  0.555
# T0020  copyright / administrative decision-      0.917           0.146            0.479            0.958  0.738
# T0002  digital / govtech / public / governm      0.781           0.500            0.938            1.000  0.862
# T0014  artificial intelligence / patent / i      0.875           0.062            0.604            0.812  0.694
# T0025  access medicine / medicine africa /       0.552           0.354            0.646            0.385  0.492
# T0033  automated decision-making / value po      0.333           0.188            0.667            0.875  0.586
# T0015  dashboard / digital project / queens      0.052           0.583            0.500            0.385  0.338
# T0023  valuation / asset / ip / property         0.052           0.312            0.875            0.385  0.394
# T0034  learning / machine / quantum / adver      0.177           0.083            0.521            0.385  0.320
# T0003  energy / storage / hydrogen / renewa      0.896           1.000            0.292            0.385  0.586
# T0046  trust / citizen / government / publi      0.469           0.000            0.833            0.385  0.470
# T0009  indigenous / traditional cultural /       0.469           0.896            0.708            0.385  0.546
# T0024  opengov / ul / strong / li                0.010           0.938            0.375            0.385  0.338
# T0038  patent law / future patent / artific      0.708           0.542            0.750            0.833  0.743
# T0012  ai / public / governance / sector         1.000           0.250            0.979            0.917  0.877
# T0042  genetic resource / benefit sharing /      0.333           0.375            0.729            0.385  0.450
# T0041  llm / medical / clinical / language       0.396           0.333            0.104            0.385  0.316
# T0001  ai / patent / invention / aesthetic       0.979           0.167            0.771            0.854  0.790
# T0000  intellectual property / property rig      0.667           0.271            0.896            0.385  0.575
# T0018  marine / park / australian / specy        0.469           0.625            0.438            0.385  0.450
# T0017  chatgpt / generative / ai / educatio      0.781           0.125            0.458            0.385  0.488
# T0027  trust / covid-19 / public / antibiot      0.177           0.208            0.812            0.385  0.404
# T0011  population / africa / kilometre / km      0.260           0.562            0.062            0.385  0.293
# T0031  indigenous / knowledge / sovereignty      0.812           0.854            0.583            0.385  0.613
# T0036  sensing / isac / remote / satellite       0.104           0.479            0.250            0.385  0.282
# T0008  additive manufacturing / material /       0.854           0.646            0.333            0.385  0.542
# T0047  intellectual capital / sme / enterpr      0.469           0.812            0.562            0.385  0.502
# T0007  gi / geographical / indication / tra      0.740           0.917            0.396            0.385  0.555
# T0044  quantum / readout / spin / sensing        0.260           0.604            0.125            0.385  0.313
# T0040  synthetic biology / consortia / micr      0.260           0.292            0.271            0.385  0.311
# T0016  agreement / trade / intellectual pro      0.688           0.750            0.917            0.385  0.642
# T0026  trademark / infringement / brand / e      0.833           0.042            0.354            0.792  0.613
# T0028  ipr / intellectual property / proper      0.260           0.958            0.792            0.385  0.512
# T0039  edge / computing / mobile / device        0.177           0.979            0.312            0.385  0.377
# T0021  post-quantum / cryptography / securi      0.396           0.438            0.167            0.385  0.343
# T0022  ip / law / intellectual property / f      0.948           0.771            0.854            0.385  0.706
# T0029  blockchain / smart contract / techno      0.552           0.521            0.417            0.385  0.458
# T0037  quantum / circuit / computing / proc      0.948           0.875            0.000            0.385  0.518
# T0045  genome / editing / crispr / gene          0.396           0.396            0.146            0.385  0.333
# T0005  watermark / image / neural / attack       0.646           0.667            0.042            0.385  0.414
# T0019  learning / machine / dl / classifica      0.177           0.458            0.208            0.385  0.291
# T0032  robot / navigation / mobile / locali      0.615           0.792            0.188            0.385  0.454
#
# 3 topic(s) suppressed as too thin to index honestly: T0048, T0035, T0043

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 46 topics — largest deviation 7.7e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 3 of 49 topics carry fewer than 15 documents and have no index at all. They are suppressed rather than scored zero: an unmeasurable index and a low one are different claims.
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 49 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 49 of 49 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#  #  topic                                       H   signal   emrg    fit    lev  index  composite
# --  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#  1  service delivery / public service / digita  H2  strong  0.702  0.263  0.068  0.716      0.880
#  2  trust / public institution / driver / oecd  H2  strong  0.802  0.179  0.045  0.676      0.835
#  3  geographical / indication / trade / mark    H1  strong  0.595  0.318  0.070  0.543      0.830
#  4  prior art / patent / art search / retrieva  H1  strong  0.760  0.059  0.121  0.703      0.732
#  5  ipgod / ip right / property government / g  H1  weak    0.554  0.121  0.230  0.555      0.732
#  6  copyright / administrative decision-making  H2  strong  0.818  0.057  0.096  0.738      0.724
#  7  digital / govtech / public / government     H1  strong  0.441  0.228  0.082  0.862      0.719
#  8  artificial intelligence / patent / invento  H1  strong  0.595  0.150  0.059  0.694      0.715
#  9  access medicine / medicine africa / law ac  H1  weak    0.685  0.214  0.037  0.492      0.698
# 10  automated decision-making / value position  H2  weak    0.735  0.095  0.044  0.586      0.696
# 11  dashboard / digital project / queensland /  H2  strong  0.748  0.068  0.058  0.338      0.695
# 12  valuation / asset / ip / property           H1  weak    0.607  0.095  0.067  0.394      0.682
# 13  learning / machine / quantum / adversarial  H1  weak    0.514  0.170  0.052  0.320      0.674
# 14  energy / storage / hydrogen / renewable     H1  strong  0.506  0.164  0.054  0.586      0.654
# 15  trust / citizen / government / public       H1  weak    0.376  0.167  0.071  0.470      0.651
# 16  indigenous / traditional cultural / cultur  H1  strong  0.371  0.160  0.136  0.546      0.634
# 17  opengov / ul / strong / li                  H2  strong  0.716  0.058  0.052  0.338      0.617
# 18  patent law / future patent / artificial in  H2  weak    0.652  0.062  0.067  0.743      0.609
# 19  ai / public / governance / sector           H1  strong  0.371  0.165  0.068  0.877      0.602
# 20  genetic resource / benefit sharing / abs /  H1  weak    0.503  0.155  0.044  0.450      0.584
# 21  llm / medical / clinical / language         H1  weak    0.661  0.080  0.041  0.316      0.574
# 22  image / deep / learning / retrieval         H1  weak    0.443  0.077  0.069      —      0.551
# 23  ai / patent / invention / aesthetic         H2  strong  0.439  0.085  0.059  0.790      0.527
# 24  intellectual property / property right / e  H1  strong  0.703  0.055  0.042  0.575      0.524
# 25  marine / park / australian / specy          H2  strong  0.646  0.066  0.042  0.450      0.519
# 26  chatgpt / generative / ai / education       H1  strong  0.527  0.111  0.033  0.488      0.478
# 27  elevation / elvis / river / resolution      H2  strong  0.699  0.065  0.027      —      0.468
# 28  trust / covid-19 / public / antibiotic      H1  weak    0.417  0.113  0.038  0.404      0.441
# 29  population / africa / kilometre / km        H2  strong  0.666  0.036  0.043  0.293      0.441
# 30  indigenous / knowledge / sovereignty / peo  H1  weak    0.254  0.077  0.108  0.613      0.426
# 31  sensing / isac / remote / satellite         H1  weak    0.456  0.055  0.048  0.282      0.405
# 32  additive manufacturing / material / metal   H1  strong  0.372  0.133  0.030  0.542      0.394
# 33  intellectual capital / sme / enterprise /   H1  weak    0.354  0.134  0.033  0.502      0.386
# 34  gi / geographical / indication / trade      H1  strong  0.264  0.295  0.027  0.555      0.383
# 35  quantum / readout / spin / sensing          H1  weak    0.455  0.066  0.037  0.313      0.377
# 36  synthetic biology / consortia / microbial   H1  weak    0.579  0.050  0.037  0.311      0.358
# 37  agreement / trade / intellectual property   H1  strong  0.296  0.119  0.037  0.642      0.343
# 38  trademark / infringement / brand / e-comme  H2  strong  0.307  0.067  0.051  0.613      0.342
# 39  quantum / internet / network / repeater     H1  weak    0.586  0.040  0.035      —      0.334
# 40  ipr / intellectual property / property rig  H1  weak    0.273  0.081  0.038  0.512      0.301
# 41  edge / computing / mobile / device          H1  weak    0.418  0.039  0.044  0.377      0.292
# 42  post-quantum / cryptography / security / a  H1  strong  0.335  0.073  0.034  0.343      0.280
# 43  ip / law / intellectual property / fashion  H1  weak    0.218  0.055  0.065  0.706      0.270
# 44  blockchain / smart contract / technology /  H1  weak    0.332  0.049  0.045  0.458      0.254
# 45  quantum / circuit / computing / processor   H1  weak    0.329  0.053  0.043  0.518      0.229
# 46  genome / editing / crispr / gene            H1  weak    0.526  0.034  0.019  0.333      0.225
# 47  watermark / image / neural / attack         H1  strong  0.341  0.054  0.035  0.414      0.199
# 48  learning / machine / dl / classification    H1  strong  0.245  0.044  0.043  0.291      0.144
# 49  robot / navigation / mobile / localization  H1  weak    0.308  0.034  0.022  0.454      0.071

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.077, leverage 0.044).
#
# ACT (15)
#       1  service delivery / public service / digital / government
#       2  trust / public institution / driver / oecd
#       3  geographical / indication / trade / mark
#       5  ipgod / ip right / property government / government open
#       7  digital / govtech / public / government
#       8  artificial intelligence / patent / inventorship / intelligen
#      10  automated decision-making / value position / social service
#      12  valuation / asset / ip / property
#      13  learning / machine / quantum / adversarial
#      14  energy / storage / hydrogen / renewable
#      15  trust / citizen / government / public
#      16  indigenous / traditional cultural / cultural expression / in
#      19  ai / public / governance / sector
#      23  ai / patent / invention / aesthetic
#      30  indigenous / knowledge / sovereignty / people
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (10)
#       9  access medicine / medicine africa / law access / compulsory
#      20  genetic resource / benefit sharing / abs / access benefit
#      21  llm / medical / clinical / language
#      26  chatgpt / generative / ai / education
#      28  trust / covid-19 / public / antibiotic
#      32  additive manufacturing / material / metal / bone
#      33  intellectual capital / sme / enterprise / innovation
#      34  gi / geographical / indication / trade
#      37  agreement / trade / intellectual property / pharmaceutical
#      40  ipr / intellectual property / property right / creative
#
# CAPABILITY LOOKING FOR A PROBLEM (10)
#       4  prior art / patent / art search / retrieval
#       6  copyright / administrative decision-making / aripo
#      11  dashboard / digital project / queensland / contribution publ
#      17  opengov / ul / strong / li
#      18  patent law / future patent / artificial intelligence / inven
#      22  image / deep / learning / retrieval
#      31  sensing / isac / remote / satellite
#      38  trademark / infringement / brand / e-commerce
#      43  ip / law / intellectual property / fashion
#      44  blockchain / smart contract / technology / music
#
# WATCH (14)
#      24  intellectual property / property right / enforcement intelle
#      25  marine / park / australian / specy
#      27  elevation / elvis / river / resolution
#      29  population / africa / kilometre / km
#      35  quantum / readout / spin / sensing
#      36  synthetic biology / consortia / microbial / artificial flowe
#      39  quantum / internet / network / repeater
#      41  edge / computing / mobile / device
#      42  post-quantum / cryptography / security / algorithm
#      45  quantum / circuit / computing / processor
#      46  genome / editing / crispr / gene
#      47  watermark / image / neural / attack
#      48  learning / machine / dl / classification
#      49  robot / navigation / mobile / localization

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = 'T0013'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  service delivery / public service / digital / government
# 39 documents · 2019–2026 · H2 · strong
#
# Defining terms: service delivery, service, delivery, public service, digital, government, local government, public, digital transformation, vgi, government service, local
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     4  ██████████████
#      2020     4  ██████████████
#      2021     3  ██████████
#      2022     1  ███
#      2023     2  ███████
#      2024     4  ██████████████  ← burst
#      2025     7  ████████████████████████  ← burst
#      2026     2  ███████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Governance in Public Service Delivery
#     crossref · 2025 · E-Government in Bangladesh
#     https://doi.org/10.4324/9781003631699-2
#   • Towards Digital Anti-Corruption Typology for Public Service Delivery
#     crossref · 2019 · Proceedings of the 20th Annual International Conference on Digital Government
#     https://doi.org/10.1145/3325112.3325266
#   • Understanding value of digital service delivery by governments in Mexico
#     crossref · 2024 · Government Information Quarterly
#     https://doi.org/10.1016/j.giq.2024.101936
#   • Digital Government Governance: Enhancing Public Service Delivery and Citizen Engagement in the D
#     crossref · 2026 · Digital Transformation and Sustainability in South Asia
#     https://doi.org/10.1007/978-3-032-28051-0_3
#   • Measuring Public Service Delivery in Bangladesh
#     crossref · 2025 · E-Government in Bangladesh
#     https://doi.org/10.4324/9781003631699-5

# %%
TOPIC_ID = 'T0010'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  trust / public institution / driver / oecd
# 44 documents · 2018–2026 · H2 · strong
#
# Defining terms: trust, public institution, trust public, institution, driver trust, public, driver, oecd, presidency, survey driver, trust presidency, oecd survey
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     3  ██████████
#      2019     0
#      2020     1  ███
#      2021     3  ██████████
#      2022     3  ██████████
#      2023     4  ██████████████
#      2024     4  ██████████████  ← burst
#      2025     7  ████████████████████████  ← burst
#      2026     5  █████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Drivers of Trust in Public Institutions in New Zealand
#     crossref · 2023 · Building Trust in Public Institutions
#     https://doi.org/10.1787/948accf8-en
#   • Drivers of Trust in Public Institutions in Norway
#     crossref · 2022 · Building Trust in Public Institutions
#     https://doi.org/10.1787/81b01318-en
#   • Drivers of Trust in Public Institutions in Australia
#     crossref · 2025 · Building Trust in Public Institutions
#     https://doi.org/10.1787/28a876c2-en
#   • Drivers of trust in public institutions in Finland
#     crossref · 2021 · Building Trust in Public Institutions
#     https://doi.org/10.1787/52600c9e-en
#   • Drivers of Trust in Public Institutions in Brazil
#     crossref · 2023 · Building Trust in Public Institutions
#     https://doi.org/10.1787/fb0e1896-en

# %%
TOPIC_ID = 'T0006'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  geographical / indication / trade / mark
# 50 documents · 2018–2026 · H1 · strong
#
# Defining terms: geographical, geographical indication, indication, trade, trade mark, mark, indication trade, trade agreement, agreement, protection, gis, union
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ███████
#      2019     7  ████████████████████████
#      2020     4  ██████████████
#      2021     7  ████████████████████████
#      2022     5  █████████████████
#      2023     3  ██████████
#      2024     6  █████████████████████
#      2025     1  ███
#      2026     3  ██████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Geographical indications
#     crossref · 2020 · A Handbook on the WTO TRIPS Agreement
#     https://doi.org/10.1017/9781108883511.005
#   • Evaluating geographical indications
#     crossref · 2021 · edited-book
#     https://doi.org/10.4060/cb6511en
#   • Non-agricultural geographical indications
#     crossref · 2024 · The Protection of Geographical Indications
#     https://doi.org/10.4337/9781035332267.00017
#   • INTERNATIONAL GEOGRAPHICAL INDICATIONS REGIMES
#     crossref · 2019 · The Protection of Geographical Indications
#     https://doi.org/10.4337/9781788975414.00009
#   • International geographical indications regimes
#     crossref · 2024 · The Protection of Geographical Indications
#     https://doi.org/10.4337/9781035332267.00009

# %%
TOPIC_ID = 'T0004'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  prior art / patent / art search / retrieval
# 61 documents · 2018–2026 · H1 · strong
#
# Defining terms: prior art, patent, art, art search, prior, search, patent prior, retrieval, patent document, document, patent search, search service
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  █████████
#      2019     1  ██
#      2020     5  ███████████
#      2021     2  ████
#      2022    11  ████████████████████████  ← burst
#      2023     1  ██  ← burst
#      2024     5  ███████████  ← burst
#      2025     7  ███████████████  ← burst
#      2026     6  █████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Conducting Prior Art Searches
#     crossref · 2018 · A Guide for Implementing a Patent Strategy
#     https://doi.org/10.1002/9781119407119.ch9
#   • Search for Prior Art
#     crossref · 2026 · Patent Made Simple: How to File Without a Lawyer
#     https://doi.org/10.1007/978-3-662-73096-6_12
#   • Patent prior art search using deep learning language model
#     crossref · 2020 · Proceedings of the 24th Symposium on International Database Engineering &amp;
#     https://doi.org/10.1145/3410566.3410597
#   • Does My Invention Already Exist? Conducting a Patent/Prior Art Search
#     crossref · 2019 · Academic Entrepreneurship for Medical and Health Sciences
#     https://doi.org/10.21428/b2e239dc.7209b684
#   • Prior Art Search Using Multi-modal Embedding of Patent Documents
#     crossref · 2020 · 2020 IEEE International Conference on Big Data and Smart Computing (BigComp)
#     https://doi.org/10.1109/bigcomp48618.2020.000-6

# %%
TOPIC_ID = 'T0030'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  ipgod / ip right / property government / government open
# 21 documents · 2022–2023 · H1 · weak
#
# Defining terms: ipgod, ip, ip right, property government, government open, ip australia, right, intellectual property, intellectual, property, australia, administered ip
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     0
#      2022     5  ███████████████  ← burst
#      2023     8  ████████████████████████  ← burst
#      2024     0
#      2025     0
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • [Superceded] Intellectual Property Government Open Data 2016
#     datagovau · 2023 · IP Australia
#     https://data.gov.au/data/dataset/intellectual-property-government-open-data-2016
#   • Intellectual Property Government Open Data 2017 (GovHack)
#     datagovau · 2023 · IP Australia
#     https://data.gov.au/data/dataset/intellectual-property-government-open-data-2017-govhack
#   • [Superceded] Intellectual Property Government Open Data 2017
#     datagovau · 2023 · IP Australia
#     https://data.gov.au/data/dataset/intellectual-property-government-open-data-2017
#   • IPGOD2020
#     datagovau · 2023 · IP Australia
#     https://data.gov.au/data/dataset/ipgod2020
#   • IPGOD2022
#     datagovau · 2022 · IP Australia
#     https://data.gov.au/data/dataset/ipgod2022

# %%
TOPIC_ID = 'T0020'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  copyright / administrative decision-making / aripo
# 53 documents · 2020–2026 · H2 · strong
#
# Defining terms: copyright, administrative decision-making, aripo, administrative, decision-making
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     3  ██████████████████
#      2021     1  ██████
#      2022     2  ████████████
#      2023     2  ████████████
#      2024     4  ████████████████████████  ← burst
#      2025     4  ████████████████████████  ← burst
#      2026     4  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Copyright
#     crossref · 2026 · Artificial Intelligence
#     https://doi.org/10.1016/b978-0-44-324840-5.00003-2
#   • Copyright
#     crossref · 2025 · Edge Artificial Intelligence
#     https://doi.org/10.1016/b978-0-443-26720-8.12001-8
#   • Copyright
#     crossref · 2026 · Aquaculture with Artificial Intelligence
#     https://doi.org/10.1016/b978-0-443-33704-8.12001-4
#   • Copyright
#     crossref · 2026 · Emotional Artificial Intelligence
#     https://doi.org/10.1016/b978-0-443-44744-0.09991-4
#   • Copyright
#     crossref · 2022 · Human-Centered Artificial Intelligence
#     https://doi.org/10.1016/b978-0-323-85648-5.12001-8

# %%
TOPIC_ID = 'T0002'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  digital / govtech / public / government
# 71 documents · 2018–2026 · H1 · strong
#
# Defining terms: digital, govtech, public, government, service, public service, service delivery, digital transformation, delivery, transformation, citizen, digital government
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ████
#      2019     2  ████
#      2020     0
#      2021     1  ██
#      2022     7  ██████████████  ← burst
#      2023     7  ██████████████  ← burst
#      2024    12  ████████████████████████  ← burst
#      2025    10  ████████████████████  ← burst
#      2026     7  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Digital Transformation Practices and Government Service Delivery in Developing Countries
#     crossref · 2026 · International Journal of Technology and Systems
#     https://doi.org/10.47604/ijts.3597
#   • Digital transformation in government: Lessons from GovTech Singapore
#     openalex · 2025 · Journal of Information Technology Teaching Cases
#     https://doi.org/10.1177/20438869251362871
#   • Cloud-Native Government: Digital Infrastructure Transforming Public Service Delivery
#     crossref · 2025 · Journal of Computer Science and Technology Studies
#     https://doi.org/10.32996/jcsts.2025.7.7.6
#   • Enhancing Public Service Delivery through Digital Transformation: Challenges and Opportunities i
#     openalex · 2024 · Pakistan Journal of Life and Social Sciences (PJLSS)
#     https://doi.org/10.57239/pjlss-2024-22.2.001601
#   • Cross-Country Empirical Analysis of Govtech Platforms on Citizen Engagement
#     openalex · 2024
#     https://doi.org/10.1596/1813-9450-10716

# %%
TOPIC_ID = 'T0014'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  artificial intelligence / patent / inventorship / intelligence technology
# 54 documents · 2018–2026 · H1 · strong
#
# Defining terms: artificial intelligence, intelligence, artificial, patent, inventorship, intelligence patent, intelligence technology, age artificial, invention, generative artificial, inventorship age, authorship
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  ██████
#      2019     2  ██████
#      2020     8  ████████████████████████
#      2021     1  ███
#      2022     0
#      2023     4  ████████████
#      2024     1  ███
#      2025     5  ███████████████
#      2026     2  ██████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Inventorship in the Age of Artificial Intelligence
#     crossref · 2020 · SSRN Electronic Journal
#     https://doi.org/10.2139/ssrn.3664637
#   • Artificial Intelligence and IP (part 3)
#     crossref · 2023 · World Patent Information
#     https://doi.org/10.1016/j.wpi.2023.102242
#   • Patentability Analysis of Artificial Intelligence and Big Data Patent Applications
#     crossref · 2023 · Journal of Artificial Intelligence Practice
#     https://doi.org/10.23977/jaip.2023.060801
#   • Artificial intelligence and inventorship: an Australian perspective
#     crossref · 2020 · Journal of Intellectual Property Law &amp; Practice
#     https://doi.org/10.1093/jiplp/jpaa039
#   • Artificial Intelligence, Patent Networks, Blockchains, and Digitalization
#     crossref · 2025 · Patent Valuation
#     https://doi.org/10.1007/978-3-031-88443-6_7

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
