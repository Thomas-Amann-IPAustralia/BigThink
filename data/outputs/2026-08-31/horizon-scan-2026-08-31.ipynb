# %% [markdown]
# # IPAVentures horizon scan — run `2026-08-31`
#
# Generated 2026-08-31 06:48 UTC by `python -m src.notebook --run-id 2026-08-31`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = '2026-08-31'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    2026-08-31
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 7,501

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : hashing
# Clustering method : agglomerative
# Clustering thresh : 0.14
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status     in  out  seconds  message
# ------------------------  -------  ----  ---  -------  ----------------------------------------------------------------
# stage0_strategy           success     —   34    0.100  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage2_emergence          failed      —    —    5.000  Constraint Error: Duplicate key "topic_id: T0000" violates prim…
# stage0_strategy           success     —   34    0.100  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage2_emergence          success  7501  102   19.700  102 topics from 7501 documents across 9 slices (2018-2026); 19 …
# stage5_synthesis          success   102  102    2.700  ranked 102 topics; outputs written
# stage3_scoring            success   102  102    1.800  scored 102 topics; mean fit 0.091, mean leverage 0.058, 6 criti…
# stage4_opportunity_index  success   102  102    0.400  indexed 89 of 102 topics (13 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# crossref        2437        2018       2026      13
# gdelt           2317        2026       2026      16
# arxiv           2018        2018       2026       9
# openalex         581        2018       2026      20
# datagovau        148        2022       2026       3
#
# What this run's collection actually did (per source query):
#
# source  status  queries  records
# ------  ------  -------  -------
# (no rows)

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018        509
# 2019        570
# 2020        604
# 2021        548
# 2022        527
# 2023        561
# 2024        581
# 2025        649
# 2026       2952
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       3239
# Political           1438
# Economic            1009
# Legal                908
# Values               424
# Social               334
# Environmental        149

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                   STEEPV         documents  sources
# ---------------------------  -------------  ---------  -------
# ai_governance_assurance      Political            692        5
# ai_authorship_inventorship   Legal                553        4
# ip_search_retrieval          Technological        494        3
# ct_quantum                   Technological        493        3
# digital_identity_provenance  Technological        477        3
# gov_service_delivery         Political            457        4
# ip_admin_automation          Technological        443        4
# indigenous_knowledge         Values               424        3
# ip_enforcement_counterfeit   Economic             410        3
# ip_finance_valuation         Economic             375        3
# ct_autonomous                Technological        358        2
# geographical_indications     Legal                355        3
# ct_biotech                   Technological        337        3
# trust_institutions           Social               334        3
# ip_policy_reform             Political            289        4
# ct_ai                        Technological        277        3
# ip_sme_access                Economic             224        2
# ct_advanced_ict              Technological        189        2
# ct_advanced_manufacturing    Technological        171        2
# ct_energy                    Environmental        149        2

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic             label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# ----------------  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# 2026-08-31-T0028  additive manufacturing / arc additive / wire    41  0.87  0.30  0.57  0.62  0.94       0.90  H3  strong
# 2026-08-31-T0002  copyright / page / economic right / exceptio   182  0.92  0.31  0.75  0.67  0.56       0.88  H2  strong
# 2026-08-31-T0029  dashboard / digital project / queensland / c    38  0.81  0.42  0.60  0.51  0.84       0.80  H2  strong
# 2026-08-31-T0020  valuation / property / intellectual / kenya     61  0.77  0.08  0.42  0.63  0.98       0.80  H1  strong
# 2026-08-31-T0006  artificial intelligence / patent / examinati   121  0.76  0.25  0.36  0.68  0.82       0.79  H2  strong
# 2026-08-31-T0074  trust / chapter / political / britain           16  0.54  0.13  0.39  0.64  0.95       0.77  H2  weak
# 2026-08-31-T0000  intellectual property / property right / enf   358  0.60  0.15  0.46  0.71  0.61       0.76  H2  strong
# 2026-08-31-T0057  african / gis / property organization / oapi    25  0.69  0.08  0.39  0.62  1.00       0.76  H1  weak
# 2026-08-31-T0003  service delivery / local government / public   164  0.65  0.19  0.38  0.68  0.29       0.74  H2  strong
# 2026-08-31-T0004  trust / institution / public / driver          134  0.78  0.07  0.38  0.70  0.80       0.74  H2  strong
# 2026-08-31-T0007  heritage / cultural / intellectual / propert   121  0.68  0.26  0.35  0.64  0.66       0.73  H1  strong
# 2026-08-31-T0013  africa / kilometre km / square kilometre / p    75  0.51  0.20  0.36  0.64  0.89       0.72  H2  strong
# 2026-08-31-T0041  li / ul / nsw / opengov                         33  0.75  0.38  0.49  0.50  0.74       0.70  H2  strong
# 2026-08-31-T0060  elevation / elvis / river / area cover          14  0.78  0.28  0.79  0.50  0.30       0.69  H2  weak
# 2026-08-31-T0101  patent portfolio / portfolio management         42  0.91  0.26  0.28  0.54  0.70       0.67  H2  weak
# 2026-08-31-T0036  patent law / artificial intelligence / futur    56  0.80  0.06  0.31  0.60  0.95       0.66  H2  strong
# 2026-08-31-T0072  foramen / ovale / closure / carcinoid           13  0.82  0.00  0.63  0.66  0.78       0.65  H1  noise
# 2026-08-31-T0034  park / australian marine / specy / reef         48  0.57  0.42  0.38  0.50  0.50       0.64  H2  strong
# 2026-08-31-T0001  geographical indication / gi / trade / produ   186  0.57  0.02  0.41  0.64  0.83       0.63  H2  latent
# 2026-08-31-T0010  prior art / patent / art search / retrieval    121  0.74  0.05  0.33  0.62  0.86       0.63  H2  strong
# 2026-08-31-T0045  patent retrieval / integration image / retri    24  0.80  0.00  0.43  0.70  0.69       0.62  H2  latent
# 2026-08-31-T0066  good governance / trust / citizen / public i    17  0.74  0.00  0.38  0.65  0.94       0.62  H1  noise
# 2026-08-31-T0062  corporate governance / finance corporate / g    37  0.85  0.04  0.30  0.57  0.88       0.61  H2  noise
# 2026-08-31-T0054  index / stop line / positioning / aided coop    28  0.93  0.00  0.53  0.59  0.74       0.61  H1  noise
# 2026-08-31-T0039  access medicine / medicine africa / law acce    43  0.82  0.00  0.34  0.61  0.99       0.60  H1  latent
# 2026-08-31-T0058  image / patent / retrieval / classification     15  0.49  0.03  0.42  0.57  0.92       0.60  H2  noise
# 2026-08-31-T0086  patent / examination / invention / rebuttal     32  0.71  0.19  0.28  0.55  0.63       0.59  H2  weak
# 2026-08-31-T0017  automated decision-making / administrative l    85  0.77  0.02  0.29  0.63  0.85       0.59  H1  latent
# 2026-08-31-T0046  genetic resource / benefit sharing / access     34  0.52  0.06  0.32  0.65  0.73       0.59  H1  strong
# 2026-08-31-T0047  trust / financial / institution / iceland       41  0.49  0.07  0.27  0.61  0.96       0.57  H1  strong
# 2026-08-31-T0059  patent / ai / language / nlp                    18  0.37  0.08  0.37  0.57  0.97       0.57  H1  weak
# 2026-08-31-T0018  trust / institution / public / citizen          53  0.30  0.17  0.34  0.66  0.85       0.57  H3  strong
# 2026-08-31-T0027  patent / prior art / examiner / invention       36  0.28  0.10  0.36  0.62  0.98       0.57  H2  strong
# 2026-08-31-T0052  ipgod / ip right / government open / propert    30  0.55  0.10  0.35  0.51  0.37       0.56  H1  strong
# 2026-08-31-T0014  indigenous / traditional knowledge / cultura    66  0.46  0.04  0.38  0.50  0.97       0.56  H1  latent
# 2026-08-31-T0065  ketupat / culture / acknowledgment / muslim     31  0.84  0.00  0.37  0.56  0.86       0.56  H1  noise
# 2026-08-31-T0093  quantum / sensing / metrology / estimation      12  0.42  0.10  0.38  0.50  0.92       0.55  H3  weak
# 2026-08-31-T0080  watermarking / pseudorandom / prc / robustne    11  0.44  0.11  0.44  0.50  0.68       0.55  H2  weak
# 2026-08-31-T0053  decision making / automated decision / makin    38  0.84  0.00  0.31  0.59  0.93       0.55  H1  noise
# 2026-08-31-T0019  ai / adm / automated decision-making / accou    74  0.30  0.25  0.28  0.62  0.85       0.53  H3  strong
# 2026-08-31-T0068  manipulation / robot / long-horizon / object    13  0.37  0.20  0.41  0.50  0.78       0.53  H3  weak
# 2026-08-31-T0043  patent / retrieval / idea generation / query    29  0.28  0.26  0.33  0.54  0.90       0.53  H1  strong
# 2026-08-31-T0031  synthetic biology / engineering / metabolic     48  0.56  0.05  0.30  0.51  0.91       0.52  H1  strong
# 2026-08-31-T0061  digital government / digital landscape / nsw    64  0.73  0.08  0.22  0.54  0.73       0.52  H1  weak
# 2026-08-31-T0038  crispr / gene / genome / editing                27  0.40  0.04  0.37  0.58  0.84       0.52  H1  latent
# 2026-08-31-T0030  llm / language / braille / reasoning            39  0.31  0.23  0.32  0.53  0.91       0.51  H2  strong
# 2026-08-31-T0022  watermarking / text / llm / language            45  0.34  0.30  0.36  0.50  0.87       0.51  H1  strong
# 2026-08-31-T0026  trade / agreement / free / eu                   76  0.71  0.00  0.31  0.60  0.95       0.51  H1  latent
# 2026-08-31-T0095  competition law / eu competition / ipr / int    20  0.54  0.00  0.30  0.61  0.97       0.50  H1  noise
# 2026-08-31-T0069  driving / autonomous / visual / lidar           15  0.39  0.08  0.37  0.50  0.92       0.50  H2  weak
# 2026-08-31-T0071  watermarking / mesh / attack / nerf             14  0.39  0.08  0.38  0.50  0.86       0.49  H1  weak
# 2026-08-31-T0097  backdoor / attack / dataset / trigger           20  0.44  0.08  0.29  0.50  0.97       0.49  H1  weak
# 2026-08-31-T0040  erasure / diffusion / concept / text-to-imag    31  0.33  0.22  0.33  0.50  0.96       0.48  H2  strong
# 2026-08-31-T0015  service delivery / digital / public service    102  0.29  0.13  0.28  0.59  0.89       0.48  H2  strong
# 2026-08-31-T0096  unregistered / registered design / design pr    19  0.58  0.00  0.32  0.56  0.88       0.47  H1  noise
# 2026-08-31-T0098  neural / network / classification / deep con    10  0.48  0.00  0.44  0.54  0.73       0.47  H1  noise
# 2026-08-31-T0011  energy / storage / hydrogen / renewable        110  0.45  0.00  0.30  0.58  0.99       0.47  H1  latent
# 2026-08-31-T0090  image / generative adversarial / font / adve    15  0.43  0.03  0.33  0.50  1.00       0.46  H1  noise
# 2026-08-31-T0033  ai / chatgpt / generative / content             95  0.34  0.23  0.21  0.54  0.79       0.45  H1  strong
# 2026-08-31-T0042  graph / gnn / node / neural network             37  0.35  0.10  0.29  0.50  1.00       0.45  H1  strong
# 2026-08-31-T0051  quantum / qubit / circuit / superconducting     29  0.36  0.08  0.30  0.50  1.00       0.45  H2  weak
# 2026-08-31-T0024  valuation / briefing / market / valuer          51  0.34  0.00  0.32  0.70  0.99       0.45  H1  latent
# 2026-08-31-T0092  robot / path / exploration / srm                13  0.41  0.03  0.36  0.50  0.96       0.45  H2  noise
# 2026-08-31-T0012  ai / patent / invention / law                  145  0.22  0.26  0.24  0.56  0.81       0.45  H2  strong
# 2026-08-31-T0081  medicinal / nbsp / cultural / plant             21  0.33  0.11  0.27  0.50  0.94       0.44  H3  weak
# 2026-08-31-T0037  quantum / error / qubit / code                  38  0.40  0.05  0.30  0.50  0.99       0.44  H1  strong
# 2026-08-31-T0021  aesthetic / reef / nesp / image                 71  0.20  0.38  0.27  0.50  0.76       0.43  H3  strong
# 2026-08-31-T0087  watermarking / attack / replay / networked      15  0.51  0.00  0.34  0.50  1.00       0.43  H1  noise
# 2026-08-31-T0063  video / vmt / low-light / feature               28  0.37  0.08  0.27  0.50  0.97       0.42  H1  weak
# 2026-08-31-T0082  chinese / patent / chapter implementation /     50  0.80  0.00  0.25  0.53  0.74       0.42  H1  noise
# 2026-08-31-T0073  unlearning / cross-modal / persona / cbd        41  0.38  0.21  0.21  0.50  0.80       0.41  H3  weak
# 2026-08-31-T0078  driving / autonomous / imitation / traffic      16  0.49  0.00  0.34  0.50  0.99       0.41  H1  noise
# 2026-08-31-T0084  kd / distillation / teacher / knowledge         15  0.45  0.00  0.36  0.50  0.97       0.41  H1  noise
# 2026-08-31-T0005  ip / intellectual / property / right           145  0.15  0.05  0.29  0.63  0.81       0.40  H2  strong
# 2026-08-31-T0085  auv / reef / underwater / sirius                28  0.43  0.10  0.24  0.49  0.82       0.40  H2  weak
# 2026-08-31-T0100  bp-net / malaria / quantum / llm                12  0.36  0.00  0.38  0.53  0.92       0.40  H1  noise
# 2026-08-31-T0070  logo / detection / image / dataset              15  0.36  0.03  0.36  0.50  0.92       0.40  H1  noise
# 2026-08-31-T0075  fairness / algorithmic / machine learning /     18  0.43  0.00  0.32  0.61  0.40       0.39  H3  noise
# 2026-08-31-T0091  learning / visual / navigation / mid-level      10  0.43  0.00  0.45  0.50  0.72       0.38  H1  noise
# 2026-08-31-T0079  odometry / sensor / fusion / vehicle            14  0.41  0.00  0.37  0.51  0.40       0.37  H1  noise
# 2026-08-31-T0044  autonomous / sensor / vehicle / driving         26  0.32  0.00  0.34  0.52  1.00       0.37  H1  latent
# 2026-08-31-T0056  quantum / spin / nv / diamond                   22  0.41  0.00  0.33  0.50  0.98       0.36  H1  noise
# 2026-08-31-T0035  patent / classification / claim / tc            28  0.33  0.05  0.37  0.50  0.75       0.36  H2  strong
# 2026-08-31-T0009  watermark / attack / dnn / adversarial          70  0.26  0.07  0.39  0.50  0.47       0.35  H1  strong
# 2026-08-31-T0067  autonomous / vehicle / avs / simulation         13  0.39  0.00  0.41  0.50  0.78       0.35  H2  noise
# 2026-08-31-T0083  dataset / image / gan / pre-training            15  0.39  0.00  0.35  0.50  0.97       0.35  H1  noise
# 2026-08-31-T0076  additive manufacturing / material / printing    30  0.43  0.00  0.23  0.55  0.83       0.35  H1  noise
# 2026-08-31-T0023  navigation / odometry / positioning / inerti    39  0.27  0.05  0.35  0.48  0.99       0.35  H1  strong
# 2026-08-31-T0088  hps / dataset / influence function / documen    12  0.37  0.00  0.38  0.50  0.92       0.35  H1  noise
# 2026-08-31-T0094  nodule / lung / ct / cancer                     19  0.39  0.00  0.28  0.50  0.98       0.31  H1  noise
# 2026-08-31-T0032  robot / navigation / mobile / autonomous        36  0.37  0.00  0.34  0.49  0.99       0.31  H1  latent
# 2026-08-31-T0064  trademark / infringement / brand / e-commerc    47  0.42  0.05  0.22  0.42  0.76       0.30  H2  weak
# 2026-08-31-T0077  blockchain / contract / smart / copyright de    33  0.40  0.00  0.23  0.52  0.80       0.29  H1  noise
# 2026-08-31-T0089  influencer / authenticity / celebrity / mark    33  0.51  0.00  0.25  0.49  0.90       0.29  H1  noise
# 2026-08-31-T0049  point cloud / object / voxel / correspondenc    34  0.35  0.00  0.28  0.50  1.00       0.29  H1  latent
# 2026-08-31-T0016  reinforcement / learning / agent / rl           58  0.27  0.00  0.36  0.51  0.82       0.29  H1  latent
# 2026-08-31-T0050  sensing / isac / remote / irrigation            36  0.35  0.00  0.26  0.52  0.85       0.27  H1  noise
# 2026-08-31-T0099  ticket / ssl / lane / downstream                30  0.40  0.00  0.22  0.50  0.84       0.25  H1  noise
# 2026-08-31-T0008  watermark / image / attack / distortion         83  0.30  0.01  0.35  0.50  0.56       0.24  H2  latent
# 2026-08-31-T0048  patent / technology / graphene / sca            41  0.23  0.04  0.26  0.49  0.89       0.23  H2  latent
# 2026-08-31-T0025  quantum / algorithm / variational / gauge      162  0.36  0.00  0.22  0.50  0.68       0.18  H1  latent
# 2026-08-31-T0055  indigenous / voice / sovereignty / knowledge    82  0.33  0.00  0.21  0.49  0.74       0.12  H1  noise

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 102 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 102 of 102 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 5,127 of 7,501 documents (68%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 18 topic(s) sit within 0.05 of a Three Horizons cut-point (watermarking / pseudorandom / prc / robu (0.37 → H2); service delivery / digital / public serv (0.37 → H2); robot / path / exploration / srm (0.40 → H2); geographical indication / gi / trade / p (0.71 → H2); trust / institution / public / driver (0.71 → H2); erasure / diffusion / concept / text-to- (0.71 → H2); trademark / infringement / brand / e-com (0.71 → H2); driving / autonomous / visual / lidar (0.71 → H2); auv / reef / underwater / sirius (0.71 → H2); service delivery / local government / pu (0.71 → H2); watermark / image / attack / distortion (0.71 → H2); ai / patent / invention / law (0.71 → H2); patent / prior art / examiner / inventio (0.71 → H2); automated decision-making / administrati (0.77 → H1); watermarking / mesh / attack / nerf (0.77 → H1); competition law / eu competition / ipr / (0.77 → H1); backdoor / attack / dataset / trigger (0.77 → H1); african / gis / property organization /  (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic             label                                   fit  closest objective                     leverage  DISR field
# ----------------  ------------------------------------  -----  ------------------------------------  --------  ------------------------------------
# 2026-08-31-T0006  artificial intelligence / patent / …  0.167  4.2 Innovative digital and data-dri…     0.124  —
# 2026-08-31-T0053  decision making / automated decisio…  0.436  SI-3 AI and Automated Decision Maki…     0.208  —
# 2026-08-31-T0074  trust / chapter / political / brita…  0.211  1.1 Trust and confidence in a high-…     0.048  —
# 2026-08-31-T0014  indigenous / traditional knowledge …  0.200  SI-5 First Nations Strategy              0.163  —
# 2026-08-31-T0066  good governance / trust / citizen /…  0.145  1.1 Trust and confidence in a high-…     0.105  —
# 2026-08-31-T0003  service delivery / local government…  0.149  4.2 Innovative digital and data-dri…     0.058  —
# 2026-08-31-T0059  patent / ai / language / nlp          0.200  SI-3 AI and Automated Decision Maki…     0.069  CT-AI Artificial intelligence
# 2026-08-31-T0002  copyright / page / economic right /…  0.071  4.1 Innovation and adaptiveness in …     0.075  —
# 2026-08-31-T0019  ai / adm / automated decision-makin…  0.183  SI-3 AI and Automated Decision Maki…     0.119  —
# 2026-08-31-T0052  ipgod / ip right / government open …  0.135  4.1 Innovation and adaptiveness in …     0.233  —
# 2026-08-31-T0004  trust / institution / public / driv…  0.190  1.1 Trust and confidence in a high-…     0.044  —
# 2026-08-31-T0039  access medicine / medicine africa /…  0.195  2.1 Access to and benefits from IP …     0.056  —
# 2026-08-31-T0036  patent law / artificial intelligenc…  0.083  4.2 Innovative digital and data-dri…     0.066  —
# 2026-08-31-T0046  genetic resource / benefit sharing …  0.142  2.1 Access to and benefits from IP …     0.063  —
# 2026-08-31-T0010  prior art / patent / art search / r…  0.070  4.1 Innovation and adaptiveness in …     0.090  —
# 2026-08-31-T0017  automated decision-making / adminis…  0.141  SI-3 AI and Automated Decision Maki…     0.057  —
# 2026-08-31-T0028  additive manufacturing / arc additi…  0.053  SI-3 AI and Automated Decision Maki…     0.082  —
# 2026-08-31-T0062  corporate governance / finance corp…  0.084  2.2 Customer experience excellence …     0.063  —
# 2026-08-31-T0057  african / gis / property organizati…  0.073  SI-1 Geographical indications regis…     0.052  —
# 2026-08-31-T0001  geographical indication / gi / trad…  0.347  SI-1 Geographical indications regis…     0.036  —
# 2026-08-31-T0000  intellectual property / property ri…  0.065  4.1 Innovation and adaptiveness in …     0.057  —
# 2026-08-31-T0045  patent retrieval / integration imag…  0.070  4.1 Innovation and adaptiveness in …     0.077  —
# 2026-08-31-T0041  li / ul / nsw / opengov               0.071  4.2 Innovative digital and data-dri…     0.055  —
# 2026-08-31-T0015  service delivery / digital / public…  0.259  4.2 Innovative digital and data-dri…     0.059  —
# 2026-08-31-T0033  ai / chatgpt / generative / content   0.227  SI-3 AI and Automated Decision Maki…     0.065  CT-AI Artificial intelligence
# 2026-08-31-T0029  dashboard / digital project / queen…  0.052  1.3 Reputation, influence and contr…     0.064  —
# 2026-08-31-T0095  competition law / eu competition / …  0.116  4.1 Innovation and adaptiveness in …     0.068  —
# 2026-08-31-T0072  foramen / ovale / closure / carcino…  0.070  2.1 Access to and benefits from IP …     0.048  —
# 2026-08-31-T0075  fairness / algorithmic / machine le…  0.231  SI-3 AI and Automated Decision Maki…     0.112  —
# 2026-08-31-T0027  patent / prior art / examiner / inv…  0.056  4.2 Innovative digital and data-dri…     0.132  —
# 2026-08-31-T0061  digital government / digital landsc…  0.097  4.2 Innovative digital and data-dri…     0.058  —
# 2026-08-31-T0058  image / patent / retrieval / classi…  0.052  3.1 Capabilities for current and fu…     0.098  —
# 2026-08-31-T0096  unregistered / registered design / …  0.081  2.1 Access to and benefits from IP …     0.086  —
# 2026-08-31-T0005  ip / intellectual / property / right  0.153  2.1 Access to and benefits from IP …     0.088  —
# 2026-08-31-T0012  ai / patent / invention / law         0.100  SI-3 AI and Automated Decision Maki…     0.087  —
# 2026-08-31-T0018  trust / institution / public / citi…  0.165  1.1 Trust and confidence in a high-…     0.030  —
# 2026-08-31-T0047  trust / financial / institution / i…  0.162  1.1 Trust and confidence in a high-…     0.031  —
# 2026-08-31-T0026  trade / agreement / free / eu         0.163  1.3 Reputation, influence and contr…     0.043  —
# 2026-08-31-T0011  energy / storage / hydrogen / renew…  0.165  1.2 Awareness of the IP system           0.045  CT-ENERGY Clean energy generation a…
# 2026-08-31-T0060  elevation / elvis / river / area co…  0.080  4.2 Innovative digital and data-dri…     0.026  —
# 2026-08-31-T0007  heritage / cultural / intellectual …  0.056  SI-2 Regulatory reform supporting t…     0.040  —
# 2026-08-31-T0034  park / australian marine / specy / …  0.066  4.2 Innovative digital and data-dri…     0.035  —
# 2026-08-31-T0085  auv / reef / underwater / sirius      0.085  SI-2 Regulatory reform supporting t…     0.078  —
# 2026-08-31-T0020  valuation / property / intellectual…  0.032  2.1 Access to and benefits from IP …     0.054  —
# 2026-08-31-T0037  quantum / error / qubit / code        0.163  1.3 Reputation, influence and contr…     0.043  CT-QUANTUM Quantum technologies
# 2026-08-31-T0086  patent / examination / invention / …  0.023  SI-6 Capability Framework and innov…     0.166  —
# 2026-08-31-T0038  crispr / gene / genome / editing      0.130  1.1 Trust and confidence in a high-…     0.019  CT-BIO Biotechnologies
# 2026-08-31-T0043  patent / retrieval / idea generatio…  0.056  1.1 Trust and confidence in a high-…     0.044  —
# 2026-08-31-T0101  patent portfolio / portfolio manage…  0.039  4.1 Innovation and adaptiveness in …     0.042  —
# 2026-08-31-T0013  africa / kilometre km / square kilo…  0.034  2.2 Customer experience excellence …     0.044  —
# 2026-08-31-T0065  ketupat / culture / acknowledgment …  0.063  3.1 Capabilities for current and fu…     0.033  —
# 2026-08-31-T0024  valuation / briefing / market / val…  0.057  1.3 Reputation, influence and contr…     0.053  —
# 2026-08-31-T0054  index / stop line / positioning / a…  0.045  SI-2 Regulatory reform supporting t…     0.039  —
# 2026-08-31-T0030  llm / language / braille / reasoning  0.056  SI-3 AI and Automated Decision Maki…     0.042  —
# 2026-08-31-T0064  trademark / infringement / brand / …  0.076  2.1 Access to and benefits from IP …     0.067  —
# 2026-08-31-T0093  quantum / sensing / metrology / est…  0.047  1.2 Awareness of the IP system           0.043  —
# 2026-08-31-T0035  patent / classification / claim / tc  0.055  4.1 Innovation and adaptiveness in …     0.110  —
# 2026-08-31-T0067  autonomous / vehicle / avs / simula…  0.068  4.2 Innovative digital and data-dri…     0.061  —
# 2026-08-31-T0055  indigenous / voice / sovereignty / …  0.077  SI-5 First Nations Strategy              0.087  —
# 2026-08-31-T0097  backdoor / attack / dataset / trigg…  0.078  4.1 Innovation and adaptiveness in …     0.023  —
# 2026-08-31-T0031  synthetic biology / engineering / m…  0.045  4.2 Innovative digital and data-dri…     0.047  —
# 2026-08-31-T0082  chinese / patent / chapter implemen…  0.063  SI-5 First Nations Strategy              0.045  —
# 2026-08-31-T0022  watermarking / text / llm / language  0.054  SI-3 AI and Automated Decision Maki…     0.038  —
# 2026-08-31-T0080  watermarking / pseudorandom / prc /…  0.053  4.1 Innovation and adaptiveness in …     0.027  —
# 2026-08-31-T0100  bp-net / malaria / quantum / llm      0.062  1.1 Trust and confidence in a high-…     0.049  —
# 2026-08-31-T0098  neural / network / classification /…  0.051  4.1 Innovation and adaptiveness in …     0.041  —
# 2026-08-31-T0068  manipulation / robot / long-horizon…  0.041  SI-4 SME education and outreach, in…     0.041  —
# 2026-08-31-T0063  video / vmt / low-light / feature     0.063  SI-3 AI and Automated Decision Maki…     0.041  —
# 2026-08-31-T0092  robot / path / exploration / srm      0.047  SI-2 Regulatory reform supporting t…     0.048  —
# 2026-08-31-T0048  patent / technology / graphene / sca  0.063  SI-1 Geographical indications regis…     0.065  —
# 2026-08-31-T0008  watermark / image / attack / distor…  0.116  SI-5 First Nations Strategy              0.042  —
# 2026-08-31-T0076  additive manufacturing / material /…  0.134  SI-2 Regulatory reform supporting t…     0.029  CT-AMM Advanced manufacturing and m…
# 2026-08-31-T0079  odometry / sensor / fusion / vehicle  0.048  SI-2 Regulatory reform supporting t…     0.055  —
# 2026-08-31-T0069  driving / autonomous / visual / lid…  0.052  SI-1 Geographical indications regis…     0.027  —
# 2026-08-31-T0088  hps / dataset / influence function …  0.104  1.3 Reputation, influence and contr…     0.029  —
# 2026-08-31-T0078  driving / autonomous / imitation / …  0.048  SI-3 AI and Automated Decision Maki…     0.046  —
# 2026-08-31-T0089  influencer / authenticity / celebri…  0.087  1.3 Reputation, influence and contr…     0.036  —
# 2026-08-31-T0090  image / generative adversarial / fo…  0.059  4.1 Innovation and adaptiveness in …     0.021  —
# 2026-08-31-T0081  medicinal / nbsp / cultural / plant   0.066  SI-2 Regulatory reform supporting t…     0.021  —
# 2026-08-31-T0021  aesthetic / reef / nesp / image       0.044  SI-2 Regulatory reform supporting t…     0.045  —
# 2026-08-31-T0023  navigation / odometry / positioning…  0.052  4.1 Innovation and adaptiveness in …     0.051  —
# 2026-08-31-T0070  logo / detection / image / dataset    0.042  SI-5 First Nations Strategy              0.055  —
# 2026-08-31-T0099  ticket / ssl / lane / downstream      0.062  4.1 Innovation and adaptiveness in …     0.049  —
# 2026-08-31-T0071  watermarking / mesh / attack / nerf   0.039  2.1 Access to and benefits from IP …     0.038  —
# 2026-08-31-T0087  watermarking / attack / replay / ne…  0.045  SI-1 Geographical indications regis…     0.041  —
# 2026-08-31-T0073  unlearning / cross-modal / persona …  0.048  1.2 Awareness of the IP system           0.040  —
# 2026-08-31-T0084  kd / distillation / teacher / knowl…  0.038  1.3 Reputation, influence and contr…     0.053  —
# 2026-08-31-T0091  learning / visual / navigation / mi…  0.042  SI-1 Geographical indications regis…     0.052  —
# 2026-08-31-T0042  graph / gnn / node / neural network   0.040  SI-1 Geographical indications regis…     0.038  —
# 2026-08-31-T0051  quantum / qubit / circuit / superco…  0.047  SI-1 Geographical indications regis…     0.023  —
# 2026-08-31-T0094  nodule / lung / ct / cancer           0.067  4.2 Innovative digital and data-dri…     0.025  —
# 2026-08-31-T0040  erasure / diffusion / concept / tex…  0.033  1.3 Reputation, influence and contr…     0.027  —
# 2026-08-31-T0050  sensing / isac / remote / irrigation  0.042  4.2 Innovative digital and data-dri…     0.050  —
# 2026-08-31-T0044  autonomous / sensor / vehicle / dri…  0.036  SI-2 Regulatory reform supporting t…     0.033  —
# 2026-08-31-T0016  reinforcement / learning / agent / …  0.045  1.2 Awareness of the IP system           0.034  —
# 2026-08-31-T0025  quantum / algorithm / variational /…  0.046  1.1 Trust and confidence in a high-…     0.036  —
# 2026-08-31-T0077  blockchain / contract / smart / cop…  0.039  4.2 Innovative digital and data-dri…     0.040  —
# 2026-08-31-T0083  dataset / image / gan / pre-training  0.041  2.2 Customer experience excellence …     0.029  —
# 2026-08-31-T0009  watermark / attack / dnn / adversar…  0.038  SI-5 First Nations Strategy              0.032  —
# 2026-08-31-T0056  quantum / spin / nv / diamond         0.035  3.1 Capabilities for current and fu…     0.026  —
# 2026-08-31-T0049  point cloud / object / voxel / corr…  0.031  4.2 Innovative digital and data-dri…     0.041  —
# 2026-08-31-T0032  robot / navigation / mobile / auton…  0.041  4.1 Innovation and adaptiveness in …     0.024  —
#
# strategic fit  range 0.023–0.436  median 0.063
# asset leverage range 0.019–0.233  median 0.047

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic             label                                 attention  attention_tone  policy_salience  research_growth  index
# ----------------  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# 2026-08-31-T0006  artificial intelligence / patent / e      0.837           0.010            0.663            0.921  0.728
# 2026-08-31-T0053  decision making / automated decision      0.738           0.505            0.941            0.262  0.590
# 2026-08-31-T0074  trust / chapter / political / britai      0.178           0.020            0.624            0.262  0.294
# 2026-08-31-T0014  indigenous / traditional knowledge /      0.500           0.713            0.822            0.713  0.676
# 2026-08-31-T0066  good governance / trust / citizen /       0.233           0.079            0.901            0.262  0.382
# 2026-08-31-T0003  service delivery / local government       0.891           0.247            0.931            0.614  0.727
# 2026-08-31-T0059  patent / ai / language / nlp              0.178           0.198            0.881            0.847  0.582
# 2026-08-31-T0002  copyright / page / economic right /       0.688           0.168            0.772            1.000  0.757
# 2026-08-31-T0019  ai / adm / automated decision-making      0.856           0.099            0.852            0.881  0.775
# 2026-08-31-T0052  ipgod / ip right / government open /      0.500           0.535            0.990            0.262  0.536
# 2026-08-31-T0004  trust / institution / public / drive      0.856           0.050            0.812            0.262  0.541
# 2026-08-31-T0039  access medicine / medicine africa /       0.688           0.515            0.683            0.262  0.516
# 2026-08-31-T0036  patent law / artificial intelligence      0.812           0.337            0.792            0.673  0.702
# 2026-08-31-T0046  genetic resource / benefit sharing /      0.549           0.129            0.614            0.262  0.414
# 2026-08-31-T0010  prior art / patent / art search / re      0.955           0.040            0.644            0.683  0.678
# 2026-08-31-T0017  automated decision-making / administ      0.891           0.356            0.693            0.564  0.666
# 2026-08-31-T0028  additive manufacturing / arc additiv      0.500           0.545            0.376            0.891  0.614
# 2026-08-31-T0062  corporate governance / finance corpo      0.777           0.406            1.000            0.262  0.604
# 2026-08-31-T0057  african / gis / property organizatio      0.386           0.307            0.584            0.792  0.567
# 2026-08-31-T0001  geographical indication / gi / trade      0.688           0.208            0.574            0.634  0.586
# 2026-08-31-T0000  intellectual property / property rig      0.653           0.297            0.960            0.262  0.546
# 2026-08-31-T0045  patent retrieval / integration image      0.233           0.287            0.703            0.262  0.360
# 2026-08-31-T0041  li / ul / nsw / opengov                   0.446           0.842            0.564            0.262  0.455
# 2026-08-31-T0015  service delivery / digital / public       0.921           0.228            0.951            0.594  0.731
# 2026-08-31-T0033  ai / chatgpt / generative / content       0.980           0.218            0.634            0.693  0.708
# 2026-08-31-T0029  dashboard / digital project / queens      0.426           0.446            0.604            0.535  0.508
# 2026-08-31-T0095  competition law / eu competition / i      0.386           0.366            0.723            0.262  0.419
# 2026-08-31-T0075  fairness / algorithmic / machine lea      0.287           0.277            0.515            0.262  0.331
# 2026-08-31-T0027  patent / prior art / examiner / inve      0.317           0.594            0.713            0.911  0.652
# 2026-08-31-T0061  digital government / digital landsca      0.921           0.158            0.861            0.554  0.688
# 2026-08-31-T0058  image / patent / retrieval / classif      0.054           0.495            0.535            0.663  0.434
# 2026-08-31-T0096  unregistered / registered design / d      0.346           0.792            0.762            0.262  0.467
# 2026-08-31-T0005  ip / intellectual / property / right      0.955           0.148            0.980            0.723  0.784
# 2026-08-31-T0012  ai / patent / invention / law             0.990           0.257            0.921            0.941  0.870
# 2026-08-31-T0018  trust / institution / public / citiz      0.500           0.416            0.911            0.901  0.728
# 2026-08-31-T0047  trust / financial / institution / ic      0.738           0.564            0.871            0.262  0.581
# 2026-08-31-T0026  trade / agreement / free / eu             0.891           0.574            0.832            0.262  0.618
# 2026-08-31-T0011  energy / storage / hydrogen / renewa      0.941           0.871            0.475            0.262  0.584
# 2026-08-31-T0007  heritage / cultural / intellectual /      0.921           0.743            0.673            0.644  0.744
# 2026-08-31-T0034  park / australian marine / specy / r      0.738           0.960            0.545            0.262  0.551
# 2026-08-31-T0085  auv / reef / underwater / sirius          0.569           0.901            0.010            0.653  0.506
# 2026-08-31-T0020  valuation / property / intellectual       0.777           0.782            0.743            0.262  0.588
# 2026-08-31-T0037  quantum / error / qubit / code            0.530           0.921            0.366            0.703  0.598
# 2026-08-31-T0086  patent / examination / invention / r      0.653           0.465            0.842            0.802  0.728
# 2026-08-31-T0038  crispr / gene / genome / editing          0.267           0.772            0.050            0.262  0.274
# 2026-08-31-T0043  patent / retrieval / idea generation      0.346           0.812            0.802            0.980  0.732
# 2026-08-31-T0101  patent portfolio / portfolio managem      0.802           0.752            0.970            0.733  0.811
# 2026-08-31-T0013  africa / kilometre km / square kilom      0.653           0.485            0.178            0.262  0.384
# 2026-08-31-T0065  ketupat / culture / acknowledgment /      0.599           0.703            0.505            0.262  0.470
# 2026-08-31-T0024  valuation / briefing / market / valu      0.624           0.861            0.653            0.262  0.531
# 2026-08-31-T0054  index / stop line / positioning / ai      0.465           0.267            0.455            0.262  0.368
# 2026-08-31-T0030  llm / language / braille / reasoning      0.465           0.436            0.396            0.970  0.624
# 2026-08-31-T0064  trademark / infringement / brand / e      0.822           0.059            0.525            0.574  0.575
# 2026-08-31-T0035  patent / classification / claim / tc      0.178           0.614            0.752            0.772  0.574
# 2026-08-31-T0055  indigenous / voice / sovereignty / k      0.970           0.089            0.733            0.262  0.561
# 2026-08-31-T0097  backdoor / attack / dataset / trigge      0.386           0.634            0.218            0.752  0.505
# 2026-08-31-T0031  synthetic biology / engineering / me      0.738           0.455            0.059            0.262  0.377
# 2026-08-31-T0082  chinese / patent / chapter implement      0.871           0.584            0.782            0.262  0.602
# 2026-08-31-T0022  watermarking / text / llm / language      0.426           0.030            0.485            0.990  0.592
# 2026-08-31-T0063  video / vmt / low-light / feature         0.530           0.346            0.040            0.743  0.468
# 2026-08-31-T0048  patent / technology / graphene / sca      0.738           0.663            0.891            0.584  0.711
# 2026-08-31-T0008  watermark / image / attack / distort      0.584           0.386            0.099            0.545  0.433
# 2026-08-31-T0076  additive manufacturing / material /       0.599           0.762            0.416            0.262  0.456
# 2026-08-31-T0069  driving / autonomous / visual / lida      0.134           0.723            0.079            0.847  0.442
# 2026-08-31-T0078  driving / autonomous / imitation / t      0.233           0.139            0.158            0.262  0.215
# 2026-08-31-T0089  influencer / authenticity / celebrit      0.738           0.475            0.386            0.262  0.456
# 2026-08-31-T0090  image / generative adversarial / fon      0.233           0.941            0.139            0.262  0.304
# 2026-08-31-T0081  medicinal / nbsp / cultural / plant       0.386           0.426            0.554            0.832  0.588
# 2026-08-31-T0021  aesthetic / reef / nesp / image           0.837           0.653            0.148            0.812  0.644
# 2026-08-31-T0023  navigation / odometry / positioning       0.317           0.109            0.436            0.262  0.301
# 2026-08-31-T0070  logo / detection / image / dataset        0.134           0.624            0.317            0.624  0.407
# 2026-08-31-T0099  ticket / ssl / lane / downstream          0.624           0.178            0.089            0.262  0.318
# 2026-08-31-T0087  watermarking / attack / replay / net      0.233           0.683            0.356            0.262  0.325
# 2026-08-31-T0073  unlearning / cross-modal / persona /      0.792           0.000            0.297            0.782  0.579
# 2026-08-31-T0084  kd / distillation / teacher / knowle      0.178           0.119            0.277            0.262  0.224
# 2026-08-31-T0042  graph / gnn / node / neural network       0.569           0.931            0.228            0.822  0.621
# 2026-08-31-T0051  quantum / qubit / circuit / supercon      0.465           0.891            0.307            0.762  0.583
# 2026-08-31-T0094  nodule / lung / ct / cancer               0.346           0.832            0.069            0.262  0.309
# 2026-08-31-T0040  erasure / diffusion / concept / text      0.386           0.970            0.198            0.960  0.613
# 2026-08-31-T0050  sensing / isac / remote / irrigation      0.624           0.852            0.446            0.262  0.481
# 2026-08-31-T0044  autonomous / sensor / vehicle / driv      0.287           0.693            0.495            0.262  0.375
# 2026-08-31-T0016  reinforcement / learning / agent / r      0.317           0.525            0.465            0.262  0.357
# 2026-08-31-T0025  quantum / algorithm / variational /       1.000           0.980            0.020            0.262  0.507
# 2026-08-31-T0077  blockchain / contract / smart / copy      0.688           0.673            0.594            0.262  0.514
# 2026-08-31-T0083  dataset / image / gan / pre-training      0.178           0.376            0.337            0.262  0.268
# 2026-08-31-T0009  watermark / attack / dnn / adversari      0.233           0.396            0.129            0.262  0.238
# 2026-08-31-T0056  quantum / spin / nv / diamond             0.287           0.802            0.000            0.262  0.271
# 2026-08-31-T0049  point cloud / object / voxel / corre      0.549           0.822            0.406            0.262  0.446
# 2026-08-31-T0032  robot / navigation / mobile / autono      0.426           0.881            0.188            0.262  0.366
#
# 13 topic(s) suppressed as too thin to index honestly: 2026-08-31-T0072, 2026-08-31-T0060, 2026-08-31-T0093, 2026-08-31-T0067, 2026-08-31-T0080, 2026-08-31-T0100, 2026-08-31-T0098, 2026-08-31-T0068, 2026-08-31-T0092, 2026-08-31-T0079, 2026-08-31-T0088, 2026-08-31-T0071, 2026-08-31-T0091

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 89 topics — largest deviation 9.09e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 13 of 102 topics carry fewer than 15 documents and have no index at all. They are suppressed rather than scored zero: an unmeasurable index and a low one are different claims.
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 102 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 102 of 102 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  artificial intelligence / patent / examina  H2  strong  0.786  0.167  0.124  0.728      0.934
#   2  decision making / automated decision / mak  H1  noise   0.551  0.436  0.208  0.590      0.847
#   3  trust / chapter / political / britain       H2  weak    0.770  0.211  0.048  0.294      0.844
#   4  indigenous / traditional knowledge / cultu  H1  latent  0.561  0.200  0.163  0.676      0.837
#   5  good governance / trust / citizen / public  H1  noise   0.616  0.145  0.105  0.382      0.829
#   6  service delivery / local government / publ  H2  strong  0.737  0.149  0.058  0.727      0.827
#   7  patent / ai / language / nlp                H1  weak    0.574  0.200  0.069  0.582      0.809
#   8  copyright / page / economic right / except  H2  strong  0.880  0.071  0.075  0.757      0.807
#   9  ai / adm / automated decision-making / acc  H3  strong  0.529  0.183  0.119  0.775      0.796
#  10  ipgod / ip right / government open / prope  H1  strong  0.562  0.135  0.233  0.536      0.793
#  11  trust / institution / public / driver       H2  strong  0.735  0.190  0.044  0.541      0.792
#  12  access medicine / medicine africa / law ac  H1  latent  0.602  0.195  0.056  0.516      0.791
#  13  patent law / artificial intelligence / fut  H2  strong  0.655  0.083  0.066  0.702      0.769
#  14  genetic resource / benefit sharing / acces  H1  strong  0.586  0.142  0.063  0.414      0.750
#  15  prior art / patent / art search / retrieva  H2  strong  0.627  0.070  0.090  0.678      0.749
#  16  automated decision-making / administrative  H1  latent  0.587  0.141  0.057  0.666      0.736
#  17  additive manufacturing / arc additive / wi  H3  strong  0.897  0.053  0.082  0.614      0.735
#  18  corporate governance / finance corporate /  H2  noise   0.611  0.084  0.063  0.604      0.735
#  19  african / gis / property organization / oa  H1  weak    0.761  0.073  0.052  0.567      0.733
#  20  geographical indication / gi / trade / pro  H2  latent  0.632  0.347  0.036  0.586      0.732
#  21  intellectual property / property right / e  H2  strong  0.763  0.065  0.057  0.546      0.725
#  22  patent retrieval / integration image / ret  H2  latent  0.618  0.070  0.077  0.360      0.724
#  23  li / ul / nsw / opengov                     H2  strong  0.705  0.071  0.055  0.455      0.722
#  24  service delivery / digital / public servic  H2  strong  0.481  0.259  0.059  0.731      0.709
#  25  ai / chatgpt / generative / content         H1  strong  0.454  0.227  0.065  0.708      0.697
#  26  dashboard / digital project / queensland /  H2  strong  0.799  0.052  0.064  0.508      0.692
#  27  competition law / eu competition / ipr / i  H1  noise   0.495  0.116  0.068  0.419      0.671
#  28  foramen / ovale / closure / carcinoid       H1  noise   0.645  0.070  0.048      —      0.670
#  29  fairness / algorithmic / machine learning   H3  noise   0.389  0.231  0.112  0.331      0.667
#  30  patent / prior art / examiner / invention   H2  strong  0.565  0.056  0.132  0.652      0.659
#  31  digital government / digital landscape / n  H1  weak    0.524  0.097  0.058  0.688      0.652
#  32  image / patent / retrieval / classificatio  H2  noise   0.600  0.052  0.098  0.434      0.637
#  33  unregistered / registered design / design   H1  noise   0.468  0.081  0.086  0.467      0.631
#  34  ip / intellectual / property / right        H2  strong  0.402  0.153  0.088  0.784      0.622
#  35  ai / patent / invention / law               H2  strong  0.447  0.100  0.087  0.870      0.621
#  36  trust / institution / public / citizen      H3  strong  0.572  0.165  0.030  0.728      0.619
#  37  trust / financial / institution / iceland   H1  strong  0.574  0.162  0.031  0.581      0.617
#  38  trade / agreement / free / eu               H1  latent  0.513  0.163  0.043  0.618      0.616
#  39  energy / storage / hydrogen / renewable     H1  latent  0.465  0.165  0.045  0.584      0.600
#  40  elevation / elvis / river / area cover      H2  weak    0.693  0.080  0.026      —      0.597
#  41  heritage / cultural / intellectual / prope  H1  strong  0.732  0.056  0.040  0.744      0.586
#  42  park / australian marine / specy / reef     H2  strong  0.643  0.066  0.035  0.551      0.572
#  43  auv / reef / underwater / sirius            H2  weak    0.401  0.085  0.078  0.506      0.557
#  44  valuation / property / intellectual / keny  H1  strong  0.796  0.032  0.054  0.588      0.549
#  45  quantum / error / qubit / code              H1  strong  0.438  0.163  0.043  0.598      0.546
#  46  patent / examination / invention / rebutta  H2  weak    0.590  0.023  0.166  0.728      0.542
#  47  crispr / gene / genome / editing            H1  latent  0.522  0.130  0.019  0.274      0.493
#  48  patent / retrieval / idea generation / que  H1  strong  0.527  0.056  0.044  0.732      0.491
#  49  patent portfolio / portfolio management     H2  weak    0.674  0.039  0.042  0.811      0.479
#  50  africa / kilometre km / square kilometre /  H2  strong  0.722  0.034  0.044  0.384      0.477
#  51  ketupat / culture / acknowledgment / musli  H1  noise   0.560  0.063  0.033  0.470      0.476
#  52  valuation / briefing / market / valuer      H1  latent  0.449  0.057  0.053  0.531      0.462
#  53  index / stop line / positioning / aided co  H1  noise   0.609  0.045  0.039  0.368      0.454
#  54  llm / language / braille / reasoning        H2  strong  0.515  0.056  0.042  0.624      0.454
#  55  trademark / infringement / brand / e-comme  H2  weak    0.298  0.076  0.067  0.575      0.453
#  56  quantum / sensing / metrology / estimation  H3  weak    0.554  0.047  0.043      —      0.447
#  57  patent / classification / claim / tc        H2  strong  0.359  0.055  0.110  0.574      0.441
#  58  autonomous / vehicle / avs / simulation     H2  noise   0.350  0.068  0.061      —      0.440
#  59  indigenous / voice / sovereignty / knowled  H1  noise   0.121  0.077  0.087  0.561      0.437
#  60  backdoor / attack / dataset / trigger       H1  weak    0.491  0.078  0.023  0.505      0.433
#  61  synthetic biology / engineering / metaboli  H1  strong  0.525  0.045  0.047  0.377      0.430
#  62  chinese / patent / chapter implementation   H1  noise   0.421  0.063  0.045  0.602      0.416
#  63  watermarking / text / llm / language        H1  strong  0.515  0.054  0.038  0.592      0.411
#  64  watermarking / pseudorandom / prc / robust  H2  weak    0.552  0.053  0.027      —      0.406
#  65  bp-net / malaria / quantum / llm            H1  noise   0.401  0.062  0.049      —      0.400
#  66  neural / network / classification / deep c  H1  noise   0.467  0.051  0.041      —      0.379
#  67  manipulation / robot / long-horizon / obje  H3  weak    0.527  0.041  0.041      —      0.377
#  68  video / vmt / low-light / feature           H1  weak    0.422  0.063  0.041  0.468      0.376
#  69  robot / path / exploration / srm            H2  noise   0.448  0.047  0.048      —      0.374
#  70  patent / technology / graphene / sca        H2  latent  0.227  0.063  0.065  0.711      0.373
#  71  watermark / image / attack / distortion     H2  latent  0.241  0.116  0.042  0.433      0.363
#  72  additive manufacturing / material / printi  H1  noise   0.349  0.134  0.029  0.456      0.359
#  73  odometry / sensor / fusion / vehicle        H1  noise   0.370  0.048  0.055      —      0.349
#  74  driving / autonomous / visual / lidar       H2  weak    0.495  0.052  0.027  0.442      0.346
#  75  hps / dataset / influence function / docum  H1  noise   0.346  0.104  0.029      —      0.343
#  76  driving / autonomous / imitation / traffic  H1  noise   0.414  0.048  0.046  0.215      0.337
#  77  influencer / authenticity / celebrity / ma  H1  noise   0.291  0.087  0.036  0.456      0.337
#  78  image / generative adversarial / font / ad  H1  noise   0.455  0.059  0.021  0.304      0.335
#  79  medicinal / nbsp / cultural / plant         H3  weak    0.438  0.066  0.021  0.588      0.333
#  80  aesthetic / reef / nesp / image             H3  strong  0.432  0.044  0.045  0.644      0.323
#  81  navigation / odometry / positioning / iner  H1  strong  0.347  0.052  0.051  0.301      0.318
#  82  logo / detection / image / dataset          H1  noise   0.395  0.042  0.055  0.407      0.314
#  83  ticket / ssl / lane / downstream            H1  noise   0.253  0.062  0.049  0.318      0.311
#  84  watermarking / mesh / attack / nerf         H1  weak    0.492  0.039  0.038      —      0.301
#  85  watermarking / attack / replay / networked  H1  noise   0.427  0.045  0.041  0.325      0.299
#  86  unlearning / cross-modal / persona / cbd    H3  weak    0.415  0.048  0.040  0.579      0.299
#  87  kd / distillation / teacher / knowledge     H1  noise   0.411  0.038  0.053  0.224      0.291
#  88  learning / visual / navigation / mid-level  H1  noise   0.384  0.042  0.052      —      0.290
#  89  graph / gnn / node / neural network         H1  strong  0.453  0.040  0.038  0.621      0.275
#  90  quantum / qubit / circuit / superconductin  H2  weak    0.450  0.047  0.023  0.583      0.256
#  91  nodule / lung / ct / cancer                 H1  noise   0.310  0.067  0.025  0.309      0.253
#  92  erasure / diffusion / concept / text-to-im  H2  strong  0.484  0.033  0.027  0.613      0.232
#  93  sensing / isac / remote / irrigation        H1  noise   0.271  0.042  0.050  0.481      0.221
#  94  autonomous / sensor / vehicle / driving     H1  latent  0.365  0.036  0.033  0.375      0.151
#  95  reinforcement / learning / agent / rl       H1  latent  0.288  0.045  0.034  0.357      0.143
#  96  quantum / algorithm / variational / gauge   H1  latent  0.182  0.046  0.036  0.507      0.142
#  97  blockchain / contract / smart / copyright   H1  noise   0.292  0.039  0.040  0.514      0.141
#  98  dataset / image / gan / pre-training        H1  noise   0.350  0.041  0.029  0.268      0.141
#  99  watermark / attack / dnn / adversarial      H1  strong  0.353  0.038  0.032  0.238      0.138
# 100  quantum / spin / nv / diamond               H1  noise   0.363  0.035  0.026  0.271      0.114
# 101  point cloud / object / voxel / corresponde  H1  latent  0.288  0.031  0.041  0.446      0.113
# 102  robot / navigation / mobile / autonomous    H1  latent  0.305  0.041  0.024  0.366      0.108

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.063, leverage 0.047).
#
# ACT (34)
#       1  artificial intelligence / patent / examination / inventorshi
#       2  decision making / automated decision / making accountability
#       3  trust / chapter / political / britain
#       4  indigenous / traditional knowledge / cultural / intellectual
#       5  good governance / trust / citizen / public institution
#       6  service delivery / local government / public service / digit
#       7  patent / ai / language / nlp
#       8  copyright / page / economic right / exception limitation
#       9  ai / adm / automated decision-making / accountability
#      10  ipgod / ip right / government open / property government
#      12  access medicine / medicine africa / law access / compulsory
#      13  patent law / artificial intelligence / future patent / intel
#      14  genetic resource / benefit sharing / access benefit / abs
#      15  prior art / patent / art search / retrieval
#      16  automated decision-making / administrative law / decision-ma
#      18  corporate governance / finance corporate / governance ip / a
#      19  african / gis / property organization / oapi
#      21  intellectual property / property right / enforcement intelle
#      22  patent retrieval / integration image / retrieval process / i
#      23  li / ul / nsw / opengov
#      24  service delivery / digital / public service / e-government
#      25  ai / chatgpt / generative / content
#      27  competition law / eu competition / ipr / intellectual proper
#      28  foramen / ovale / closure / carcinoid
#      29  fairness / algorithmic / machine learning / automated decisi
#      31  digital government / digital landscape / nsw / sa
#      33  unregistered / registered design / design protection / chapt
#      34  ip / intellectual / property / right
#      35  ai / patent / invention / law
#      43  auv / reef / underwater / sirius
#      55  trademark / infringement / brand / e-commerce
#      58  autonomous / vehicle / avs / simulation
#      59  indigenous / voice / sovereignty / knowledge
#      70  patent / technology / graphene / sca
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (17)
#      11  trust / institution / public / driver
#      20  geographical indication / gi / trade / product
#      36  trust / institution / public / citizen
#      37  trust / financial / institution / iceland
#      38  trade / agreement / free / eu
#      39  energy / storage / hydrogen / renewable
#      40  elevation / elvis / river / area cover
#      42  park / australian marine / specy / reef
#      45  quantum / error / qubit / code
#      47  crispr / gene / genome / editing
#      60  backdoor / attack / dataset / trigger
#      71  watermark / image / attack / distortion
#      72  additive manufacturing / material / printing / ceramic
#      75  hps / dataset / influence function / document
#      77  influencer / authenticity / celebrity / marketing
#      79  medicinal / nbsp / cultural / plant
#      91  nodule / lung / ct / cancer
#
# CAPABILITY LOOKING FOR A PROBLEM (17)
#      17  additive manufacturing / arc additive / wire / manufacturing
#      26  dashboard / digital project / queensland / contribution publ
#      30  patent / prior art / examiner / invention
#      32  image / patent / retrieval / classification
#      44  valuation / property / intellectual / kenya
#      46  patent / examination / invention / rebuttal
#      52  valuation / briefing / market / valuer
#      57  patent / classification / claim / tc
#      65  bp-net / malaria / quantum / llm
#      69  robot / path / exploration / srm
#      73  odometry / sensor / fusion / vehicle
#      81  navigation / odometry / positioning / inertial
#      82  logo / detection / image / dataset
#      83  ticket / ssl / lane / downstream
#      87  kd / distillation / teacher / knowledge
#      88  learning / visual / navigation / mid-level
#      93  sensing / isac / remote / irrigation
#
# WATCH (34)
#      41  heritage / cultural / intellectual / property
#      48  patent / retrieval / idea generation / query
#      49  patent portfolio / portfolio management
#      50  africa / kilometre km / square kilometre / population
#      51  ketupat / culture / acknowledgment / muslim
#      53  index / stop line / positioning / aided cooperative
#      54  llm / language / braille / reasoning
#      56  quantum / sensing / metrology / estimation
#      61  synthetic biology / engineering / metabolic / microalgae
#      62  chinese / patent / chapter implementation / medicine
#      63  watermarking / text / llm / language
#      64  watermarking / pseudorandom / prc / robustness
#      66  neural / network / classification / deep convolutional
#      67  manipulation / robot / long-horizon / object
#      68  video / vmt / low-light / feature
#      74  driving / autonomous / visual / lidar
#      76  driving / autonomous / imitation / traffic
#      78  image / generative adversarial / font / adversarial network
#      80  aesthetic / reef / nesp / image
#      84  watermarking / mesh / attack / nerf
#      85  watermarking / attack / replay / networked
#      86  unlearning / cross-modal / persona / cbd
#      89  graph / gnn / node / neural network
#      90  quantum / qubit / circuit / superconducting
#      92  erasure / diffusion / concept / text-to-image
#      94  autonomous / sensor / vehicle / driving
#      95  reinforcement / learning / agent / rl
#      96  quantum / algorithm / variational / gauge
#      97  blockchain / contract / smart / copyright detection
#      98  dataset / image / gan / pre-training
#      99  watermark / attack / dnn / adversarial
#     100  quantum / spin / nv / diamond
#     101  point cloud / object / voxel / correspondence
#     102  robot / navigation / mobile / autonomous

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = '2026-08-31-T0006'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  artificial intelligence / patent / examination / inventorship
# 121 documents · 2018–2026 · H2 · strong
#
# Defining terms: artificial intelligence, intelligence, artificial, patent, examination, inventorship, bibliometric examination, infant, intelligence infant, intelligence patent, examination artificial, bibliometric
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     3  ███
#      2019     5  █████
#      2020    11  ███████████
#      2021     5  █████
#      2022     2  ██
#      2023    10  ██████████
#      2024    12  █████████████
#      2025    23  ████████████████████████  ← burst
#      2026    13  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Artificial Intelligence and Inventorship
#     crossref · 2025 · Lecture Notes in Networks and Systems
#     https://doi.org/10.1007/978-981-97-8457-8_4
#   • Review for "Bibliometric Examination of Artificial Intelligence Studies on Infants"
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/icd.70098/v2/review1
#   • Review for "Bibliometric Examination of Artificial Intelligence Studies on Infants"
#     crossref · 2025 · peer-review
#     https://doi.org/10.1002/icd.70098/v2/review2
#   • Patent Analysis of Artificial Intelligence: A Comprehensive Study (2013–2022)
#     crossref · 2024 · Lecture Notes in Networks and Systems
#     https://doi.org/10.1007/978-3-031-70411-6_19
#   • Legal Issues of Artificial Intelligence and Patent
#     crossref · 2018 · Korea Law Review
#     https://doi.org/10.36532/kulri.2018.90.197

# %%
TOPIC_ID = '2026-08-31-T0053'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  decision making / automated decision / making accountability / government
# 38 documents · 2018–2026 · H1 · noise
#
# Defining terms: decision making, decision, making, automated decision, making accountability, automated, accountability, government, financial, vehicle, ai, tool
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ██████
#      2019     2  ████████████
#      2020     2  ████████████
#      2021     4  ████████████████████████
#      2022     1  ██████
#      2023     0
#      2024     1  ██████
#      2025     1  ██████
#      2026     1  ██████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Tools for Decision Making
#     crossref · 2021 · monograph
#     https://doi.org/10.4324/9781003129431
#   • Automated Modeling/Decision Making
#     crossref · 2022 · Encyclopedia of Big Data
#     https://doi.org/10.1007/978-3-319-32010-6_17
#   • Can AI Replace Government for Decision Making
#     crossref · 2021 · Introduction to Algorithmic Government
#     https://doi.org/10.1007/978-981-16-0282-5_4
#   • A data quality approach to the identification of discrimination risk in automated decision makin
#     crossref · 2021 · Government Information Quarterly
#     https://doi.org/10.1016/j.giq.2021.101619
#   • Decision Making and Accountability in the U.S. Space Program: A Perspective
#     crossref · 2019 · Space Policy Alternatives
#     https://doi.org/10.4324/9780429307232-8

# %%
TOPIC_ID = '2026-08-31-T0074'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  trust / chapter / political / britain
# 16 documents · 2024–2024 · H2 · weak
#
# Defining terms: trust, chapter, trust chapter, political, level trust, britain, judgement, problem trust, trust judgement, declined, low trust, citizen
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     0
#      2022     0
#      2023     0
#      2024    10  ████████████████████████  ← burst
#      2025     0
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Is there a problem of trust?
#     crossref · 2024 · Trust
#     https://doi.org/10.1093/oso/9780198896449.003.0005
#   • The problem of trust
#     crossref · 2024 · Trust
#     https://doi.org/10.1093/oso/9780198896449.003.0009
#   • What is trust?
#     crossref · 2024 · Trust
#     https://doi.org/10.1093/oso/9780198896449.003.0002
#   • Why has trust declined?
#     crossref · 2024 · Trust
#     https://doi.org/10.1093/oso/9780198896449.003.0006
#   • Why study trust?
#     crossref · 2024 · Trust
#     https://doi.org/10.1093/oso/9780198896449.003.0001

# %%
TOPIC_ID = '2026-08-31-T0014'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  indigenous / traditional knowledge / cultural / intellectual
# 66 documents · 2018–2026 · H1 · latent
#
# Defining terms: indigenous, traditional knowledge, cultural, traditional, traditional cultural, cultural expression, intellectual, intellectual property, expression, knowledge, property, indigenous people
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  █████
#      2019     5  █████████████
#      2020     9  ████████████████████████
#      2021     4  ███████████
#      2022     6  ████████████████
#      2023     9  ████████████████████████
#      2024     3  ████████
#      2025     8  █████████████████████
#      2026     4  ███████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Intellectual Property Rights, Indigenous Cultural Expression and Traditional Knowledge
#     crossref · 2026 · Encyclopedia of Global Justice
#     https://doi.org/10.1007/978-3-642-27828-0_10071-1
#   • Legal Protection of the Traditional Knowledge and Traditional Cultural Expressions of the Indige
#     crossref · 2019 · Cambridge Handbook of Intellectual Property in Central and Eastern Europe
#     https://doi.org/10.1017/9781316661253.020
#   • Traditional knowledge and intellectual property rights
#     crossref · 2020 · Traditional Knowledge, Genetic Resources, Customary Law and Intellectual Prope
#     https://doi.org/10.4337/9781785368486.00009
#   • Preservation or Protection? The Intellectual Property Debate Surrounding Traditional Cultural Ex
#     crossref · 2025 · posted-content
#     https://doi.org/10.2139/ssrn.5221877
#   • Traditional Cultural Expressions
#     crossref · 2025 · Elgar Encyclopedia of Intellectual Property Law
#     https://doi.org/10.4337/9781800886933.traditional.cultural.expressions

# %%
TOPIC_ID = '2026-08-31-T0066'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  good governance / trust / citizen / public institution
# 17 documents · 2018–2024 · H1 · noise
#
# Defining terms: good governance, governance, trust, citizen trust, good, citizen, public institution, institution, public, trust local, government, local government
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ████████
#      2019     2  ████████████████
#      2020     0
#      2021     1  ████████
#      2022     1  ████████
#      2023     2  ████████████████
#      2024     3  ████████████████████████
#      2025     0
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Citizens' Trust and Good Governance in LGI
#     crossref · 2024 · Good Governance in Bangladesh
#     https://doi.org/10.4324/9781003505853-7
#   • Introduction to Citizens' Trust and Governance
#     crossref · 2024 · Good Governance in Bangladesh
#     https://doi.org/10.4324/9781003505853-1
#   • Nexus Between Citizens’ Trust and Good Governance in Public Institutions of South Asia
#     crossref · 2024 · Indian Journal of Public Administration
#     https://doi.org/10.1177/00195561241248140
#   • Citizens' trust in government as a function of good governance and government agency's provision
#     openalex · 2021 · Government Information Quarterly
#     https://doi.org/10.1016/j.giq.2021.101597
#   • Reaching SDGs Through Public Institutions and Good Governance: Why Trust Matters
#     crossref · 2022 · Reducing Inequalities Towards Sustainable Development Goals
#     https://doi.org/10.1201/9781003339250-5

# %%
TOPIC_ID = '2026-08-31-T0003'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  service delivery / local government / public service / digital
# 164 documents · 2018–2026 · H2 · strong
#
# Defining terms: service delivery, delivery, service, local government, government, local, public service, digital, financial autonomy, state local, government system, imo
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018    10  ████████
#      2019     8  ██████
#      2020     7  █████
#      2021     4  ███
#      2022     7  █████
#      2023    23  ██████████████████  ← burst
#      2024    31  ████████████████████████  ← burst
#      2025    16  ████████████
#      2026    10  ████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Review of: "Financial Autonomy: Panacea for Improved Service Delivery in Imo State Local Governm
#     crossref · 2024 · peer-review
#     https://doi.org/10.32388/c3xj9v
#   • Review of: "Financial Autonomy: Panacea for Improved Service Delivery in Imo State Local Governm
#     crossref · 2023 · peer-review
#     https://doi.org/10.32388/zqy68i
#   • Review of: "Financial Autonomy: Panacea for Improved Service Delivery in Imo State Local Governm
#     crossref · 2024 · peer-review
#     https://doi.org/10.32388/yeglyv
#   • Review of: "Financial Autonomy: Panacea for Improved Service Delivery in Imo State Local Governm
#     crossref · 2024 · peer-review
#     https://doi.org/10.32388/7n7kng
#   • Review of: "Financial Autonomy: Panacea for Improved Service Delivery in Imo State Local Governm
#     crossref · 2024 · peer-review
#     https://doi.org/10.32388/wb9xsm

# %%
TOPIC_ID = '2026-08-31-T0059'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  patent / ai / language / nlp
# 18 documents · 2021–2026 · H1 · weak
#
# Defining terms: patent, ai, ai patent, language, language processing, natural language, nlp, similarity patent, similarity, text, processing, patent dataset
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     0
#      2020     0
#      2021     3  ██████████████████
#      2022     1  ██████
#      2023     4  ████████████████████████
#      2024     1  ██████
#      2025     2  ████████████
#      2026     1  ██████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Identifying Artificial Intelligence (AI) Invention: A Novel AI Patent Dataset
#     crossref · 2021 · posted-content
#     https://doi.org/10.2139/ssrn.3866793
#   • An Empirical Study of Artificial Intelligence Patent Litigation
#     crossref · 2025 · posted-content
#     https://doi.org/10.2139/ssrn.5328093
#   • A Novel Patent Similarity Measurement Methodology: Semantic Distance and Technological Distance
#     arxiv · 2023 · arXiv
#     http://arxiv.org/abs/2303.16767v2
#   • Natural language processing in the patent domain: a survey
#     crossref · 2025 · Artificial Intelligence Review
#     https://doi.org/10.1007/s10462-025-11168-z
#   • Role of Artificial Intelligence in Patent Examination
#     crossref · 2026 · posted-content
#     https://doi.org/10.2139/ssrn.7307806

# %%
TOPIC_ID = '2026-08-31-T0002'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  copyright / page / economic right / exception limitation
# 182 documents · 2018–2026 · H2 · strong
#
# Defining terms: copyright, copyright page, page, economic right, exception limitation, copyright law, uk, act cdpa, cdpa, right, copyright owner, act
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     2  █
#      2019     5  ███
#      2020    11  ███████
#      2021    12  ████████
#      2022    15  ██████████
#      2023    22  ██████████████
#      2024    23  ███████████████
#      2025    31  ████████████████████  ← burst
#      2026    37  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Copyright
#     crossref · 2026 · Emotional Artificial Intelligence
#     https://doi.org/10.1016/b978-0-443-44744-0.09991-4
#   • Copyright
#     crossref · 2026 · Artificial Intelligence
#     https://doi.org/10.1016/b978-0-44-324840-5.00003-2
#   • Copyright
#     crossref · 2022 · Human-Centered Artificial Intelligence
#     https://doi.org/10.1016/b978-0-323-85648-5.12001-8
#   • Copyright
#     crossref · 2025 · Edge Artificial Intelligence
#     https://doi.org/10.1016/b978-0-443-26720-8.12001-8
#   • Copyright
#     crossref · 2024 · Artificial Intelligence in Manufacturing
#     https://doi.org/10.1016/b978-0-323-99134-6.50003-6

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
