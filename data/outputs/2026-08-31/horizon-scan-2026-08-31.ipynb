# %% [markdown]
# # IPAVentures horizon scan — run `2026-08-31`
#
# Generated 2026-08-31 03:25 UTC by `python -m src.notebook --run-id 2026-08-31`.
#
# This notebook is the audit trail for one horizon-scanning run. It reads a
# frozen corpus out of DuckDB and walks the pipeline stage by stage: what went
# in, what each stage did to it, and what came out. Every code cell is runnable
# against the same database, and the outputs shown were produced by running them.
#
# **What this notebook establishes, and what it does not.**
#
# It establishes that the published shortlist follows *deterministically* from
# this corpus and these weights. Four numbers — the emergence score, the Three
# Horizons band, the opportunity index and the composite rank — are recomputed
# from their stored inputs and checked against what the pipeline stored, so the
# arithmetic is not something you have to take on trust.
#
# It establishes nothing whatsoever about whether the weights are *right*. No
# weight in this pipeline has been validated against a known past opportunity.
# The ranking is a hypothesis about ranking, and the useful argument to have over
# this document is about the corpus and the weights, not about the arithmetic.
#
# Three caveats that survive every number below:
#
# 1. **The opportunity index is not a market size.** It is a relative, unitless,
#    within-run ordering and cannot be converted into a dollar figure.
# 2. **Scores are relative to this run's population.** Emergence and composite
#    scores are percentile-ranked within the run; they are not comparable to
#    another run's unless the corpus and config snapshot match.
# 3. **The scan cannot find what the scan frame does not ask for.** A topic's
#    absence from this document is not evidence of its absence from the world.
#
# **Reproducing this.** Open the notebook from inside a checkout of the
# repository with `data/bigthink.duckdb` present, and run all cells. Stage 1 is
# deliberately not re-executed — collectors hit live rate-limited APIs, so
# re-running collection would produce a different corpus and quietly invalidate
# every comparison below.

# %% [markdown]
# ## Setup
#
# Open the corpus read-only and locate the repository.

# %%
import json
import sys
from pathlib import Path

import duckdb
import numpy as np

# Find the repository, so this notebook runs from wherever it has been opened.
REPO_ROOT = Path.cwd().resolve()
while not (REPO_ROOT / "bigthink_config.yaml").exists() and REPO_ROOT != REPO_ROOT.parent:
    REPO_ROOT = REPO_ROOT.parent
if not (REPO_ROOT / "bigthink_config.yaml").exists():
    raise SystemExit(
        "Could not locate the BigThink repository from the current directory. "
        "Open this notebook from inside a checkout of the repo."
    )
sys.path.insert(0, str(REPO_ROOT))

from src import db
from src.notebook import diff_config, table, verify_close, verify_identical

RUN_ID = '2026-08-31'
DB_PATH = REPO_ROOT / 'data/bigthink.duckdb'

# Read-only, deliberately. This notebook exists to explain a run; it must not
# be able to alter the corpus that run was computed from.
conn = duckdb.connect(str(DB_PATH), read_only=True)

print(f"run_id    {RUN_ID}")
print(f"database  {DB_PATH}")
print(f"documents {conn.execute('SELECT count(*) FROM documents').fetchone()[0]:,}")
# Out:
# run_id    2026-08-31
# database  /home/runner/work/BigThink/BigThink/data/bigthink.duckdb
# documents 15,036

# %% [markdown]
# ## Provenance — what produced these numbers
#
# Every stage writes a row to `pipeline_runs` carrying a full snapshot of the
# config it ran under. That snapshot, not the file currently on disk, is what
# this notebook verifies against: a threshold edited after the run must not be
# able to change what "reproduced" means retrospectively.

# %%
# The weights checked throughout this notebook come from the run itself, not
# from today's bigthink_config.yaml. Editing a threshold after a run must not
# quietly change what "reproduced" means.
snapshot = conn.execute(
    """
    SELECT stage, config_snapshot FROM pipeline_runs
    WHERE run_id = ? AND config_snapshot IS NOT NULL AND config_snapshot <> ''
    ORDER BY id DESC LIMIT 1
    """,
    [RUN_ID],
).fetchone()
if not snapshot:
    raise SystemExit(f"No config snapshot recorded for run_id={RUN_ID!r}.")

CONFIG = json.loads(snapshot[1])
ROTOLO_WEIGHTS = CONFIG["emergence"]["rotolo_weights"]
RANK_WEIGHTS = CONFIG["synthesis"]["rank_weights"]

print(f"Config recovered from the {snapshot[0]!r} stage log.\n")
print("Embedding backend :", CONFIG["embeddings"]["backend"])
_topics_cfg = CONFIG["emergence"]["topics"]
_backend = CONFIG["embeddings"]["backend"]
_method = _topics_cfg.get("method", "agglomerative")
# Runs before 2026-08-30 stored one threshold map keyed by backend alone, when
# there was only one numpy method. Read either shape, so an old notebook still
# reports the number its own run actually used.
_thresh = (_topics_cfg.get("similarity_thresholds", {}).get(_method)
           or _topics_cfg.get("similarity_threshold_by_backend", {}))
print("Clustering method :", _method)
print("Clustering thresh :", _thresh.get(_backend, "not recorded"))
print("Time slice        :", CONFIG["emergence"]["time_slice"])
print("Collection window :",
      CONFIG["collection"]["start_year"], "-", CONFIG["collection"]["end_year"])
print()
print("Rotolo weights (emergence):",
      ", ".join(f"{k} {v}" for k, v in sorted(ROTOLO_WEIGHTS.items())))
print("Rank weights   (shortlist):",
      ", ".join(f"{k} {v}" for k, v in sorted(RANK_WEIGHTS.items())))
# Out:
# Config recovered from the 'stage4_opportunity_index' stage log.
#
# Embedding backend : hashing
# Clustering method : agglomerative
# Clustering thresh : 0.14
# Time slice        : year
# Collection window : 2018 - 2026
#
# Rotolo weights (emergence): coherence 0.15, growth 0.3, impact 0.2, novelty 0.25, uncertainty 0.1
# Rank weights   (shortlist): asset_leverage 0.25, emergence 0.4, strategic_fit 0.35

# %% [markdown]
# ### Stage execution log
#
# What ran, over how much, and how it ended.

# %%
print(table(
    conn.execute(
        """
        SELECT stage, status, records_in, records_out,
               round(date_diff('millisecond', started_at, finished_at) / 1000.0, 1) AS seconds,
               message
        FROM pipeline_runs WHERE run_id = ? ORDER BY id
        """,
        [RUN_ID],
    ).fetchall(),
    ["stage", "status", "in", "out", "seconds", "message"],
    max_width=64,
))
# Out:
# stage                     status      in    out   seconds  message
# ------------------------  -------  -----  -----  --------  ----------------------------------------------------------------
# stage0_strategy           success      —     34     0.100  34 refs (9 objectives, 6 initiatives, 7 critical-tech fields, 1…
# stage1_collect            partial  15468  15036  9764.500  15468 fetched, 15036 new, 7 failed/skipped pairs, 9 partial in …
# stage2_emergence          success  15036    120    44.000  120 topics from 15036 documents across 9 slices (2018-2026); 60…
# stage5_synthesis          success    120    120     3.000  ranked 120 topics; outputs written
# stage3_scoring            success    120    120     2.000  scored 120 topics; mean fit 0.102, mean leverage 0.054, 10 crit…
# stage4_opportunity_index  success    120    120     0.500  indexed 120 of 120 topics (0 suppressed as too thin)

# %% [markdown]
# ### Has the repository moved since this run?
#
# If any value below differs, the code you are reading is not quite the code that produced these scores.

# %%
from src.config import load_config, snapshot_config

# Has the repository moved since this run? Comparing scores across configs is
# the mistake this method is most exposed to, so the notebook checks rather
# than assuming.
current = json.loads(snapshot_config(load_config()))
differences = diff_config(CONFIG, current)
if not differences:
    print("The config on disk is identical to the one that produced this run.")
else:
    print(f"{len(differences)} config value(s) have changed since this run.")
    print("Scores below were computed under the STORED values, not these.\n")
    print(table(
        [(p, w, n) for p, w, n in differences[:30]],
        ["setting", "at run time", "on disk now"],
        max_width=44,
    ))
# Out:
# The config on disk is identical to the one that produced this run.

# %% [markdown]
# ## Stage 0 — Strategy encoding
#
# The published strategy is turned into a reference set: corporate-plan
# objectives and initiatives, DISR critical-technology fields, and an inventory
# of what IP Australia would bring to an opportunity. Each reference carries a
# text body (embedded into a vector) and a lexicon of terms.
#
# This is the yardstick every strategic-fit and asset-leverage score is measured
# against, which makes it the most consequential reviewable artefact in the repo
# after the scan frame. The files are `data/strategy/*.yaml` and they are meant
# to be critiqued without reading any Python.

# %%
print(table(
    conn.execute(
        """
        SELECT ref_type, count(*) AS refs, round(avg(weight), 2) AS avg_weight
        FROM strategy_refs GROUP BY ref_type ORDER BY ref_type
        """
    ).fetchall(),
    ["reference type", "count", "avg weight"],
))
print()
print("Every strategic-fit score below is a similarity against one of these.")
print("A topic the strategy does not describe cannot score highly on fit, however")
print("important it is — that is a property of the instrument, not a finding.\n")
print(table(
    conn.execute(
        "SELECT ref_type, code, label FROM strategy_refs ORDER BY ref_type, code, ref_id"
    ).fetchall(),
    ["type", "code", "label"],
    max_width=58,
))
# Out:
# reference type  count  avg weight
# --------------  -----  ----------
# asset              12       0.920
# critical_tech       7       1.000
# initiative          6       1.000
# objective           9       1.020
#
# Every strategic-fit score below is a similarity against one of these.
# A topic the strategy does not describe cannot score highly on fit, however
# important it is — that is a property of the instrument, not a finding.
#
# type           code             label
# -------------  ---------------  ----------------------------------------------------------
# asset          AS-CONVENING     Convening power and international IP standing
# asset          AS-DATAPIPE      Zero-budget analytical pipeline pattern
# asset          AS-EXAMINATION   Examination workforce and AI/ADM trials
# asset          AS-FIRSTNATIONS  First Nations Strategy partnerships
# asset          AS-IPFR          IP First Response
# asset          AS-IPGOD         IPGOD / IPLoRD longitudinal registry data
# asset          AS-OCTAVIUS      Octavius — rule extraction and code generation
# asset          AS-PATANALYTICS  Patent Analytics Hub and Office of the Chief Economist
# asset          AS-RAPID         IP RAPID / IP Rights Overview dashboard
# asset          AS-TMCHECKER     TM Checker
# asset          AS-TRIPWIRE      Tripwire — autonomous source-monitoring pipeline
# asset          AS-WISEAU        Wiseau — document parsing and extraction
# critical_tech  CT-AI            Artificial intelligence
# critical_tech  CT-AMM           Advanced manufacturing and materials
# critical_tech  CT-AUTON         Autonomous systems, robotics, positioning, timing and sen…
# critical_tech  CT-BIO           Biotechnologies
# critical_tech  CT-ENERGY        Clean energy generation and storage
# critical_tech  CT-ICT           Advanced information and communication technologies
# critical_tech  CT-QUANTUM       Quantum technologies
# initiative     SI-1             Geographical indications registration under the A-EU FTA
# initiative     SI-2             Regulatory reform supporting the productivity agenda
# initiative     SI-3             AI and Automated Decision Making in IP administration
# initiative     SI-4             SME education and outreach, including the IP First Respon…
# initiative     SI-5             First Nations Strategy
# initiative     SI-6             Capability Framework and innovative learning mindset
# objective      1.1              Trust and confidence in a high-quality IP rights system
# objective      1.2              Awareness of the IP system
# objective      1.3              Reputation, influence and contribution to the IP ecosystem
# objective      2.1              Access to and benefits from IP rights ownership
# objective      2.2              Customer experience excellence in IP rights services
# objective      3.1              Capabilities for current and future needs of the IP system
# objective      3.2              Customer-centric, empowered, inclusive and risk-engaging …
# objective      4.1              Innovation and adaptiveness in stewardship of the IP righ…
# objective      4.2              Innovative digital and data-driven customer and staff ser…

# %% [markdown]
# ## Stage 1 — Signal collection
#
# Seed queries from `data/strategy/scan_frame.yaml` are issued against each
# enabled source; results are normalised, STEEPV-tagged, deduplicated on a stable
# `native_id`, and written to DuckDB.
#
# **This stage is not reproducible and is not re-run here.** The collectors call
# live APIs under rate limits and daily budgets; a source that was healthy during
# the run may be retired or metered now. What follows describes the corpus that
# exists, from the collection log the run wrote at the time.
#
# Read this section as the answer to "what could this scan possibly have found?",
# because everything downstream is conditioned on it.

# %%
# NOTE the difference between these two tables. The corpus ACCUMULATES across
# runs — each run adds to it and growth curves lengthen instead of resetting —
# so the first table is the whole corpus the topics were formed from. The
# second is only what THIS run fetched. They are not meant to reconcile.
print("The corpus these topics were formed from, by source:\n")
print(table(
    conn.execute(
        """
        SELECT source, count(*) AS documents, min(year) AS first_year,
               max(year) AS last_year, count(DISTINCT scan_frame_key) AS frames
        FROM documents GROUP BY source ORDER BY documents DESC
        """
    ).fetchall(),
    ["source", "documents", "first year", "last year", "frames"],
))
print()
print("What this run's collection actually did (per source query):\n")
print(table(
    conn.execute(
        """
        SELECT source, status, count(*) AS queries, sum(records) AS records
        FROM collection_log WHERE run_id = ?
        GROUP BY source, status ORDER BY source, status
        """,
        [RUN_ID],
    ).fetchall(),
    ["source", "status", "queries", "records"],
))
# Out:
# The corpus these topics were formed from, by source:
#
# source     documents  first year  last year  frames
# ---------  ---------  ----------  ---------  ------
# gdelt           8054        2024       2026      17
# openalex        3799        2018       2026      20
# crossref        2357        2018       2026      13
# arxiv            678        2018       2026       3
# datagovau        148        2022       2026       3
#
# What this run's collection actually did (per source query):
#
# source     status   queries  records
# ---------  -------  -------  -------
# arxiv      failed         6        0
# arxiv      success        3      679
# crossref   success       13     2498
# datagovau  success        3      150
# gdelt      failed         1        0
# gdelt      partial        9     4079
# gdelt      success        8     4120
# openalex   success       20     3942

# %%
print("Documents per year — the history the growth curves are fitted to:\n")
print(table(
    conn.execute(
        "SELECT year, count(*) FROM documents WHERE year IS NOT NULL "
        "GROUP BY year ORDER BY year"
    ).fetchall(),
    ["year", "documents"],
))
print()
print("STEEPV coverage. The scan frame decides this distribution, and it")
print("mirrors where free structured data exists rather than where")
print("opportunities are:\n")
print(table(
    conn.execute(
        "SELECT steepv, count(*) FROM documents GROUP BY steepv ORDER BY 2 DESC"
    ).fetchall(),
    ["STEEPV", "documents"],
))
# Out:
# Documents per year — the history the growth curves are fitted to:
#
# year  documents
# ----  ---------
# 2018        784
# 2019        852
# 2020       1018
# 2021        905
# 2022        796
# 2023        843
# 2024       1495
# 2025       4596
# 2026       3747
#
# STEEPV coverage. The scan frame decides this distribution, and it
# mirrors where free structured data exists rather than where
# opportunities are:
#
# STEEPV         documents
# -------------  ---------
# Technological       6084
# Political           2763
# Economic            1910
# Legal               1759
# Values              1038
# Social               840
# Environmental        642

# %% [markdown]
# ### What each seed query actually returned
#
# `scan_frame.yaml` is the biggest single determinant of the output — the scan cannot find what the frame does not ask for. A frame that returned almost nothing is a blind spot in this run's evidence, and no amount of re-weighting downstream can compensate for it.

# %%
# The scan frame is the single biggest determinant of what this scan could
# possibly have found, so it is worth seeing which seed queries actually
# yielded a corpus and which returned almost nothing. A frame near the bottom
# of this table is a blind spot, whatever the shortlist says.
print(table(
    conn.execute(
        """
        SELECT scan_frame_key, any_value(steepv) AS steepv, count(*) AS documents,
               count(DISTINCT source) AS sources
        FROM documents WHERE scan_frame_key IS NOT NULL
        GROUP BY scan_frame_key ORDER BY documents DESC
        """
    ).fetchall(),
    ["scan frame", "STEEPV", "documents", "sources"],
    max_width=40,
))
# Out:
# scan frame                   STEEPV         documents  sources
# ---------------------------  -------------  ---------  -------
# ai_governance_assurance      Political           1210        4
# digital_identity_provenance  Technological       1099        2
# gov_service_delivery         Political           1066        4
# ct_biotech                   Technological       1058        3
# indigenous_knowledge         Values              1038        3
# ct_quantum                   Technological       1023        2
# ai_authorship_inventorship   Legal                972        4
# ip_finance_valuation         Economic             844        3
# trust_institutions           Social               840        3
# geographical_indications     Legal                787        3
# ip_admin_automation          Technological        731        4
# ct_energy                    Environmental        642        2
# ip_enforcement_counterfeit   Economic             619        3
# ct_advanced_manufacturing    Technological        617        2
# ip_search_retrieval          Technological        611        3
# ip_policy_reform             Political            487        4
# ct_ai                        Technological        474        2
# ip_sme_access                Economic             447        3
# ct_autonomous                Technological        349        1
# ct_advanced_ict              Technological        122        1

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Failed queries by source: arxiv (6), gdelt (1). Each failure costs that frame's contribution to the corpus, so the shortlist is drawn from a slightly different scan than the frame file describes.

# %% [markdown]
# ## Stage 2 — Emergence detection
#
# Documents are embedded, clustered into topics, sliced into a time series, and
# scored on the five attributes of emergence from Rotolo, Hicks & Martin (2015):
#
# | Attribute | Indicator |
# |---|---|
# | novelty | mean embedding distance from the earlier corpus centroid |
# | growth | slice-over-slice CAGR blended with Kleinberg burst intensity |
# | coherence | intra-topic cosine density |
# | impact | citation percentile, computed *within* source |
# | uncertainty | normalised entropy over institutions and source types |
#
# Two choices here shape everything after them, and both are deliberate:
#
# - **Impact percentiles are computed within source.** arXiv reports no
#   citations. Ranked globally, every preprint would sit at the bottom and the
#   fastest-moving evidence in the corpus would be systematically penalised.
# - **A logistic curve is fitted directly rather than by linearising the
#   logit.** Linearisation reports an early-exponential topic as *saturated*,
#   which inverts the Three Horizons band for precisely the technologies a
#   horizon scan exists to find.

# %%
topics = db.fetch_topics(conn, RUN_ID)   # emergence_score DESC — Stage 5 read them in this order

print(table(
    [
        (t["topic_id"], (t["label"] or "")[:44], t["document_count"],
         t["novelty"], t["growth"], t["coherence"], t["impact"], t["uncertainty"],
         t["emergence_score"], t["horizon"], t["signal_class"])
        for t in topics
    ],
    ["topic", "label", "docs", "nov", "grw", "coh", "imp", "unc",
     "emergence", "H", "signal"],
    places=2,
))
# Out:
# topic  label                                         docs   nov   grw   coh   imp   unc  emergence  H   signal
# -----  --------------------------------------------  ----  ----  ----  ----  ----  ----  ---------  --  ------
# T0003  copyright / page / exception limitation / ec   292  0.92  0.37  0.55  0.61  0.83       0.93  H2  strong
# T0059  examination / artificial / intelligence / ec    27  0.79  0.20  0.39  0.67  0.88       0.90  H2  strong
# T0008  geographical indication / protection geograp   182  0.76  0.21  0.36  0.58  0.90       0.88  H2  strong
# T0015  artificial intelligence / patent / inventors   208  0.74  0.18  0.32  0.59  0.83       0.82  H1  strong
# T0044  dashboard / digital project / queensland / c    70  0.80  0.43  0.38  0.50  0.82       0.78  H2  strong
# T0025  kilometre km / square kilometre / africa / p   124  0.53  0.20  0.27  0.58  0.98       0.78  H2  strong
# T0022  heritage / cultural / property / intellectua   187  0.76  0.21  0.28  0.56  0.79       0.77  H1  strong
# T0019  prior art / patent / art search / retrieval    159  0.73  0.14  0.29  0.59  0.79       0.76  H2  strong
# T0000  intellectual property / property right / enf   472  0.66  0.09  0.45  0.66  0.73       0.75  H1  strong
# T0074  generative / ai / artificial intelligence /     70  0.72  0.20  0.29  0.55  0.79       0.74  H1  weak
# T0011  service delivery / government / local / publ   214  0.59  0.12  0.27  0.61  0.83       0.73  H2  strong
# T0055  li / ul / nsw / opengov                         53  0.74  0.40  0.35  0.50  0.73       0.72  H2  strong
# T0013  llm / language / large / reasoning             118  0.28  0.39  0.33  0.60  0.88       0.72  H1  strong
# T0010  energy storage / battery / renewable / stora   188  0.66  0.03  0.31  0.53  0.99       0.70  H1  strong
# T0005  trust / public institution / oecd / driver     197  0.73  0.00  0.33  0.63  0.90       0.70  H2  strong
# T0039  adm / automated / decision-making / eu          49  0.29  0.28  0.30  0.58  0.95       0.69  H2  strong
# T0088  elevation / elvis / river / area cover          45  0.77  0.29  0.33  0.50  0.42       0.69  H2  strong
# T0031  valuation / property / intellectual / kenya    119  0.80  0.00  0.32  0.57  0.90       0.68  H1  strong
# T0087  large language / emergent ability / ability     70  0.81  0.16  0.23  0.54  0.71       0.68  H1  weak
# T0021  crispr / cas9 / editing / gene                  98  0.32  0.08  0.32  0.59  0.98       0.67  H1  strong
# T0047  australian marine / park / reef / access fol    61  0.57  0.43  0.32  0.50  0.48       0.66  H2  strong
# T0075  accountability / broadening intelligence / h    46  0.85  0.00  0.30  0.55  0.86       0.66  H3  weak
# T0085  trust / chapter / political / crisis            41  0.49  0.15  0.24  0.55  0.84       0.65  H1  weak
# T0095  patent / claim / novelty / prior art            24  0.44  0.19  0.30  0.52  0.83       0.64  H2  weak
# T0051  robot / agricultural / row / phenotyping        72  0.30  0.00  0.21  0.49  0.93       0.29  H1  strong
# T0092  logo / detection / object / voxel               54  0.37  0.00  0.19  0.51  0.78       0.28  H1  weak
# T0017  quantum / cryptography / computing / cryptog   428  0.29  0.00  0.24  0.48  0.81       0.26  H1  strong
# T0036  sme / intellectual / property / innovation      89  0.27  0.00  0.23  0.42  0.89       0.24  H1  strong
# T0069  organic / certification / farmer / green pro    62  0.38  0.00  0.20  0.43  0.78       0.24  H1  weak
# T0107  counterfeiting / counterfeit good / consumer    81  0.40  0.00  0.18  0.46  0.66       0.23  H1  weak
# T0073  medicinal plant / dayak / traditional / know    87  0.31  0.00  0.19  0.46  0.82       0.22  H1  weak
# T0043  patent / classification / document / tc        108  0.28  0.00  0.20  0.47  0.82       0.20  H1  strong

# %% [markdown]
# ### Re-deriving the emergence score
#
# The score above is not an opaque model output. It is a weighted sum of five
# percentile-ranked attributes, and the cell below recomputes it from the stored
# attributes and the stored weights.

# %%
from src.normalise import percentile_rank
from src.stage2_emergence import assign_horizon

ATTRS = ("novelty", "growth", "coherence", "impact", "uncertainty")

# emergence_score is a weighted sum of the five attributes AFTER each has been
# percentile-ranked within this run's population. Rank-normalising is what
# makes the configured weights mean what they say: a weighted sum of raw values
# is dominated by whichever attribute happens to have the widest spread.
#
# The consequence, stated plainly: the score is RELATIVE TO THIS RUN. A run of
# uniformly dull topics still produces one scoring near 1.0.
ranked = {a: percentile_rank([float(t[a]) for t in topics]) for a in ATTRS}
recomputed = [
    sum(ranked[a][i] * float(ROTOLO_WEIGHTS[a]) for a in ATTRS)
    for i in range(len(topics))
]
verify_close("emergence_score", [t["emergence_score"] for t in topics], recomputed)

# The Three Horizons band is a pure function of the fitted logistic maturity
# and two cut-points from the config. Nothing about a topic's age enters it.
verify_identical(
    "Three Horizons band",
    [t["horizon"] for t in topics],
    [assign_horizon(float(t["maturity"]), CONFIG) for t in topics],
)
# Out:
# PASS  emergence_score reproduced for 120 topics — largest deviation 0 (tolerance 1e-09)
# PASS  Three Horizons band reproduced — 120 of 120 entries identical

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - 12,155 of 15,036 documents (81%) are attached to any topic. The remainder did not cluster tightly enough to be assigned and are absent from every score below.
# >
# > - 6 topic(s) sit within 0.05 of a Three Horizons cut-point (intellectual / copyright / artificial cr (0.33 → H3); adm / automated / decision-making / eu (0.36 → H2); patent / examination / claim clarity / c (0.37 → H2); examination / artificial / intelligence  (0.71 → H2); artificial intelligence / patent / inven (0.77 → H1); patent retrieval / information retrieval (0.77 → H1)). Their band is an artefact of where the cut falls, not a finding about them; do not present these as confidently H1/H2/H3.

# %% [markdown]
# ## Stage 3 — Strategic fit and asset leverage
#
# Two scores per topic, each blending an embedding similarity with a lexical
# overlap term so that a topic naming an objective explicitly is not penalised by
# embedding drift.
#
# - **Strategic fit** — closeness to the Stage 0 objectives and initiatives.
#   Answers "is this on strategy?"
# - **Asset leverage** — closeness to IP Australia's own data, capability and
#   relationship inventory. Answers "could we credibly act on it?", which is the
#   question that separates an interesting trend from a viable venture.
#
# Watch the *spread* of each axis below, not just the values. Both are
# rank-normalised before they enter the ranking, so a compressed axis still
# contributes its full configured share of the ordering while carrying much less
# real information than that share implies.

# %%
ranked_topics = db.fetch_ranked_topics(conn, RUN_ID)

print(table(
    [
        (r["topic_id"], (r["label"] or "")[:38], r["strategic_fit"],
         r["best_objective"] or "—", r["asset_leverage"],
         r["critical_tech"] or "—")
        for r in ranked_topics
    ],
    ["topic", "label", "fit", "closest objective", "leverage", "DISR field"],
    max_width=36,
))
print()
fits = [float(r["strategic_fit"] or 0.0) for r in ranked_topics]
levs = [float(r["asset_leverage"] or 0.0) for r in ranked_topics]
print(f"strategic fit  range {min(fits):.3f}–{max(fits):.3f}  median {np.median(fits):.3f}")
print(f"asset leverage range {min(levs):.3f}–{max(levs):.3f}  median {np.median(levs):.3f}")
# Out:
# topic  label                                   fit  closest objective                     leverage  DISR field
# -----  ------------------------------------  -----  ------------------------------------  --------  ------------------------------------
# T0008  geographical indication / protectio…  0.312  SI-1 Geographical indications regis…     0.062  —
# T0015  artificial intelligence / patent / …  0.146  4.2 Innovative digital and data-dri…     0.070  —
# T0059  examination / artificial / intellig…  0.110  SI-3 AI and Automated Decision Maki…     0.179  —
# T0039  adm / automated / decision-making /…  0.187  SI-3 AI and Automated Decision Maki…     0.065  —
# T0005  trust / public institution / oecd /…  0.178  1.1 Trust and confidence in a high-…     0.060  —
# T0060  decision making / automated decisio…  0.338  SI-3 AI and Automated Decision Maki…     0.165  —
# T0011  service delivery / government / loc…  0.142  4.2 Innovative digital and data-dri…     0.054  —
# T0063  genetic resource / benefit sharing …  0.129  2.1 Access to and benefits from IP …     0.077  —
# T0085  trust / chapter / political / crisis  0.215  1.1 Trust and confidence in a high-…     0.049  —
# T0087  large language / emergent ability /…  0.151  SI-3 AI and Automated Decision Maki…     0.050  —
# T0019  prior art / patent / art search / r…  0.070  4.1 Innovation and adaptiveness in …     0.092  —
# T0003  copyright / page / exception limita…  0.062  2.1 Access to and benefits from IP …     0.086  —
# T0000  intellectual property / property ri…  0.087  SI-3 AI and Automated Decision Maki…     0.056  —
# T0014  digital / service delivery / public…  0.240  4.2 Innovative digital and data-dri…     0.068  —
# T0013  llm / language / large / reasoning    0.094  SI-3 AI and Automated Decision Maki…     0.054  —
# T0070  ipgod / ip right / government open …  0.137  4.1 Innovation and adaptiveness in …     0.239  —
# T0100  criminal / ip / enforcement / remedy  0.092  4.1 Innovation and adaptiveness in …     0.074  —
# T0074  generative / ai / artificial intell…  0.269  4.2 Innovative digital and data-dri…     0.024  CT-AI Artificial intelligence
# T0010  energy storage / battery / renewabl…  0.140  4.1 Innovation and adaptiveness in …     0.042  CT-ENERGY Clean energy generation a…
# T0004  intellectual property / ipr / right…  0.140  2.1 Access to and benefits from IP …     0.065  —
# T0029  automated decision-making / adminis…  0.107  SI-3 AI and Automated Decision Maki…     0.054  —
# T0095  patent / claim / novelty / prior art  0.063  4.1 Innovation and adaptiveness in …     0.096  —
# T0044  dashboard / digital project / queen…  0.062  1.3 Reputation, influence and contr…     0.059  —
# T0050  access medicine / medicine africa /…  0.227  2.1 Access to and benefits from IP …     0.040  —
# T0045  patent retrieval / information retr…  0.088  4.1 Innovation and adaptiveness in …     0.066  —
# T0027  trust / institution / political / p…  0.177  1.1 Trust and confidence in a high-…     0.061  —
# T0079  ai / clinical / intervention / repo…  0.086  SI-3 AI and Automated Decision Maki…     0.061  —
# T0077  trade mark / geographical indicatio…  0.157  SI-1 Geographical indications regis…     0.085  —
# T0106  corporate governance / finance corp…  0.092  2.2 Customer experience excellence …     0.064  —
# T0081  digital government / nsw / sa / dig…  0.099  4.2 Innovative digital and data-dri…     0.054  —
# T0090  trust science / trust scientist / o…  0.187  1.1 Trust and confidence in a high-…     0.076  —
# T0007  indigenous / traditional knowledge …  0.168  SI-5 First Nations Strategy              0.161  —
# T0016  ai / education / generative / chatg…  0.096  4.2 Innovative digital and data-dri…     0.047  —
# T0055  li / ul / nsw / opengov               0.060  4.2 Innovative digital and data-dri…     0.052  —
# T0057  quantum / photonic / dot / silicon    0.106  SI-5 First Nations Strategy              0.063  —
# T0104  quantum / many-body system / optica…  0.111  4.1 Innovation and adaptiveness in …     0.038  —
# T0067  quantum / machine learning / advers…  0.278  4.2 Innovative digital and data-dri…     0.029  CT-AI Artificial intelligence
# T0076  trust / financial / institution / i…  0.119  1.1 Trust and confidence in a high-…     0.049  —
# T0117  intellectual / copyright / artifici…  0.069  1.3 Reputation, influence and contr…     0.050  —
# T0023  synthetic biology / biological / ce…  0.174  SI-3 AI and Automated Decision Maki…     0.035  CT-BIO Biotechnologies
# T0022  heritage / cultural / property / in…  0.045  SI-1 Geographical indications regis…     0.050  —
# T0034  trade / agreement / afcfta / free     0.171  1.3 Reputation, influence and contr…     0.039  —
# T0018  ai / governance / public / artifici…  0.175  SI-3 AI and Automated Decision Maki…     0.055  —
# T0075  accountability / broadening intelli…  0.068  1.3 Reputation, influence and contr…     0.038  —
# T0102  patent / examination / claim clarit…  0.033  SI-3 AI and Automated Decision Maki…     0.195  —
# T0002  energy / storage / hydrogen / batte…  0.149  4.1 Innovation and adaptiveness in …     0.037  CT-ENERGY Clean energy generation a…
# T0053  quantum / key distribution / qkd / …  0.081  4.1 Innovation and adaptiveness in …     0.040  —
# T0088  elevation / elvis / river / area co…  0.082  4.2 Innovative digital and data-dri…     0.026  —
# T0025  kilometre km / square kilometre / a…  0.043  4.2 Innovative digital and data-dri…     0.046  —
# T0038  ai / patent / invention / inventor    0.086  SI-3 AI and Automated Decision Maki…     0.076  —
# T0052  xai / intelligence / explainable / …  0.221  SI-3 AI and Automated Decision Maki…     0.045  CT-AI Artificial intelligence
# T0099  e-government / trust / public / kor…  0.138  1.1 Trust and confidence in a high-…     0.051  —
# T0031  valuation / property / intellectual…  0.040  2.1 Access to and benefits from IP …     0.052  —
# T0047  australian marine / park / reef / a…  0.067  4.2 Innovative digital and data-dri…     0.029  —
# T0032  valuation / briefing / valuer / pro…  0.063  1.3 Reputation, influence and contr…     0.049  —
# T0037  patent / retrieval / search / embed…  0.047  SI-1 Geographical indications regis…     0.054  —
# T0083  quantum / floquet / physic / gauge …  0.064  4.2 Innovative digital and data-dri…     0.033  —
# T0020  covid-19 / trust / vaccine / health   0.093  1.1 Trust and confidence in a high-…     0.041  —
# T0086  ai / copyright / generative / chatg…  0.111  4.2 Innovative digital and data-dri…     0.033  —
# T0056  ip / law / intellectual property / …  0.106  4.1 Innovation and adaptiveness in …     0.067  —
# T0080  additive manufacturing / arc additi…  0.139  SI-5 First Nations Strategy              0.033  CT-AMM Advanced manufacturing and m…
# T0091  regulatory policy / regulatory refo…  0.138  SI-2 Regulatory reform supporting t…     0.038  —
# T0094  patent / sdg / value / innovation     0.098  4.1 Innovation and adaptiveness in …     0.075  —
# T0036  sme / intellectual / property / inn…  0.234  SI-4 SME education and outreach, in…     0.046  —
# T0118  genome editing / chapter argue / af…  0.120  2.1 Access to and benefits from IP …     0.035  —
# T0065  isac / communication / wireless / n…  0.050  3.1 Capabilities for current and fu…     0.055  —
# T0033  quantum / qubit / circuit / gate      0.147  3.1 Capabilities for current and fu…     0.045  CT-QUANTUM Quantum technologies
# T0054  green innovation / firm / enterpris…  0.123  4.2 Innovative digital and data-dri…     0.043  —
# T0119  cancer / tumor / t-cell / mutant      0.060  2.1 Access to and benefits from IP …     0.056  —
# T0009  additive manufacturing / material /…  0.140  SI-4 SME education and outreach, in…     0.029  CT-AMM Advanced manufacturing and m…
# T0006  gi / geographical indication / prod…  0.328  SI-1 Geographical indications regis…     0.031  —
# T0110  chinese / chapter implementation / …  0.063  SI-5 First Nations Strategy              0.056  —
# T0112  chatgpt / clinical / medical / lang…  0.075  4.1 Innovation and adaptiveness in …     0.030  —
# T0108  patent portfolio / portfolio manage…  0.040  4.1 Innovation and adaptiveness in …     0.041  —
# T0048  trademark / e-commerce / infringeme…  0.084  2.1 Access to and benefits from IP …     0.064  —
# T0109  source separation / clap / soundsca…  0.050  SI-5 First Nations Strategy              0.040  —
# T0042  gene / synthetic / cell / biology     0.052  SI-3 AI and Automated Decision Maki…     0.036  —
# T0071  firm / vc / patent / innovation       0.078  4.1 Innovation and adaptiveness in …     0.067  —
# T0021  crispr / cas9 / editing / gene        0.048  SI-3 AI and Automated Decision Maki…     0.028  —
# T0111  regulatory / crop / nanomedicine / …  0.077  4.2 Innovative digital and data-dri…     0.032  —
# T0061  intellectual capital / sme / enterp…  0.167  SI-4 SME education and outreach, in…     0.036  —
# T0041  quantum / entanglement / repeater /…  0.050  4.1 Innovation and adaptiveness in …     0.032  —
# T0084  image / patent / retrieval / face x…  0.058  3.1 Capabilities for current and fu…     0.075  —
# T0103  distillation / aede / data-free / k…  0.061  4.1 Innovation and adaptiveness in …     0.041  —
# T0049  robotic / surgical / autonomous / s…  0.172  4.1 Innovation and adaptiveness in …     0.023  CT-AUTON Autonomous systems, roboti…
# T0001  ai / kente / indigenous / health      0.060  1.3 Reputation, influence and contr…     0.066  —
# T0064  supply chain / blockchain / food / …  0.076  4.2 Innovative digital and data-dri…     0.043  —
# T0024  synthetic biology / metabolic / eng…  0.037  4.1 Innovation and adaptiveness in …     0.045  —
# T0093  deep / inertial / learning / dl       0.042  4.1 Innovation and adaptiveness in …     0.044  —
# T0072  quantum / reservoir / computing / n…  0.032  4.1 Innovation and adaptiveness in …     0.037  —
# T0058  quantum / direct communication / se…  0.051  4.1 Innovation and adaptiveness in …     0.025  —
# T0096  video / retrieval / captioning / fe…  0.081  4.1 Innovation and adaptiveness in …     0.037  —
# T0043  patent / classification / document …  0.057  4.1 Innovation and adaptiveness in …     0.137  —
# T0078  citation / patent / journal / pp      0.046  4.2 Innovative digital and data-dri…     0.054  —
# T0068  influencer / social media / authent…  0.086  4.2 Innovative digital and data-dri…     0.035  —
# T0069  organic / certification / farmer / …  0.145  SI-1 Geographical indications regis…     0.029  —
# T0092  logo / detection / object / voxel     0.070  4.1 Innovation and adaptiveness in …     0.049  —
# T0098  gnn / graph / prediction / node       0.036  1.1 Trust and confidence in a high-…     0.038  —
# T0017  quantum / cryptography / computing …  0.083  4.2 Innovative digital and data-dri…     0.044  —
# T0066  indoor / positioning / navigation /…  0.056  1.2 Awareness of the IP system           0.047  —
# T0113  human right / court human / europea…  0.051  4.1 Innovation and adaptiveness in …     0.043  —
# T0105  csr / institutional investor / corp…  0.067  1.2 Awareness of the IP system           0.027  —
# T0107  counterfeiting / counterfeit good /…  0.057  4.1 Innovation and adaptiveness in …     0.057  —
# T0035  learning / machine / classification…  0.048  4.2 Innovative digital and data-dri…     0.056  —
# T0101  copyrighted / prompt / unlearning /…  0.048  SI-5 First Nations Strategy              0.022  —
# T0115  quantum / sensing / sensor / ultras…  0.063  4.2 Innovative digital and data-dri…     0.028  —
# T0097  mof / cof / organic framework / cov…  0.061  1.2 Awareness of the IP system           0.022  —
# T0114  gene / therapy / vector / aav         0.057  1.1 Trust and confidence in a high-…     0.017  —
# T0062  quantum / ml / dl / learning          0.050  4.2 Innovative digital and data-dri…     0.032  —
# T0116  polymer / delivery / synthetic / dr…  0.031  4.2 Innovative digital and data-dri…     0.019  —
# T0051  robot / agricultural / row / phenot…  0.062  4.2 Innovative digital and data-dri…     0.044  —
# T0073  medicinal plant / dayak / tradition…  0.045  SI-5 First Nations Strategy              0.073  —
# T0012  navigation / robot / autonomous / s…  0.054  3.1 Capabilities for current and fu…     0.048  —
# T0028  remote sensing / sensor / uav / agr…  0.055  4.1 Innovation and adaptiveness in …     0.049  —
# T0040  unlearning / erasure / diffusion / …  0.046  1.3 Reputation, influence and contr…     0.030  —
# T0030  blockchain / security / privacy / t…  0.046  1.1 Trust and confidence in a high-…     0.036  —
# T0082  nodule / fault / drought / sensing …  0.039  4.1 Innovation and adaptiveness in …     0.031  —
# T0089  soft / robot / actuation / magnetic   0.041  4.2 Innovative digital and data-dri…     0.023  —
# T0026  watermark / dnn / image / copyright   0.041  4.1 Innovation and adaptiveness in …     0.032  —
# T0046  iot / edge / thing / computing        0.050  SI-5 First Nations Strategy              0.020  —
#
# strategic fit  range 0.031–0.338  median 0.081
# asset leverage range 0.017–0.239  median 0.047

# %% [markdown]
# ## Stage 4 — Opportunity index
#
# **This is a relative, unitless, within-run ordering. It is not a market size,
# it is not a dollar figure, and it cannot be converted into one.** This is the
# most important caveat in the method and the easiest one to lose in a slide.
#
# Components are percentile-ranked within the run before being combined, which is
# the only way measures on this many different scales can be added at all. Two
# guards are worth checking in the output below:
#
# - Topics thinner than `opportunity_index.min_documents` are **suppressed, not
#   scored**. A composite built on eight documents looks identical to one built
#   on eight hundred, and that is exactly how a horizon scan misleads people.
# - A component with no data has its **weight redistributed** across the
#   components that do. Without that, disabling a source would silently shrink
#   every index and leave the ranking looking unchanged while measuring something
#   different.
#
# The index is deliberately excluded from the ranking formula in Stage 5. It is
# the weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness.

# %%
scored = [r for r in ranked_topics if not r["index_suppressed"]]
suppressed = [r for r in ranked_topics if r["index_suppressed"]]

if scored:
    weights = scored[0]["index_components"].get("_effective_weights", {})
    print("Effective component weights after redistribution:")
    print("  " + ", ".join(f"{k} {v}" for k, v in sorted(weights.items())))
    omitted = scored[0]["index_components"].get("_omitted_components") or []
    print("  omitted for lack of data: " + (", ".join(omitted) if omitted else "none"))
    print()

    keys = sorted(k for k in scored[0]["index_components"] if not k.startswith("_"))
    print(table(
        [
            (r["topic_id"], (r["label"] or "")[:36],
             *[r["index_components"].get(k) for k in keys], r["opportunity_index"])
            for r in scored
        ],
        ["topic", "label", *keys, "index"],
        max_width=36,
    ))

if suppressed:
    print()
    print(f"{len(suppressed)} topic(s) suppressed as too thin to index honestly: "
          + ", ".join(r["topic_id"] for r in suppressed))
# Out:
# Effective component weights after redistribution:
#   attention 0.2941, attention_tone 0.1176, policy_salience 0.2353, research_growth 0.3529
#   omitted for lack of data: patent_activity
#
# topic  label                                 attention  attention_tone  policy_salience  research_growth  index
# -----  ------------------------------------  ---------  --------------  ---------------  ---------------  -----
# T0008  geographical indication / protection      0.773           0.773            0.513            0.866  0.744
# T0015  artificial intelligence / patent / i      0.937           0.126            0.748            0.807  0.751
# T0059  examination / artificial / intellige      0.008           0.899            0.580            0.992  0.595
# T0039  adm / automated / decision-making /       0.118           0.193            0.807            0.983  0.594
# T0005  trust / public institution / oecd /       0.790           0.059            0.832            0.361  0.562
# T0060  decision making / automated decision      0.622           0.378            0.714            0.361  0.523
# T0011  service delivery / government / loca      0.924           0.135            0.924            0.748  0.769
# T0063  genetic resource / benefit sharing /      0.492           0.395            0.622            0.361  0.465
# T0085  trust / chapter / political / crisis      0.193           0.034            0.597            0.361  0.329
# T0087  large language / emergent ability /       0.555           0.160            0.378            0.832  0.565
# T0019  prior art / patent / art search / re      0.815           0.580            0.563            0.798  0.722
# T0003  copyright / page / exception limitat      0.916           0.479            0.773            0.966  0.849
# T0096  video / retrieval / captioning / few      0.231           0.513            0.067            0.361  0.272
# T0043  patent / classification / document /      0.740           0.655            0.866            0.361  0.626
# T0078  citation / patent / journal / pp          0.193           0.740            0.555            0.874  0.583
# T0068  influencer / social media / authenti      0.874           0.269            0.344            0.361  0.497
# T0069  organic / certification / farmer / g      0.492           0.521            0.193            0.361  0.379
# T0092  logo / detection / object / voxel         0.458           0.109            0.101            0.361  0.299
# T0098  gnn / graph / prediction / node           0.034           0.185            0.025            0.361  0.165
# T0017  quantum / cryptography / computing /      1.000           0.966            0.294            0.361  0.605
# T0066  indoor / positioning / navigation /       0.471           0.639            0.302            0.361  0.412
# T0113  human right / court human / european      0.429           0.403            0.857            0.361  0.503
# T0105  csr / institutional investor / corpo      0.164           0.084            0.546            0.361  0.314
# T0107  counterfeiting / counterfeit good /       0.664           0.000            0.244            0.361  0.380
# T0035  learning / machine / classification       0.055           0.076            0.202            0.361  0.200
# T0101  copyrighted / prompt / unlearning /       0.256           0.605            0.185            0.933  0.519
# T0115  quantum / sensing / sensor / ultraso      0.429           0.950            0.092            0.361  0.387
# T0097  mof / cof / organic framework / cova      0.458           0.538            0.319            0.361  0.401
# T0114  gene / therapy / vector / aav             0.109           0.235            0.084            0.361  0.207
# T0062  quantum / ml / dl / learning              0.143           0.698            0.286            0.361  0.319
# T0116  polymer / delivery / synthetic / dru      0.193           0.294            0.126            0.361  0.249
# T0051  robot / agricultural / row / phenoty      0.517           0.622            0.328            0.361  0.430
# T0073  medicinal plant / dayak / traditiona      0.681           0.916            0.571            0.361  0.570
# T0012  navigation / robot / autonomous / se      0.643           0.832            0.336            0.361  0.494
# T0028  remote sensing / sensor / uav / agri      0.517           0.664            0.353            0.361  0.441
# T0040  unlearning / erasure / diffusion / c      0.698           0.042            0.135            0.958  0.580
# T0030  blockchain / security / privacy / te      0.853           0.454            0.462            0.361  0.541
# T0082  nodule / fault / drought / sensing i      0.000           0.891            0.008            0.361  0.234
# T0089  soft / robot / actuation / magnetic       0.357           0.790            0.277            0.361  0.391
# T0026  watermark / dnn / image / copyright       0.517           0.353            0.160            0.361  0.359
# T0046  iot / edge / thing / computing            0.748           0.958            0.370            0.361  0.547

# %% [markdown]
# ### Re-deriving the index
#
# Recomputed from the stored components and the effective weights actually used, which is also the only way to see the redistribution having happened rather than take it on trust.

# %%
from src.notebook import TOLERANCE_INDEX

# The index is a plain weighted sum of stored components, so it is checkable
# the same way everything else here is. It is the one check that cannot run to
# machine precision: Stage 4 stores its components and effective weights
# rounded to 4 dp for legibility, while the index it stored was computed from
# the unrounded values. That rounding is the entire error budget below, which
# is why the tolerance is 1e-3 and not 1e-9. A deviation materially larger than
# ~1e-4 here is not rounding and should be treated as a defect.
verify_close(
    "opportunity_index",
    [r["opportunity_index"] for r in scored],
    [
        sum(r["index_components"][k] * w
            for k, w in r["index_components"]["_effective_weights"].items())
        for r in scored
    ],
    tolerance=TOLERANCE_INDEX,
)
# Out:
# PASS  opportunity_index reproduced for 120 topics — largest deviation 8.26e-05 (tolerance 0.001)

# %% [markdown]
# > **Noted automatically from this run's own numbers.**
# >
# > - Component(s) **patent_activity** had no data and their weight was redistributed across the rest. The index remains internally consistent but measures fewer things than the config describes — say so when presenting it, rather than quoting the configured weights.

# %% [markdown]
# ## Stage 5 — Ranking and synthesis
#
# The shortlist is a weighted combination of three axes — emergence, strategic
# fit and asset leverage — each percentile-ranked within the run before
# weighting, so that the configured weights describe what the code actually does.
#
# The opportunity index is deliberately **not** one of the axes. It is the
# weakest-founded number in the pipeline, and folding it into the headline
# ordering would launder that weakness into the thing everyone reads first.

# %% [markdown]
# ### Re-deriving the published order
#
# The cell below reproduces the ranking by calling `stage5_synthesis.composite_scores` — the same function the pipeline called, not a reimplementation of it, so the check cannot drift away from the code it is meant to be checking. If it agrees, then given this corpus and these weights the ordering is not a matter of opinion. Whether they are the right weights is a separate question, and an open one.

# %%
from src.stage5_synthesis import composite_scores

# Reproduced by calling the pipeline's own ranking function, not by
# reimplementing it here. A reimplementation can drift away from the code it is
# meant to be checking; this cannot.
#
# Stage 5 read topics in emergence_score DESC order and sorted them stably, so
# the reproduction has to start from that same order to be faithful.
by_id = {r["topic_id"]: r for r in ranked_topics}
rows = [by_id[t["topic_id"]] for t in topics]

recomputed = composite_scores(rows, RANK_WEIGHTS)
verify_close("composite_rank_score", [r["composite_rank_score"] for r in rows], recomputed)

order = sorted(range(len(rows)), key=lambda i: -recomputed[i])
verify_identical(
    "shortlist ordering",
    [r["topic_id"] for r in ranked_topics],        # stored, ORDER BY rank
    [rows[i]["topic_id"] for i in order],          # recomputed
)
# Out:
# PASS  composite_rank_score reproduced for 120 topics — largest deviation 0 (tolerance 1e-09)
# PASS  shortlist ordering reproduced — 120 of 120 entries identical

# %% [markdown]
# ### The published shortlist

# %%
print(table(
    [
        (r["rank"], (r["label"] or r["topic_id"])[:42], r["horizon"], r["signal_class"],
         r["emergence_score"], r["strategic_fit"], r["asset_leverage"],
         None if r["index_suppressed"] else r["opportunity_index"],
         r["composite_rank_score"])
        for r in ranked_topics
    ],
    ["#", "topic", "H", "signal", "emrg", "fit", "lev", "index", "composite"],
    places=3, max_width=42,
))
# Out:
#   #  topic                                       H   signal   emrg    fit    lev  index  composite
# ---  ------------------------------------------  --  ------  -----  -----  -----  -----  ---------
#   1  geographical indication / protection geogr  H2  strong  0.877  0.312  0.062  0.744      0.929
#   2  artificial intelligence / patent / invento  H1  strong  0.821  0.146  0.070  0.751      0.884
#   3  examination / artificial / intelligence /   H2  strong  0.899  0.110  0.179  0.595      0.875
#   4  adm / automated / decision-making / eu      H2  strong  0.695  0.187  0.065  0.594      0.872
#   5  trust / public institution / oecd / driver  H2  strong  0.698  0.178  0.060  0.562      0.853
#   6  decision making / automated decision / adm  H2  strong  0.514  0.338  0.165  0.523      0.819
#   7  service delivery / government / local / pu  H2  strong  0.729  0.142  0.054  0.769      0.800
#   8  genetic resource / benefit sharing / acces  H1  weak    0.618  0.129  0.077  0.465      0.792
#   9  trust / chapter / political / crisis        H1  weak    0.648  0.215  0.049  0.329      0.790
# 112  medicinal plant / dayak / traditional / kn  H1  weak    0.215  0.045  0.073  0.570      0.255
# 113  navigation / robot / autonomous / sensor    H1  strong  0.305  0.054  0.048  0.494      0.253
# 114  remote sensing / sensor / uav / agricultur  H1  strong  0.290  0.055  0.049  0.441      0.247
# 115  unlearning / erasure / diffusion / concept  H2  strong  0.457  0.046  0.030  0.580      0.246
# 116  blockchain / security / privacy / technolo  H1  strong  0.394  0.046  0.036  0.541      0.231
# 117  nodule / fault / drought / sensing image    H1  weak    0.440  0.039  0.031  0.234      0.206
# 118  soft / robot / actuation / magnetic         H1  weak    0.392  0.041  0.023  0.391      0.144
# 119  watermark / dnn / image / copyright         H1  strong  0.341  0.041  0.032  0.359      0.142
# 120  iot / edge / thing / computing              H1  strong  0.304  0.050  0.020  0.547      0.100

# %% [markdown]
# ### Strategic fit × asset leverage
#
# The view that separates an interesting trend from a viable venture, split at the median of each axis. Note that a median split guarantees a populated *act* quadrant whether or not anything in the run deserves one — the quadrant is a relative position, not a verdict.

# %%
from src.stage5_synthesis import quadrant

# Recomputed here rather than read back: Stage 5 records the quadrant in
# topics.csv but does not persist it to `topic_scores`, so the database cannot
# be asked for it. Recomputing from the stored axes and the same median split
# Stage 5 used gives the identical placement, and shows the derivation.
fit_cut = float(np.median([float(r["strategic_fit"] or 0.0) for r in ranked_topics]))
lev_cut = float(np.median([float(r["asset_leverage"] or 0.0) for r in ranked_topics]))
LABELS = ("watch", "on-strategy, no right-to-play",
          "capability looking for a problem", "act")

placement = {
    r["topic_id"]: quadrant(
        float(r["strategic_fit"] or 0.0), float(r["asset_leverage"] or 0.0),
        fit_cut, lev_cut, LABELS,
    )
    for r in ranked_topics
}

print(f"Split at the median of each axis (fit {fit_cut:.3f}, leverage {lev_cut:.3f}).\n")
for name in ("act", "on-strategy, no right-to-play",
             "capability looking for a problem", "watch"):
    members = [r for r in ranked_topics if placement[r["topic_id"]] == name]
    print(f"{name.upper()} ({len(members)})")
    for r in members:
        print(f"    {r['rank']:>3}  {(r['label'] or r['topic_id'])[:60]}")
    if not members:
        print("    (none)")
    print()
# Out:
# Split at the median of each axis (fit 0.081, leverage 0.047).
#
# ACT (34)
#       1  geographical indication / protection geographical / cheese /
#       2  artificial intelligence / patent / inventorship / law
#       3  examination / artificial / intelligence / economic scenarios
#       4  adm / automated / decision-making / eu
#       5  trust / public institution / oecd / driver
#       6  decision making / automated decision / adm / algorithmic fai
#       7  service delivery / government / local / public service
#       8  genetic resource / benefit sharing / access benefit / abs
#       9  trust / chapter / political / crisis
#      10  large language / emergent ability / ability large / implemen
#      13  intellectual property / property right / enforcement intelle
#      14  digital / service delivery / public / government
#      15  llm / language / large / reasoning
#      16  ipgod / ip right / government open / property government
#      17  criminal / ip / enforcement / remedy
#      20  intellectual property / ipr / right / trade
#      21  automated decision-making / administrative law / value posit
#      25  patent retrieval / information retrieval / retrieval patent
#      26  trust / institution / political / public
#      27  ai / clinical / intervention / reporting
#      28  trade mark / geographical indication / tce / gis
#      29  corporate governance / finance corporate / governance ip / a
#      30  digital government / nsw / sa / digital landscape
#      31  trust science / trust scientist / open science / public trus
#      32  indigenous / traditional knowledge / traditional cultural /
#      33  ai / education / generative / chatgpt
#      35  quantum / photonic / dot / silicon
#      38  trust / financial / institution / internal control
#      43  ai / governance / public / artificial intelligence
#      50  ai / patent / invention / inventor
#      52  e-government / trust / public / korean
#      60  ip / law / intellectual property / european
#      63  patent / sdg / value / innovation
#      75  trademark / e-commerce / infringement / counterfeiting
#
# ON-STRATEGY, NO RIGHT-TO-PLAY (26)
#      18  generative / ai / artificial intelligence / image translatio
#      19  energy storage / battery / renewable / storage system
#      24  access medicine / medicine africa / law access / framework a
#      36  quantum / many-body system / optical / snspd
#      37  quantum / machine learning / adversarial / classical
#      40  synthetic biology / biological / cell / application syntheti
#      42  trade / agreement / afcfta / free
#      46  energy / storage / hydrogen / battery
#      47  quantum / key distribution / qkd / key rate
#      48  elevation / elvis / river / area cover
#      51  xai / intelligence / explainable / artificial
#      58  covid-19 / trust / vaccine / health
#      59  ai / copyright / generative / chatgpt
#      61  additive manufacturing / arc additive / wire / powder
#      62  regulatory policy / regulatory reform / bt / cotton seed
#      64  sme / intellectual / property / innovation
#      65  genome editing / chapter argue / affordability access / argu
#      67  quantum / qubit / circuit / gate
#      68  green innovation / firm / enterprise / corporate
#      70  additive manufacturing / material / bone / printing
#      71  gi / geographical indication / product / trade
#      81  intellectual capital / sme / enterprise / innovation
#      85  robotic / surgical / autonomous / system
#      95  influencer / social media / authenticity / celebrity
#      96  organic / certification / farmer / green production
#      99  quantum / cryptography / computing / cryptographic
#
# CAPABILITY LOOKING FOR A PROBLEM (26)
#      11  prior art / patent / art search / retrieval
#      12  copyright / page / exception limitation / economic right
#      22  patent / claim / novelty / prior art
#      23  dashboard / digital project / queensland / contribution publ
#      34  li / ul / nsw / opengov
#      39  intellectual / copyright / artificial creation / creativity
#      41  heritage / cultural / property / intellectual
#      45  patent / examination / claim clarity / crowdsourcing
#      53  valuation / property / intellectual / kenya
#      55  valuation / briefing / valuer / property
#      56  patent / retrieval / search / embedding
#      66  isac / communication / wireless / network
#      69  cancer / tumor / t-cell / mutant
#      72  chinese / chapter implementation / patent / medicine
#      78  firm / vc / patent / innovation
#      83  image / patent / retrieval / face x-ray
#      86  ai / kente / indigenous / health
#      93  patent / classification / document / tc
#      94  citation / patent / journal / pp
#      97  logo / detection / object / voxel
#     100  indoor / positioning / navigation / uwb
#     103  counterfeiting / counterfeit good / consumer / retailer
#     104  learning / machine / classification / breast
#     112  medicinal plant / dayak / traditional / knowledge
#     113  navigation / robot / autonomous / sensor
#     114  remote sensing / sensor / uav / agriculture
#
# WATCH (34)
#      44  accountability / broadening intelligence / holdee / social c
#      49  kilometre km / square kilometre / africa / population
#      54  australian marine / park / reef / access following
#      57  quantum / floquet / physic / gauge theory
#      73  chatgpt / clinical / medical / language
#      74  patent portfolio / portfolio management / health humanity /
#      76  source separation / clap / soundscape / video
#      77  gene / synthetic / cell / biology
#      79  crispr / cas9 / editing / gene
#      80  regulatory / crop / nanomedicine / filtering
#      82  quantum / entanglement / repeater / network
#      84  distillation / aede / data-free / knowledge
#      87  supply chain / blockchain / food / traceability
#      88  synthetic biology / metabolic / engineering / gene
#      89  deep / inertial / learning / dl
#      90  quantum / reservoir / computing / neural network
#      91  quantum / direct communication / secure direct / qsdc
#      92  video / retrieval / captioning / few-shot
#      98  gnn / graph / prediction / node
#     101  human right / court human / european court / intellectual pr
#     102  csr / institutional investor / corporate social / social res
#     105  copyrighted / prompt / unlearning / lvlm
#     106  quantum / sensing / sensor / ultrasound
#     107  mof / cof / organic framework / covalent
#     108  gene / therapy / vector / aav
#     109  quantum / ml / dl / learning
#     110  polymer / delivery / synthetic / drug
#     111  robot / agricultural / row / phenotyping
#     115  unlearning / erasure / diffusion / concept
#     116  blockchain / security / privacy / technology
#     117  nodule / fault / drought / sensing image
#     118  soft / robot / actuation / magnetic
#     119  watermark / dnn / image / copyright
#     120  iot / edge / thing / computing

# %% [markdown]
# ## Evidence — the documents behind the top 8 topics
#
# Reading the primary documents is the cheapest and most reliable quality control
# in this method, and the only one that finds clustering artefacts. Some topics
# below will not be themes at all; they will be a set of documents that happen to
# share vocabulary. Finding those is the point of this section, not a sign that
# something has gone wrong.
#
# For each topic: its scores, its defining terms, its trajectory, and the
# documents nearest its centre.

# %%
TOPIC_ID = 'T0008'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #1  geographical indication / protection geographical / cheese / registration
# 182 documents · 2018–2026 · H2 · strong
#
# Defining terms: geographical indication, indication, geographical, protection geographical, protection, cheese, registration, gis, trade, registered geographical, registered, product
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     5  ██████
#      2019    12  ██████████████
#      2020     6  ███████
#      2021     7  ████████
#      2022     9  ██████████
#      2023    10  ███████████
#      2024    13  ███████████████
#      2025    21  ████████████████████████  ← burst
#      2026    12  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Geographical Indications
#     crossref · 2025 · Elgar Encyclopedia of Intellectual Property Law
#     https://doi.org/10.4337/9781800886933.geographical.indications
#   • Geographical indications
#     crossref · 2020 · A Handbook on the WTO TRIPS Agreement
#     https://doi.org/10.1017/9781108883511.005
#   • Geographical Indications
#     crossref · 2018 · Encyclopedia of Law and Economics
#     https://doi.org/10.1007/978-1-4614-7883-6_192-1
#   • Geographical Indications
#     crossref · 2026 · EU External Action, Principles of
#     https://doi.org/10.4337/9781800885240.geographical.indications
#   • Geographical Indications
#     crossref · 2025 · Encyclopedia of Law and Economics
#     https://doi.org/10.1007/978-3-031-76422-6_192

# %%
TOPIC_ID = 'T0015'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #2  artificial intelligence / patent / inventorship / law
# 208 documents · 2018–2026 · H1 · strong
#
# Defining terms: artificial intelligence, patent, artificial, intelligence, patent law, inventorship, intelligence patent, law, intelligence inventorship, patent artificial, intelligence technology, future patent
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     4  ██████
#      2019     8  ████████████
#      2020    12  ██████████████████
#      2021     6  █████████
#      2022     4  ██████
#      2023     8  ████████████
#      2024     8  ████████████
#      2025    16  ████████████████████████  ← burst
#      2026     8  ████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Artificial Intelligence and Patent Law
#     crossref · 2024 · Artificial Intelligence
#     https://doi.org/10.1201/9781003483571-11
#   • Artificial Intelligence
#     gdelt · 2026 · sify.com
#     https://www.sify.com/ai-analytics/artificial-intelligence/
#   • IMPACT OF ARTIFICIAL INTELLIGENCE ON PATENT LAW
#     crossref · 2023 · Humanities Studies
#     https://doi.org/10.32782/hst-2023-17-94-17
#   • Artificial intelligence is breaking patent law
#     crossref · 2022 · Nature
#     https://doi.org/10.1038/d41586-022-01391-x
#   • Artificial Intelligence and Inventorship
#     crossref · 2025 · Lecture Notes in Networks and Systems
#     https://doi.org/10.1007/978-981-97-8457-8_4

# %%
TOPIC_ID = 'T0059'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #3  examination / artificial / intelligence / economic scenarios
# 27 documents · 2019–2026 · H2 · strong
#
# Defining terms: examination, artificial, intelligence, artificial intelligence, capable artificial, economic scenarios, examination economic, federal revenue, forensic examination, labor examination, replace labor, revenue ai
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     0
#      2019     1  █████
#      2020     0
#      2021     2  ██████████
#      2022     0
#      2023     3  ██████████████
#      2024     5  ████████████████████████  ← burst
#      2025     5  ████████████████████████  ← burst
#      2026     3  ██████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Artificial intelligence approaches for ultrasound examination in pregnancy
#     crossref · 2024 · Artificial Intelligence and Machine Learning for Women’s Health Issues
#     https://doi.org/10.1016/b978-0-443-21889-7.00012-9
#   • Artificial Intelligence in Managerial Decision-Making: An Empirical Examination
#     crossref · 2024 · Nanotechnology Perceptions
#     https://doi.org/10.62441/nano-ntp.v20i5.16
#   • Legal Examination and Regulation of Artificial Intelligence Algorithm
#     crossref · 2021 · 2021 International Conference on Computer Information Science and Artificial I
#     https://doi.org/10.1109/cisai54367.2021.00119
#   • Federal Revenue When AI Replaces Labor: An Examination of Economic Scenarios with Highly Capable
#     crossref · 2026 · edited-book
#     https://doi.org/10.7249/rra4980-1
#   • Federal Revenue when AI Replaces Labor: An Examination of Economic Scenarios with Highly Capable
#     crossref · 2025 · edited-book
#     https://doi.org/10.7249/wra4443-1

# %%
TOPIC_ID = 'T0039'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #4  adm / automated / decision-making / eu
# 49 documents · 2018–2026 · H2 · strong
#
# Defining terms: adm, automated, automated decision-making, decision-making, decision, eu, law, administrative, automated decision, right, explanation, public law
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     1  ███
#      2019     0
#      2020     2  █████
#      2021     4  ███████████
#      2022     1  ███
#      2023     3  ████████
#      2024     5  █████████████  ← burst
#      2025     3  ████████  ← burst
#      2026     9  ████████████████████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Automated Decision-Making (ADM) in EU Public Law
#     crossref · 2023 · posted-content
#     https://doi.org/10.2139/ssrn.4561116
#   • Automated Decision-Making in The EU Member State’s Public Administration: The Compliance of Auto
#     openalex · 2023 · European Studies. The Review of European Law, Economics and Politics
#     https://doi.org/10.2478/eustu-2023-0017
#   • Reviewable Automated Decision-Making
#     crossref · 2020 · posted-content
#     https://doi.org/10.2139/ssrn.3689166
#   • Simplification of Administrative Procedures through Fully Automated Decision-Making: The Case of
#     openalex · 2021 · Administrative Sciences
#     https://doi.org/10.3390/admsci11040149
#   • Digitalization of administrative procedures in Ukraine: limits of automated government decision-
#     crossref · 2026 · Legal Ukraine
#     https://doi.org/10.37749/2308-9639-2026-5(281)-14

# %%
TOPIC_ID = 'T0005'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #5  trust / public institution / oecd / driver
# 197 documents · 2018–2026 · H2 · strong
#
# Defining terms: trust, public institution, institution, trust public, public, driver trust, public trust, oecd, driver, covid-19, citizen, government
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018    20  ████████████████████████
#      2019     8  ██████████
#      2020    11  █████████████
#      2021    13  ████████████████
#      2022     8  ██████████
#      2023    14  █████████████████
#      2024    11  █████████████
#      2025    10  ████████████
#      2026    13  ████████████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Restoring Trust in Public Institutions
#     crossref · 2025 · posted-content
#     https://doi.org/10.2139/ssrn.5154495
#   • Do Citizens Trust in Public Institutions? An Overview of Trust in States and in Public Instituti
#     crossref · 2026 · 2026 IEEE 13th International Joint Conference on Cybernetics and Computational
#     https://doi.org/10.1109/iccc68994.2026.11511603
#   • Drivers of Trust in Public Institutions in New Zealand
#     crossref · 2023 · Building Trust in Public Institutions
#     https://doi.org/10.1787/948accf8-en
#   • Drivers of Trust in Public Institutions in Norway
#     crossref · 2022 · Building Trust in Public Institutions
#     https://doi.org/10.1787/81b01318-en
#   • Drivers of Trust in Public Institutions in Australia
#     crossref · 2025 · Building Trust in Public Institutions
#     https://doi.org/10.1787/28a876c2-en

# %%
TOPIC_ID = 'T0060'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #6  decision making / automated decision / adm / algorithmic fairness
# 85 documents · 2018–2026 · H2 · strong
#
# Defining terms: decision making, automated decision, decision, making, adm, automated, algorithmic fairness, property analytic, migration, intelligence machine, fairness, aadm
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     3  ████████████████████████
#      2019     2  ████████████████
#      2020     1  ████████
#      2021     3  ████████████████████████
#      2022     2  ████████████████
#      2023     0
#      2024     2  ████████████████
#      2025     2  ████████████████
#      2026     3  ████████████████████████
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Automated Decision Making
#     gdelt · 2025 · mondaq.com
#     https://www.mondaq.com:443/unitedstates/privacy-protection/1714862/automated-decision-making
#   • Automated Modeling/Decision Making
#     crossref · 2022 · Encyclopedia of Big Data
#     https://doi.org/10.1007/978-3-319-32010-6_17
#   • Can AI Replace Government for Decision Making
#     crossref · 2021 · Introduction to Algorithmic Government
#     https://doi.org/10.1007/978-981-16-0282-5_4
#   • A data quality approach to the identification of discrimination risk in automated decision makin
#     crossref · 2021 · Government Information Quarterly
#     https://doi.org/10.1016/j.giq.2021.101619
#   • Is It Fair? A Case Study of Automated Decision Making in Canadian Migration Management
#     crossref · 2026 · posted-content
#     https://doi.org/10.32920/29873930

# %%
TOPIC_ID = 'T0011'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #7  service delivery / government / local / public service
# 214 documents · 2018–2026 · H2 · strong
#
# Defining terms: service delivery, service, delivery, government, local government, local, public service, digital, county, south africa, government service, public
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     9  ████████████
#      2019     9  ████████████
#      2020     7  █████████
#      2021     6  ████████
#      2022     6  ████████
#      2023     9  ████████████
#      2024    18  ████████████████████████  ← burst
#      2025    14  ███████████████████  ← burst
#      2026     7  █████████  ← burst
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Governance in Public Service Delivery
#     crossref · 2025 · E-Government in Bangladesh
#     https://doi.org/10.4324/9781003631699-2
#   • Governance and Public Service Delivery Under the Labour Government
#     crossref · 2018 · Implementing Sure Start Policy
#     https://doi.org/10.1007/978-981-10-1795-7_2
#   • Enhancing public service delivery in government procurement
#     crossref · 2024 · Handbook Of Public Service Delivery
#     https://doi.org/10.4337/9781035315314.00019
#   • Digital Service Delivery in Africa: An Introduction
#     crossref · 2022 · Palgrave Studies of Marketing in Emerging Economies
#     https://doi.org/10.1007/978-3-030-83909-3_1
#   • Public service delivery in today’s Georgia
#     crossref · 2018 · The Routledge Handbook of International Local Government
#     https://doi.org/10.4324/9781315306278-16

# %%
TOPIC_ID = 'T0063'
topic = next(r for r in ranked_topics if r["topic_id"] == TOPIC_ID)

print(f"#{topic['rank']}  {topic['label'] or TOPIC_ID}")
print(f"{topic['document_count']} documents · {topic['first_slice']}–{topic['last_slice']} · "
      f"{topic['horizon']} · {topic['signal_class']}")
print()
print("Defining terms: " + ", ".join(t for t, _ in (topic["terms"] or [])[:12]))
print()

series = db.fetch_topic_timeseries(conn, TOPIC_ID)
if series:
    peak = max(int(p["doc_count"]) for p in series) or 1
    print("Trajectory (← burst marks slices the Kleinberg automaton flagged):")
    for point in series:
        count = int(point["doc_count"])
        bar = "█" * int(round(24 * count / peak))
        print(f"  {point['time_slice']:>7} {count:5d}  {bar}"
              + ("  ← burst" if point["in_burst"] else ""))
    print()

print("Nearest documents — the primary text every score above derives from.")
print("If these are not a coherent theme, the topic is a clustering artefact")
print("and belongs in the discard pile, whatever it scored:\n")
for doc in db.fetch_topic_documents(conn, TOPIC_ID, limit=5):
    meta = " · ".join(str(x) for x in [doc["source"], doc["year"] or "", doc["venue"] or ""] if x)
    print(f"  • {(doc['title'] or '(untitled)')[:96]}")
    print(f"    {meta[:96]}")
    if doc["url"]:
        print(f"    {doc['url']}")
# Out:
# #8  genetic resource / benefit sharing / access benefit / abs
# 64 documents · 2018–2025 · H1 · weak
#
# Defining terms: genetic resource, benefit sharing, genetic, access benefit, abs, sharing, access, resource, sequence information, benefit, plant genetic, mgr
#
# Trajectory (← burst marks slices the Kleinberg automaton flagged):
#      2018     8  ████████████████████████  ← burst
#      2019     0
#      2020     3  █████████
#      2021     2  ██████
#      2022     1  ███
#      2023     0
#      2024     1  ███
#      2025     2  ██████
#      2026     0
#
# Nearest documents — the primary text every score above derives from.
# If these are not a coherent theme, the topic is a clustering artefact
# and belongs in the discard pile, whatever it scored:
#
#   • Biodiversity, Genetic Resources and Intellectual Property
#     crossref · 2018 · monograph
#     https://doi.org/10.4324/9781315098517
#   • Biodiversity, genetic resources and intellectual property
#     crossref · 2018 · Biodiversity, Genetic Resources and Intellectual Property
#     https://doi.org/10.4324/9781315098517-1
#   • Reshaping the international access to genetic resources and benefit sharing process?
#     crossref · 2018 · Biodiversity, Genetic Resources and Intellectual Property
#     https://doi.org/10.4324/9781315098517-9
#   • Access to Plant Genetic Resources for Food and Agriculture
#     crossref · 2020 · Local Knowledge, Intellectual Property and Agricultural Innovation
#     https://doi.org/10.1007/978-981-15-4611-2_3
#   • Access and Benefit Sharing of Genetic Resources, Information and Traditional Knowledge
#     openalex · 2022
#     https://doi.org/10.4324/9781003301998

# %% [markdown]
# ## What a reviewer should push on
#
# The arithmetic above is checkable and has been checked. The judgement calls are
# where this method can actually be wrong, and they are these:
#
# 1. **The scan frame.** `data/strategy/scan_frame.yaml` decides what could be
#    found at all. Its STEEPV distribution mirrors where free structured data
#    exists, not where opportunities are, so the scan will keep finding
#    technology trends and keep missing social, values-based and environmental
#    ones. A miss caused by the frame cannot be fixed by re-weighting — and
#    trying is the standard way to overfit a method like this into uselessness.
# 2. **The weights.** Every weight was set by reading the literature and
#    thinking, not by fitting to a known outcome. The test that would change
#    this: take an opportunity IP Australia already pursued, set
#    `collection.end_year` to the year before that work began, re-run, and see
#    where it lands.
# 3. **The topics.** Read the evidence sections above and mark the ones that are
#    not coherent themes. A clustering artefact scores exactly as confidently as
#    a real topic.
# 4. **The thresholds.** The clustering threshold decides how much of the corpus
#    is assigned to any topic at all, and the Three Horizons cut-points decide
#    the band a topic is reported in. Both are recorded in the config snapshot
#    above; neither is a law of nature.
#
# Where to write the answers: `data/outputs/<run_id>/observations.yaml`. Anything
# recorded there is inserted into this notebook as an analyst observation the
# next time it is generated, so the reading travels with the numbers.
#
# ---
#
# *Method: `docs/method.md`. Live project state, open issues and the calibration
# log: `PROJECT_STATE.md`.*
